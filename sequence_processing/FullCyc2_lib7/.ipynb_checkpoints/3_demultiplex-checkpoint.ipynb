# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/fullCyc2_lib7/run1'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib7'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'fullCyc2_lib7'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-fullCyc2_lib7.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib7

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                         #Sample  primer_number exp_type extraction_plate_ID  \
# 9      MR.A.13C-Xyl.D1.R2_Frac5            129      SIP                 NaN
# 22     MR.A.13C-Xyl.D1.R2_Frac6            130      SIP                 NaN
# 35     MR.A.13C-Xyl.D1.R2_Frac7            131      SIP                 NaN
# 48     MR.A.13C-Xyl.D1.R2_Frac8            132      SIP                 NaN
# 61     MR.A.13C-Xyl.D1.R2_Frac9            133      SIP                 NaN
# 74    MR.A.13C-Xyl.D1.R2_Frac10            134      SIP                 NaN
# 87    MR.A.13C-Xyl.D1.R2_Frac11            135      SIP                 NaN
# 101   MR.A.13C-Xyl.D1.R2_Frac12            136      SIP                 NaN
# 115   MR.A.13C-Xyl.D1.R2_Frac13            137      SIP                 NaN
# 129   MR.A.13C-Xyl.D1.R2_Frac14            138      SIP                 NaN
# 143   MR.A.13C-Xyl.D1.R2_Frac15            139      SIP                 NaN
# 156   MR.A.13C-Xyl.D1.R2_Frac16            140      SIP                 NaN
# 169   MR.A.13C-Xyl.D1.R2_Frac17            141      SIP                 NaN
# 182   MR.A.13C-Xyl.D1.R2_Frac18            142      SIP                 NaN
# 195   MR.A.13C-Xyl.D1.R2_Frac19            143      SIP                 NaN
# 208   MR.A.13C-Xyl.D1.R2_Frac20            144      SIP                 NaN
# 220   MR.A.13C-Xyl.D1.R2_Frac21            145      SIP                 NaN
# 232   MR.A.13C-Xyl.D1.R2_Frac22            146      SIP                 NaN
# 244   MR.A.13C-Xyl.D1.R2_Frac23            147      SIP                 NaN
# 256   MR.A.13C-Xyl.D1.R2_Frac24            148      SIP                 NaN
# 268   MR.A.13C-Xyl.D1.R2_Frac25            149      SIP                 NaN
# 280   MR.A.13C-Xyl.D1.R2_Frac26            150      SIP                 NaN
# 292   MR.A.13C-Xyl.D1.R2_Frac27            151      SIP                 NaN
# 304       MR.A.13C-Xyl.D1.R2_NC            152      SIP                 NaN
# 316   MR.A.13C-Pal.D14.R2_Frac4            153      SIP                 NaN
# 328   MR.A.13C-Pal.D14.R2_Frac5            154      SIP                 NaN
# 340   MR.A.13C-Pal.D14.R2_Frac6            155      SIP                 NaN
# 353   MR.A.13C-Pal.D14.R2_Frac7            156      SIP                 NaN
# 366   MR.A.13C-Pal.D14.R2_Frac8            157      SIP                 NaN
# 379   MR.A.13C-Pal.D14.R2_Frac9            158      SIP                 NaN
# ...                         ...            ...      ...                 ...
# 1963  MR.M.13C-Ami.D3.R1_Frac21             17      SIP                 NaN
# 1975  MR.M.13C-Ami.D3.R1_Frac22             18      SIP                 NaN
# 1987  MR.M.13C-Ami.D3.R1_Frac23             19      SIP                 NaN
# 1999  MR.M.13C-Ami.D3.R1_Frac24             20      SIP                 NaN
# 2011  MR.M.13C-Ami.D3.R1_Frac25             21      SIP                 NaN
# 2023  MR.M.13C-Ami.D3.R1_Frac26             22      SIP                 NaN
# 2035  MR.M.13C-Ami.D3.R1_Frac27             23      SIP                 NaN
# 2047  MR.M.13C-Ami.D3.R1_Frac28             24      SIP                 NaN
# 2058      MR.M.13C-Ami.D3.R1_NC             25      SIP                 NaN
# 2069      MR.M.13C-Ami.D3.R1_MC             26      SIP                 NaN
# 2081   MR.A.13C-Cel.D6.R1_Frac5             27      SIP                 NaN
# 2093   MR.A.13C-Cel.D6.R1_Frac6             28      SIP                 NaN
# 2105   MR.A.13C-Cel.D6.R1_Frac7             29      SIP                 NaN
# 2117   MR.A.13C-Cel.D6.R1_Frac8             30      SIP                 NaN
# 2129   MR.A.13C-Cel.D6.R1_Frac9             31      SIP                 NaN
# 2141  MR.A.13C-Cel.D6.R1_Frac10             32      SIP                 NaN
# 2153  MR.A.13C-Cel.D6.R1_Frac11             33      SIP                 NaN
# 2165  MR.A.13C-Cel.D6.R1_Frac12             34      SIP                 NaN
# 2177  MR.A.13C-Cel.D6.R1_Frac13             35      SIP                 NaN
# 2189  MR.A.13C-Cel.D6.R1_Frac14             36      SIP                 NaN
# 2201  MR.A.13C-Cel.D6.R1_Frac15             37      SIP                 NaN
# 2213  MR.A.13C-Cel.D6.R1_Frac16             38      SIP                 NaN
# 2225  MR.A.13C-Cel.D6.R1_Frac17             39      SIP                 NaN
# 2236  MR.F.12C-Con.D1.R1_Frac22             70      SIP                 NaN
# 2248   MR.M.13C-Ami.D1.R2_Frac6             80      SIP                 NaN
# 2260  MR.M.13C-Ami.D1.R2_Frac23             97      SIP                 NaN
# 2272  MR.A.12C-Con.D6.R2_Frac12            112      SIP                 NaN
# 2284  MR.A.12C-Con.D6.R2_Frac13            113      SIP                 NaN
# 2293  MR.A.13C-Ami.D1.R1_Frac11            185      SIP                 NaN
# 2298  MR.A.13C-Ami.D1.R1_Frac18            192      SIP                 NaN
#
#          library_ID         pool_plate_ID pool_plate_well  \
# 9     fullCyc2_lib7  fullCyc2_lib7_Pool_2              A5
# 22    fullCyc2_lib7  fullCyc2_lib7_Pool_2              B5
# 35    fullCyc2_lib7  fullCyc2_lib7_Pool_2              C5
# 48    fullCyc2_lib7  fullCyc2_lib7_Pool_2              D5
# 61    fullCyc2_lib7  fullCyc2_lib7_Pool_2              E5
# 74    fullCyc2_lib7  fullCyc2_lib7_Pool_2              F5
# 87    fullCyc2_lib7  fullCyc2_lib7_Pool_2              G5
# 101   fullCyc2_lib7  fullCyc2_lib7_Pool_2              H5
# 115   fullCyc2_lib7  fullCyc2_lib7_Pool_2              A6
# 129   fullCyc2_lib7  fullCyc2_lib7_Pool_2              B6
# 143   fullCyc2_lib7  fullCyc2_lib7_Pool_2              C6
# 156   fullCyc2_lib7  fullCyc2_lib7_Pool_2              D6
# 169   fullCyc2_lib7  fullCyc2_lib7_Pool_2              E6
# 182   fullCyc2_lib7  fullCyc2_lib7_Pool_2              F6
# 195   fullCyc2_lib7  fullCyc2_lib7_Pool_2              G6
# 208   fullCyc2_lib7  fullCyc2_lib7_Pool_2              H6
# 220   fullCyc2_lib7  fullCyc2_lib7_Pool_2              A7
# 232   fullCyc2_lib7  fullCyc2_lib7_Pool_2              B7
# 244   fullCyc2_lib7  fullCyc2_lib7_Pool_2              C7
# 256   fullCyc2_lib7  fullCyc2_lib7_Pool_2              D7
# 268   fullCyc2_lib7  fullCyc2_lib7_Pool_2              E7
# 280   fullCyc2_lib7  fullCyc2_lib7_Pool_2              F7
# 292   fullCyc2_lib7  fullCyc2_lib7_Pool_2              G7
# 304   fullCyc2_lib7  fullCyc2_lib7_Pool_2              H7
# 316   fullCyc2_lib7  fullCyc2_lib7_Pool_2              A8
# 328   fullCyc2_lib7  fullCyc2_lib7_Pool_2              B8
# 340   fullCyc2_lib7  fullCyc2_lib7_Pool_2              C8
# 353   fullCyc2_lib7  fullCyc2_lib7_Pool_2              D8
# 366   fullCyc2_lib7  fullCyc2_lib7_Pool_2              E8
# 379   fullCyc2_lib7  fullCyc2_lib7_Pool_2              F8
# ...             ...                   ...             ...
# 1963  fullCyc2_lib7  fullCyc2_lib7_Pool_1              A3
# 1975  fullCyc2_lib7  fullCyc2_lib7_Pool_1              B3
# 1987  fullCyc2_lib7  fullCyc2_lib7_Pool_1              C3
# 1999  fullCyc2_lib7  fullCyc2_lib7_Pool_1              D3
# 2011  fullCyc2_lib7  fullCyc2_lib7_Pool_1              E3
# 2023  fullCyc2_lib7  fullCyc2_lib7_Pool_1              F3
# 2035  fullCyc2_lib7  fullCyc2_lib7_Pool_1              G3
# 2047  fullCyc2_lib7  fullCyc2_lib7_Pool_1              H3
# 2058  fullCyc2_lib7  fullCyc2_lib7_Pool_1              A4
# 2069  fullCyc2_lib7  fullCyc2_lib7_Pool_1              B4
# 2081  fullCyc2_lib7  fullCyc2_lib7_Pool_1              C4
# 2093  fullCyc2_lib7  fullCyc2_lib7_Pool_1              D4
# 2105  fullCyc2_lib7  fullCyc2_lib7_Pool_1              E4
# 2117  fullCyc2_lib7  fullCyc2_lib7_Pool_1              F4
# 2129  fullCyc2_lib7  fullCyc2_lib7_Pool_1              G4
# 2141  fullCyc2_lib7  fullCyc2_lib7_Pool_1              H4
# 2153  fullCyc2_lib7  fullCyc2_lib7_Pool_1              A5
# 2165  fullCyc2_lib7  fullCyc2_lib7_Pool_1              B5
# 2177  fullCyc2_lib7  fullCyc2_lib7_Pool_1              C5
# 2189  fullCyc2_lib7  fullCyc2_lib7_Pool_1              D5
# 2201  fullCyc2_lib7  fullCyc2_lib7_Pool_1              E5
# 2213  fullCyc2_lib7  fullCyc2_lib7_Pool_1              F5
# 2225  fullCyc2_lib7  fullCyc2_lib7_Pool_1              G5
# 2236  fullCyc2_lib7  fullCyc2_lib7_Pool_1              F9
# 2248  fullCyc2_lib7  fullCyc2_lib7_Pool_1             H10
# 2260  fullCyc2_lib7  fullCyc2_lib7_Pool_2              A1
# 2272  fullCyc2_lib7  fullCyc2_lib7_Pool_2              H2
# 2284  fullCyc2_lib7  fullCyc2_lib7_Pool_2              A3
# 2293  fullCyc2_lib7  fullCyc2_lib7_Pool_2             A12
# 2298  fullCyc2_lib7  fullCyc2_lib7_Pool_2             H12
#
#                   soil_ID substrate   day     ...       \
# 9      MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 22     MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 35     MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 48     MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 61     MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 74     MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 87     MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 101    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 115    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 129    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 143    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 156    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 169    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 182    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 195    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 208    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 220    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 232    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 244    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 256    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 268    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 280    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 292    MR.A.13C-Xyl.D1.R2   13C-Xyl   1.0     ...
# 304    MR.A.13C-Xyl.D1.R2   13C-Xyl   NaN     ...
# 316   MR.A.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 328   MR.A.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 340   MR.A.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 353   MR.A.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 366   MR.A.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 379   MR.A.13C-Pal.D14.R2   13C-Pal  14.0     ...
# ...                   ...       ...   ...     ...
# 1963   MR.M.13C-Ami.D3.R1   13C-Ami   3.0     ...
# 1975   MR.M.13C-Ami.D3.R1   13C-Ami   3.0     ...
# 1987   MR.M.13C-Ami.D3.R1   13C-Ami   3.0     ...
# 1999   MR.M.13C-Ami.D3.R1   13C-Ami   3.0     ...
# 2011   MR.M.13C-Ami.D3.R1   13C-Ami   3.0     ...
# 2023   MR.M.13C-Ami.D3.R1   13C-Ami   3.0     ...
# 2035   MR.M.13C-Ami.D3.R1   13C-Ami   3.0     ...
# 2047   MR.M.13C-Ami.D3.R1   13C-Ami   3.0     ...
# 2058   MR.M.13C-Ami.D3.R1   13C-Ami   NaN     ...
# 2069   MR.M.13C-Ami.D3.R1   13C-Ami   NaN     ...
# 2081   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2093   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2105   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2117   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2129   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2141   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2153   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2165   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2177   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2189   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2201   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2213   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2225   MR.A.13C-Cel.D6.R1   13C-Cel   6.0     ...
# 2236   MR.F.12C-Con.D1.R1   12C-Con   1.0     ...
# 2248   MR.M.13C-Ami.D1.R2   13C-Ami   1.0     ...
# 2260   MR.M.13C-Ami.D1.R2   13C-Ami   1.0     ...
# 2272   MR.A.12C-Con.D6.R2   12C-Con   6.0     ...
# 2284   MR.A.12C-Con.D6.R2   12C-Con   6.0     ...
# 2293   MR.A.13C-Ami.D1.R1   13C-Ami   1.0     ...
# 2298   MR.A.13C-Ami.D1.R1   13C-Ami   1.0     ...
#
#       water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 9                             NaN        NaN        NaN        NaN        NaN
# 22                            NaN        NaN        NaN        NaN        NaN
# 35                            NaN        NaN        NaN        NaN        NaN
# 48                            NaN        NaN        NaN        NaN        NaN
# 61                            NaN        NaN        NaN        NaN        NaN
# 74                            NaN        NaN        NaN        NaN        NaN
# 87                            NaN        NaN        NaN        NaN        NaN
# 101                           NaN        NaN        NaN        NaN        NaN
# 115                           NaN        NaN        NaN        NaN        NaN
# 129                           NaN        NaN        NaN        NaN        NaN
# 143                           NaN        NaN        NaN        NaN        NaN
# 156                           NaN        NaN        NaN        NaN        NaN
# 169                           NaN        NaN        NaN        NaN        NaN
# 182                           NaN        NaN        NaN        NaN        NaN
# 195                           NaN        NaN        NaN        NaN        NaN
# 208                           NaN        NaN        NaN        NaN        NaN
# 220                           NaN        NaN        NaN        NaN        NaN
# 232                           NaN        NaN        NaN        NaN        NaN
# 244                           NaN        NaN        NaN        NaN        NaN
# 256                           NaN        NaN        NaN        NaN        NaN
# 268                           NaN        NaN        NaN        NaN        NaN
# 280                           NaN        NaN        NaN        NaN        NaN
# 292                           NaN        NaN        NaN        NaN        NaN
# 304                           NaN        NaN        NaN        NaN        NaN
# 316                           NaN        NaN        NaN        NaN        NaN
# 328                           NaN        NaN        NaN        NaN        NaN
# 340                           NaN        NaN        NaN        NaN        NaN
# 353                           NaN        NaN        NaN        NaN        NaN
# 366                           NaN        NaN        NaN        NaN        NaN
# 379                           NaN        NaN        NaN        NaN        NaN
# ...                           ...        ...        ...        ...        ...
# 1963                          NaN        NaN        NaN        NaN        NaN
# 1975                          NaN        NaN        NaN        NaN        NaN
# 1987                          NaN        NaN        NaN        NaN        NaN
# 1999                          NaN        NaN        NaN        NaN        NaN
# 2011                          NaN        NaN        NaN        NaN        NaN
# 2023                          NaN        NaN        NaN        NaN        NaN
# 2035                          NaN        NaN        NaN        NaN        NaN
# 2047                          NaN        NaN        NaN        NaN        NaN
# 2058                          NaN        NaN        NaN        NaN        NaN
# 2069                          NaN        NaN        NaN        NaN        NaN
# 2081                          NaN        NaN        NaN        NaN        NaN
# 2093                          NaN        NaN        NaN        NaN        NaN
# 2105                          NaN        NaN        NaN        NaN        NaN
# 2117                          NaN        NaN        NaN        NaN        NaN
# 2129                          NaN        NaN        NaN        NaN        NaN
# 2141                          NaN        NaN        NaN        NaN        NaN
# 2153                          NaN        NaN        NaN        NaN        NaN
# 2165                          NaN        NaN        NaN        NaN        NaN
# 2177                          NaN        NaN        NaN        NaN        NaN
# 2189                          NaN        NaN        NaN        NaN        NaN
# 2201                          NaN        NaN        NaN        NaN        NaN
# 2213                          NaN        NaN        NaN        NaN        NaN
# 2225                          NaN        NaN        NaN        NaN        NaN
# 2236                          NaN        NaN        NaN        NaN        NaN
# 2248                          NaN        NaN        NaN        NaN        NaN
# 2260                          NaN        NaN        NaN        NaN        NaN
# 2272                          NaN        NaN        NaN        NaN        NaN
# 2284                          NaN        NaN        NaN        NaN        NaN
# 2293                          NaN        NaN        NaN        NaN        NaN
# 2298                          NaN        NaN        NaN        NaN        NaN
#
#      clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 9           NaN           0.085   NaN     CTACTATA     CGTACTCA
# 22          NaN           0.082   NaN     CGTTACTA     CGTACTCA
# 35          NaN           0.093   NaN     AGAGTCAC     CGTACTCA
# 48          NaN           0.102   NaN     TACGAGAC     CGTACTCA
# 61          NaN           0.149   NaN     ACGTCTCG     CGTACTCA
# 74          NaN           0.169   NaN     TCGACGAG     CGTACTCA
# 87          NaN            0.25   NaN     GATCGTGT     CGTACTCA
# 101         NaN           0.393   NaN     GTCAGATA     CGTACTCA
# 115         NaN           1.006   NaN     CTACTATA     CTACGCAG
# 129         NaN           4.805   NaN     CGTTACTA     CTACGCAG
# 143         NaN           7.389   NaN     AGAGTCAC     CTACGCAG
# 156         NaN          20.421   NaN     TACGAGAC     CTACGCAG
# 169         NaN          13.202   NaN     ACGTCTCG     CTACGCAG
# 182         NaN          20.483   NaN     TCGACGAG     CTACGCAG
# 195         NaN          10.444   NaN     GATCGTGT     CTACGCAG
# 208         NaN           5.244   NaN     GTCAGATA     CTACGCAG
# 220         NaN           2.527   NaN     CTACTATA     GGAGACTA
# 232         NaN           2.477   NaN     CGTTACTA     GGAGACTA
# 244         NaN           1.085   NaN     AGAGTCAC     GGAGACTA
# 256         NaN           0.969   NaN     TACGAGAC     GGAGACTA
# 268         NaN           0.395   NaN     ACGTCTCG     GGAGACTA
# 280         NaN           0.332   NaN     TCGACGAG     GGAGACTA
# 292         NaN           0.161   NaN     GATCGTGT     GGAGACTA
# 304         NaN             NaN   NaN     GTCAGATA     GGAGACTA
# 316         NaN             0.2   NaN     CTACTATA     GTCGCTCG
# 328         NaN           0.279   NaN     CGTTACTA     GTCGCTCG
# 340         NaN           0.526   NaN     AGAGTCAC     GTCGCTCG
# 353         NaN           0.861   NaN     TACGAGAC     GTCGCTCG
# 366         NaN           0.607   NaN     ACGTCTCG     GTCGCTCG
# 379         NaN           0.937   NaN     TCGACGAG     GTCGCTCG
# ...         ...             ...   ...          ...          ...
# 1963        NaN           6.102   NaN     ATCGTACG     AGTAGCGT
# 1975        NaN            4.15   NaN     ACTATCTG     AGTAGCGT
# 1987        NaN             2.6   NaN     TAGCGAGT     AGTAGCGT
# 1999        NaN           3.221   NaN     CTGCGTGT     AGTAGCGT
# 2011        NaN           1.891   NaN     TCATCGAG     AGTAGCGT
# 2023        NaN           1.786   NaN     CGTGAGTG     AGTAGCGT
# 2035        NaN           1.143   NaN     GGATATCT     AGTAGCGT
# 2047        NaN           0.475   NaN     GACACCGT     AGTAGCGT
# 2058        NaN             NaN   NaN     ATCGTACG     CAGTGAGT
# 2069        NaN             NaN   NaN     ACTATCTG     CAGTGAGT
# 2081        NaN           0.112   NaN     TAGCGAGT     CAGTGAGT
# 2093        NaN           0.144   NaN     CTGCGTGT     CAGTGAGT
# 2105        NaN           0.162   NaN     TCATCGAG     CAGTGAGT
# 2117        NaN           0.173   NaN     CGTGAGTG     CAGTGAGT
# 2129        NaN           0.215   NaN     GGATATCT     CAGTGAGT
# 2141        NaN           0.277   NaN     GACACCGT     CAGTGAGT
# 2153        NaN           0.326   NaN     ATCGTACG     CGTACTCA
# 2165        NaN           0.414   NaN     ACTATCTG     CGTACTCA
# 2177        NaN           0.535   NaN     TAGCGAGT     CGTACTCA
# 2189        NaN           2.465   NaN     CTGCGTGT     CGTACTCA
# 2201        NaN            9.02   NaN     TCATCGAG     CGTACTCA
# 2213        NaN          21.678   NaN     CGTGAGTG     CGTACTCA
# 2225        NaN          22.752   NaN     GGATATCT     CGTACTCA
# 2236        NaN           5.269   NaN     CGTGAGTG     GTCGTAGT
# 2248        NaN          -0.442   NaN     GACACCGT     TAGCAGAC
# 2260        NaN           1.882   NaN     CTACTATA     AACTCTCG
# 2272        NaN           1.272   NaN     GTCAGATA     ACTATGTC
# 2284        NaN           3.759   NaN     CTACTATA     AGTAGCGT
# 2293        NaN           0.425   NaN     CTACTATA     TCGCTATA
# 2298        NaN          17.699   NaN     GTCAGATA     TCGCTATA
#
# [192 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 20 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 192

[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MR.A.13C-Xyl.D1.R2_Frac5'),
#  ('tgagtacgcgttacta', 'MR.A.13C-Xyl.D1.R2_Frac6'),
#  ('tgagtacgagagtcac', 'MR.A.13C-Xyl.D1.R2_Frac7'),
#  ('tgagtacgtacgagac', 'MR.A.13C-Xyl.D1.R2_Frac8'),
#  ('tgagtacgacgtctcg', 'MR.A.13C-Xyl.D1.R2_Frac9'),
#  ('tgagtacgtcgacgag', 'MR.A.13C-Xyl.D1.R2_Frac10'),
#  ('tgagtacggatcgtgt', 'MR.A.13C-Xyl.D1.R2_Frac11'),
#  ('tgagtacggtcagata', 'MR.A.13C-Xyl.D1.R2_Frac12'),
#  ('ctgcgtagctactata', 'MR.A.13C-Xyl.D1.R2_Frac13'),
#  ('ctgcgtagcgttacta', 'MR.A.13C-Xyl.D1.R2_Frac14'),
#  ('ctgcgtagagagtcac', 'MR.A.13C-Xyl.D1.R2_Frac15'),
#  ('ctgcgtagtacgagac', 'MR.A.13C-Xyl.D1.R2_Frac16'),
#  ('ctgcgtagacgtctcg', 'MR.A.13C-Xyl.D1.R2_Frac17'),
#  ('ctgcgtagtcgacgag', 'MR.A.13C-Xyl.D1.R2_Frac18'),
#  ('ctgcgtaggatcgtgt', 'MR.A.13C-Xyl.D1.R2_Frac19'),
#  ('ctgcgtaggtcagata', 'MR.A.13C-Xyl.D1.R2_Frac20'),
#  ('tagtctccctactata', 'MR.A.13C-Xyl.D1.R2_Frac21'),
#  ('tagtctcccgttacta', 'MR.A.13C-Xyl.D1.R2_Frac22'),
#  ('tagtctccagagtcac', 'MR.A.13C-Xyl.D1.R2_Frac23'),
#  ('tagtctcctacgagac', 'MR.A.13C-Xyl.D1.R2_Frac24'),
#  ('tagtctccacgtctcg', 'MR.A.13C-Xyl.D1.R2_Frac25'),
#  ('tagtctcctcgacgag', 'MR.A.13C-Xyl.D1.R2_Frac26'),
#  ('tagtctccgatcgtgt', 'MR.A.13C-Xyl.D1.R2_Frac27'),
#  ('tagtctccgtcagata', 'MR.A.13C-Xyl.D1.R2_NC'),
#  ('cgagcgacctactata', 'MR.A.13C-Pal.D14.R2_Frac4'),
#  ('cgagcgaccgttacta', 'MR.A.13C-Pal.D14.R2_Frac5'),
#  ('cgagcgacagagtcac', 'MR.A.13C-Pal.D14.R2_Frac6'),
#  ('cgagcgactacgagac', 'MR.A.13C-Pal.D14.R2_Frac7'),
#  ('cgagcgacacgtctcg', 'MR.A.13C-Pal.D14.R2_Frac8'),
#  ('cgagcgactcgacgag', 'MR.A.13C-Pal.D14.R2_Frac9'),
#  ('tgagtacggacaccgt', 'MR.A.13C-Cel.D6.R1_Frac18'),
#  ('ctgcgtagatcgtacg', 'MR.A.13C-Cel.D6.R1_Frac19'),
#  ('ctgcgtagactatctg', 'MR.A.13C-Cel.D6.R1_Frac20'),
#  ('ctgcgtagtagcgagt', 'MR.A.13C-Cel.D6.R1_Frac21'),
#  ('ctgcgtagctgcgtgt', 'MR.A.13C-Cel.D6.R1_Frac22'),
#  ('ctgcgtagtcatcgag', 'MR.A.13C-Cel.D6.R1_Frac23'),
#  ('ctgcgtagcgtgagtg', 'MR.A.13C-Cel.D6.R1_Frac24'),
#  ('ctgcgtagggatatct', 'MR.A.13C-Cel.D6.R1_Frac25'),
#  ('ctgcgtaggacaccgt', 'MR.A.13C-Cel.D6.R1_Frac26'),
#  ('tagtctccatcgtacg', 'MR.A.13C-Cel.D6.R1_Frac27'),
#  ('tagtctccactatctg', 'MR.A.13C-Cel.D6.R1_Frac28'),
#  ('tagtctcctagcgagt', 'MR.A.13C-Cel.D6.R1_NC'),
#  ('tagtctccctgcgtgt', 'MR.F.12C-Con.D1.R1_Frac4'),
#  ('tagtctcctcatcgag', 'MR.F.12C-Con.D1.R1_Frac5'),
#  ('tagtctcccgtgagtg', 'MR.F.12C-Con.D1.R1_Frac6'),
#  ('tagtctccggatatct', 'MR.F.12C-Con.D1.R1_Frac7'),
#  ('tagtctccgacaccgt', 'MR.F.12C-Con.D1.R1_Frac8'),
#  ('cgagcgacatcgtacg', 'MR.F.12C-Con.D1.R1_Frac9'),
#  ('cgagcgacactatctg', 'MR.F.12C-Con.D1.R1_Frac10'),
#  ('cgagcgactagcgagt', 'MR.F.12C-Con.D1.R1_Frac11'),
#  ('cgagcgacctgcgtgt', 'MR.F.12C-Con.D1.R1_Frac12'),
#  ('cgagcgactcatcgag', 'MR.F.12C-Con.D1.R1_Frac13'),
#  ('cgagcgaccgtgagtg', 'MR.F.12C-Con.D1.R1_Frac14'),
#  ('cgagcgacggatatct', 'MR.F.12C-Con.D1.R1_Frac15'),
#  ('cgagcgacgacaccgt', 'MR.F.12C-Con.D1.R1_Frac16'),
#  ('actacgacatcgtacg', 'MR.F.12C-Con.D1.R1_Frac17'),
#  ('actacgacactatctg', 'MR.F.12C-Con.D1.R1_Frac18'),
#  ('actacgactagcgagt', 'MR.F.12C-Con.D1.R1_Frac19'),
#  ('actacgacctgcgtgt', 'MR.F.12C-Con.D1.R1_Frac20'),
#  ('actacgactcatcgag', 'MR.F.12C-Con.D1.R1_Frac21'),
#  ('actacgacggatatct', 'MR.F.12C-Con.D1.R1_Frac23'),
#  ('actacgacgacaccgt', 'MR.F.12C-Con.D1.R1_Frac24'),
#  ('gtctgctaatcgtacg', 'MR.F.12C-Con.D1.R1_Frac25'),
#  ('gtctgctaactatctg', 'MR.F.12C-Con.D1.R1_Frac26'),
#  ('gtctgctatagcgagt', 'MR.F.12C-Con.D1.R1_Frac27'),
#  ('gtctgctactgcgtgt', 'MR.F.12C-Con.D1.R1_Frac28'),
#  ('gtctgctatcatcgag', 'MR.F.12C-Con.D1.R1_NC'),
#  ('gtctgctacgtgagtg', 'MR.M.13C-Ami.D1.R2_Frac4'),
#  ('gtctgctaggatatct', 'MR.M.13C-Ami.D1.R2_Frac5'),
#  ('gtctatgaatcgtacg', 'MR.M.13C-Ami.D1.R2_Frac7'),
#  ('gtctatgaactatctg', 'MR.M.13C-Ami.D1.R2_Frac8'),
#  ('gtctatgatagcgagt', 'MR.M.13C-Ami.D1.R2_Frac9'),
#  ('gtctatgactgcgtgt', 'MR.M.13C-Ami.D1.R2_Frac10'),
#  ('gtctatgatcatcgag', 'MR.M.13C-Ami.D1.R2_Frac11'),
#  ('gtctatgacgtgagtg', 'MR.M.13C-Ami.D1.R2_Frac12'),
#  ('gtctatgaggatatct', 'MR.M.13C-Ami.D1.R2_Frac13'),
#  ('gtctatgagacaccgt', 'MR.M.13C-Ami.D1.R2_Frac14'),
#  ('tatagcgaatcgtacg', 'MR.M.13C-Ami.D1.R2_Frac15'),
#  ('tatagcgaactatctg', 'MR.M.13C-Ami.D1.R2_Frac16'),
#  ('tatagcgatagcgagt', 'MR.M.13C-Ami.D1.R2_Frac17'),
#  ('tatagcgactgcgtgt', 'MR.M.13C-Ami.D1.R2_Frac18'),
#  ('tatagcgatcatcgag', 'MR.M.13C-Ami.D1.R2_Frac19'),
#  ('tatagcgacgtgagtg', 'MR.M.13C-Ami.D1.R2_Frac20'),
#  ('tatagcgaggatatct', 'MR.M.13C-Ami.D1.R2_Frac21'),
#  ('tatagcgagacaccgt', 'MR.M.13C-Ami.D1.R2_Frac22'),
#  ('cgagagttcgttacta', 'MR.M.13C-Ami.D1.R2_Frac24'),
#  ('cgagagttagagtcac', 'MR.M.13C-Ami.D1.R2_Frac25'),
#  ('cgagagtttacgagac', 'MR.M.13C-Ami.D1.R2_Frac26'),
#  ('cgagagttacgtctcg', 'MR.M.13C-Ami.D1.R2_Frac27'),
#  ('cgagagtttcgacgag', 'MR.M.13C-Ami.D1.R2_NC'),
#  ('cgagagttgatcgtgt', 'MR.A.12C-Con.D6.R2_Frac3'),
#  ('cgagagttgtcagata', 'MR.A.12C-Con.D6.R2_Frac4'),
#  ('gacatagtctactata', 'MR.A.12C-Con.D6.R2_Frac5'),
#  ('gacatagtcgttacta', 'MR.A.12C-Con.D6.R2_Frac6'),
#  ('gacatagtagagtcac', 'MR.A.12C-Con.D6.R2_Frac7'),
#  ('gacatagttacgagac', 'MR.A.12C-Con.D6.R2_Frac8'),
#  ('gacatagtacgtctcg', 'MR.A.12C-Con.D6.R2_Frac9'),
#  ('gacatagttcgacgag', 'MR.A.12C-Con.D6.R2_Frac10'),
#  ('gacatagtgatcgtgt', 'MR.A.12C-Con.D6.R2_Frac11'),
#  ('acgctactcgttacta', 'MR.A.12C-Con.D6.R2_Frac14'),
#  ('acgctactagagtcac', 'MR.A.12C-Con.D6.R2_Frac15'),
#  ('acgctacttacgagac', 'MR.A.12C-Con.D6.R2_Frac16'),
#  ('acgctactacgtctcg', 'MR.A.12C-Con.D6.R2_Frac17'),
#  ('acgctacttcgacgag', 'MR.A.12C-Con.D6.R2_Frac18'),
#  ('acgctactgatcgtgt', 'MR.A.12C-Con.D6.R2_Frac19'),
#  ('acgctactgtcagata', 'MR.A.12C-Con.D6.R2_Frac20'),
#  ('actcactgctactata', 'MR.A.12C-Con.D6.R2_Frac21'),
#  ('actcactgcgttacta', 'MR.A.12C-Con.D6.R2_Frac22'),
#  ('actcactgagagtcac', 'MR.A.12C-Con.D6.R2_Frac23'),
#  ('actcactgtacgagac', 'MR.A.12C-Con.D6.R2_Frac24'),
#  ('actcactgacgtctcg', 'MR.A.12C-Con.D6.R2_Frac25'),
#  ('actcactgtcgacgag', 'MR.A.12C-Con.D6.R2_Frac26'),
#  ('actcactggatcgtgt', 'MR.A.12C-Con.D6.R2_Frac27'),
#  ('actcactggtcagata', 'MR.A.12C-Con.D6.R2_NC'),
#  ('cgagcgacgatcgtgt', 'MR.A.13C-Pal.D14.R2_Frac10'),
#  ('cgagcgacgtcagata', 'MR.A.13C-Pal.D14.R2_Frac11'),
#  ('actacgacctactata', 'MR.A.13C-Pal.D14.R2_Frac12'),
#  ('actacgaccgttacta', 'MR.A.13C-Pal.D14.R2_Frac13'),
#  ('actacgacagagtcac', 'MR.A.13C-Pal.D14.R2_Frac14'),
#  ('actacgactacgagac', 'MR.A.13C-Pal.D14.R2_Frac15'),
#  ('actacgacacgtctcg', 'MR.A.13C-Pal.D14.R2_Frac16'),
#  ('actacgactcgacgag', 'MR.A.13C-Pal.D14.R2_Frac17'),
#  ('actacgacgatcgtgt', 'MR.A.13C-Pal.D14.R2_Frac18'),
#  ('actacgacgtcagata', 'MR.A.13C-Pal.D14.R2_Frac19'),
#  ('gtctgctactactata', 'MR.A.13C-Pal.D14.R2_Frac20'),
#  ('gtctgctacgttacta', 'MR.A.13C-Pal.D14.R2_Frac21'),
#  ('gtctgctaagagtcac', 'MR.A.13C-Pal.D14.R2_Frac22'),
#  ('gtctgctatacgagac', 'MR.A.13C-Pal.D14.R2_Frac23'),
#  ('gtctgctaacgtctcg', 'MR.A.13C-Pal.D14.R2_Frac24'),
#  ('gtctgctatcgacgag', 'MR.A.13C-Pal.D14.R2_Frac25'),
#  ('gtctgctagatcgtgt', 'MR.A.13C-Pal.D14.R2_Frac26'),
#  ('gtctgctagtcagata', 'MR.A.13C-Pal.D14.R2_Frac27'),
#  ('gtctatgactactata', 'MR.A.13C-Pal.D14.R2_NC'),
#  ('gtctatgacgttacta', 'MR.A.13C-Ami.D1.R1_Frac4'),
#  ('gtctatgaagagtcac', 'MR.A.13C-Ami.D1.R1_Frac5'),
#  ('gtctatgatacgagac', 'MR.A.13C-Ami.D1.R1_Frac6'),
#  ('gtctatgaacgtctcg', 'MR.A.13C-Ami.D1.R1_Frac7'),
#  ('gtctatgatcgacgag', 'MR.A.13C-Ami.D1.R1_Frac8'),
#  ('gtctatgagatcgtgt', 'MR.A.13C-Ami.D1.R1_Frac9'),
#  ('gtctatgagtcagata', 'MR.A.13C-Ami.D1.R1_Frac10'),
#  ('tatagcgacgttacta', 'MR.A.13C-Ami.D1.R1_Frac12'),
#  ('tatagcgaagagtcac', 'MR.A.13C-Ami.D1.R1_Frac13'),
#  ('tatagcgatacgagac', 'MR.A.13C-Ami.D1.R1_Frac14'),
#  ('tatagcgaacgtctcg', 'MR.A.13C-Ami.D1.R1_Frac15'),
#  ('tatagcgatcgacgag', 'MR.A.13C-Ami.D1.R1_Frac16'),
#  ('tatagcgagatcgtgt', 'MR.A.13C-Ami.D1.R1_Frac17'),
#  ('cgagagttatcgtacg', 'MR.M.13C-Ami.D3.R1_Frac5'),
#  ('cgagagttactatctg', 'MR.M.13C-Ami.D3.R1_Frac6'),
#  ('cgagagtttagcgagt', 'MR.M.13C-Ami.D3.R1_Frac7'),
#  ('cgagagttctgcgtgt', 'MR.M.13C-Ami.D3.R1_Frac8'),
#  ('cgagagtttcatcgag', 'MR.M.13C-Ami.D3.R1_Frac9'),
#  ('cgagagttcgtgagtg', 'MR.M.13C-Ami.D3.R1_Frac10'),
#  ('cgagagttggatatct', 'MR.M.13C-Ami.D3.R1_Frac11'),
#  ('cgagagttgacaccgt', 'MR.M.13C-Ami.D3.R1_Frac12'),
#  ('gacatagtatcgtacg', 'MR.M.13C-Ami.D3.R1_Frac13'),
#  ('gacatagtactatctg', 'MR.M.13C-Ami.D3.R1_Frac14'),
#  ('gacatagttagcgagt', 'MR.M.13C-Ami.D3.R1_Frac15'),
#  ('gacatagtctgcgtgt', 'MR.M.13C-Ami.D3.R1_Frac16'),
#  ('gacatagttcatcgag', 'MR.M.13C-Ami.D3.R1_Frac17'),
#  ('gacatagtcgtgagtg', 'MR.M.13C-Ami.D3.R1_Frac18'),
#  ('gacatagtggatatct', 'MR.M.13C-Ami.D3.R1_Frac19'),
#  ('gacatagtgacaccgt', 'MR.M.13C-Ami.D3.R1_Frac20'),
#  ('acgctactatcgtacg', 'MR.M.13C-Ami.D3.R1_Frac21'),
#  ('acgctactactatctg', 'MR.M.13C-Ami.D3.R1_Frac22'),
#  ('acgctacttagcgagt', 'MR.M.13C-Ami.D3.R1_Frac23'),
#  ('acgctactctgcgtgt', 'MR.M.13C-Ami.D3.R1_Frac24'),
#  ('acgctacttcatcgag', 'MR.M.13C-Ami.D3.R1_Frac25'),
#  ('acgctactcgtgagtg', 'MR.M.13C-Ami.D3.R1_Frac26'),
#  ('acgctactggatatct', 'MR.M.13C-Ami.D3.R1_Frac27'),
#  ('acgctactgacaccgt', 'MR.M.13C-Ami.D3.R1_Frac28'),
#  ('actcactgatcgtacg', 'MR.M.13C-Ami.D3.R1_NC'),
#  ('actcactgactatctg', 'MR.M.13C-Ami.D3.R1_MC'),
#  ('actcactgtagcgagt', 'MR.A.13C-Cel.D6.R1_Frac5'),
#  ('actcactgctgcgtgt', 'MR.A.13C-Cel.D6.R1_Frac6'),
#  ('actcactgtcatcgag', 'MR.A.13C-Cel.D6.R1_Frac7'),
#  ('actcactgcgtgagtg', 'MR.A.13C-Cel.D6.R1_Frac8'),
#  ('actcactgggatatct', 'MR.A.13C-Cel.D6.R1_Frac9'),
#  ('actcactggacaccgt', 'MR.A.13C-Cel.D6.R1_Frac10'),
#  ('tgagtacgatcgtacg', 'MR.A.13C-Cel.D6.R1_Frac11'),
#  ('tgagtacgactatctg', 'MR.A.13C-Cel.D6.R1_Frac12'),
#  ('tgagtacgtagcgagt', 'MR.A.13C-Cel.D6.R1_Frac13'),
#  ('tgagtacgctgcgtgt', 'MR.A.13C-Cel.D6.R1_Frac14'),
#  ('tgagtacgtcatcgag', 'MR.A.13C-Cel.D6.R1_Frac15'),
#  ('tgagtacgcgtgagtg', 'MR.A.13C-Cel.D6.R1_Frac16'),
#  ('tgagtacgggatatct', 'MR.A.13C-Cel.D6.R1_Frac17'),
#  ('actacgaccgtgagtg', 'MR.F.12C-Con.D1.R1_Frac22'),
#  ('gtctgctagacaccgt', 'MR.M.13C-Ami.D1.R2_Frac6'),
#  ('cgagagttctactata', 'MR.M.13C-Ami.D1.R2_Frac23'),
#  ('gacatagtgtcagata', 'MR.A.12C-Con.D6.R2_Frac12'),
#  ('acgctactctactata', 'MR.A.12C-Con.D6.R2_Frac13'),
#  ('tatagcgactactata', 'MR.A.13C-Ami.D1.R1_Frac11'),
#  ('tatagcgagtcagata', 'MR.A.13C-Ami.D1.R1_Frac18')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 2608169 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 2916329.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                          Sample  seq_count
# 0     MR.M.13C-Ami.D1.R2_Frac11      18034
# 1     MR.F.12C-Con.D1.R1_Frac16      18007
# 2     MR.A.13C-Cel.D6.R1_Frac16      17750
# 3    MR.A.13C-Pal.D14.R2_Frac13       5653
# 4     MR.A.13C-Ami.D1.R1_Frac16      38318
# 5     MR.M.13C-Ami.D3.R1_Frac27      15175
# 6    MR.A.13C-Pal.D14.R2_Frac10      13656
# 7      MR.A.13C-Ami.D1.R1_Frac7      17635
# 8     MR.F.12C-Con.D1.R1_Frac21      13164
# 9      MR.F.12C-Con.D1.R1_Frac9      10424
# 10    MR.A.13C-Cel.D6.R1_Frac15      25429
# 11   MR.A.13C-Pal.D14.R2_Frac16       5494
# 12     MR.A.13C-Xyl.D1.R2_Frac5       9829
# 13    MR.M.13C-Ami.D1.R2_Frac17      13949
# 14    MR.M.13C-Ami.D3.R1_Frac14       9540
# 15    MR.A.13C-Ami.D1.R1_Frac11      14213
# 16    MR.A.13C-Xyl.D1.R2_Frac22       6214
# 17     MR.A.13C-Cel.D6.R1_Frac5      31946
# 18    MR.A.13C-Ami.D1.R1_Frac10      26937
# 19     MR.A.13C-Ami.D1.R1_Frac8      26014
# 20    MR.M.13C-Ami.D3.R1_Frac17      24090
# 21    MR.A.13C-Ami.D1.R1_Frac17      23267
# 22    MR.A.12C-Con.D6.R2_Frac16      36427
# 23    MR.M.13C-Ami.D3.R1_Frac16      16417
# 24    MR.M.13C-Ami.D1.R2_Frac23      10998
# 25    MR.F.12C-Con.D1.R1_Frac24      27821
# 26    MR.F.12C-Con.D1.R1_Frac11      11829
# 27    MR.A.13C-Ami.D1.R1_Frac14      54166
# 28    MR.A.13C-Xyl.D1.R2_Frac26      10228
# 29    MR.A.12C-Con.D6.R2_Frac10      35638
# ..                          ...        ...
# 162   MR.M.13C-Ami.D1.R2_Frac20       7960
# 163   MR.A.13C-Xyl.D1.R2_Frac15       3500
# 164   MR.F.12C-Con.D1.R1_Frac27      13784
# 165   MR.F.12C-Con.D1.R1_Frac18       7431
# 166    MR.F.12C-Con.D1.R1_Frac5      12049
# 167    MR.M.13C-Ami.D3.R1_Frac5      15414
# 168   MR.F.12C-Con.D1.R1_Frac20       8298
# 169   MR.M.13C-Ami.D1.R2_Frac22      12133
# 170    MR.F.12C-Con.D1.R1_Frac8      14827
# 171   MR.M.13C-Ami.D1.R2_Frac16       6983
# 172    MR.A.13C-Xyl.D1.R2_Frac6       7060
# 173  MR.A.13C-Pal.D14.R2_Frac18      11867
# 174   MR.M.13C-Ami.D1.R2_Frac24      10624
# 175  MR.A.13C-Pal.D14.R2_Frac19      16978
# 176    MR.F.12C-Con.D1.R1_Frac7      10493
# 177   MR.A.13C-Cel.D6.R1_Frac25      11737
# 178    MR.A.13C-Xyl.D1.R2_Frac7       6974
# 179       MR.M.13C-Ami.D3.R1_MC       6927
# 180   MR.A.13C-Xyl.D1.R2_Frac14       5696
# 181   MR.A.13C-Xyl.D1.R2_Frac23       7775
# 182  MR.A.13C-Pal.D14.R2_Frac14       4387
# 183   MR.A.12C-Con.D6.R2_Frac25       9507
# 184       MR.A.12C-Con.D6.R2_NC       1697
# 185   MR.A.12C-Con.D6.R2_Frac17      14558
# 186       MR.F.12C-Con.D1.R1_NC        542
# 187      MR.A.13C-Pal.D14.R2_NC        605
# 188       MR.A.13C-Cel.D6.R1_NC       1685
# 189       MR.M.13C-Ami.D1.R2_NC       1084
# 190       MR.M.13C-Ami.D3.R1_NC        512
# 191       MR.A.13C-Xyl.D1.R2_NC        580
#
# [192 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 10000,]
# Out:
#                         Sample seq_count
# 3   MR.A.13C-Pal.D14.R2_Frac13      5653
# 11  MR.A.13C-Pal.D14.R2_Frac16      5494
# 12    MR.A.13C-Xyl.D1.R2_Frac5      9829
# 14   MR.M.13C-Ami.D3.R1_Frac14      9540
# 16   MR.A.13C-Xyl.D1.R2_Frac22      6214
# 31  MR.A.13C-Pal.D14.R2_Frac21      6605
# 34   MR.F.12C-Con.D1.R1_Frac13      8618
# 37  MR.A.13C-Pal.D14.R2_Frac12      6835
# 44   MR.A.13C-Xyl.D1.R2_Frac21      6113
# 51   MR.M.13C-Ami.D3.R1_Frac24      9958
# 55   MR.A.13C-Xyl.D1.R2_Frac25      5104
# 58    MR.M.13C-Ami.D1.R2_Frac8      9386
# 62   MR.A.13C-Cel.D6.R1_Frac14      9130
# 75   MR.A.13C-Pal.D14.R2_Frac5      5932
# 83   MR.A.13C-Pal.D14.R2_Frac7      7276
# 86   MR.M.13C-Ami.D1.R2_Frac21      8652
# 87   MR.F.12C-Con.D1.R1_Frac12      9768
# 89   MR.A.13C-Xyl.D1.R2_Frac13      7584
# 90   MR.A.13C-Cel.D6.R1_Frac12      7500
# 91    MR.F.12C-Con.D1.R1_Frac4      8468
# 102  MR.F.12C-Con.D1.R1_Frac26      6615
# 103  MR.F.12C-Con.D1.R1_Frac10      5855
# 104  MR.A.13C-Pal.D14.R2_Frac9      9945
# 109  MR.A.13C-Xyl.D1.R2_Frac18      6815
# 111  MR.A.13C-Pal.D14.R2_Frac6      5330
# 114  MR.M.13C-Ami.D1.R2_Frac18      8961
# 121  MR.A.13C-Cel.D6.R1_Frac28      7301
# 125  MR.A.13C-Pal.D14.R2_Frac4      7578
# 135  MR.A.13C-Pal.D14.R2_Frac8      6111
# 136  MR.M.13C-Ami.D3.R1_Frac22      6284
# 137 MR.A.13C-Pal.D14.R2_Frac22      4899
# 142  MR.A.13C-Cel.D6.R1_Frac20      7052
# 145  MR.F.12C-Con.D1.R1_Frac28      8646
# 147 MR.A.13C-Pal.D14.R2_Frac20      6905
# 148   MR.M.13C-Ami.D3.R1_Frac6      9120
# 149  MR.A.13C-Ami.D1.R1_Frac12      9451
# 156  MR.A.13C-Xyl.D1.R2_Frac17      3670
# 160 MR.A.13C-Pal.D14.R2_Frac24      6425
# 162  MR.M.13C-Ami.D1.R2_Frac20      7960
# 163  MR.A.13C-Xyl.D1.R2_Frac15      3500
# 165  MR.F.12C-Con.D1.R1_Frac18      7431
# 168  MR.F.12C-Con.D1.R1_Frac20      8298
# 171  MR.M.13C-Ami.D1.R2_Frac16      6983
# 172   MR.A.13C-Xyl.D1.R2_Frac6      7060
# 178   MR.A.13C-Xyl.D1.R2_Frac7      6974
# 179      MR.M.13C-Ami.D3.R1_MC      6927
# 180  MR.A.13C-Xyl.D1.R2_Frac14      5696
# 181  MR.A.13C-Xyl.D1.R2_Frac23      7775
# 182 MR.A.13C-Pal.D14.R2_Frac14      4387
# 183  MR.A.12C-Con.D6.R2_Frac25      9507
# 184      MR.A.12C-Con.D6.R2_NC      1697
# 186      MR.F.12C-Con.D1.R1_NC       542
# 187     MR.A.13C-Pal.D14.R2_NC       605
# 188      MR.A.13C-Cel.D6.R1_NC      1685
# 189      MR.M.13C-Ami.D1.R2_NC      1084
# 190      MR.M.13C-Ami.D3.R1_NC       512
# 191      MR.A.13C-Xyl.D1.R2_NC       580

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 192 samples
# You should have 192 samples
