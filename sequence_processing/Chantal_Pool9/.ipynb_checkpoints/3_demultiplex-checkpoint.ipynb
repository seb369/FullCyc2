# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/Chantal_Pool9'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/Chantal_Pool9'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'Chantal_Pool9'

# Index and paired files
index_read1_file = 'index1.pool9.fq.gz'
index_read2_file = 'index2.pool9.fq.gz'
read12_screed = 'pear_merged-Chantal_Pool9.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/Chantal_Pool9

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/envs/seq_pipeline/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/envs/seq_pipeline/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/envs/seq_pipeline/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#          #Sample  primer_number exp_type extraction_plate_ID     library_ID  \
# 0    EL.A.151026            129     bulk            14012016  Chantal_Pool9
# 13   MP.F.151026            130     bulk            14012016  Chantal_Pool9
# 65       16.70          60.027   NaN     TCGACGAG     CGTACTCA
# 78       25.00          32.446   NaN     GATCGTGT     CGTACTCA
# 91       10.00          54.671   NaN     GTCAGATA     CGTACTCA
# 105      31.66           4.766   NaN     CTACTATA     CTACGCAG
# 119      30.00          21.027   NaN     CGTTACTA     CTACGCAG
# 133      16.60          53.043   NaN     AGAGTCAC     CTACGCAG
# 147      13.10          17.866   NaN     TACGAGAC     CTACGCAG
# 160      33.30          18.764   NaN     ACGTCTCG     CTACGCAG
# 173      23.30          54.607   NaN     TCGACGAG     CTACGCAG
# 186       1.70          65.229   NaN     GATCGTGT     CTACGCAG
# 199       3.40          59.901   NaN     GTCAGATA     CTACGCAG
# 212      16.70          76.509   NaN     CTACTATA     GGAGACTA
# 224      11.70           60.65   NaN     CGTTACTA     GGAGACTA
# 236      50.00           9.834   NaN     AGAGTCAC     GGAGACTA
# 248      16.70          41.075   NaN     TACGAGAC     GGAGACTA
# 260      16.60          41.645   NaN     ACGTCTCG     GGAGACTA
# 272      10.00          59.115   NaN     TCGACGAG     GGAGACTA
# 284      11.70         102.073   NaN     GATCGTGT     GGAGACTA
# 296      11.60            68.8   NaN     GTCAGATA     GGAGACTA
# 308      21.40          82.298   NaN     CTACTATA     GTCGCTCG
# 320       6.70          74.413   NaN     CGTTACTA     GTCGCTCG
# 332      23.30          61.298   NaN     AGAGTCAC     GTCGCTCG
# 344      23.30          64.906   NaN     TACGAGAC     GTCGCTCG
# 357      25.00           4.432   NaN     ACGTCTCG     GTCGCTCG
# 370      10.00          39.765   NaN     TCGACGAG     GTCGCTCG
#
# [30 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 24 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 30
[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('ctgcgtaggtcagata', 'CF.C.151027'),
#  ('cgagcgaccgttacta', 'PP.F.151026'),
#  ('ctgcgtaggatcgtgt', 'PP.M.151026'),
#  ('tagtctccgatcgtgt', 'MP.M.151026'),
#  ('tgagtacgtcgacgag', 'MF.M.151026'),
#  ('ctgcgtagctactata', 'CF.A.151027'),
#  ('tagtctcccgttacta', 'MR.F.151027'),
#  ('tagtctcctacgagac', 'BH.M.151026'),
#  ('cgagcgactcgacgag', 'BH.A.151026'),
#  ('tagtctccgtcagata', 'MW.F.151027'),
#  ('cgagcgacacgtctcg', 'MF.A.151026'),
#  ('ctgcgtagagagtcac', 'CC.F.151027'),
#  ('tgagtacgtacgagac', 'SS.A.151026'),
#  ('tagtctccctactata', 'CC.M.151027'),
#  ('ctgcgtagtcgacgag', 'EL.F.151026'),
#  ('cgagcgacagagtcac', 'CF.M.151027'),
#  ('cgagcgactacgagac', 'BH.F.151026'),
#  ('tagtctccacgtctcg', 'EL.M.151026'),
#  ('tagtctcctcgacgag', 'SS.M.151026'),
#  ('tgagtacgagagtcac', 'MR.M.151027'),
#  ('tgagtacggtcagata', 'MF.F.151026'),
#  ('ctgcgtagcgttacta', 'PP.A.151026'),
#  ('tgagtacgacgtctcg', 'MR.A.151027'),
#  ('tgagtacggatcgtgt', 'MP.A.151026'),
#  ('cgagcgacctactata', 'SS.F.151026'),
#  ('tagtctccagagtcac', 'MW.A.151027'),
#  ('tgagtacgctactata', 'EL.A.151026'),
#  ('ctgcgtagacgtctcg', 'CC.A.151027'),
#  ('ctgcgtagtacgagac', 'MW.M.151027'),
#  ('tgagtacgcgttacta', 'MP.F.151026')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 7881815 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 928383

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#          Sample  seq_count
# 0   MW.F.151027      27886
# 1   EL.A.151026      25965
# 2   MR.M.151027      25120
# 3   MF.A.151026      23921
# 4   CC.A.151027      36357
# 5   CC.F.151027      26489
# 6   MP.M.151026      31606
# 7   CC.M.151027      19661
# 8   BH.F.151026      39565
# 9   MW.A.151027      29309
# 10  EL.F.151026      37604
# 11  PP.M.151026      34364
# 12  MR.A.151027      29966
# 13  PP.A.151026      28948
# 14  MR.F.151027      31147
# 15  MF.M.151026      37365
# 16  MP.F.151026      32156
# 17  CF.M.151027      29821
# 18  BH.M.151026      33628
# 19  CF.A.151027      28772
# 20  CF.C.151027      26471
# 21  MP.A.151026      37800
# 22  BH.A.151026      30528
# 23  SS.A.151026      36723
# 24  EL.M.151026      22117
# 25  SS.F.151026      15999
# 26  MW.M.151027      29209
# 27  PP.F.151026      23856
# 28  SS.M.151026      64815
# 29  MF.F.151026      31215

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 10000,]
# Out:
# [1] Sample    seq_count
# <0 rows> (or 0-length row.names)

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 30 samples
# You should have 30 samples

# %% [markdown]
# ## Make separate fastq files for each demultiplex sample

# %%
for sam in list(df_meta['Sample']):
    header_file = os.path.join('for_sra', '_'.join([sam.replace('.', ''), 'headers.txt']))
    with open('pear_merged-Chantal_Pool9.assembled.dmult.fastq', 'r') as fn:
        with open(header_file, 'w') as headfile:
            for line in fn.readlines():
                if re.search(sam, line):
                    fastq_head = line.split("orig_name=",1)[1]
                    headfile.write(fastq_head)

# %%
for sam in list(df_meta['Sample']):
    header_file = os.path.join('for_sra', '_'.join([sam.replace('.', ''), 'headers.txt']))
    fastqF = os.path.join('for_sra', '_'.join([sam.replace('.', ''), 'R1.fq']))
    fastqR = os.path.join('for_sra', '_'.join([sam.replace('.', ''), 'R2.fq']))
    cmd = ''.join(['filterbyname.sh in=forward.fastq out=', fastqF, ' names=', header_file, ' include=t'])
    os.system(cmd)
    cmd = ''.join(['filterbyname.sh in=reverse.fastq out=', fastqR, ' names=', header_file, ' include=t'])
    os.system(cmd)

# %%
from Bio import SeqIO
forward_seq_cnt = {}
reverse_seq_cnt = {}
for sam in list(df_meta['Sample']):
    fastqF = SeqIO.parse(os.path.join('for_sra', '_'.join([sam.replace('.', ''), 'R1.fq'])), 'fastq')
    fastqR = SeqIO.parse(os.path.join('for_sra', '_'.join([sam.replace('.', ''), 'R2.fq'])), 'fastq')
    forward_seq_cnt[sam] = len([1 for record in fastqF])
    reverse_seq_cnt[sam] = len([1 for record in fastqR])

# %%
df_forward_seq_cnt = pd.DataFrame.from_dict(forward_seq_cnt, orient='index')
df_forward_seq_cnt.index.name = 'Sample'
df_forward_seq_cnt.reset_index(inplace=True)
df_forward_seq_cnt.columns = ['Sample', 'forward_seq_count']

df_reverse_seq_cnt = pd.DataFrame.from_dict(reverse_seq_cnt, orient='index')
df_reverse_seq_cnt.index.name = 'Sample'
df_reverse_seq_cnt.reset_index(inplace=True)
df_reverse_seq_cnt.columns = ['Sample', 'reverse_seq_count']

test_seq_count = pd.merge(df_forward_seq_cnt, df_reverse_seq_cnt, on='Sample')
test_seq_count = pd.merge(df_seq_cnt, test_seq_count, on='Sample')
test_seq_count
# Out:
#          Sample  seq_count  forward_seq_count  reverse_seq_count
# 0   MW.F.151027      27886              27886              27886
# 1   EL.A.151026      25965              25965              25965
# 2   MR.M.151027      25120              25120              25120
# 3   MF.A.151026      23921              23921              23921
# 4   CC.A.151027      36357              36357              36357
# 5   CC.F.151027      26489              26489              26489
# 6   MP.M.151026      31606              31606              31606
# 7   CC.M.151027      19661              19661              19661
# 8   BH.F.151026      39565              39565              39565
# 9   MW.A.151027      29309              29309              29309
# 10  EL.F.151026      37604              37604              37604
# 11  PP.M.151026      34364              34364              34364
# 12  MR.A.151027      29966              29966              29966
# 13  PP.A.151026      28948              28948              28948
# 14  MR.F.151027      31147              31147              31147
# 15  MF.M.151026      37365              37365              37365
# 16  MP.F.151026      32156              32156              32156
# 17  CF.M.151027      29821              29821              29821
# 18  BH.M.151026      33628              33628              33628
# 19  CF.A.151027      28772              28772              28772
# 20  CF.C.151027      26471              26471              26471
# 21  MP.A.151026      37800              37800              37800
# 22  BH.A.151026      30528              30528              30528
# 23  SS.A.151026      36723              36723              36723
# 24  EL.M.151026      22117              22117              22117
# 25  SS.F.151026      15999              15999              15999
# 26  MW.M.151027      29209              29209              29209
# 27  PP.F.151026      23856              23856              23856
# 28  SS.M.151026      64815              64815              64815
# 29  MF.F.151026      31215              31215              31215
