# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/fullCyc2_lib6/run1'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib6'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'fullCyc2_lib6'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-fullCyc2_lib6.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib6

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                          #Sample  primer_number exp_type extraction_plate_ID  \
# 8     MR.M.13C-Pal.D30.R1_Frac24            129      SIP                 NaN
# 21    MR.M.13C-Pal.D30.R1_Frac25            130      SIP                 NaN
# 34    MR.M.13C-Pal.D30.R1_Frac26            131      SIP                 NaN
# 47    MR.M.13C-Pal.D30.R1_Frac27            132      SIP                 NaN
# 60    MR.M.13C-Pal.D30.R1_Frac28            133      SIP                 NaN
# 73        MR.M.13C-Pal.D30.R1_NC            134      SIP                 NaN
# 86     MR.F.13C-Ami.D14.R1_Frac4            135      SIP                 NaN
# 100    MR.F.13C-Ami.D14.R1_Frac5            136      SIP                 NaN
# 114    MR.F.13C-Ami.D14.R1_Frac6            137      SIP                 NaN
# 128    MR.F.13C-Ami.D14.R1_Frac7            138      SIP                 NaN
# 142    MR.F.13C-Ami.D14.R1_Frac8            139      SIP                 NaN
# 155    MR.F.13C-Ami.D14.R1_Frac9            140      SIP                 NaN
# 168   MR.F.13C-Ami.D14.R1_Frac10            141      SIP                 NaN
# 181   MR.F.13C-Ami.D14.R1_Frac11            142      SIP                 NaN
# 194   MR.F.13C-Ami.D14.R1_Frac12            143      SIP                 NaN
# 207   MR.F.13C-Ami.D14.R1_Frac13            144      SIP                 NaN
# 219   MR.F.13C-Ami.D14.R1_Frac14            145      SIP                 NaN
# 231   MR.F.13C-Ami.D14.R1_Frac15            146      SIP                 NaN
# 243   MR.F.13C-Ami.D14.R1_Frac16            147      SIP                 NaN
# 255   MR.F.13C-Ami.D14.R1_Frac17            148      SIP                 NaN
# 267   MR.F.13C-Ami.D14.R1_Frac18            149      SIP                 NaN
# 279   MR.F.13C-Ami.D14.R1_Frac19            150      SIP                 NaN
# 291   MR.F.13C-Ami.D14.R1_Frac20            151      SIP                 NaN
# 303   MR.F.13C-Ami.D14.R1_Frac21            152      SIP                 NaN
# 315   MR.F.13C-Ami.D14.R1_Frac22            153      SIP                 NaN
# 327   MR.F.13C-Ami.D14.R1_Frac23            154      SIP                 NaN
# 339   MR.F.13C-Ami.D14.R1_Frac24            155      SIP                 NaN
# 352   MR.F.13C-Ami.D14.R1_Frac25            156      SIP                 NaN
# 365   MR.F.13C-Ami.D14.R1_Frac26            157      SIP                 NaN
# 378   MR.F.13C-Ami.D14.R1_Frac27            158      SIP                 NaN
# ...                          ...            ...      ...                 ...
# 1950  MR.M.13C-Pal.D14.R2_Frac11             16      SIP                 NaN
# 1962  MR.M.13C-Pal.D14.R2_Frac12             17      SIP                 NaN
# 1974  MR.M.13C-Pal.D14.R2_Frac13             18      SIP                 NaN
# 1986  MR.M.13C-Pal.D14.R2_Frac14             19      SIP                 NaN
# 1998  MR.M.13C-Pal.D14.R2_Frac15             20      SIP                 NaN
# 2010  MR.M.13C-Pal.D14.R2_Frac16             21      SIP                 NaN
# 2022  MR.M.13C-Pal.D14.R2_Frac17             22      SIP                 NaN
# 2034  MR.M.13C-Pal.D14.R2_Frac18             23      SIP                 NaN
# 2046  MR.M.13C-Pal.D14.R2_Frac19             24      SIP                 NaN
# 2057  MR.M.13C-Pal.D14.R2_Frac20             25      SIP                 NaN
# 2068  MR.M.13C-Pal.D14.R2_Frac21             26      SIP                 NaN
# 2080  MR.M.13C-Pal.D14.R2_Frac22             27      SIP                 NaN
# 2092  MR.M.13C-Pal.D14.R2_Frac23             28      SIP                 NaN
# 2104  MR.M.13C-Pal.D14.R2_Frac24             29      SIP                 NaN
# 2116  MR.M.13C-Pal.D14.R2_Frac25             30      SIP                 NaN
# 2128  MR.M.13C-Pal.D14.R2_Frac26             31      SIP                 NaN
# 2140  MR.M.13C-Pal.D14.R2_Frac27             32      SIP                 NaN
# 2152      MR.M.13C-Pal.D14.R2_NC             33      SIP                 NaN
# 2164      MR.M.13C-Pal.D14.R2_MC             34      SIP                 NaN
# 2176    MR.A.13C-Ami.D6.R1_Frac4             35      SIP                 NaN
# 2188    MR.A.13C-Ami.D6.R1_Frac5             36      SIP                 NaN
# 2200    MR.A.13C-Ami.D6.R1_Frac6             37      SIP                 NaN
# 2212    MR.A.13C-Ami.D6.R1_Frac7             38      SIP                 NaN
# 2224    MR.A.13C-Ami.D6.R1_Frac8             39      SIP                 NaN
# 2235   MR.A.13C-Xyl.D3.R2_Frac14             70      SIP                 NaN
# 2247   MR.A.13C-Xyl.D3.R2_Frac24             80      SIP                 NaN
# 2259  MR.A.13C-Van.D14.R2_Frac14             97      SIP                 NaN
# 2271   MR.M.13C-Pal.D30.R1_Frac7            112      SIP                 NaN
# 2283   MR.M.13C-Pal.D30.R1_Frac8            113      SIP                 NaN
# 2292       MR.F.13C-Xyl.D1.R2_NC            185      SIP                 NaN
#
#          library_ID         pool_plate_ID pool_plate_well  \
# 8     fullCyc2_lib6  fullCyc2_lib6_Pool_2              A5
# 21    fullCyc2_lib6  fullCyc2_lib6_Pool_2              B5
# 34    fullCyc2_lib6  fullCyc2_lib6_Pool_2              C5
# 47    fullCyc2_lib6  fullCyc2_lib6_Pool_2              D5
# 60    fullCyc2_lib6  fullCyc2_lib6_Pool_2              E5
# 73    fullCyc2_lib6  fullCyc2_lib6_Pool_2              F5
# 86    fullCyc2_lib6  fullCyc2_lib6_Pool_2              G5
# 100   fullCyc2_lib6  fullCyc2_lib6_Pool_2              H5
# 114   fullCyc2_lib6  fullCyc2_lib6_Pool_2              A6
# 128   fullCyc2_lib6  fullCyc2_lib6_Pool_2              B6
# 142   fullCyc2_lib6  fullCyc2_lib6_Pool_2              C6
# 155   fullCyc2_lib6  fullCyc2_lib6_Pool_2              D6
# 168   fullCyc2_lib6  fullCyc2_lib6_Pool_2              E6
# 181   fullCyc2_lib6  fullCyc2_lib6_Pool_2              F6
# 194   fullCyc2_lib6  fullCyc2_lib6_Pool_2              G6
# 207   fullCyc2_lib6  fullCyc2_lib6_Pool_2              H6
# 219   fullCyc2_lib6  fullCyc2_lib6_Pool_2              A7
# 231   fullCyc2_lib6  fullCyc2_lib6_Pool_2              B7
# 243   fullCyc2_lib6  fullCyc2_lib6_Pool_2              C7
# 255   fullCyc2_lib6  fullCyc2_lib6_Pool_2              D7
# 267   fullCyc2_lib6  fullCyc2_lib6_Pool_2              E7
# 279   fullCyc2_lib6  fullCyc2_lib6_Pool_2              F7
# 291   fullCyc2_lib6  fullCyc2_lib6_Pool_2              G7
# 303   fullCyc2_lib6  fullCyc2_lib6_Pool_2              H7
# 315   fullCyc2_lib6  fullCyc2_lib6_Pool_2              A8
# 327   fullCyc2_lib6  fullCyc2_lib6_Pool_2              B8
# 339   fullCyc2_lib6  fullCyc2_lib6_Pool_2              C8
# 352   fullCyc2_lib6  fullCyc2_lib6_Pool_2              D8
# 365   fullCyc2_lib6  fullCyc2_lib6_Pool_2              E8
# 378   fullCyc2_lib6  fullCyc2_lib6_Pool_2              F8
# ...             ...                   ...             ...
# 1950  fullCyc2_lib6  fullCyc2_lib6_Pool_1              H2
# 1962  fullCyc2_lib6  fullCyc2_lib6_Pool_1              A3
# 1974  fullCyc2_lib6  fullCyc2_lib6_Pool_1              B3
# 1986  fullCyc2_lib6  fullCyc2_lib6_Pool_1              C3
# 1998  fullCyc2_lib6  fullCyc2_lib6_Pool_1              D3
# 2010  fullCyc2_lib6  fullCyc2_lib6_Pool_1              E3
# 2022  fullCyc2_lib6  fullCyc2_lib6_Pool_1              F3
# 2034  fullCyc2_lib6  fullCyc2_lib6_Pool_1              G3
# 2046  fullCyc2_lib6  fullCyc2_lib6_Pool_1              H3
# 2057  fullCyc2_lib6  fullCyc2_lib6_Pool_1              A4
# 2068  fullCyc2_lib6  fullCyc2_lib6_Pool_1              B4
# 2080  fullCyc2_lib6  fullCyc2_lib6_Pool_1              C4
# 2092  fullCyc2_lib6  fullCyc2_lib6_Pool_1              D4
# 2104  fullCyc2_lib6  fullCyc2_lib6_Pool_1              E4
# 2116  fullCyc2_lib6  fullCyc2_lib6_Pool_1              F4
# 2128  fullCyc2_lib6  fullCyc2_lib6_Pool_1              G4
# 2140  fullCyc2_lib6  fullCyc2_lib6_Pool_1              H4
# 2152  fullCyc2_lib6  fullCyc2_lib6_Pool_1              A5
# 2164  fullCyc2_lib6  fullCyc2_lib6_Pool_1              B5
# 2176  fullCyc2_lib6  fullCyc2_lib6_Pool_1              C5
# 2188  fullCyc2_lib6  fullCyc2_lib6_Pool_1              D5
# 2200  fullCyc2_lib6  fullCyc2_lib6_Pool_1              E5
# 2212  fullCyc2_lib6  fullCyc2_lib6_Pool_1              F5
# 2224  fullCyc2_lib6  fullCyc2_lib6_Pool_1              G5
# 2235  fullCyc2_lib6  fullCyc2_lib6_Pool_1              F9
# 2247  fullCyc2_lib6  fullCyc2_lib6_Pool_1             H10
# 2259  fullCyc2_lib6  fullCyc2_lib6_Pool_2              A1
# 2271  fullCyc2_lib6  fullCyc2_lib6_Pool_2              H2
# 2283  fullCyc2_lib6  fullCyc2_lib6_Pool_2              A3
# 2292  fullCyc2_lib6  fullCyc2_lib6_Pool_2             A12
#
#                   soil_ID substrate   day     ...       \
# 8     MR.M.13C-Pal.D30.R1   13C-Pal  30.0     ...
# 21    MR.M.13C-Pal.D30.R1   13C-Pal  30.0     ...
# 34    MR.M.13C-Pal.D30.R1   13C-Pal  30.0     ...
# 47    MR.M.13C-Pal.D30.R1   13C-Pal  30.0     ...
# 60    MR.M.13C-Pal.D30.R1   13C-Pal  30.0     ...
# 73    MR.M.13C-Pal.D30.R1   13C-Pal   NaN     ...
# 86    MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 100   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 114   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 128   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 142   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 155   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 168   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 181   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 194   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 207   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 219   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 231   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 243   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 255   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 267   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 279   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 291   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 303   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 315   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 327   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 339   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 352   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 365   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 378   MR.F.13C-Ami.D14.R1   13C-Ami  14.0     ...
# ...                   ...       ...   ...     ...
# 1950  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 1962  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 1974  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 1986  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 1998  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2010  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2022  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2034  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2046  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2057  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2068  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2080  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2092  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2104  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2116  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2128  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2140  MR.M.13C-Pal.D14.R2   13C-Pal  14.0     ...
# 2152  MR.M.13C-Pal.D14.R2   13C-Pal   NaN     ...
# 2164  MR.M.13C-Pal.D14.R2   13C-Pal   NaN     ...
# 2176   MR.A.13C-Ami.D6.R1   13C-Ami   6.0     ...
# 2188   MR.A.13C-Ami.D6.R1   13C-Ami   6.0     ...
# 2200   MR.A.13C-Ami.D6.R1   13C-Ami   6.0     ...
# 2212   MR.A.13C-Ami.D6.R1   13C-Ami   6.0     ...
# 2224   MR.A.13C-Ami.D6.R1   13C-Ami   6.0     ...
# 2235   MR.A.13C-Xyl.D3.R2   13C-Xyl   3.0     ...
# 2247   MR.A.13C-Xyl.D3.R2   13C-Xyl   3.0     ...
# 2259  MR.A.13C-Van.D14.R2   13C-Van  14.0     ...
# 2271  MR.M.13C-Pal.D30.R1   13C-Pal  30.0     ...
# 2283  MR.M.13C-Pal.D30.R1   13C-Pal  30.0     ...
# 2292   MR.F.13C-Xyl.D1.R2   13C-Xyl   NaN     ...
#
#       water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 8                             NaN        NaN        NaN        NaN        NaN
# 21                            NaN        NaN        NaN        NaN        NaN
# 34                            NaN        NaN        NaN        NaN        NaN
# 47                            NaN        NaN        NaN        NaN        NaN
# 60                            NaN        NaN        NaN        NaN        NaN
# 73                            NaN        NaN        NaN        NaN        NaN
# 86                            NaN        NaN        NaN        NaN        NaN
# 100                           NaN        NaN        NaN        NaN        NaN
# 114                           NaN        NaN        NaN        NaN        NaN
# 128                           NaN        NaN        NaN        NaN        NaN
# 142                           NaN        NaN        NaN        NaN        NaN
# 155                           NaN        NaN        NaN        NaN        NaN
# 168                           NaN        NaN        NaN        NaN        NaN
# 181                           NaN        NaN        NaN        NaN        NaN
# 194                           NaN        NaN        NaN        NaN        NaN
# 207                           NaN        NaN        NaN        NaN        NaN
# 219                           NaN        NaN        NaN        NaN        NaN
# 231                           NaN        NaN        NaN        NaN        NaN
# 243                           NaN        NaN        NaN        NaN        NaN
# 255                           NaN        NaN        NaN        NaN        NaN
# 267                           NaN        NaN        NaN        NaN        NaN
# 279                           NaN        NaN        NaN        NaN        NaN
# 291                           NaN        NaN        NaN        NaN        NaN
# 303                           NaN        NaN        NaN        NaN        NaN
# 315                           NaN        NaN        NaN        NaN        NaN
# 327                           NaN        NaN        NaN        NaN        NaN
# 339                           NaN        NaN        NaN        NaN        NaN
# 352                           NaN        NaN        NaN        NaN        NaN
# 365                           NaN        NaN        NaN        NaN        NaN
# 378                           NaN        NaN        NaN        NaN        NaN
# ...                           ...        ...        ...        ...        ...
# 1950                          NaN        NaN        NaN        NaN        NaN
# 1962                          NaN        NaN        NaN        NaN        NaN
# 1974                          NaN        NaN        NaN        NaN        NaN
# 1986                          NaN        NaN        NaN        NaN        NaN
# 1998                          NaN        NaN        NaN        NaN        NaN
# 2010                          NaN        NaN        NaN        NaN        NaN
# 2022                          NaN        NaN        NaN        NaN        NaN
# 2034                          NaN        NaN        NaN        NaN        NaN
# 2046                          NaN        NaN        NaN        NaN        NaN
# 2057                          NaN        NaN        NaN        NaN        NaN
# 2068                          NaN        NaN        NaN        NaN        NaN
# 2080                          NaN        NaN        NaN        NaN        NaN
# 2092                          NaN        NaN        NaN        NaN        NaN
# 2104                          NaN        NaN        NaN        NaN        NaN
# 2116                          NaN        NaN        NaN        NaN        NaN
# 2128                          NaN        NaN        NaN        NaN        NaN
# 2140                          NaN        NaN        NaN        NaN        NaN
# 2152                          NaN        NaN        NaN        NaN        NaN
# 2164                          NaN        NaN        NaN        NaN        NaN
# 2176                          NaN        NaN        NaN        NaN        NaN
# 2188                          NaN        NaN        NaN        NaN        NaN
# 2200                          NaN        NaN        NaN        NaN        NaN
# 2212                          NaN        NaN        NaN        NaN        NaN
# 2224                          NaN        NaN        NaN        NaN        NaN
# 2235                          NaN        NaN        NaN        NaN        NaN
# 2247                          NaN        NaN        NaN        NaN        NaN
# 2259                          NaN        NaN        NaN        NaN        NaN
# 2271                          NaN        NaN        NaN        NaN        NaN
# 2283                          NaN        NaN        NaN        NaN        NaN
# 2292                          NaN        NaN        NaN        NaN        NaN
#
#      clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 8           NaN           2.187   NaN     CTACTATA     CGTACTCA
# 21          NaN           1.065   NaN     CGTTACTA     CGTACTCA
# 34          NaN           0.829   NaN     AGAGTCAC     CGTACTCA
# 47          NaN           0.566   NaN     TACGAGAC     CGTACTCA
# 60          NaN           0.468   NaN     ACGTCTCG     CGTACTCA
# 73          NaN             NaN   NaN     TCGACGAG     CGTACTCA
# 86          NaN           0.132   NaN     GATCGTGT     CGTACTCA
# 100         NaN           0.132   NaN     GTCAGATA     CGTACTCA
# 114         NaN           0.127   NaN     CTACTATA     CTACGCAG
# 128         NaN           0.141   NaN     CGTTACTA     CTACGCAG
# 142         NaN           0.164   NaN     AGAGTCAC     CTACGCAG
# 155         NaN           0.279   NaN     TACGAGAC     CTACGCAG
# 168         NaN           0.509   NaN     ACGTCTCG     CTACGCAG
# 181         NaN           0.622   NaN     TCGACGAG     CTACGCAG
# 194         NaN           0.981   NaN     GATCGTGT     CTACGCAG
# 207         NaN           2.773   NaN     GTCAGATA     CTACGCAG
# 219         NaN           6.863   NaN     CTACTATA     GGAGACTA
# 231         NaN          14.277   NaN     CGTTACTA     GGAGACTA
# 243         NaN          31.665   NaN     AGAGTCAC     GGAGACTA
# 255         NaN          18.149   NaN     TACGAGAC     GGAGACTA
# 267         NaN          23.271   NaN     ACGTCTCG     GGAGACTA
# 279         NaN          17.529   NaN     TCGACGAG     GGAGACTA
# 291         NaN           8.274   NaN     GATCGTGT     GGAGACTA
# 303         NaN           5.005   NaN     GTCAGATA     GGAGACTA
# 315         NaN           2.905   NaN     CTACTATA     GTCGCTCG
# 327         NaN           1.569   NaN     CGTTACTA     GTCGCTCG
# 339         NaN           1.198   NaN     AGAGTCAC     GTCGCTCG
# 352         NaN           0.625   NaN     TACGAGAC     GTCGCTCG
# 365         NaN           0.428   NaN     ACGTCTCG     GTCGCTCG
# 378         NaN           0.344   NaN     TCGACGAG     GTCGCTCG
# ...         ...             ...   ...          ...          ...
# 1950        NaN           0.493   NaN     GACACCGT     ACTATGTC
# 1962        NaN           0.833   NaN     ATCGTACG     AGTAGCGT
# 1974        NaN           1.512   NaN     ACTATCTG     AGTAGCGT
# 1986        NaN          10.078   NaN     TAGCGAGT     AGTAGCGT
# 1998        NaN          32.053   NaN     CTGCGTGT     AGTAGCGT
# 2010        NaN          65.376   NaN     TCATCGAG     AGTAGCGT
# 2022        NaN          58.846   NaN     CGTGAGTG     AGTAGCGT
# 2034        NaN          41.288   NaN     GGATATCT     AGTAGCGT
# 2046        NaN          20.252   NaN     GACACCGT     AGTAGCGT
# 2057        NaN          10.707   NaN     ATCGTACG     CAGTGAGT
# 2068        NaN           5.516   NaN     ACTATCTG     CAGTGAGT
# 2080        NaN           4.053   NaN     TAGCGAGT     CAGTGAGT
# 2092        NaN            3.18   NaN     CTGCGTGT     CAGTGAGT
# 2104        NaN           2.565   NaN     TCATCGAG     CAGTGAGT
# 2116        NaN           0.837   NaN     CGTGAGTG     CAGTGAGT
# 2128        NaN           0.623   NaN     GGATATCT     CAGTGAGT
# 2140        NaN           0.448   NaN     GACACCGT     CAGTGAGT
# 2152        NaN             NaN   NaN     ATCGTACG     CGTACTCA
# 2164        NaN             NaN   NaN     ACTATCTG     CGTACTCA
# 2176        NaN           0.192   NaN     TAGCGAGT     CGTACTCA
# 2188        NaN           0.191   NaN     CTGCGTGT     CGTACTCA
# 2200        NaN           0.191   NaN     TCATCGAG     CGTACTCA
# 2212        NaN            0.25   NaN     CGTGAGTG     CGTACTCA
# 2224        NaN           0.305   NaN     GGATATCT     CGTACTCA
# 2235        NaN          13.844   NaN     CGTGAGTG     GTCGTAGT
# 2247        NaN           1.442   NaN     GACACCGT     TAGCAGAC
# 2259        NaN           7.914   NaN     CTACTATA     AACTCTCG
# 2271        NaN           0.302   NaN     GTCAGATA     ACTATGTC
# 2283        NaN           0.351   NaN     CTACTATA     AGTAGCGT
# 2292        NaN             NaN   NaN     CTACTATA     TCGCTATA
#
# [189 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 20 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 189

[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MR.M.13C-Pal.D30.R1_Frac24'),
#  ('tgagtacgcgttacta', 'MR.M.13C-Pal.D30.R1_Frac25'),
#  ('tgagtacgagagtcac', 'MR.M.13C-Pal.D30.R1_Frac26'),
#  ('tgagtacgtacgagac', 'MR.M.13C-Pal.D30.R1_Frac27'),
#  ('tgagtacgacgtctcg', 'MR.M.13C-Pal.D30.R1_Frac28'),
#  ('tgagtacgtcgacgag', 'MR.M.13C-Pal.D30.R1_NC'),
#  ('tgagtacggatcgtgt', 'MR.F.13C-Ami.D14.R1_Frac4'),
#  ('tgagtacggtcagata', 'MR.F.13C-Ami.D14.R1_Frac5'),
#  ('ctgcgtagctactata', 'MR.F.13C-Ami.D14.R1_Frac6'),
#  ('ctgcgtagcgttacta', 'MR.F.13C-Ami.D14.R1_Frac7'),
#  ('ctgcgtagagagtcac', 'MR.F.13C-Ami.D14.R1_Frac8'),
#  ('ctgcgtagtacgagac', 'MR.F.13C-Ami.D14.R1_Frac9'),
#  ('ctgcgtagacgtctcg', 'MR.F.13C-Ami.D14.R1_Frac10'),
#  ('ctgcgtagtcgacgag', 'MR.F.13C-Ami.D14.R1_Frac11'),
#  ('ctgcgtaggatcgtgt', 'MR.F.13C-Ami.D14.R1_Frac12'),
#  ('ctgcgtaggtcagata', 'MR.F.13C-Ami.D14.R1_Frac13'),
#  ('tagtctccctactata', 'MR.F.13C-Ami.D14.R1_Frac14'),
#  ('tagtctcccgttacta', 'MR.F.13C-Ami.D14.R1_Frac15'),
#  ('tagtctccagagtcac', 'MR.F.13C-Ami.D14.R1_Frac16'),
#  ('tagtctcctacgagac', 'MR.F.13C-Ami.D14.R1_Frac17'),
#  ('tagtctccacgtctcg', 'MR.F.13C-Ami.D14.R1_Frac18'),
#  ('tagtctcctcgacgag', 'MR.F.13C-Ami.D14.R1_Frac19'),
#  ('tagtctccgatcgtgt', 'MR.F.13C-Ami.D14.R1_Frac20'),
#  ('tagtctccgtcagata', 'MR.F.13C-Ami.D14.R1_Frac21'),
#  ('cgagcgacctactata', 'MR.F.13C-Ami.D14.R1_Frac22'),
#  ('cgagcgaccgttacta', 'MR.F.13C-Ami.D14.R1_Frac23'),
#  ('cgagcgacagagtcac', 'MR.F.13C-Ami.D14.R1_Frac24'),
#  ('cgagcgactacgagac', 'MR.F.13C-Ami.D14.R1_Frac25'),
#  ('cgagcgacacgtctcg', 'MR.F.13C-Ami.D14.R1_Frac26'),
#  ('cgagcgactcgacgag', 'MR.F.13C-Ami.D14.R1_Frac27'),
#  ('tgagtacggacaccgt', 'MR.A.13C-Ami.D6.R1_Frac9'),
#  ('ctgcgtagatcgtacg', 'MR.A.13C-Ami.D6.R1_Frac10'),
#  ('ctgcgtagactatctg', 'MR.A.13C-Ami.D6.R1_Frac11'),
#  ('ctgcgtagtagcgagt', 'MR.A.13C-Ami.D6.R1_Frac12'),
#  ('ctgcgtagctgcgtgt', 'MR.A.13C-Ami.D6.R1_Frac13'),
#  ('ctgcgtagtcatcgag', 'MR.A.13C-Ami.D6.R1_Frac14'),
#  ('ctgcgtagcgtgagtg', 'MR.A.13C-Ami.D6.R1_Frac15'),
#  ('ctgcgtagggatatct', 'MR.A.13C-Ami.D6.R1_Frac16'),
#  ('ctgcgtaggacaccgt', 'MR.A.13C-Ami.D6.R1_Frac17'),
#  ('tagtctccatcgtacg', 'MR.A.13C-Ami.D6.R1_Frac18'),
#  ('tagtctccactatctg', 'MR.A.13C-Ami.D6.R1_Frac19'),
#  ('tagtctcctagcgagt', 'MR.A.13C-Ami.D6.R1_Frac20'),
#  ('tagtctccctgcgtgt', 'MR.A.13C-Ami.D6.R1_Frac21'),
#  ('tagtctcctcatcgag', 'MR.A.13C-Ami.D6.R1_Frac22'),
#  ('tagtctcccgtgagtg', 'MR.A.13C-Ami.D6.R1_Frac23'),
#  ('tagtctccggatatct', 'MR.A.13C-Ami.D6.R1_Frac24'),
#  ('tagtctccgacaccgt', 'MR.A.13C-Ami.D6.R1_Frac25'),
#  ('cgagcgacatcgtacg', 'MR.A.13C-Ami.D6.R1_Frac26'),
#  ('cgagcgacactatctg', 'MR.A.13C-Ami.D6.R1_Frac27'),
#  ('cgagcgactagcgagt', 'MR.A.13C-Ami.D6.R1_NC'),
#  ('cgagcgacctgcgtgt', 'MR.A.13C-Xyl.D3.R2_Frac4'),
#  ('cgagcgactcatcgag', 'MR.A.13C-Xyl.D3.R2_Frac5'),
#  ('cgagcgaccgtgagtg', 'MR.A.13C-Xyl.D3.R2_Frac6'),
#  ('cgagcgacggatatct', 'MR.A.13C-Xyl.D3.R2_Frac7'),
#  ('cgagcgacgacaccgt', 'MR.A.13C-Xyl.D3.R2_Frac8'),
#  ('actacgacatcgtacg', 'MR.A.13C-Xyl.D3.R2_Frac9'),
#  ('actacgacactatctg', 'MR.A.13C-Xyl.D3.R2_Frac10'),
#  ('actacgactagcgagt', 'MR.A.13C-Xyl.D3.R2_Frac11'),
#  ('actacgacctgcgtgt', 'MR.A.13C-Xyl.D3.R2_Frac12'),
#  ('actacgactcatcgag', 'MR.A.13C-Xyl.D3.R2_Frac13'),
#  ('actacgacggatatct', 'MR.A.13C-Xyl.D3.R2_Frac15'),
#  ('actacgacgacaccgt', 'MR.A.13C-Xyl.D3.R2_Frac16'),
#  ('gtctgctaatcgtacg', 'MR.A.13C-Xyl.D3.R2_Frac17'),
#  ('gtctgctaactatctg', 'MR.A.13C-Xyl.D3.R2_Frac18'),
#  ('gtctgctatagcgagt', 'MR.A.13C-Xyl.D3.R2_Frac19'),
#  ('gtctgctactgcgtgt', 'MR.A.13C-Xyl.D3.R2_Frac20'),
#  ('gtctgctatcatcgag', 'MR.A.13C-Xyl.D3.R2_Frac21'),
#  ('gtctgctacgtgagtg', 'MR.A.13C-Xyl.D3.R2_Frac22'),
#  ('gtctgctaggatatct', 'MR.A.13C-Xyl.D3.R2_Frac23'),
#  ('gtctatgaatcgtacg', 'MR.A.13C-Xyl.D3.R2_Frac25'),
#  ('gtctatgaactatctg', 'MR.A.13C-Xyl.D3.R2_Frac26'),
#  ('gtctatgatagcgagt', 'MR.A.13C-Xyl.D3.R2_Frac27'),
#  ('gtctatgactgcgtgt', 'MR.A.13C-Xyl.D3.R2_NC'),
#  ('gtctatgatcatcgag', 'MR.A.13C-Van.D14.R2_Frac2'),
#  ('gtctatgacgtgagtg', 'MR.A.13C-Van.D14.R2_Frac3'),
#  ('gtctatgaggatatct', 'MR.A.13C-Van.D14.R2_Frac4'),
#  ('gtctatgagacaccgt', 'MR.A.13C-Van.D14.R2_Frac5'),
#  ('tatagcgaatcgtacg', 'MR.A.13C-Van.D14.R2_Frac6'),
#  ('tatagcgaactatctg', 'MR.A.13C-Van.D14.R2_Frac7'),
#  ('tatagcgatagcgagt', 'MR.A.13C-Van.D14.R2_Frac8'),
#  ('tatagcgactgcgtgt', 'MR.A.13C-Van.D14.R2_Frac9'),
#  ('tatagcgatcatcgag', 'MR.A.13C-Van.D14.R2_Frac10'),
#  ('tatagcgacgtgagtg', 'MR.A.13C-Van.D14.R2_Frac11'),
#  ('tatagcgaggatatct', 'MR.A.13C-Van.D14.R2_Frac12'),
#  ('tatagcgagacaccgt', 'MR.A.13C-Van.D14.R2_Frac13'),
#  ('cgagagttcgttacta', 'MR.A.13C-Van.D14.R2_Frac15'),
#  ('cgagagttagagtcac', 'MR.A.13C-Van.D14.R2_Frac16'),
#  ('cgagagtttacgagac', 'MR.A.13C-Van.D14.R2_Frac17'),
#  ('cgagagttacgtctcg', 'MR.A.13C-Van.D14.R2_Frac18'),
#  ('cgagagtttcgacgag', 'MR.A.13C-Van.D14.R2_Frac19'),
#  ('cgagagttgatcgtgt', 'MR.A.13C-Van.D14.R2_Frac20'),
#  ('cgagagttgtcagata', 'MR.A.13C-Van.D14.R2_Frac21'),
#  ('gacatagtctactata', 'MR.A.13C-Van.D14.R2_Frac22'),
#  ('gacatagtcgttacta', 'MR.A.13C-Van.D14.R2_Frac23'),
#  ('gacatagtagagtcac', 'MR.A.13C-Van.D14.R2_Frac24'),
#  ('gacatagttacgagac', 'MR.A.13C-Van.D14.R2_Frac25'),
#  ('gacatagtacgtctcg', 'MR.A.13C-Van.D14.R2_Frac26'),
#  ('gacatagttcgacgag', 'MR.A.13C-Van.D14.R2_NC'),
#  ('gacatagtgatcgtgt', 'MR.M.13C-Pal.D30.R1_Frac6'),
#  ('acgctactcgttacta', 'MR.M.13C-Pal.D30.R1_Frac9'),
#  ('acgctactagagtcac', 'MR.M.13C-Pal.D30.R1_Frac10'),
#  ('acgctacttacgagac', 'MR.M.13C-Pal.D30.R1_Frac11'),
#  ('acgctactacgtctcg', 'MR.M.13C-Pal.D30.R1_Frac12'),
#  ('acgctacttcgacgag', 'MR.M.13C-Pal.D30.R1_Frac13'),
#  ('acgctactgatcgtgt', 'MR.M.13C-Pal.D30.R1_Frac14'),
#  ('acgctactgtcagata', 'MR.M.13C-Pal.D30.R1_Frac15'),
#  ('actcactgctactata', 'MR.M.13C-Pal.D30.R1_Frac16'),
#  ('actcactgcgttacta', 'MR.M.13C-Pal.D30.R1_Frac17'),
#  ('actcactgagagtcac', 'MR.M.13C-Pal.D30.R1_Frac18'),
#  ('actcactgtacgagac', 'MR.M.13C-Pal.D30.R1_Frac19'),
#  ('actcactgacgtctcg', 'MR.M.13C-Pal.D30.R1_Frac20'),
#  ('actcactgtcgacgag', 'MR.M.13C-Pal.D30.R1_Frac21'),
#  ('actcactggatcgtgt', 'MR.M.13C-Pal.D30.R1_Frac22'),
#  ('actcactggtcagata', 'MR.M.13C-Pal.D30.R1_Frac23'),
#  ('cgagcgacgatcgtgt', 'MR.F.13C-Ami.D14.R1_NC'),
#  ('cgagcgacgtcagata', 'MR.F.13C-Xyl.D1.R2_Frac4'),
#  ('actacgacctactata', 'MR.F.13C-Xyl.D1.R2_Frac5'),
#  ('actacgaccgttacta', 'MR.F.13C-Xyl.D1.R2_Frac6'),
#  ('actacgacagagtcac', 'MR.F.13C-Xyl.D1.R2_Frac7'),
#  ('actacgactacgagac', 'MR.F.13C-Xyl.D1.R2_Frac8'),
#  ('actacgacacgtctcg', 'MR.F.13C-Xyl.D1.R2_Frac9'),
#  ('actacgactcgacgag', 'MR.F.13C-Xyl.D1.R2_Frac10'),
#  ('actacgacgatcgtgt', 'MR.F.13C-Xyl.D1.R2_Frac11'),
#  ('actacgacgtcagata', 'MR.F.13C-Xyl.D1.R2_Frac12'),
#  ('gtctgctactactata', 'MR.F.13C-Xyl.D1.R2_Frac13'),
#  ('gtctgctacgttacta', 'MR.F.13C-Xyl.D1.R2_Frac14'),
#  ('gtctgctaagagtcac', 'MR.F.13C-Xyl.D1.R2_Frac15'),
#  ('gtctgctatacgagac', 'MR.F.13C-Xyl.D1.R2_Frac16'),
#  ('gtctgctaacgtctcg', 'MR.F.13C-Xyl.D1.R2_Frac17'),
#  ('gtctgctatcgacgag', 'MR.F.13C-Xyl.D1.R2_Frac18'),
#  ('gtctgctagatcgtgt', 'MR.F.13C-Xyl.D1.R2_Frac19'),
#  ('gtctgctagtcagata', 'MR.F.13C-Xyl.D1.R2_Frac20'),
#  ('gtctatgactactata', 'MR.F.13C-Xyl.D1.R2_Frac21'),
#  ('gtctatgacgttacta', 'MR.F.13C-Xyl.D1.R2_Frac22'),
#  ('gtctatgaagagtcac', 'MR.F.13C-Xyl.D1.R2_Frac23'),
#  ('gtctatgatacgagac', 'MR.F.13C-Xyl.D1.R2_Frac24'),
#  ('gtctatgaacgtctcg', 'MR.F.13C-Xyl.D1.R2_Frac25'),
#  ('gtctatgatcgacgag', 'MR.F.13C-Xyl.D1.R2_Frac26'),
#  ('gtctatgagatcgtgt', 'MR.F.13C-Xyl.D1.R2_Frac27'),
#  ('gtctatgagtcagata', 'MR.F.13C-Xyl.D1.R2_Frac28'),
#  ('tatagcgacgttacta', 'MR.A.13C-Van.D30.R3_Frac14'),
#  ('tatagcgaagagtcac', 'MR.A.13C-Van.D30.R3_Frac15'),
#  ('tatagcgatacgagac', 'MR.A.13C-Van.D30.R3_Frac16'),
#  ('tatagcgaacgtctcg', 'MR.A.13C-Van.D30.R3_NC'),
#  ('cgagagttatcgtacg', 'MR.F.13C-Pal.D14.R1_Frac20'),
#  ('cgagagttactatctg', 'MR.F.13C-Pal.D14.R1_Frac21'),
#  ('cgagagtttagcgagt', 'MR.F.13C-Pal.D14.R1_Frac22'),
#  ('cgagagttctgcgtgt', 'MR.F.13C-Pal.D14.R1_Frac23'),
#  ('cgagagtttcatcgag', 'MR.F.13C-Pal.D14.R1_Frac24'),
#  ('cgagagttcgtgagtg', 'MR.F.13C-Pal.D14.R1_Frac25'),
#  ('cgagagttggatatct', 'MR.F.13C-Pal.D14.R1_Frac26'),
#  ('cgagagttgacaccgt', 'MR.F.13C-Pal.D14.R1_Frac27'),
#  ('gacatagtatcgtacg', 'MR.F.13C-Pal.D14.R1_NC'),
#  ('gacatagtactatctg', 'MR.M.13C-Pal.D14.R2_Frac5'),
#  ('gacatagttagcgagt', 'MR.M.13C-Pal.D14.R2_Frac6'),
#  ('gacatagtctgcgtgt', 'MR.M.13C-Pal.D14.R2_Frac7'),
#  ('gacatagttcatcgag', 'MR.M.13C-Pal.D14.R2_Frac8'),
#  ('gacatagtcgtgagtg', 'MR.M.13C-Pal.D14.R2_Frac9'),
#  ('gacatagtggatatct', 'MR.M.13C-Pal.D14.R2_Frac10'),
#  ('gacatagtgacaccgt', 'MR.M.13C-Pal.D14.R2_Frac11'),
#  ('acgctactatcgtacg', 'MR.M.13C-Pal.D14.R2_Frac12'),
#  ('acgctactactatctg', 'MR.M.13C-Pal.D14.R2_Frac13'),
#  ('acgctacttagcgagt', 'MR.M.13C-Pal.D14.R2_Frac14'),
#  ('acgctactctgcgtgt', 'MR.M.13C-Pal.D14.R2_Frac15'),
#  ('acgctacttcatcgag', 'MR.M.13C-Pal.D14.R2_Frac16'),
#  ('acgctactcgtgagtg', 'MR.M.13C-Pal.D14.R2_Frac17'),
#  ('acgctactggatatct', 'MR.M.13C-Pal.D14.R2_Frac18'),
#  ('acgctactgacaccgt', 'MR.M.13C-Pal.D14.R2_Frac19'),
#  ('actcactgatcgtacg', 'MR.M.13C-Pal.D14.R2_Frac20'),
#  ('actcactgactatctg', 'MR.M.13C-Pal.D14.R2_Frac21'),
#  ('actcactgtagcgagt', 'MR.M.13C-Pal.D14.R2_Frac22'),
#  ('actcactgctgcgtgt', 'MR.M.13C-Pal.D14.R2_Frac23'),
#  ('actcactgtcatcgag', 'MR.M.13C-Pal.D14.R2_Frac24'),
#  ('actcactgcgtgagtg', 'MR.M.13C-Pal.D14.R2_Frac25'),
#  ('actcactgggatatct', 'MR.M.13C-Pal.D14.R2_Frac26'),
#  ('actcactggacaccgt', 'MR.M.13C-Pal.D14.R2_Frac27'),
#  ('tgagtacgatcgtacg', 'MR.M.13C-Pal.D14.R2_NC'),
#  ('tgagtacgactatctg', 'MR.M.13C-Pal.D14.R2_MC'),
#  ('tgagtacgtagcgagt', 'MR.A.13C-Ami.D6.R1_Frac4'),
#  ('tgagtacgctgcgtgt', 'MR.A.13C-Ami.D6.R1_Frac5'),
#  ('tgagtacgtcatcgag', 'MR.A.13C-Ami.D6.R1_Frac6'),
#  ('tgagtacgcgtgagtg', 'MR.A.13C-Ami.D6.R1_Frac7'),
#  ('tgagtacgggatatct', 'MR.A.13C-Ami.D6.R1_Frac8'),
#  ('actacgaccgtgagtg', 'MR.A.13C-Xyl.D3.R2_Frac14'),
#  ('gtctgctagacaccgt', 'MR.A.13C-Xyl.D3.R2_Frac24'),
#  ('cgagagttctactata', 'MR.A.13C-Van.D14.R2_Frac14'),
#  ('gacatagtgtcagata', 'MR.M.13C-Pal.D30.R1_Frac7'),
#  ('acgctactctactata', 'MR.M.13C-Pal.D30.R1_Frac8'),
#  ('tatagcgactactata', 'MR.F.13C-Xyl.D1.R2_NC')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 3597192 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 5071111.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                          Sample  seq_count
# 0     MR.A.13C-Xyl.D3.R2_Frac19      36097
# 1    MR.A.13C-Van.D30.R3_Frac14      29960
# 2    MR.A.13C-Van.D14.R2_Frac26      25960
# 3    MR.F.13C-Pal.D14.R1_Frac21      47396
# 4     MR.A.13C-Ami.D6.R1_Frac10      34475
# 5     MR.F.13C-Xyl.D1.R2_Frac14      18034
# 6    MR.M.13C-Pal.D30.R1_Frac26      19860
# 7     MR.M.13C-Pal.D14.R2_Frac6      39809
# 8     MR.A.13C-Ami.D6.R1_Frac17      42039
# 9    MR.F.13C-Pal.D14.R1_Frac22      36618
# 10     MR.A.13C-Ami.D6.R1_Frac4      41395
# 11   MR.F.13C-Ami.D14.R1_Frac12      23652
# 12    MR.A.13C-Ami.D6.R1_Frac24      19809
# 13     MR.A.13C-Ami.D6.R1_Frac5      32464
# 14     MR.A.13C-Ami.D6.R1_Frac7      36306
# 15    MR.M.13C-Pal.D14.R2_Frac8      27970
# 16   MR.F.13C-Pal.D14.R1_Frac24      24067
# 17   MR.M.13C-Pal.D14.R2_Frac27      30579
# 18   MR.M.13C-Pal.D30.R1_Frac27      29158
# 19    MR.A.13C-Ami.D6.R1_Frac12      52575
# 20    MR.A.13C-Ami.D6.R1_Frac27      23467
# 21   MR.F.13C-Pal.D14.R1_Frac20      35856
# 22    MR.F.13C-Ami.D14.R1_Frac6      29565
# 23    MR.A.13C-Xyl.D3.R2_Frac10      36733
# 24    MR.A.13C-Van.D14.R2_Frac9      24778
# 25   MR.M.13C-Pal.D30.R1_Frac15      36925
# 26   MR.A.13C-Van.D14.R2_Frac12      23784
# 27   MR.M.13C-Pal.D14.R2_Frac15      29466
# 28    MR.A.13C-Xyl.D3.R2_Frac21      21297
# 29    MR.A.13C-Ami.D6.R1_Frac19      22262
# ..                          ...        ...
# 159  MR.M.13C-Pal.D30.R1_Frac19      29767
# 160      MR.F.13C-Pal.D14.R1_NC       1748
# 161  MR.F.13C-Ami.D14.R1_Frac21      17083
# 162   MR.A.13C-Ami.D6.R1_Frac26      29145
# 163  MR.M.13C-Pal.D14.R2_Frac10      25903
# 164   MR.A.13C-Ami.D6.R1_Frac22      21390
# 165  MR.M.13C-Pal.D14.R2_Frac20      17230
# 166  MR.A.13C-Van.D14.R2_Frac15      23904
# 167  MR.M.13C-Pal.D30.R1_Frac17      23061
# 168  MR.F.13C-Pal.D14.R1_Frac26      41139
# 169  MR.M.13C-Pal.D30.R1_Frac25      14843
# 170   MR.F.13C-Xyl.D1.R2_Frac15      19811
# 171   MR.A.13C-Xyl.D3.R2_Frac23      14143
# 172   MR.A.13C-Xyl.D3.R2_Frac24      20530
# 173  MR.M.13C-Pal.D30.R1_Frac22      36112
# 174      MR.M.13C-Pal.D30.R1_NC       2817
# 175   MR.A.13C-Xyl.D3.R2_Frac13      38165
# 176  MR.M.13C-Pal.D30.R1_Frac18      17539
# 177   MR.F.13C-Ami.D14.R1_Frac8      22670
# 178  MR.M.13C-Pal.D30.R1_Frac11      34115
# 179   MR.A.13C-Van.D14.R2_Frac5      32060
# 180       MR.A.13C-Ami.D6.R1_NC        955
# 181  MR.M.13C-Pal.D30.R1_Frac23      20444
# 182      MR.F.13C-Ami.D14.R1_NC        819
# 183  MR.F.13C-Ami.D14.R1_Frac24      16425
# 184       MR.A.13C-Xyl.D3.R2_NC        597
# 185      MR.A.13C-Van.D30.R3_NC       2362
# 186      MR.M.13C-Pal.D14.R2_NC        781
# 187       MR.F.13C-Xyl.D1.R2_NC        976
# 188      MR.A.13C-Van.D14.R2_NC        821
#
# [189 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 10000,]
# Out:
#                         Sample seq_count
# 127 MR.M.13C-Pal.D14.R2_Frac11      4926
# 160     MR.F.13C-Pal.D14.R1_NC      1748
# 174     MR.M.13C-Pal.D30.R1_NC      2817
# 180      MR.A.13C-Ami.D6.R1_NC       955
# 182     MR.F.13C-Ami.D14.R1_NC       819
# 184      MR.A.13C-Xyl.D3.R2_NC       597
# 185     MR.A.13C-Van.D30.R3_NC      2362
# 186     MR.M.13C-Pal.D14.R2_NC       781
# 187      MR.F.13C-Xyl.D1.R2_NC       976
# 188     MR.A.13C-Van.D14.R2_NC       821

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 189 samples
# You should have 189 samples
