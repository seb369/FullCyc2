# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/160506_FC2Grad_1'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/160506_FC2Grad_1'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = '160506_FC2Grad_1'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-160506_FC2Grad_1.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/160506_FC2Grad_1

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                             #Sample  primer_number exp_type  \
# 3         MR.M.13C-Xyl.D3.R1_Frac21            129      SIP
# 16        MR.M.13C-Xyl.D3.R1_Frac22            130      SIP
# 29        MR.M.13C-Xyl.D3.R1_Frac23            131      SIP
# 42        MR.M.13C-Xyl.D3.R1_Frac24            132      SIP
# 55        MR.M.13C-Xyl.D3.R1_Frac25            133      SIP
# 68        MR.M.13C-Xyl.D3.R1_Frac26            134      SIP
# 81        MR.M.13C-Xyl.D3.R1_Frac27            135      SIP
# 95        MR.M.13C-Xyl.D3.R1_Frac28            136      SIP
# 109           MR.M.13C-Xyl.D3.R1_NC            137      SIP
# 123       MR.F.13C-Van.D14.R2_Frac5            138      SIP
# 137       MR.F.13C-Van.D14.R2_Frac6            139      SIP
# 150       MR.F.13C-Van.D14.R2_Frac7            140      SIP
# 163       MR.F.13C-Van.D14.R2_Frac8            141      SIP
# 177       MR.F.13C-Van.D14.R2_Frac9            142      SIP
# 190      MR.F.13C-Van.D14.R2_Frac11            144      SIP
# 203      MR.F.13C-Van.D14.R2_Frac12            145      SIP
# 215      MR.F.13C-Van.D14.R2_Frac13            146      SIP
# 227      MR.F.13C-Van.D14.R2_Frac14            147      SIP
# 239      MR.F.13C-Van.D14.R2_Frac15            148      SIP
# 251      MR.F.13C-Van.D14.R2_Frac16            149      SIP
# 263      MR.F.13C-Van.D14.R2_Frac17            150      SIP
# 275      MR.F.13C-Van.D14.R2_Frac18            151      SIP
# 287      MR.F.13C-Van.D14.R2_Frac19            152      SIP
# 299      MR.F.13C-Van.D14.R2_Frac20            153      SIP
# 311      MR.F.13C-Van.D14.R2_Frac21            154      SIP
# 323      MR.F.13C-Van.D14.R2_Frac22            155      SIP
# 335      MR.F.13C-Van.D14.R2_Frac23            156      SIP
# 348      MR.F.13C-Van.D14.R2_Frac24            157      SIP
# 361      MR.F.13C-Van.D14.R2_Frac25            158      SIP
# 977        MR.F.13C-Ami.D1.R1_Frac5             91      SIP
# ...                             ...            ...      ...
# 1453     MR.F.13C-Van.D14.R2_Frac27            160      SIP
# 1464         MR.F.13C-Van.D14.R2_NC            161      SIP
# 1476       MR.F.13C-Ami.D3.R2_Frac6            162      SIP
# 1488       MR.F.13C-Ami.D3.R2_Frac7            163      SIP
# 1500       MR.F.13C-Ami.D3.R2_Frac8            164      SIP
# 1512       MR.F.13C-Ami.D3.R2_Frac9            165      SIP
# 1524      MR.F.13C-Ami.D3.R2_Frac10            166      SIP
# 1536      MR.F.13C-Ami.D3.R2_Frac11            167      SIP
# 1548      MR.F.13C-Ami.D3.R2_Frac12            168      SIP
# 1560      MR.F.13C-Ami.D3.R2_Frac13            169      SIP
# 1572      MR.F.13C-Ami.D3.R2_Frac14            170      SIP
# 1583      MR.F.13C-Ami.D3.R2_Frac15            171      SIP
# 1595      MR.F.13C-Ami.D3.R2_Frac16            172      SIP
# 1606      MR.F.13C-Ami.D3.R2_Frac17            173      SIP
# 1617      MR.F.13C-Ami.D3.R2_Frac18            174      SIP
# 1628      MR.F.13C-Ami.D3.R2_Frac19            175      SIP
# 1639      MR.F.13C-Ami.D3.R2_Frac20            176      SIP
# 1650      MR.F.13C-Ami.D3.R2_Frac21            177      SIP
# 1660      MR.F.13C-Ami.D3.R2_Frac22            178      SIP
# 1670      MR.F.13C-Ami.D3.R2_Frac23            179      SIP
# 1680      MR.F.13C-Ami.D3.R2_Frac24            180      SIP
# 1690      MR.F.13C-Ami.D3.R2_Frac25            181      SIP
# 1700      MR.F.13C-Ami.D3.R2_Frac26            182      SIP
# 1709  MR.F.13C-Ami.D3.R2_Frac27_bad            183      SIP
# 1718      MR.F.13C-Ami.D3.R2_Frac28            184      SIP
# 1727          MR.F.13C-Ami.D3.R2_NC            186      SIP
# 2253      MR.F.13C-Ami.D1.R1_Frac11             97      SIP
# 2265          MR.F.13C-Ami.D1.R1_NC            112      SIP
# 2277          MR.F.13C-Ami.D1.R1_MC            113      SIP
# 2289      MR.F.13C-Ami.D3.R2_Frac29            185      SIP
#
#      extraction_plate_ID        library_ID        pool_plate_ID  \
# 3                    NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 16                   NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 29                   NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 42                   NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 55                   NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 68                   NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 81                   NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 95                   NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 109                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 123                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 137                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 150                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 163                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 177                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 190                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 203                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 215                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 227                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 239                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 251                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 263                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 275                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 287                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 299                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 311                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 323                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 335                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 348                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 361                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 977                  NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# ...                  ...               ...                  ...
# 1453                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1464                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1476                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1488                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1500                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1512                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1524                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1536                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1548                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1560                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1572                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1583                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1595                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1606                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1617                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1628                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1639                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1650                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1660                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1670                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1680                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1690                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1700                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1709                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1718                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 1727                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 2253                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 2265                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 2277                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
# 2289                 NaN  160506_FC2Grad_1  Andrew_Pool_Plate_1
#
#      pool_plate_well              soil_ID substrate   day     ...       \
# 3                 G5   MR.M.13C-Xyl.D3.R1   13C-Xyl   3.0     ...
# 16                H5   MR.M.13C-Xyl.D3.R1   13C-Xyl   3.0     ...
# 29                A6   MR.M.13C-Xyl.D3.R1   13C-Xyl   3.0     ...
# 42                B6   MR.M.13C-Xyl.D3.R1   13C-Xyl   3.0     ...
# 55                C6   MR.M.13C-Xyl.D3.R1   13C-Xyl   3.0     ...
# 68                D6   MR.M.13C-Xyl.D3.R1   13C-Xyl   3.0     ...
# 81                E6   MR.M.13C-Xyl.D3.R1   13C-Xyl   3.0     ...
# 95                F6   MR.M.13C-Xyl.D3.R1   13C-Xyl   3.0     ...
# 109               G6   MR.M.13C-Xyl.D3.R1   13C-Xyl   NaN     ...
# 123               H6  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 137               A7  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 150               B7  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 163               C7  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 177               D7  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 190               F7  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 203               G7  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 215               H7  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 227               A8  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 239               B8  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 251               C8  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 263               D8  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 275               E8  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 287               F8  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 299               G8  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 311               H8  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 323               A9  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 335               B9  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 348               C9  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 361               D9  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 977               A1   MR.F.13C-Ami.D1.R1   13C-Ami   1.0     ...
# ...              ...                  ...       ...   ...     ...
# 1453              F9  MR.F.13C-Van.D14.R2   13C-Van  14.0     ...
# 1464              G9  MR.F.13C-Van.D14.R2   13C-Van   NaN     ...
# 1476              H9   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1488             A10   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1500             B10   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1512             C10   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1524             D10   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1536             E10   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1548             F10   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1560             G10   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1572             H10   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1583             A11   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1595             B11   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1606             C11   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1617             D11   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1628             E11   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1639             F11   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1650             G11   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1660             H11   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1670             A12   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1680             B12   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1690             C12   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1700             D12   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1709             E12   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1718             F12   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
# 1727             H12   MR.F.13C-Ami.D3.R2   13C-Ami   NaN     ...
# 2253              G1   MR.F.13C-Ami.D1.R1   13C-Ami   1.0     ...
# 2265              F3   MR.F.13C-Ami.D1.R1   13C-Ami   NaN     ...
# 2277              G3   MR.F.13C-Ami.D1.R1   13C-Ami   NaN     ...
# 2289             G12   MR.F.13C-Ami.D3.R2   13C-Ami   3.0     ...
#
#       water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 3                             NaN        NaN        NaN        NaN        NaN
# 16                            NaN        NaN        NaN        NaN        NaN
# 29                            NaN        NaN        NaN        NaN        NaN
# 42                            NaN        NaN        NaN        NaN        NaN
# 55                            NaN        NaN        NaN        NaN        NaN
# 68                            NaN        NaN        NaN        NaN        NaN
# 81                            NaN        NaN        NaN        NaN        NaN
# 95                            NaN        NaN        NaN        NaN        NaN
# 109                           NaN        NaN        NaN        NaN        NaN
# 123                           NaN        NaN        NaN        NaN        NaN
# 137                           NaN        NaN        NaN        NaN        NaN
# 150                           NaN        NaN        NaN        NaN        NaN
# 163                           NaN        NaN        NaN        NaN        NaN
# 177                           NaN        NaN        NaN        NaN        NaN
# 190                           NaN        NaN        NaN        NaN        NaN
# 203                           NaN        NaN        NaN        NaN        NaN
# 215                           NaN        NaN        NaN        NaN        NaN
# 227                           NaN        NaN        NaN        NaN        NaN
# 239                           NaN        NaN        NaN        NaN        NaN
# 251                           NaN        NaN        NaN        NaN        NaN
# 263                           NaN        NaN        NaN        NaN        NaN
# 275                           NaN        NaN        NaN        NaN        NaN
# 287                           NaN        NaN        NaN        NaN        NaN
# 299                           NaN        NaN        NaN        NaN        NaN
# 311                           NaN        NaN        NaN        NaN        NaN
# 323                           NaN        NaN        NaN        NaN        NaN
# 335                           NaN        NaN        NaN        NaN        NaN
# 348                           NaN        NaN        NaN        NaN        NaN
# 361                           NaN        NaN        NaN        NaN        NaN
# 977                           NaN        NaN        NaN        NaN        NaN
# ...                           ...        ...        ...        ...        ...
# 1453                          NaN        NaN        NaN        NaN        NaN
# 1464                          NaN        NaN        NaN        NaN        NaN
# 1476                          NaN        NaN        NaN        NaN        NaN
# 1488                          NaN        NaN        NaN        NaN        NaN
# 1500                          NaN        NaN        NaN        NaN        NaN
# 1512                          NaN        NaN        NaN        NaN        NaN
# 1524                          NaN        NaN        NaN        NaN        NaN
# 1536                          NaN        NaN        NaN        NaN        NaN
# 1548                          NaN        NaN        NaN        NaN        NaN
# 1560                          NaN        NaN        NaN        NaN        NaN
# 1572                          NaN        NaN        NaN        NaN        NaN
# 1583                          NaN        NaN        NaN        NaN        NaN
# 1595                          NaN        NaN        NaN        NaN        NaN
# 1606                          NaN        NaN        NaN        NaN        NaN
# 1617                          NaN        NaN        NaN        NaN        NaN
# 1628                          NaN        NaN        NaN        NaN        NaN
# 1639                          NaN        NaN        NaN        NaN        NaN
# 1650                          NaN        NaN        NaN        NaN        NaN
# 1660                          NaN        NaN        NaN        NaN        NaN
# 1670                          NaN        NaN        NaN        NaN        NaN
# 1680                          NaN        NaN        NaN        NaN        NaN
# 1690                          NaN        NaN        NaN        NaN        NaN
# 1700                          NaN        NaN        NaN        NaN        NaN
# 1709                          NaN        NaN        NaN        NaN        NaN
# 1718                          NaN        NaN        NaN        NaN        NaN
# 1727                          NaN        NaN        NaN        NaN        NaN
# 2253                          NaN        NaN        NaN        NaN        NaN
# 2265                          NaN        NaN        NaN        NaN        NaN
# 2277                          NaN        NaN        NaN        NaN        NaN
# 2289                          NaN        NaN        NaN        NaN        NaN
#
#      clay__perc DNA_conc__ng_ul               notes  fwd_barcode  rev_barcode
# 3           NaN           8.626                 NaN     CTACTATA     CGTACTCA
# 16          NaN           4.842                 NaN     CGTTACTA     CGTACTCA
# 29          NaN           3.078                 NaN     AGAGTCAC     CGTACTCA
# 42          NaN            1.55                 NaN     TACGAGAC     CGTACTCA
# 55          NaN           1.311                 NaN     ACGTCTCG     CGTACTCA
# 68          NaN           0.857                 NaN     TCGACGAG     CGTACTCA
# 81          NaN           0.533                 NaN     GATCGTGT     CGTACTCA
# 95          NaN           0.221                 NaN     GTCAGATA     CGTACTCA
# 109         NaN             NaN                 NaN     CTACTATA     CTACGCAG
# 123         NaN          -1.453                 NaN     CGTTACTA     CTACGCAG
# 137         NaN          -1.436                 NaN     AGAGTCAC     CTACGCAG
# 150         NaN          -1.442                 NaN     TACGAGAC     CTACGCAG
# 163         NaN           -1.44                 NaN     ACGTCTCG     CTACGCAG
# 177         NaN           -1.44                 NaN     TCGACGAG     CTACGCAG
# 190         NaN          -1.333                 NaN     GTCAGATA     CTACGCAG
# 203         NaN          -1.132                 NaN     CTACTATA     GGAGACTA
# 215         NaN          -0.239                 NaN     CGTTACTA     GGAGACTA
# 227         NaN           1.629                 NaN     AGAGTCAC     GGAGACTA
# 239         NaN           2.645                 NaN     TACGAGAC     GGAGACTA
# 251         NaN           6.142                 NaN     ACGTCTCG     GGAGACTA
# 263         NaN           4.519                 NaN     TCGACGAG     GGAGACTA
# 275         NaN           4.411                 NaN     GATCGTGT     GGAGACTA
# 287         NaN            3.36                 NaN     GTCAGATA     GGAGACTA
# 299         NaN           0.513                 NaN     CTACTATA     GTCGCTCG
# 311         NaN          -0.306                 NaN     CGTTACTA     GTCGCTCG
# 323         NaN          -0.836                 NaN     AGAGTCAC     GTCGCTCG
# 335         NaN          -0.991                 NaN     TACGAGAC     GTCGCTCG
# 348         NaN          -1.229                 NaN     ACGTCTCG     GTCGCTCG
# 361         NaN          -1.265                 NaN     TCGACGAG     GTCGCTCG
# 977         NaN           0.216                 NaN     TAGCGAGT     TCGCTATA
# ...         ...             ...                 ...          ...          ...
# 1453        NaN          -1.335                 NaN     GTCAGATA     GTCGCTCG
# 1464        NaN             NaN                 NaN     CTACTATA     GTCGTAGT
# 1476        NaN           0.009                 NaN     CGTTACTA     GTCGTAGT
# 1488        NaN           0.008                 NaN     AGAGTCAC     GTCGTAGT
# 1500        NaN            0.01                 NaN     TACGAGAC     GTCGTAGT
# 1512        NaN            0.02                 NaN     ACGTCTCG     GTCGTAGT
# 1524        NaN            0.03                 NaN     TCGACGAG     GTCGTAGT
# 1536        NaN           0.076                 NaN     GATCGTGT     GTCGTAGT
# 1548        NaN           0.186                 NaN     GTCAGATA     GTCGTAGT
# 1560        NaN           0.342                 NaN     CTACTATA     TAGCAGAC
# 1572        NaN            0.51                 NaN     CGTTACTA     TAGCAGAC
# 1583        NaN           0.764                 NaN     AGAGTCAC     TAGCAGAC
# 1595        NaN           1.325                 NaN     TACGAGAC     TAGCAGAC
# 1606        NaN           2.478                 NaN     ACGTCTCG     TAGCAGAC
# 1617        NaN           4.457                 NaN     TCGACGAG     TAGCAGAC
# 1628        NaN           7.451                 NaN     GATCGTGT     TAGCAGAC
# 1639        NaN           6.378                 NaN     GTCAGATA     TAGCAGAC
# 1650        NaN            5.98                 NaN     CTACTATA     TCATAGAC
# 1660        NaN           4.917                 NaN     CGTTACTA     TCATAGAC
# 1670        NaN           2.232                 NaN     AGAGTCAC     TCATAGAC
# 1680        NaN            0.97                 NaN     TACGAGAC     TCATAGAC
# 1690        NaN            0.63                 NaN     ACGTCTCG     TCATAGAC
# 1700        NaN           0.347                 NaN     TCGACGAG     TCATAGAC
# 1709        NaN           0.181  too_many_sequences     GATCGTGT     TCATAGAC
# 1718        NaN           0.125                 NaN     GTCAGATA     TCATAGAC
# 1727        NaN             NaN                 NaN     CGTTACTA     TCGCTATA
# 2253        NaN           0.702                 NaN     CTACTATA     AACTCTCG
# 2265        NaN             NaN                 NaN     GTCAGATA     ACTATGTC
# 2277        NaN             NaN                 NaN     CTACTATA     AGTAGCGT
# 2289        NaN           0.108                 NaN     CTACTATA     TCGCTATA
#
# [96 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 24 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 96
[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MR.M.13C-Xyl.D3.R1_Frac21'),
#  ('tgagtacgcgttacta', 'MR.M.13C-Xyl.D3.R1_Frac22'),
#  ('tgagtacgagagtcac', 'MR.M.13C-Xyl.D3.R1_Frac23'),
#  ('tgagtacgtacgagac', 'MR.M.13C-Xyl.D3.R1_Frac24'),
#  ('tgagtacgacgtctcg', 'MR.M.13C-Xyl.D3.R1_Frac25'),
#  ('tgagtacgtcgacgag', 'MR.M.13C-Xyl.D3.R1_Frac26'),
#  ('tgagtacggatcgtgt', 'MR.M.13C-Xyl.D3.R1_Frac27'),
#  ('tgagtacggtcagata', 'MR.M.13C-Xyl.D3.R1_Frac28'),
#  ('ctgcgtagctactata', 'MR.M.13C-Xyl.D3.R1_NC'),
#  ('ctgcgtagcgttacta', 'MR.F.13C-Van.D14.R2_Frac5'),
#  ('ctgcgtagagagtcac', 'MR.F.13C-Van.D14.R2_Frac6'),
#  ('ctgcgtagtacgagac', 'MR.F.13C-Van.D14.R2_Frac7'),
#  ('ctgcgtagacgtctcg', 'MR.F.13C-Van.D14.R2_Frac8'),
#  ('ctgcgtagtcgacgag', 'MR.F.13C-Van.D14.R2_Frac9'),
#  ('ctgcgtaggtcagata', 'MR.F.13C-Van.D14.R2_Frac11'),
#  ('tagtctccctactata', 'MR.F.13C-Van.D14.R2_Frac12'),
#  ('tagtctcccgttacta', 'MR.F.13C-Van.D14.R2_Frac13'),
#  ('tagtctccagagtcac', 'MR.F.13C-Van.D14.R2_Frac14'),
#  ('tagtctcctacgagac', 'MR.F.13C-Van.D14.R2_Frac15'),
#  ('tagtctccacgtctcg', 'MR.F.13C-Van.D14.R2_Frac16'),
#  ('tagtctcctcgacgag', 'MR.F.13C-Van.D14.R2_Frac17'),
#  ('tagtctccgatcgtgt', 'MR.F.13C-Van.D14.R2_Frac18'),
#  ('tagtctccgtcagata', 'MR.F.13C-Van.D14.R2_Frac19'),
#  ('cgagcgacctactata', 'MR.F.13C-Van.D14.R2_Frac20'),
#  ('cgagcgaccgttacta', 'MR.F.13C-Van.D14.R2_Frac21'),
#  ('cgagcgacagagtcac', 'MR.F.13C-Van.D14.R2_Frac22'),
#  ('cgagcgactacgagac', 'MR.F.13C-Van.D14.R2_Frac23'),
#  ('cgagcgacacgtctcg', 'MR.F.13C-Van.D14.R2_Frac24'),
#  ('cgagcgactcgacgag', 'MR.F.13C-Van.D14.R2_Frac25'),
#  ('tatagcgatagcgagt', 'MR.F.13C-Ami.D1.R1_Frac5'),
#  ('tatagcgactgcgtgt', 'MR.F.13C-Ami.D1.R1_Frac6'),
#  ('tatagcgatcatcgag', 'MR.F.13C-Ami.D1.R1_Frac7'),
#  ('tatagcgacgtgagtg', 'MR.F.13C-Ami.D1.R1_Frac8'),
#  ('tatagcgaggatatct', 'MR.F.13C-Ami.D1.R1_Frac9'),
#  ('tatagcgagacaccgt', 'MR.F.13C-Ami.D1.R1_Frac10'),
#  ('cgagagttcgttacta', 'MR.F.13C-Ami.D1.R1_Frac12'),
#  ('cgagagttagagtcac', 'MR.F.13C-Ami.D1.R1_Frac13'),
#  ('cgagagtttacgagac', 'MR.F.13C-Ami.D1.R1_Frac14'),
#  ('cgagagttacgtctcg', 'MR.F.13C-Ami.D1.R1_Frac15'),
#  ('cgagagtttcgacgag', 'MR.F.13C-Ami.D1.R1_Frac16'),
#  ('cgagagttgatcgtgt', 'MR.F.13C-Ami.D1.R1_Frac17'),
#  ('cgagagttgtcagata', 'MR.F.13C-Ami.D1.R1_Frac18'),
#  ('gacatagtctactata', 'MR.F.13C-Ami.D1.R1_Frac19'),
#  ('gacatagtcgttacta', 'MR.F.13C-Ami.D1.R1_Frac20'),
#  ('gacatagtagagtcac', 'MR.F.13C-Ami.D1.R1_Frac21'),
#  ('gacatagttacgagac', 'MR.F.13C-Ami.D1.R1_Frac22'),
#  ('gacatagtacgtctcg', 'MR.F.13C-Ami.D1.R1_Frac23'),
#  ('gacatagttcgacgag', 'MR.F.13C-Ami.D1.R1_Frac24'),
#  ('gacatagtgatcgtgt', 'MR.F.13C-Ami.D1.R1_Frac25'),
#  ('acgctactcgttacta', 'MR.M.13C-Xyl.D3.R1_Frac6'),
#  ('acgctactagagtcac', 'MR.M.13C-Xyl.D3.R1_Frac7'),
#  ('acgctacttacgagac', 'MR.M.13C-Xyl.D3.R1_Frac8'),
#  ('acgctactacgtctcg', 'MR.M.13C-Xyl.D3.R1_Frac9'),
#  ('acgctacttcgacgag', 'MR.M.13C-Xyl.D3.R1_Frac10'),
#  ('acgctactgatcgtgt', 'MR.M.13C-Xyl.D3.R1_Frac11'),
#  ('acgctactgtcagata', 'MR.M.13C-Xyl.D3.R1_Frac12'),
#  ('actcactgctactata', 'MR.M.13C-Xyl.D3.R1_Frac13'),
#  ('actcactgcgttacta', 'MR.M.13C-Xyl.D3.R1_Frac14'),
#  ('actcactgagagtcac', 'MR.M.13C-Xyl.D3.R1_Frac15'),
#  ('actcactgtacgagac', 'MR.M.13C-Xyl.D3.R1_Frac16'),
#  ('actcactgacgtctcg', 'MR.M.13C-Xyl.D3.R1_Frac17'),
#  ('actcactgtcgacgag', 'MR.M.13C-Xyl.D3.R1_Frac18_bad'),
#  ('actcactggatcgtgt', 'MR.M.13C-Xyl.D3.R1_Frac19'),
#  ('actcactggtcagata', 'MR.M.13C-Xyl.D3.R1_Frac20_bad'),
#  ('ctgcgtaggatcgtgt', 'MR.F.13C-Van.D14.R2_Frac10'),
#  ('cgagcgacgatcgtgt', 'MR.F.13C-Van.D14.R2_Frac26'),
#  ('cgagcgacgtcagata', 'MR.F.13C-Van.D14.R2_Frac27'),
#  ('actacgacctactata', 'MR.F.13C-Van.D14.R2_NC'),
#  ('actacgaccgttacta', 'MR.F.13C-Ami.D3.R2_Frac6'),
#  ('actacgacagagtcac', 'MR.F.13C-Ami.D3.R2_Frac7'),
#  ('actacgactacgagac', 'MR.F.13C-Ami.D3.R2_Frac8'),
#  ('actacgacacgtctcg', 'MR.F.13C-Ami.D3.R2_Frac9'),
#  ('actacgactcgacgag', 'MR.F.13C-Ami.D3.R2_Frac10'),
#  ('actacgacgatcgtgt', 'MR.F.13C-Ami.D3.R2_Frac11'),
#  ('actacgacgtcagata', 'MR.F.13C-Ami.D3.R2_Frac12'),
#  ('gtctgctactactata', 'MR.F.13C-Ami.D3.R2_Frac13'),
#  ('gtctgctacgttacta', 'MR.F.13C-Ami.D3.R2_Frac14'),
#  ('gtctgctaagagtcac', 'MR.F.13C-Ami.D3.R2_Frac15'),
#  ('gtctgctatacgagac', 'MR.F.13C-Ami.D3.R2_Frac16'),
#  ('gtctgctaacgtctcg', 'MR.F.13C-Ami.D3.R2_Frac17'),
#  ('gtctgctatcgacgag', 'MR.F.13C-Ami.D3.R2_Frac18'),
#  ('gtctgctagatcgtgt', 'MR.F.13C-Ami.D3.R2_Frac19'),
#  ('gtctgctagtcagata', 'MR.F.13C-Ami.D3.R2_Frac20'),
#  ('gtctatgactactata', 'MR.F.13C-Ami.D3.R2_Frac21'),
#  ('gtctatgacgttacta', 'MR.F.13C-Ami.D3.R2_Frac22'),
#  ('gtctatgaagagtcac', 'MR.F.13C-Ami.D3.R2_Frac23'),
#  ('gtctatgatacgagac', 'MR.F.13C-Ami.D3.R2_Frac24'),
#  ('gtctatgaacgtctcg', 'MR.F.13C-Ami.D3.R2_Frac25'),
#  ('gtctatgatcgacgag', 'MR.F.13C-Ami.D3.R2_Frac26'),
#  ('gtctatgagatcgtgt', 'MR.F.13C-Ami.D3.R2_Frac27_bad'),
#  ('gtctatgagtcagata', 'MR.F.13C-Ami.D3.R2_Frac28'),
#  ('tatagcgacgttacta', 'MR.F.13C-Ami.D3.R2_NC'),
#  ('cgagagttctactata', 'MR.F.13C-Ami.D1.R1_Frac11'),
#  ('gacatagtgtcagata', 'MR.F.13C-Ami.D1.R1_NC'),
#  ('acgctactctactata', 'MR.F.13C-Ami.D1.R1_MC'),
#  ('tatagcgactactata', 'MR.F.13C-Ami.D3.R2_Frac29')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 3888710 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 1657783.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                            Sample  seq_count
# 0       MR.M.13C-Xyl.D3.R1_Frac11       9900
# 1       MR.F.13C-Ami.D1.R1_Frac24      14924
# 2       MR.M.13C-Xyl.D3.R1_Frac10      18774
# 3   MR.M.13C-Xyl.D3.R1_Frac20_bad     234597
# 4       MR.F.13C-Ami.D3.R2_Frac12      14674
# 5       MR.F.13C-Ami.D1.R1_Frac23       5533
# 6       MR.F.13C-Ami.D3.R2_Frac10      22229
# 7   MR.F.13C-Ami.D3.R2_Frac27_bad     220283
# 8       MR.M.13C-Xyl.D3.R1_Frac25       8262
# 9       MR.F.13C-Van.D14.R2_Frac7      21604
# 10      MR.F.13C-Ami.D3.R2_Frac19      46754
# 11      MR.F.13C-Ami.D1.R1_Frac15       7077
# 12       MR.F.13C-Ami.D3.R2_Frac7       9760
# 13      MR.M.13C-Xyl.D3.R1_Frac12      15528
# 14      MR.F.13C-Ami.D3.R2_Frac14      10470
# 15      MR.F.13C-Ami.D3.R2_Frac28      28486
# 16      MR.F.13C-Ami.D1.R1_Frac19      10084
# 17       MR.F.13C-Ami.D1.R1_Frac9      10560
# 18      MR.F.13C-Ami.D3.R2_Frac24      23754
# 19       MR.F.13C-Ami.D1.R1_Frac5       7393
# 20      MR.F.13C-Ami.D1.R1_Frac22      10546
# 21     MR.F.13C-Van.D14.R2_Frac23      12978
# 22       MR.M.13C-Xyl.D3.R1_Frac6       8447
# 23      MR.F.13C-Ami.D3.R2_Frac17      29137
# 24      MR.F.13C-Ami.D3.R2_Frac26      20579
# 25       MR.F.13C-Ami.D1.R1_Frac7      11077
# 26      MR.M.13C-Xyl.D3.R1_Frac27      15429
# 27      MR.F.13C-Ami.D3.R2_Frac29      22184
# 28     MR.F.13C-Van.D14.R2_Frac17       8561
# 29      MR.F.13C-Ami.D1.R1_Frac12      12940
# ..                            ...        ...
# 66     MR.F.13C-Van.D14.R2_Frac27      14555
# 67      MR.M.13C-Xyl.D3.R1_Frac14       6966
# 68      MR.F.13C-Ami.D1.R1_Frac21       5309
# 69       MR.F.13C-Ami.D3.R2_Frac8      25690
# 70      MR.F.13C-Van.D14.R2_Frac8      14379
# 71      MR.M.13C-Xyl.D3.R1_Frac24      19222
# 72     MR.F.13C-Van.D14.R2_Frac22      10448
# 73       MR.F.13C-Ami.D3.R2_Frac6      11985
# 74      MR.F.13C-Ami.D1.R1_Frac17      14569
# 75      MR.F.13C-Ami.D3.R2_Frac23      10757
# 76      MR.F.13C-Ami.D3.R2_Frac18      10784
# 77     MR.F.13C-Van.D14.R2_Frac14       9232
# 78      MR.F.13C-Ami.D1.R1_Frac20      10529
# 79     MR.F.13C-Van.D14.R2_Frac19       9345
# 80     MR.F.13C-Van.D14.R2_Frac16       5200
# 81       MR.F.13C-Ami.D1.R1_Frac8       5463
# 82     MR.F.13C-Van.D14.R2_Frac21       6660
# 83     MR.F.13C-Van.D14.R2_Frac12      14091
# 84      MR.F.13C-Ami.D3.R2_Frac21       7186
# 85          MR.F.13C-Ami.D1.R1_NC       3097
# 86      MR.M.13C-Xyl.D3.R1_Frac17        637
# 87      MR.F.13C-Van.D14.R2_Frac5       7877
# 88       MR.M.13C-Xyl.D3.R1_Frac9       5846
# 89       MR.M.13C-Xyl.D3.R1_Frac7       7577
# 90  MR.M.13C-Xyl.D3.R1_Frac18_bad         59
# 91          MR.M.13C-Xyl.D3.R1_NC        458
# 92          MR.F.13C-Ami.D3.R2_NC       2232
# 93      MR.F.13C-Van.D14.R2_Frac9         59
# 94         MR.F.13C-Van.D14.R2_NC        144
# 95          MR.F.13C-Ami.D1.R1_MC        104
#
# [96 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 1000,]
# Out:
#                           Sample seq_count
# 86     MR.M.13C-Xyl.D3.R1_Frac17       637
# 90 MR.M.13C-Xyl.D3.R1_Frac18_bad        59
# 91         MR.M.13C-Xyl.D3.R1_NC       458
# 93     MR.F.13C-Van.D14.R2_Frac9        59
# 94        MR.F.13C-Van.D14.R2_NC       144
# 95         MR.F.13C-Ami.D1.R1_MC       104
