# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/fullCyc2_lib8/run1'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib8'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'fullCyc2_lib8'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-fullCyc2_lib8.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib8

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                          #Sample  primer_number exp_type extraction_plate_ID  \
# 10    MR.F.13C-Van.D30.R2_Frac19            129      SIP                 NaN
# 23    MR.F.13C-Van.D30.R2_Frac20            130      SIP                 NaN
# 36    MR.F.13C-Van.D30.R2_Frac21            131      SIP                 NaN
# 49    MR.F.13C-Van.D30.R2_Frac22            132      SIP                 NaN
# 62    MR.F.13C-Van.D30.R2_Frac23            133      SIP                 NaN
# 75    MR.F.13C-Van.D30.R2_Frac24            134      SIP                 NaN
# 88    MR.F.13C-Van.D30.R2_Frac25            135      SIP                 NaN
# 102   MR.F.13C-Van.D30.R2_Frac26            136      SIP                 NaN
# 116   MR.F.13C-Van.D30.R2_Frac27            137      SIP                 NaN
# 130   MR.F.13C-Van.D30.R2_Frac28            138      SIP                 NaN
# 144       MR.F.13C-Van.D30.R2_NC            139      SIP                 NaN
# 157     MR.M.12C-Con.D3.R1_Frac5            140      SIP                 NaN
# 170     MR.M.12C-Con.D3.R1_Frac6            141      SIP                 NaN
# 183     MR.M.12C-Con.D3.R1_Frac7            142      SIP                 NaN
# 196     MR.M.12C-Con.D3.R1_Frac8            143      SIP                 NaN
# 209     MR.M.12C-Con.D3.R1_Frac9            144      SIP                 NaN
# 221    MR.M.12C-Con.D3.R1_Frac10            145      SIP                 NaN
# 233    MR.M.12C-Con.D3.R1_Frac11            146      SIP                 NaN
# 245    MR.M.12C-Con.D3.R1_Frac12            147      SIP                 NaN
# 257    MR.M.12C-Con.D3.R1_Frac13            148      SIP                 NaN
# 269    MR.M.12C-Con.D3.R1_Frac14            149      SIP                 NaN
# 281    MR.M.12C-Con.D3.R1_Frac15            150      SIP                 NaN
# 293    MR.M.12C-Con.D3.R1_Frac16            151      SIP                 NaN
# 305    MR.M.12C-Con.D3.R1_Frac17            152      SIP                 NaN
# 317    MR.M.12C-Con.D3.R1_Frac18            153      SIP                 NaN
# 329    MR.M.12C-Con.D3.R1_Frac19            154      SIP                 NaN
# 341    MR.M.12C-Con.D3.R1_Frac20            155      SIP                 NaN
# 354    MR.M.12C-Con.D3.R1_Frac21            156      SIP                 NaN
# 367    MR.M.12C-Con.D3.R1_Frac22            157      SIP                 NaN
# 380    MR.M.12C-Con.D3.R1_Frac23            158      SIP                 NaN
# ...                          ...            ...      ...                 ...
# 1952    MR.A.13C-Pal.D6.R1_Frac9             16      SIP                 NaN
# 1964   MR.A.13C-Pal.D6.R1_Frac10             17      SIP                 NaN
# 1976   MR.A.13C-Pal.D6.R1_Frac11             18      SIP                 NaN
# 1988   MR.A.13C-Pal.D6.R1_Frac12             19      SIP                 NaN
# 2000   MR.A.13C-Pal.D6.R1_Frac13             20      SIP                 NaN
# 2012   MR.A.13C-Pal.D6.R1_Frac14             21      SIP                 NaN
# 2024   MR.A.13C-Pal.D6.R1_Frac15             22      SIP                 NaN
# 2036   MR.A.13C-Pal.D6.R1_Frac16             23      SIP                 NaN
# 2048   MR.A.13C-Pal.D6.R1_Frac17             24      SIP                 NaN
# 2059   MR.A.13C-Pal.D6.R1_Frac18             25      SIP                 NaN
# 2070   MR.A.13C-Pal.D6.R1_Frac19             26      SIP                 NaN
# 2082   MR.A.13C-Pal.D6.R1_Frac20             27      SIP                 NaN
# 2094   MR.A.13C-Pal.D6.R1_Frac21             28      SIP                 NaN
# 2106   MR.A.13C-Pal.D6.R1_Frac22             29      SIP                 NaN
# 2118   MR.A.13C-Pal.D6.R1_Frac23             30      SIP                 NaN
# 2130   MR.A.13C-Pal.D6.R1_Frac24             31      SIP                 NaN
# 2142   MR.A.13C-Pal.D6.R1_Frac25             32      SIP                 NaN
# 2154   MR.A.13C-Pal.D6.R1_Frac26             33      SIP                 NaN
# 2166   MR.A.13C-Pal.D6.R1_Frac27             34      SIP                 NaN
# 2178   MR.A.13C-Pal.D6.R1_Frac28             35      SIP                 NaN
# 2190   MR.A.13C-Pal.D6.R1_Frac29             36      SIP                 NaN
# 2202       MR.A.13C-Pal.D6.R1_NC             37      SIP                 NaN
# 2214       MR.A.13C-Pal.D6.R1_MC             38      SIP                 NaN
# 2226    MR.A.12C-Con.D3.R1_Frac5             39      SIP                 NaN
# 2237   MR.A.13C-Van.D6.R2_Frac10             70      SIP                 NaN
# 2249   MR.A.13C-Van.D6.R2_Frac20             80      SIP                 NaN
# 2261  MR.M.13C-Xyl.D14.R1_Frac11             97      SIP                 NaN
# 2273  MR.M.13C-Xyl.D14.R1_Frac26            112      SIP                 NaN
# 2285  MR.M.13C-Xyl.D14.R1_Frac27            113      SIP                 NaN
# 2294  MR.F.12C-Con.D30.R3_Frac25            185      SIP                 NaN
#
#          library_ID         pool_plate_ID pool_plate_well  \
# 10    fullCyc2_lib8  fullCyc2_lib8_Pool_2              A5
# 23    fullCyc2_lib8  fullCyc2_lib8_Pool_2              B5
# 36    fullCyc2_lib8  fullCyc2_lib8_Pool_2              C5
# 49    fullCyc2_lib8  fullCyc2_lib8_Pool_2              D5
# 62    fullCyc2_lib8  fullCyc2_lib8_Pool_2              E5
# 75    fullCyc2_lib8  fullCyc2_lib8_Pool_2              F5
# 88    fullCyc2_lib8  fullCyc2_lib8_Pool_2              G5
# 102   fullCyc2_lib8  fullCyc2_lib8_Pool_2              H5
# 116   fullCyc2_lib8  fullCyc2_lib8_Pool_2              A6
# 130   fullCyc2_lib8  fullCyc2_lib8_Pool_2              B6
# 144   fullCyc2_lib8  fullCyc2_lib8_Pool_2              C6
# 157   fullCyc2_lib8  fullCyc2_lib8_Pool_2              D6
# 170   fullCyc2_lib8  fullCyc2_lib8_Pool_2              E6
# 183   fullCyc2_lib8  fullCyc2_lib8_Pool_2              F6
# 196   fullCyc2_lib8  fullCyc2_lib8_Pool_2              G6
# 209   fullCyc2_lib8  fullCyc2_lib8_Pool_2              H6
# 221   fullCyc2_lib8  fullCyc2_lib8_Pool_2              A7
# 233   fullCyc2_lib8  fullCyc2_lib8_Pool_2              B7
# 245   fullCyc2_lib8  fullCyc2_lib8_Pool_2              C7
# 257   fullCyc2_lib8  fullCyc2_lib8_Pool_2              D7
# 269   fullCyc2_lib8  fullCyc2_lib8_Pool_2              E7
# 281   fullCyc2_lib8  fullCyc2_lib8_Pool_2              F7
# 293   fullCyc2_lib8  fullCyc2_lib8_Pool_2              G7
# 305   fullCyc2_lib8  fullCyc2_lib8_Pool_2              H7
# 317   fullCyc2_lib8  fullCyc2_lib8_Pool_2              A8
# 329   fullCyc2_lib8  fullCyc2_lib8_Pool_2              B8
# 341   fullCyc2_lib8  fullCyc2_lib8_Pool_2              C8
# 354   fullCyc2_lib8  fullCyc2_lib8_Pool_2              D8
# 367   fullCyc2_lib8  fullCyc2_lib8_Pool_2              E8
# 380   fullCyc2_lib8  fullCyc2_lib8_Pool_2              F8
# ...             ...                   ...             ...
# 1952  fullCyc2_lib8  fullCyc2_lib8_Pool_1              H2
# 1964  fullCyc2_lib8  fullCyc2_lib8_Pool_1              A3
# 1976  fullCyc2_lib8  fullCyc2_lib8_Pool_1              B3
# 1988  fullCyc2_lib8  fullCyc2_lib8_Pool_1              C3
# 2000  fullCyc2_lib8  fullCyc2_lib8_Pool_1              D3
# 2012  fullCyc2_lib8  fullCyc2_lib8_Pool_1              E3
# 2024  fullCyc2_lib8  fullCyc2_lib8_Pool_1              F3
# 2036  fullCyc2_lib8  fullCyc2_lib8_Pool_1              G3
# 2048  fullCyc2_lib8  fullCyc2_lib8_Pool_1              H3
# 2059  fullCyc2_lib8  fullCyc2_lib8_Pool_1              A4
# 2070  fullCyc2_lib8  fullCyc2_lib8_Pool_1              B4
# 2082  fullCyc2_lib8  fullCyc2_lib8_Pool_1              C4
# 2094  fullCyc2_lib8  fullCyc2_lib8_Pool_1              D4
# 2106  fullCyc2_lib8  fullCyc2_lib8_Pool_1              E4
# 2118  fullCyc2_lib8  fullCyc2_lib8_Pool_1              F4
# 2130  fullCyc2_lib8  fullCyc2_lib8_Pool_1              G4
# 2142  fullCyc2_lib8  fullCyc2_lib8_Pool_1              H4
# 2154  fullCyc2_lib8  fullCyc2_lib8_Pool_1              A5
# 2166  fullCyc2_lib8  fullCyc2_lib8_Pool_1              B5
# 2178  fullCyc2_lib8  fullCyc2_lib8_Pool_1              C5
# 2190  fullCyc2_lib8  fullCyc2_lib8_Pool_1              D5
# 2202  fullCyc2_lib8  fullCyc2_lib8_Pool_1              E5
# 2214  fullCyc2_lib8  fullCyc2_lib8_Pool_1              F5
# 2226  fullCyc2_lib8  fullCyc2_lib8_Pool_1              G5
# 2237  fullCyc2_lib8  fullCyc2_lib8_Pool_1              F9
# 2249  fullCyc2_lib8  fullCyc2_lib8_Pool_1             H10
# 2261  fullCyc2_lib8  fullCyc2_lib8_Pool_2              A1
# 2273  fullCyc2_lib8  fullCyc2_lib8_Pool_2              H2
# 2285  fullCyc2_lib8  fullCyc2_lib8_Pool_2              A3
# 2294  fullCyc2_lib8  fullCyc2_lib8_Pool_2             A12
#
#                   soil_ID substrate   day     ...       \
# 10    MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 23    MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 36    MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 49    MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 62    MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 75    MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 88    MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 102   MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 116   MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 130   MR.F.13C-Van.D30.R2   13C-Van  30.0     ...
# 144   MR.F.13C-Van.D30.R2   13C-Van   NaN     ...
# 157    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 170    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 183    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 196    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 209    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 221    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 233    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 245    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 257    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 269    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 281    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 293    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 305    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 317    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 329    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 341    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 354    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 367    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# 380    MR.M.12C-Con.D3.R1   12C-Con   3.0     ...
# ...                   ...       ...   ...     ...
# 1952   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 1964   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 1976   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 1988   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2000   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2012   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2024   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2036   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2048   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2059   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2070   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2082   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2094   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2106   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2118   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2130   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2142   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2154   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2166   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2178   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2190   MR.A.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 2202   MR.A.13C-Pal.D6.R1   13C-Pal   NaN     ...
# 2214   MR.A.13C-Pal.D6.R1   13C-Pal   NaN     ...
# 2226   MR.A.12C-Con.D3.R1   12C-Con   3.0     ...
# 2237   MR.A.13C-Van.D6.R2   13C-Van   6.0     ...
# 2249   MR.A.13C-Van.D6.R2   13C-Van   6.0     ...
# 2261  MR.M.13C-Xyl.D14.R1   13C-Xyl  14.0     ...
# 2273  MR.M.13C-Xyl.D14.R1   13C-Xyl  14.0     ...
# 2285  MR.M.13C-Xyl.D14.R1   13C-Xyl  14.0     ...
# 2294  MR.F.12C-Con.D30.R3   12C-Con  30.0     ...
#
#       water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 10                            NaN        NaN        NaN        NaN        NaN
# 23                            NaN        NaN        NaN        NaN        NaN
# 36                            NaN        NaN        NaN        NaN        NaN
# 49                            NaN        NaN        NaN        NaN        NaN
# 62                            NaN        NaN        NaN        NaN        NaN
# 75                            NaN        NaN        NaN        NaN        NaN
# 88                            NaN        NaN        NaN        NaN        NaN
# 102                           NaN        NaN        NaN        NaN        NaN
# 116                           NaN        NaN        NaN        NaN        NaN
# 130                           NaN        NaN        NaN        NaN        NaN
# 144                           NaN        NaN        NaN        NaN        NaN
# 157                           NaN        NaN        NaN        NaN        NaN
# 170                           NaN        NaN        NaN        NaN        NaN
# 183                           NaN        NaN        NaN        NaN        NaN
# 196                           NaN        NaN        NaN        NaN        NaN
# 209                           NaN        NaN        NaN        NaN        NaN
# 221                           NaN        NaN        NaN        NaN        NaN
# 233                           NaN        NaN        NaN        NaN        NaN
# 245                           NaN        NaN        NaN        NaN        NaN
# 257                           NaN        NaN        NaN        NaN        NaN
# 269                           NaN        NaN        NaN        NaN        NaN
# 281                           NaN        NaN        NaN        NaN        NaN
# 293                           NaN        NaN        NaN        NaN        NaN
# 305                           NaN        NaN        NaN        NaN        NaN
# 317                           NaN        NaN        NaN        NaN        NaN
# 329                           NaN        NaN        NaN        NaN        NaN
# 341                           NaN        NaN        NaN        NaN        NaN
# 354                           NaN        NaN        NaN        NaN        NaN
# 367                           NaN        NaN        NaN        NaN        NaN
# 380                           NaN        NaN        NaN        NaN        NaN
# ...                           ...        ...        ...        ...        ...
# 1952                          NaN        NaN        NaN        NaN        NaN
# 1964                          NaN        NaN        NaN        NaN        NaN
# 1976                          NaN        NaN        NaN        NaN        NaN
# 1988                          NaN        NaN        NaN        NaN        NaN
# 2000                          NaN        NaN        NaN        NaN        NaN
# 2012                          NaN        NaN        NaN        NaN        NaN
# 2024                          NaN        NaN        NaN        NaN        NaN
# 2036                          NaN        NaN        NaN        NaN        NaN
# 2048                          NaN        NaN        NaN        NaN        NaN
# 2059                          NaN        NaN        NaN        NaN        NaN
# 2070                          NaN        NaN        NaN        NaN        NaN
# 2082                          NaN        NaN        NaN        NaN        NaN
# 2094                          NaN        NaN        NaN        NaN        NaN
# 2106                          NaN        NaN        NaN        NaN        NaN
# 2118                          NaN        NaN        NaN        NaN        NaN
# 2130                          NaN        NaN        NaN        NaN        NaN
# 2142                          NaN        NaN        NaN        NaN        NaN
# 2154                          NaN        NaN        NaN        NaN        NaN
# 2166                          NaN        NaN        NaN        NaN        NaN
# 2178                          NaN        NaN        NaN        NaN        NaN
# 2190                          NaN        NaN        NaN        NaN        NaN
# 2202                          NaN        NaN        NaN        NaN        NaN
# 2214                          NaN        NaN        NaN        NaN        NaN
# 2226                          NaN        NaN        NaN        NaN        NaN
# 2237                          NaN        NaN        NaN        NaN        NaN
# 2249                          NaN        NaN        NaN        NaN        NaN
# 2261                          NaN        NaN        NaN        NaN        NaN
# 2273                          NaN        NaN        NaN        NaN        NaN
# 2285                          NaN        NaN        NaN        NaN        NaN
# 2294                          NaN        NaN        NaN        NaN        NaN
#
#      clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 10          NaN          18.194   NaN     CTACTATA     CGTACTCA
# 23          NaN          11.313   NaN     CGTTACTA     CGTACTCA
# 36          NaN           7.655   NaN     AGAGTCAC     CGTACTCA
# 49          NaN           6.111   NaN     TACGAGAC     CGTACTCA
# 62          NaN           2.573   NaN     ACGTCTCG     CGTACTCA
# 75          NaN           1.352   NaN     TCGACGAG     CGTACTCA
# 88          NaN           0.684   NaN     GATCGTGT     CGTACTCA
# 102         NaN           0.676   NaN     GTCAGATA     CGTACTCA
# 116         NaN           0.452   NaN     CTACTATA     CTACGCAG
# 130         NaN           0.435   NaN     CGTTACTA     CTACGCAG
# 144         NaN             NaN   NaN     AGAGTCAC     CTACGCAG
# 157         NaN           0.205   NaN     TACGAGAC     CTACGCAG
# 170         NaN           0.197   NaN     ACGTCTCG     CTACGCAG
# 183         NaN           0.221   NaN     TCGACGAG     CTACGCAG
# 196         NaN           0.257   NaN     GATCGTGT     CTACGCAG
# 209         NaN           0.232   NaN     GTCAGATA     CTACGCAG
# 221         NaN           0.259   NaN     CTACTATA     GGAGACTA
# 233         NaN           0.286   NaN     CGTTACTA     GGAGACTA
# 245         NaN           0.348   NaN     AGAGTCAC     GGAGACTA
# 257         NaN           0.798   NaN     TACGAGAC     GGAGACTA
# 269         NaN           2.185   NaN     ACGTCTCG     GGAGACTA
# 281         NaN           7.805   NaN     TCGACGAG     GGAGACTA
# 293         NaN          17.513   NaN     GATCGTGT     GGAGACTA
# 305         NaN          12.885   NaN     GTCAGATA     GGAGACTA
# 317         NaN          15.369   NaN     CTACTATA     GTCGCTCG
# 329         NaN          16.278   NaN     CGTTACTA     GTCGCTCG
# 341         NaN          16.682   NaN     AGAGTCAC     GTCGCTCG
# 354         NaN           6.951   NaN     TACGAGAC     GTCGCTCG
# 367         NaN           3.393   NaN     ACGTCTCG     GTCGCTCG
# 380         NaN           3.058   NaN     TCGACGAG     GTCGCTCG
# ...         ...             ...   ...          ...          ...
# 1952        NaN           0.413   NaN     GACACCGT     ACTATGTC
# 1964        NaN           0.602   NaN     ATCGTACG     AGTAGCGT
# 1976        NaN           0.457   NaN     ACTATCTG     AGTAGCGT
# 1988        NaN           0.579   NaN     TAGCGAGT     AGTAGCGT
# 2000        NaN           0.364   NaN     CTGCGTGT     AGTAGCGT
# 2012        NaN           1.697   NaN     TCATCGAG     AGTAGCGT
# 2024        NaN           4.488   NaN     CGTGAGTG     AGTAGCGT
# 2036        NaN          11.539   NaN     GGATATCT     AGTAGCGT
# 2048        NaN           7.483   NaN     GACACCGT     AGTAGCGT
# 2059        NaN           8.407   NaN     ATCGTACG     CAGTGAGT
# 2070        NaN           9.676   NaN     ACTATCTG     CAGTGAGT
# 2082        NaN           7.197   NaN     TAGCGAGT     CAGTGAGT
# 2094        NaN           8.247   NaN     CTGCGTGT     CAGTGAGT
# 2106        NaN           6.175   NaN     TCATCGAG     CAGTGAGT
# 2118        NaN            6.51   NaN     CGTGAGTG     CAGTGAGT
# 2130        NaN           3.209   NaN     GGATATCT     CAGTGAGT
# 2142        NaN           1.878   NaN     GACACCGT     CAGTGAGT
# 2154        NaN           1.189   NaN     ATCGTACG     CGTACTCA
# 2166        NaN           0.733   NaN     ACTATCTG     CGTACTCA
# 2178        NaN           0.617   NaN     TAGCGAGT     CGTACTCA
# 2190        NaN           0.537   NaN     CTGCGTGT     CGTACTCA
# 2202        NaN             NaN   NaN     TCATCGAG     CGTACTCA
# 2214        NaN             NaN   NaN     CGTGAGTG     CGTACTCA
# 2226        NaN           0.112   NaN     GGATATCT     CGTACTCA
# 2237        NaN           3.185   NaN     CGTGAGTG     GTCGTAGT
# 2249        NaN           4.546   NaN     GACACCGT     TAGCAGAC
# 2261        NaN           2.757   NaN     CTACTATA     AACTCTCG
# 2273        NaN           1.031   NaN     GTCAGATA     ACTATGTC
# 2285        NaN           0.914   NaN     CTACTATA     AGTAGCGT
# 2294        NaN           0.698   NaN     CTACTATA     TCGCTATA
#
# [188 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 20 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 188

[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MR.F.13C-Van.D30.R2_Frac19'),
#  ('tgagtacgcgttacta', 'MR.F.13C-Van.D30.R2_Frac20'),
#  ('tgagtacgagagtcac', 'MR.F.13C-Van.D30.R2_Frac21'),
#  ('tgagtacgtacgagac', 'MR.F.13C-Van.D30.R2_Frac22'),
#  ('tgagtacgacgtctcg', 'MR.F.13C-Van.D30.R2_Frac23'),
#  ('tgagtacgtcgacgag', 'MR.F.13C-Van.D30.R2_Frac24'),
#  ('tgagtacggatcgtgt', 'MR.F.13C-Van.D30.R2_Frac25'),
#  ('tgagtacggtcagata', 'MR.F.13C-Van.D30.R2_Frac26'),
#  ('ctgcgtagctactata', 'MR.F.13C-Van.D30.R2_Frac27'),
#  ('ctgcgtagcgttacta', 'MR.F.13C-Van.D30.R2_Frac28'),
#  ('ctgcgtagagagtcac', 'MR.F.13C-Van.D30.R2_NC'),
#  ('ctgcgtagtacgagac', 'MR.M.12C-Con.D3.R1_Frac5'),
#  ('ctgcgtagacgtctcg', 'MR.M.12C-Con.D3.R1_Frac6'),
#  ('ctgcgtagtcgacgag', 'MR.M.12C-Con.D3.R1_Frac7'),
#  ('ctgcgtaggatcgtgt', 'MR.M.12C-Con.D3.R1_Frac8'),
#  ('ctgcgtaggtcagata', 'MR.M.12C-Con.D3.R1_Frac9'),
#  ('tagtctccctactata', 'MR.M.12C-Con.D3.R1_Frac10'),
#  ('tagtctcccgttacta', 'MR.M.12C-Con.D3.R1_Frac11'),
#  ('tagtctccagagtcac', 'MR.M.12C-Con.D3.R1_Frac12'),
#  ('tagtctcctacgagac', 'MR.M.12C-Con.D3.R1_Frac13'),
#  ('tagtctccacgtctcg', 'MR.M.12C-Con.D3.R1_Frac14'),
#  ('tagtctcctcgacgag', 'MR.M.12C-Con.D3.R1_Frac15'),
#  ('tagtctccgatcgtgt', 'MR.M.12C-Con.D3.R1_Frac16'),
#  ('tagtctccgtcagata', 'MR.M.12C-Con.D3.R1_Frac17'),
#  ('cgagcgacctactata', 'MR.M.12C-Con.D3.R1_Frac18'),
#  ('cgagcgaccgttacta', 'MR.M.12C-Con.D3.R1_Frac19'),
#  ('cgagcgacagagtcac', 'MR.M.12C-Con.D3.R1_Frac20'),
#  ('cgagcgactacgagac', 'MR.M.12C-Con.D3.R1_Frac21'),
#  ('cgagcgacacgtctcg', 'MR.M.12C-Con.D3.R1_Frac22'),
#  ('cgagcgactcgacgag', 'MR.M.12C-Con.D3.R1_Frac23'),
#  ('tgagtacggacaccgt', 'MR.A.12C-Con.D3.R1_Frac6'),
#  ('ctgcgtagatcgtacg', 'MR.A.12C-Con.D3.R1_Frac7'),
#  ('ctgcgtagactatctg', 'MR.A.12C-Con.D3.R1_Frac8'),
#  ('ctgcgtagtagcgagt', 'MR.A.12C-Con.D3.R1_Frac9'),
#  ('ctgcgtagctgcgtgt', 'MR.A.12C-Con.D3.R1_Frac10'),
#  ('ctgcgtagtcatcgag', 'MR.A.12C-Con.D3.R1_Frac11'),
#  ('ctgcgtagcgtgagtg', 'MR.A.12C-Con.D3.R1_Frac12'),
#  ('ctgcgtagggatatct', 'MR.A.12C-Con.D3.R1_Frac13'),
#  ('ctgcgtaggacaccgt', 'MR.A.12C-Con.D3.R1_Frac14'),
#  ('tagtctccatcgtacg', 'MR.A.12C-Con.D3.R1_Frac15'),
#  ('tagtctccactatctg', 'MR.A.12C-Con.D3.R1_Frac16'),
#  ('tagtctcctagcgagt', 'MR.A.12C-Con.D3.R1_Frac17'),
#  ('tagtctccctgcgtgt', 'MR.A.12C-Con.D3.R1_Frac18'),
#  ('tagtctcctcatcgag', 'MR.A.12C-Con.D3.R1_Frac19'),
#  ('tagtctcccgtgagtg', 'MR.A.12C-Con.D3.R1_Frac20'),
#  ('tagtctccggatatct', 'MR.A.12C-Con.D3.R1_Frac21'),
#  ('tagtctccgacaccgt', 'MR.A.12C-Con.D3.R1_Frac22'),
#  ('cgagcgacatcgtacg', 'MR.A.12C-Con.D3.R1_Frac23'),
#  ('cgagcgacactatctg', 'MR.A.12C-Con.D3.R1_Frac24'),
#  ('cgagcgactagcgagt', 'MR.A.12C-Con.D3.R1_Frac25'),
#  ('cgagcgacctgcgtgt', 'MR.A.12C-Con.D3.R1_Frac26'),
#  ('cgagcgactcatcgag', 'MR.A.12C-Con.D3.R1_Frac27'),
#  ('cgagcgaccgtgagtg', 'MR.A.12C-Con.D3.R1_Frac28'),
#  ('cgagcgacggatatct', 'MR.A.12C-Con.D3.R1_NC'),
#  ('cgagcgacgacaccgt', 'MR.A.13C-Van.D6.R2_Frac4'),
#  ('actacgacatcgtacg', 'MR.A.13C-Van.D6.R2_Frac5'),
#  ('actacgacactatctg', 'MR.A.13C-Van.D6.R2_Frac6'),
#  ('actacgactagcgagt', 'MR.A.13C-Van.D6.R2_Frac7'),
#  ('actacgacctgcgtgt', 'MR.A.13C-Van.D6.R2_Frac8'),
#  ('actacgactcatcgag', 'MR.A.13C-Van.D6.R2_Frac9'),
#  ('actacgacggatatct', 'MR.A.13C-Van.D6.R2_Frac11'),
#  ('actacgacgacaccgt', 'MR.A.13C-Van.D6.R2_Frac12'),
#  ('gtctgctaatcgtacg', 'MR.A.13C-Van.D6.R2_Frac13'),
#  ('gtctgctaactatctg', 'MR.A.13C-Van.D6.R2_Frac14'),
#  ('gtctgctatagcgagt', 'MR.A.13C-Van.D6.R2_Frac15'),
#  ('gtctgctactgcgtgt', 'MR.A.13C-Van.D6.R2_Frac16'),
#  ('gtctgctatcatcgag', 'MR.A.13C-Van.D6.R2_Frac17'),
#  ('gtctgctacgtgagtg', 'MR.A.13C-Van.D6.R2_Frac18'),
#  ('gtctgctaggatatct', 'MR.A.13C-Van.D6.R2_Frac19'),
#  ('gtctatgaatcgtacg', 'MR.A.13C-Van.D6.R2_Frac21'),
#  ('gtctatgaactatctg', 'MR.A.13C-Van.D6.R2_Frac22'),
#  ('gtctatgatagcgagt', 'MR.A.13C-Van.D6.R2_Frac23'),
#  ('gtctatgactgcgtgt', 'MR.A.13C-Van.D6.R2_Frac24'),
#  ('gtctatgatcatcgag', 'MR.A.13C-Van.D6.R2_Frac25'),
#  ('gtctatgacgtgagtg', 'MR.A.13C-Van.D6.R2_Frac26'),
#  ('gtctatgaggatatct', 'MR.A.13C-Van.D6.R2_Frac27'),
#  ('gtctatgagacaccgt', 'MR.A.13C-Van.D6.R2_NC'),
#  ('tatagcgaatcgtacg', 'MR.M.13C-Xyl.D14.R1_Frac3'),
#  ('tatagcgaactatctg', 'MR.M.13C-Xyl.D14.R1_Frac4'),
#  ('tatagcgatagcgagt', 'MR.M.13C-Xyl.D14.R1_Frac5'),
#  ('tatagcgactgcgtgt', 'MR.M.13C-Xyl.D14.R1_Frac6'),
#  ('tatagcgatcatcgag', 'MR.M.13C-Xyl.D14.R1_Frac7'),
#  ('tatagcgacgtgagtg', 'MR.M.13C-Xyl.D14.R1_Frac8'),
#  ('tatagcgaggatatct', 'MR.M.13C-Xyl.D14.R1_Frac9'),
#  ('tatagcgagacaccgt', 'MR.M.13C-Xyl.D14.R1_Frac10'),
#  ('cgagagttcgttacta', 'MR.M.13C-Xyl.D14.R1_Frac12'),
#  ('cgagagttagagtcac', 'MR.M.13C-Xyl.D14.R1_Frac13'),
#  ('cgagagtttacgagac', 'MR.M.13C-Xyl.D14.R1_Frac14'),
#  ('cgagagttacgtctcg', 'MR.M.13C-Xyl.D14.R1_Frac15'),
#  ('cgagagtttcgacgag', 'MR.M.13C-Xyl.D14.R1_Frac16'),
#  ('cgagagttgatcgtgt', 'MR.M.13C-Xyl.D14.R1_Frac17'),
#  ('cgagagttgtcagata', 'MR.M.13C-Xyl.D14.R1_Frac18'),
#  ('gacatagtctactata', 'MR.M.13C-Xyl.D14.R1_Frac19'),
#  ('gacatagtcgttacta', 'MR.M.13C-Xyl.D14.R1_Frac20'),
#  ('gacatagtagagtcac', 'MR.M.13C-Xyl.D14.R1_Frac21'),
#  ('gacatagttacgagac', 'MR.M.13C-Xyl.D14.R1_Frac22'),
#  ('gacatagtacgtctcg', 'MR.M.13C-Xyl.D14.R1_Frac23'),
#  ('gacatagttcgacgag', 'MR.M.13C-Xyl.D14.R1_Frac24'),
#  ('gacatagtgatcgtgt', 'MR.M.13C-Xyl.D14.R1_Frac25'),
#  ('acgctactcgttacta', 'MR.M.13C-Xyl.D14.R1_NC'),
#  ('acgctactagagtcac', 'MR.F.13C-Van.D30.R2_Frac5'),
#  ('acgctacttacgagac', 'MR.F.13C-Van.D30.R2_Frac6'),
#  ('acgctactacgtctcg', 'MR.F.13C-Van.D30.R2_Frac7'),
#  ('acgctacttcgacgag', 'MR.F.13C-Van.D30.R2_Frac8'),
#  ('acgctactgatcgtgt', 'MR.F.13C-Van.D30.R2_Frac9'),
#  ('acgctactgtcagata', 'MR.F.13C-Van.D30.R2_Frac10'),
#  ('actcactgctactata', 'MR.F.13C-Van.D30.R2_Frac11'),
#  ('actcactgcgttacta', 'MR.F.13C-Van.D30.R2_Frac12'),
#  ('actcactgagagtcac', 'MR.F.13C-Van.D30.R2_Frac13'),
#  ('actcactgtacgagac', 'MR.F.13C-Van.D30.R2_Frac14'),
#  ('actcactgacgtctcg', 'MR.F.13C-Van.D30.R2_Frac15'),
#  ('actcactgtcgacgag', 'MR.F.13C-Van.D30.R2_Frac16'),
#  ('actcactggatcgtgt', 'MR.F.13C-Van.D30.R2_Frac17'),
#  ('actcactggtcagata', 'MR.F.13C-Van.D30.R2_Frac18'),
#  ('cgagcgacgatcgtgt', 'MR.M.12C-Con.D3.R1_Frac24'),
#  ('cgagcgacgtcagata', 'MR.M.12C-Con.D3.R1_Frac25'),
#  ('actacgacctactata', 'MR.M.12C-Con.D3.R1_Frac26'),
#  ('actacgaccgttacta', 'MR.M.12C-Con.D3.R1_Frac27'),
#  ('actacgacagagtcac', 'MR.M.12C-Con.D3.R1_NC'),
#  ('actacgactacgagac', 'MR.F.12C-Con.D30.R3_Frac4'),
#  ('actacgacacgtctcg', 'MR.F.12C-Con.D30.R3_Frac5'),
#  ('actacgactcgacgag', 'MR.F.12C-Con.D30.R3_Frac6'),
#  ('actacgacgatcgtgt', 'MR.F.12C-Con.D30.R3_Frac7'),
#  ('actacgacgtcagata', 'MR.F.12C-Con.D30.R3_Frac8'),
#  ('gtctgctactactata', 'MR.F.12C-Con.D30.R3_Frac9'),
#  ('gtctgctacgttacta', 'MR.F.12C-Con.D30.R3_Frac10'),
#  ('gtctgctaagagtcac', 'MR.F.12C-Con.D30.R3_Frac11'),
#  ('gtctgctatacgagac', 'MR.F.12C-Con.D30.R3_Frac12'),
#  ('gtctgctaacgtctcg', 'MR.F.12C-Con.D30.R3_Frac13'),
#  ('gtctgctatcgacgag', 'MR.F.12C-Con.D30.R3_Frac14'),
#  ('gtctgctagatcgtgt', 'MR.F.12C-Con.D30.R3_Frac15'),
#  ('gtctgctagtcagata', 'MR.F.12C-Con.D30.R3_Frac16'),
#  ('gtctatgactactata', 'MR.F.12C-Con.D30.R3_Frac17'),
#  ('gtctatgacgttacta', 'MR.F.12C-Con.D30.R3_Frac18'),
#  ('gtctatgaagagtcac', 'MR.F.12C-Con.D30.R3_Frac19'),
#  ('gtctatgatacgagac', 'MR.F.12C-Con.D30.R3_Frac20'),
#  ('gtctatgaacgtctcg', 'MR.F.12C-Con.D30.R3_Frac21'),
#  ('gtctatgatcgacgag', 'MR.F.12C-Con.D30.R3_Frac22'),
#  ('gtctatgagatcgtgt', 'MR.F.12C-Con.D30.R3_Frac23'),
#  ('gtctatgagtcagata', 'MR.F.12C-Con.D30.R3_Frac24'),
#  ('tatagcgacgttacta', 'MR.F.12C-Con.D30.R3_Frac26'),
#  ('tatagcgaagagtcac', 'MR.F.12C-Con.D30.R3_Frac27'),
#  ('tatagcgatacgagac', 'MR.F.12C-Con.D30.R3_NC'),
#  ('cgagagttatcgtacg', 'MR.A.13C-Ami.D1.R1_Frac19'),
#  ('cgagagttactatctg', 'MR.A.13C-Ami.D1.R1_Frac20'),
#  ('cgagagtttagcgagt', 'MR.A.13C-Ami.D1.R1_Frac21'),
#  ('cgagagttctgcgtgt', 'MR.A.13C-Ami.D1.R1_Frac22'),
#  ('cgagagtttcatcgag', 'MR.A.13C-Ami.D1.R1_Frac23'),
#  ('cgagagttcgtgagtg', 'MR.A.13C-Ami.D1.R1_Frac24'),
#  ('cgagagttggatatct', 'MR.A.13C-Ami.D1.R1_Frac25'),
#  ('cgagagttgacaccgt', 'MR.A.13C-Ami.D1.R1_Frac26'),
#  ('gacatagtatcgtacg', 'MR.A.13C-Ami.D1.R1_Frac27'),
#  ('gacatagtactatctg', 'MR.A.13C-Ami.D1.R1_Frac28'),
#  ('gacatagttagcgagt', 'MR.A.13C-Ami.D1.R1_NC'),
#  ('gacatagtctgcgtgt', 'MR.A.13C-Pal.D6.R1_Frac5'),
#  ('gacatagttcatcgag', 'MR.A.13C-Pal.D6.R1_Frac6'),
#  ('gacatagtcgtgagtg', 'MR.A.13C-Pal.D6.R1_Frac7'),
#  ('gacatagtggatatct', 'MR.A.13C-Pal.D6.R1_Frac8'),
#  ('gacatagtgacaccgt', 'MR.A.13C-Pal.D6.R1_Frac9'),
#  ('acgctactatcgtacg', 'MR.A.13C-Pal.D6.R1_Frac10'),
#  ('acgctactactatctg', 'MR.A.13C-Pal.D6.R1_Frac11'),
#  ('acgctacttagcgagt', 'MR.A.13C-Pal.D6.R1_Frac12'),
#  ('acgctactctgcgtgt', 'MR.A.13C-Pal.D6.R1_Frac13'),
#  ('acgctacttcatcgag', 'MR.A.13C-Pal.D6.R1_Frac14'),
#  ('acgctactcgtgagtg', 'MR.A.13C-Pal.D6.R1_Frac15'),
#  ('acgctactggatatct', 'MR.A.13C-Pal.D6.R1_Frac16'),
#  ('acgctactgacaccgt', 'MR.A.13C-Pal.D6.R1_Frac17'),
#  ('actcactgatcgtacg', 'MR.A.13C-Pal.D6.R1_Frac18'),
#  ('actcactgactatctg', 'MR.A.13C-Pal.D6.R1_Frac19'),
#  ('actcactgtagcgagt', 'MR.A.13C-Pal.D6.R1_Frac20'),
#  ('actcactgctgcgtgt', 'MR.A.13C-Pal.D6.R1_Frac21'),
#  ('actcactgtcatcgag', 'MR.A.13C-Pal.D6.R1_Frac22'),
#  ('actcactgcgtgagtg', 'MR.A.13C-Pal.D6.R1_Frac23'),
#  ('actcactgggatatct', 'MR.A.13C-Pal.D6.R1_Frac24'),
#  ('actcactggacaccgt', 'MR.A.13C-Pal.D6.R1_Frac25'),
#  ('tgagtacgatcgtacg', 'MR.A.13C-Pal.D6.R1_Frac26'),
#  ('tgagtacgactatctg', 'MR.A.13C-Pal.D6.R1_Frac27'),
#  ('tgagtacgtagcgagt', 'MR.A.13C-Pal.D6.R1_Frac28'),
#  ('tgagtacgctgcgtgt', 'MR.A.13C-Pal.D6.R1_Frac29'),
#  ('tgagtacgtcatcgag', 'MR.A.13C-Pal.D6.R1_NC'),
#  ('tgagtacgcgtgagtg', 'MR.A.13C-Pal.D6.R1_MC'),
#  ('tgagtacgggatatct', 'MR.A.12C-Con.D3.R1_Frac5'),
#  ('actacgaccgtgagtg', 'MR.A.13C-Van.D6.R2_Frac10'),
#  ('gtctgctagacaccgt', 'MR.A.13C-Van.D6.R2_Frac20'),
#  ('cgagagttctactata', 'MR.M.13C-Xyl.D14.R1_Frac11'),
#  ('gacatagtgtcagata', 'MR.M.13C-Xyl.D14.R1_Frac26'),
#  ('acgctactctactata', 'MR.M.13C-Xyl.D14.R1_Frac27'),
#  ('tatagcgactactata', 'MR.F.12C-Con.D30.R3_Frac25')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 2519133 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 2073226.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                          Sample  seq_count
# 0    MR.F.13C-Van.D30.R2_Frac22      18154
# 1      MR.M.12C-Con.D3.R1_Frac5      20163
# 2     MR.A.13C-Van.D6.R2_Frac17      10158
# 3      MR.A.13C-Van.D6.R2_Frac4      23888
# 4     MR.F.13C-Van.D30.R2_Frac9      29593
# 5     MR.A.13C-Ami.D1.R1_Frac28      16353
# 6     MR.A.13C-Van.D6.R2_Frac21      16464
# 7     MR.A.13C-Ami.D1.R1_Frac19      31988
# 8     MR.A.13C-Van.D6.R2_Frac14      19310
# 9      MR.M.12C-Con.D3.R1_Frac6      15097
# 10   MR.F.13C-Van.D30.R2_Frac24      20618
# 11     MR.A.13C-Van.D6.R2_Frac7      19580
# 12     MR.M.12C-Con.D3.R1_Frac7      21162
# 13   MR.F.13C-Van.D30.R2_Frac26      26824
# 14   MR.F.13C-Van.D30.R2_Frac10      39597
# 15    MR.A.12C-Con.D3.R1_Frac23       6635
# 16   MR.F.13C-Van.D30.R2_Frac25      24107
# 17     MR.A.13C-Pal.D6.R1_Frac7       7609
# 18    MR.A.13C-Van.D6.R2_Frac25      12638
# 19   MR.F.13C-Van.D30.R2_Frac14      29474
# 20   MR.M.13C-Xyl.D14.R1_Frac17       8503
# 21   MR.F.13C-Van.D30.R2_Frac12      21517
# 22    MR.M.12C-Con.D3.R1_Frac22       9446
# 23    MR.A.13C-Van.D6.R2_Frac22      14271
# 24   MR.F.12C-Con.D30.R3_Frac23       5144
# 25    MR.F.13C-Van.D30.R2_Frac7      19746
# 26    MR.A.13C-Van.D6.R2_Frac13      41594
# 27    MR.A.12C-Con.D3.R1_Frac12       8150
# 28        MR.A.13C-Van.D6.R2_NC       1696
# 29    MR.A.13C-Pal.D6.R1_Frac11       3442
# ..                          ...        ...
# 158   MR.A.12C-Con.D3.R1_Frac18       4072
# 159   MR.A.12C-Con.D3.R1_Frac17       8706
# 160  MR.F.12C-Con.D30.R3_Frac11       2880
# 161   MR.A.13C-Pal.D6.R1_Frac19       2963
# 162   MR.A.13C-Pal.D6.R1_Frac29       3408
# 163   MR.M.13C-Xyl.D14.R1_Frac8       5551
# 164  MR.F.12C-Con.D30.R3_Frac10       3284
# 165  MR.M.13C-Xyl.D14.R1_Frac11       3007
# 166   MR.A.13C-Van.D6.R2_Frac15      12000
# 167   MR.A.13C-Pal.D6.R1_Frac28       6348
# 168   MR.A.13C-Van.D6.R2_Frac23      14480
# 169   MR.A.13C-Van.D6.R2_Frac19      12534
# 170    MR.A.12C-Con.D3.R1_Frac5       5517
# 171   MR.M.13C-Xyl.D14.R1_Frac4       3272
# 172  MR.M.13C-Xyl.D14.R1_Frac26       7217
# 173  MR.M.13C-Xyl.D14.R1_Frac20       3293
# 174  MR.M.13C-Xyl.D14.R1_Frac21       3167
# 175   MR.A.13C-Pal.D6.R1_Frac26       5599
# 176      MR.F.12C-Con.D30.R3_NC        340
# 177  MR.F.13C-Van.D30.R2_Frac15       9826
# 178  MR.F.12C-Con.D30.R3_Frac20       4834
# 179  MR.F.12C-Con.D30.R3_Frac21       2493
# 180  MR.F.12C-Con.D30.R3_Frac18       2566
# 181   MR.A.13C-Pal.D6.R1_Frac17       4508
# 182  MR.F.12C-Con.D30.R3_Frac17       2513
# 183  MR.F.12C-Con.D30.R3_Frac19       2108
# 184       MR.A.13C-Ami.D1.R1_NC        619
# 185      MR.M.13C-Xyl.D14.R1_NC        383
# 186       MR.A.12C-Con.D3.R1_NC        197
# 187       MR.A.13C-Pal.D6.R1_NC        183
#
# [188 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 2000,]
# Out:
#                         Sample seq_count
# 28       MR.A.13C-Van.D6.R2_NC      1696
# 118 MR.F.12C-Con.D30.R3_Frac25      1805
# 144     MR.F.13C-Van.D30.R2_NC       941
# 176     MR.F.12C-Con.D30.R3_NC       340
# 184      MR.A.13C-Ami.D1.R1_NC       619
# 185     MR.M.13C-Xyl.D14.R1_NC       383
# 186      MR.A.12C-Con.D3.R1_NC       197
# 187      MR.A.13C-Pal.D6.R1_NC       183

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 188 samples
# You should have 188 samples
