# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/160713_FC2Unfrac/run2'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/160713_FC2Unfrac'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = '160713_FC2Unfrac'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-160713_FC2Unfrac.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/160713_FC2Unfrac

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                   #Sample  primer_number        exp_type  extraction_plate_ID  \
# 12     MR.F.12C-Con.D0.R2            129  Unfractionated  Unfrac2_Enr3_160525
# 25     MR.A.13C-Van.D6.R1            130  Unfractionated  Unfrac2_Enr3_160525
# 38     MR.A.13C-Ami.D3.R2            131  Unfractionated  Unfrac2_Enr3_160525
# 51     MR.F.13C-Ami.D3.R2            132  Unfractionated  Unfrac2_Enr3_160525
# 64    MR.M.13C-Van.D14.R1            133  Unfractionated  Unfrac2_Enr3_160525
# 77    MR.M.13C-Ami.D14.R1            134  Unfractionated  Unfrac2_Enr3_160525
# 90    MR.M.13C-Pal.D14.R1            135  Unfractionated  Unfrac2_Enr3_160525
# 104   MR.F.13C-Cel.D14.R1            136  Unfractionated  Unfrac2_Enr3_160525
# 2108  160713_FC2Unfrac  Unfrac_Pool_1              E4  MR.A.13C-Cel.D30.R2
# 2120  160713_FC2Unfrac  Unfrac_Pool_1              F4   MR.A.13C-Pal.D6.R1
# 2132  160713_FC2Unfrac  Unfrac_Pool_1              G4   MR.A.12C-Con.D3.R1
# 2144  160713_FC2Unfrac  Unfrac_Pool_1              H4  MR.F.H2O-Con.D30.R3
# 2156  160713_FC2Unfrac  Unfrac_Pool_1              A5  MR.A.13C-Pal.D30.R2
# 2168  160713_FC2Unfrac  Unfrac_Pool_1              B5  MR.F.13C-Pal.D30.R2
# 2180  160713_FC2Unfrac  Unfrac_Pool_1              C5   MR.A.13C-Xyl.D6.R2
# 2192  160713_FC2Unfrac  Unfrac_Pool_1              D5   MR.A.12C-Con.D1.R2
# 2204  160713_FC2Unfrac  Unfrac_Pool_1              E5   MR.M.13C-Xyl.D6.R2
# 2216  160713_FC2Unfrac  Unfrac_Pool_1              F5  MR.F.13C-Cel.D14.R2
# 2228  160713_FC2Unfrac  Unfrac_Pool_1              G5  MR.M.13C-Van.D30.R1
# 2239  160713_FC2Unfrac  Unfrac_Pool_1              F9   MR.A.13C-Pal.D6.R2
# 2251  160713_FC2Unfrac  Unfrac_Pool_1             H10   MR.F.13C-Van.D6.R1
# 2263  160713_FC2Unfrac  Unfrac_Pool_2              A1   MR.F.13C-Xyl.D1.R1
# 2275  160713_FC2Unfrac  Unfrac_Pool_2              H2  MR.F.13C-Cel.D30.R2
# 2287  160713_FC2Unfrac  Unfrac_Pool_2              A3   MR.M.13C-Xyl.D3.R2
#
#      substrate   day     ...       water_holding_capacity__g.g  percent_N  \
# 12     12C-Con   0.0     ...                               NaN        NaN
# 25     13C-Van   6.0     ...                               NaN        NaN
# 38     13C-Ami   3.0     ...                               NaN        NaN
# 51     13C-Ami   3.0     ...                               NaN        NaN
# 64     13C-Van  14.0     ...                               NaN        NaN
# 77     13C-Ami  14.0     ...                               NaN        NaN
# 90     13C-Pal  14.0     ...                               NaN        NaN
# 104    13C-Cel  14.0     ...                               NaN        NaN
# 118    12C-Con   3.0     ...                               NaN        NaN
# 132    13C-Van  14.0     ...                               NaN        NaN
# 146    13C-Xyl   1.0     ...                               NaN        NaN
# 159    12C-Con   0.0     ...                               NaN        NaN
# 172    13C-Xyl   3.0     ...                               NaN        NaN
# 185    13C-Ami  14.0     ...                               NaN        NaN
# 198    12C-Con   1.0     ...                               NaN        NaN
# 211    13C-Ami   1.0     ...                               NaN        NaN
# 223    13C-Cel  14.0     ...                               NaN        NaN
# 235    12C-Con   3.0     ...                               NaN        NaN
# 247    13C-Ami   6.0     ...                               NaN        NaN
# 259    H2O-Con  30.0     ...                               NaN        NaN
# 271    H2O-Con  30.0     ...                               NaN        NaN
# 283    12C-Con   6.0     ...                               NaN        NaN
# 295    13C-Pal  30.0     ...                               NaN        NaN
# 307    13C-Cel  30.0     ...                               NaN        NaN
# 319    12C-Con   1.0     ...                               NaN        NaN
# 331    12C-Con  30.0     ...                               NaN        NaN
# 343    13C-Van  30.0     ...                               NaN        NaN
# 356    13C-Xyl   1.0     ...                               NaN        NaN
# 369    13C-Ami   3.0     ...                               NaN        NaN
# 382    13C-Van   6.0     ...                               NaN        NaN
# ...        ...   ...     ...                               ...        ...
# 1942   13C-Ami   1.0     ...                               NaN        NaN
# 1954   13C-Ami   6.0     ...                               NaN        NaN
# 1966   13C-Xyl   6.0     ...                               NaN        NaN
# 1978   13C-Xyl   6.0     ...                               NaN        NaN
# 1990   13C-Xyl   3.0     ...                               NaN        NaN
# 2002   H2O-Con  30.0     ...                               NaN        NaN
# 2014   12C-Con   6.0     ...                               NaN        NaN
# 2026   12C-Con   6.0     ...                               NaN        NaN
# 2038   12C-Con  14.0     ...                               NaN        NaN
# 2050   13C-Cel   6.0     ...                               NaN        NaN
# 2061   13C-Pal   6.0     ...                               NaN        NaN
# 2072   H2O-Con  30.0     ...                               NaN        NaN
# 2084   13C-Xyl   1.0     ...                               NaN        NaN
# 2096   13C-Ami  14.0     ...                               NaN        NaN
# 2108   13C-Cel  30.0     ...                               NaN        NaN
# 2120   13C-Pal   6.0     ...                               NaN        NaN
# 2132   12C-Con   3.0     ...                               NaN        NaN
# 2144   H2O-Con  30.0     ...                               NaN        NaN
# 2156   13C-Pal  30.0     ...                               NaN        NaN
# 2168   13C-Pal  30.0     ...                               NaN        NaN
# 2180   13C-Xyl   6.0     ...                               NaN        NaN
# 2192   12C-Con   1.0     ...                               NaN        NaN
# 2204   13C-Xyl   6.0     ...                               NaN        NaN
# 2216   13C-Cel  14.0     ...                               NaN        NaN
# 2228   13C-Van  30.0     ...                               NaN        NaN
# 2239   13C-Pal   6.0     ...                               NaN        NaN
# 2251   13C-Van   6.0     ...                               NaN        NaN
# 2263   13C-Xyl   1.0     ...                               NaN        NaN
# 2275   13C-Cel  30.0     ...                               NaN        NaN
# 2287   13C-Xyl   3.0     ...                               NaN        NaN
#
#       percent_C sand__perc silt__perc clay__perc DNA_conc__ng_ul notes  \
# 12          NaN        NaN        NaN        NaN          22.593   NaN
# 25          NaN        NaN        NaN        NaN           7.884   NaN
# 38          NaN        NaN        NaN        NaN           3.913   NaN
# 51          NaN        NaN        NaN        NaN           14.06   NaN
# 64          NaN        NaN        NaN        NaN          -0.088   NaN
# 77          NaN        NaN        NaN        NaN          27.094   NaN
# 90          NaN        NaN        NaN        NaN          15.905   NaN
# 104         NaN        NaN        NaN        NaN           0.173   NaN
# 118         NaN        NaN        NaN        NaN          19.152   NaN
# 132         NaN        NaN        NaN        NaN           4.091   NaN
# 146         NaN        NaN        NaN        NaN           7.907   NaN
# 159         NaN        NaN        NaN        NaN          21.587   NaN
# 172         NaN        NaN        NaN        NaN           3.028   NaN
# 185         NaN        NaN        NaN        NaN           3.914   NaN
# 198         NaN        NaN        NaN        NaN          20.092   NaN
# 211         NaN        NaN        NaN        NaN          11.775   NaN
# 223         NaN        NaN        NaN        NaN          12.647   NaN
# 235         NaN        NaN        NaN        NaN          21.254   NaN
# 185      TCGACGAG     CTACGCAG
# 198      GATCGTGT     CTACGCAG
# 211      GTCAGATA     CTACGCAG
# 223      CTACTATA     GGAGACTA
# 235      CGTTACTA     GGAGACTA
# 247      AGAGTCAC     GGAGACTA
# 259      TACGAGAC     GGAGACTA
# 271      ACGTCTCG     GGAGACTA
# 283      TCGACGAG     GGAGACTA
# 295      GATCGTGT     GGAGACTA
# 307      GTCAGATA     GGAGACTA
# 319      CTACTATA     GTCGCTCG
# 331      CGTTACTA     GTCGCTCG
# 343      AGAGTCAC     GTCGCTCG
# 356      TACGAGAC     GTCGCTCG
# 369      ACGTCTCG     GTCGCTCG
# 382      TCGACGAG     GTCGCTCG
# ...           ...          ...
# 1942     GGATATCT     ACTATGTC
# 1954     GACACCGT     ACTATGTC
# 1966     ATCGTACG     AGTAGCGT
# 1978     ACTATCTG     AGTAGCGT
# 1990     TAGCGAGT     AGTAGCGT
# 2002     CTGCGTGT     AGTAGCGT
# 2014     TCATCGAG     AGTAGCGT
# 2026     CGTGAGTG     AGTAGCGT
# 2038     GGATATCT     AGTAGCGT
# 2050     GACACCGT     AGTAGCGT
# 2061     ATCGTACG     CAGTGAGT
# 2072     ACTATCTG     CAGTGAGT
# 2084     TAGCGAGT     CAGTGAGT
# 2096     CTGCGTGT     CAGTGAGT
# 2108     TCATCGAG     CAGTGAGT
# 2120     CGTGAGTG     CAGTGAGT
# 2132     GGATATCT     CAGTGAGT
# 2144     GACACCGT     CAGTGAGT
# 2156     ATCGTACG     CGTACTCA
# 2168     ACTATCTG     CGTACTCA
# 2180     TAGCGAGT     CGTACTCA
# 2192     CTGCGTGT     CGTACTCA
# 2204     TCATCGAG     CGTACTCA
# 2216     CGTGAGTG     CGTACTCA
# 2228     GGATATCT     CGTACTCA
# 2239     CGTGAGTG     GTCGTAGT
# 2251     GACACCGT     TAGCAGAC
# 2263     CTACTATA     AACTCTCG
# 2275     GTCAGATA     ACTATGTC
# 2287     CTACTATA     AGTAGCGT
#
# [171 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 24 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 171
[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MR.F.12C-Con.D0.R2'),
#  ('tgagtacgcgttacta', 'MR.A.13C-Van.D6.R1'),
#  ('tgagtacgagagtcac', 'MR.A.13C-Ami.D3.R2'),
#  ('tgagtacgtacgagac', 'MR.F.13C-Ami.D3.R2'),
#  ('tgagtacgacgtctcg', 'MR.M.13C-Van.D14.R1'),
#  ('tgagtacgtcgacgag', 'MR.M.13C-Ami.D14.R1'),
#  ('tgagtacggatcgtgt', 'MR.M.13C-Pal.D14.R1'),
#  ('tgagtacggtcagata', 'MR.F.13C-Cel.D14.R1'),
#  ('ctgcgtagctactata', 'MR.F.12C-Con.D3.R2'),
#  ('ctgcgtagcgttacta', 'MR.A.13C-Van.D14.R1'),
#  ('ctgcgtagagagtcac', 'MR.F.13C-Xyl.D1.R2'),
#  ('ctgcgtagtacgagac', 'MR.M.12C-Con.D0.R2'),
#  ('ctgcgtagacgtctcg', 'MR.A.13C-Xyl.D3.R1'),
#  ('ctgcgtagtcgacgag', 'MR.A.13C-Ami.D14.R2'),
#  ('ctgcgtaggatcgtgt', 'MR.F.12C-Con.D1.R1'),
#  ('ctgcgtaggtcagata', 'MR.M.13C-Ami.D1.R2'),
#  ('tagtctccctactata', 'MR.M.13C-Cel.D14.R1'),
#  ('tagtctcccgttacta', 'MR.F.12C-Con.D3.R1'),
#  ('tagtctccagagtcac', 'MR.F.13C-Ami.D6.R2'),
#  ('tagtctcctacgagac', 'MR.F.H2O-Con.D30.R2'),
#  ('tagtctccacgtctcg', 'MR.M.H2O-Con.D30.R3'),
#  ('tagtctcctcgacgag', 'MR.A.12C-Con.D6.R1'),
#  ('tagtctccgatcgtgt', 'MR.A.13C-Pal.D30.R3'),
#  ('tagtctccgtcagata', 'MR.A.13C-Cel.D30.R1'),
#  ('cgagcgacctactata', 'MR.M.12C-Con.D1.R1'),
#  ('cgagcgaccgttacta', 'MR.A.12C-Con.D30.R3'),
#  ('cgagcgacagagtcac', 'MR.A.13C-Van.D30.R3'),
#  ('cgagcgactacgagac', 'MR.M.13C-Xyl.D1.R1'),
#  ('cgagcgacacgtctcg', 'MR.M.13C-Ami.D3.R2'),
#  ('cgagcgactcgacgag', 'MR.M.13C-Van.D6.R2'),
#  ('tgagtacggacaccgt', 'MR.M.12C-Con.D1.R2'),
#  ('ctgcgtagatcgtacg', 'MR.M.13C-Xyl.D6.R1'),
#  ('ctgcgtagactatctg', 'MR.A.13C-Ami.D3.R1'),
#  ('ctgcgtagtagcgagt', 'MR.M.13C-Xyl.D14.R1'),
#  ('ctgcgtagctgcgtgt', 'MR.A.13C-Van.D6.R2'),
#  ('ctgcgtagtcatcgag', 'MR.M.H2O-Con.D30.R2'),
#  ('ctgcgtagcgtgagtg', 'MR.A.13C-Pal.D30.R1'),
#  ('ctgcgtagggatatct', 'MR.M.13C-Cel.D30.R2'),
#  ('ctgcgtaggacaccgt', 'MR.F.13C-Xyl.D14.R3'),
#  ('tagtctccatcgtacg', 'MR.A.12C-Con.D3.R2'),
#  ('tagtctccactatctg', 'MR.F.13C-Ami.D14.R2'),
#  ('tagtctcctagcgagt', 'MR.M.13C-Cel.D6.R2'),
#  ('tagtctccctgcgtgt', 'MR.A.13C-Ami.D14.R1'),
#  ('tagtctcctcatcgag', 'MR.A.13C-Xyl.D14.R3'),
#  ('tagtctcccgtgagtg', 'MR.A.13C-Xyl.D1.R1'),
#  ('tagtctccggatatct', 'MR.A.H2O-Con.D30.R1'),
#  ('tagtctccgacaccgt', 'MR.M.13C-Pal.D30.R3'),
#  ('cgagcgacatcgtacg', 'MR.F.13C-Ami.D6.R1'),
#  ('cgagcgacactatctg', 'MR.M.13C-Cel.D6.R1'),
#  ('cgagcgactagcgagt', 'MR.F.12C-Con.D0.R1'),
#  ('cgagcgacctgcgtgt', 'MR.F.13C-Ami.D3.R1'),
#  ('cgagcgactcatcgag', 'MR.F.12C-Con.D1.R2'),
#  ('cgagcgaccgtgagtg', 'MR.A.12C-Con.D30.R1'),
#  ('cgagcgacggatatct', 'MR.M.13C-Van.D6.R1'),
#  ('cgagcgacgacaccgt', 'MR.M.13C-Van.D30.R3'),
#  ('actacgacatcgtacg', 'MR.A.H2O-Con.D30.R2'),
#  ('actacgacactatctg', 'MR.A.13C-Van.D30.R2'),
#  ('actacgactagcgagt', 'MR.M.12C-Con.D30.R1'),
#  ('actacgacctgcgtgt', 'MR.F.13C-Van.D30.R1'),
#  ('actacgactcatcgag', 'MR.F.13C-Ami.D1.R2'),
#  ('actacgacggatatct', 'MR.M.13C-Pal.D30.R2'),
#  ('actacgacgacaccgt', 'MR.M.13C-Cel.D30.R3'),
#  ('gtctgctaatcgtacg', 'MR.F.12C-Con.D14.R2'),
#  ('gtctgctaactatctg', 'MR.F.12C-Con.D30.R1'),
#  ('gtctgctatagcgagt', 'MR.A.13C-Xyl.D14.R2'),
#  ('gtctgctactgcgtgt', 'MR.M.12C-Con.D14.R1'),
#  ('gtctgctatcatcgag', 'MR.F.13C-Xyl.D14.R1'),
#  ('gtctgctacgtgagtg', 'MR.M.13C-Pal.D6.R2'),
#  ('gtctgctaggatatct', 'MR.F.13C-Ami.D14.R3'),
#  ('gtctatgaatcgtacg', 'MR.F.13C-Pal.D14.R1'),
#  ('gtctatgaactatctg', 'MR.M.13C-Pal.D14.R2'),
#  ('gtctatgatagcgagt', 'MR.M.12C-Con.D14.R2'),
#  ('gtctatgactgcgtgt', 'MR.M.13C-Xyl.D14.R3'),
#  ('gtctatgatcatcgag', 'MR.A.12C-Con.D14.R1'),
#  ('gtctatgacgtgagtg', 'MR.M.13C-Van.D14.R2'),
#  ('gtctatgaggatatct', 'MR.F.12C-Con.D30.R2'),
#  ('gtctatgagacaccgt', 'MR.M.13C-Pal.D6.R1'),
#  ('tatagcgaatcgtacg', 'MR.A.12C-Con.D0.R1'),
#  ('tatagcgaactatctg', 'MR.F.13C-Cel.D30.R1'),
#  ('tatagcgatagcgagt', 'MR.A.13C-Ami.D14.R3'),
#  ('tatagcgactgcgtgt', 'MR.A.13C-Cel.D30.R3'),
#  ('tatagcgatcatcgag', 'MR.F.13C-Van.D30.R2'),
#  ('tatagcgacgtgagtg', 'MR.F.12C-Con.D6.R2'),
#  ('tatagcgaggatatct', 'MR.M.12C-Con.D3.R1'),
#  ('tatagcgagacaccgt', 'MR.F.12C-Con.D30.R3'),
#  ('cgagagttcgttacta', 'MR.M.13C-Ami.D14.R3'),
#  ('cgagagttagagtcac', 'MR.M.12C-Con.D30.R3'),
#  ('cgagagtttacgagac', 'MR.A.12C-Con.D1.R1'),
#  ('cgagagttacgtctcg', 'MR.F.13C-Pal.D30.R3'),
#  ('cgagagtttcgacgag', 'MR.A.13C-Ami.D6.R1'),
#  ('cgagagttgatcgtgt', 'MR.M.13C-Pal.D30.R1'),
#  ('cgagagttgtcagata', 'MR.A.12C-Con.D14.R2'),
#  ('gacatagtctactata', 'MR.A.13C-Xyl.D3.R2'),
#  ('gacatagtcgttacta', 'MR.A.13C-Van.D14.R2'),
#  ('gacatagtagagtcac', 'MR.A.13C-Xyl.D14.R1'),
#  ('gacatagttacgagac', 'MR.M.13C-Xyl.D14.R2'),
#  ('gacatagtacgtctcg', 'MR.F.13C-Ami.D14.R1'),
#  ('gacatagttcgacgag', 'MR.M.13C-Ami.D3.R1'),
#  ('gacatagtgatcgtgt', 'MR.F.13C-Xyl.D14.R2'),
#  ('acgctactcgttacta', 'MR.M.13C-Van.D30.R2'),
#  ('acgctactagagtcac', 'MR.F.13C-Van.D6.R2'),
#  ('acgctacttacgagac', 'MR.M.H2O-Con.D30.R1'),
#  ('acgctactacgtctcg', 'MR.M.12C-Con.D3.R2'),
#  ('acgctacttcgacgag', 'MR.A.13C-Xyl.D1.R2'),
#  ('acgctactgatcgtgt', 'MR.A.12C-Con.D0.R2'),
#  ('acgctactgtcagata', 'MR.F.13C-Van.D14.R2'),
#  ('actcactgctactata', 'MR.M.13C-Xyl.D3.R1'),
#  ('actcactgcgttacta', 'MR.F.13C-Ami.D1.R1'),
#  ('actcactgagagtcac', 'MR.F.13C-Pal.D14.R2'),
#  ('actcactgtacgagac', 'MR.F.13C-Pal.D30.R1'),
#  ('actcactgacgtctcg', 'MR.A.13C-Cel.D6.R1'),
#  ('actcactgtcgacgag', 'MR.M.12C-Con.D6.R1'),
#  ('actcactggatcgtgt', 'MR.M.12C-Con.D0.R1'),
#  ('actcactggtcagata', 'MR.A.12C-Con.D30.R2'),
#  ('cgagcgacgatcgtgt', 'MR.A.13C-Cel.D14.R2'),
#  ('cgagcgacgtcagata', 'MR.A.13C-Cel.D14.R1'),
#  ('actacgacctactata', 'MR.A.13C-Pal.D14.R1'),
#  ('actacgaccgttacta', 'MR.M.13C-Ami.D6.R2'),
#  ('actacgacagagtcac', 'MR.F.13C-Cel.D6.R2'),
#  ('actacgactacgagac', 'MR.F.13C-Cel.D30.R3'),
#  ('actacgacacgtctcg', 'MR.M.13C-Ami.D1.R1'),
#  ('actacgactcgacgag', 'Unfrac_water_control'),
#  ('actacgacgatcgtgt', 'MR.F.13C-Ami.D3.R2_Frac27'),
#  ('actacgacgtcagata', 'MR.M.13C-Xyl.D3.R1_Frac18'),
#  ('gtctgctactactata', 'MR.M.13C-Xyl.D3.R1_Frac20'),
#  ('gtctgctacgttacta', 'Unfrac_MC'),
#  ('gtctgctaagagtcac', 'Unfrac_NC'),
#  ('cgagagttatcgtacg', 'MR.M.13C-Cel.D14.R2'),
#  ('cgagagttactatctg', 'MR.M.12C-Con.D30.R2'),
#  ('cgagagtttagcgagt', 'MR.A.13C-Cel.D6.R2'),
#  ('cgagagttctgcgtgt', 'MR.A.13C-Ami.D1.R1'),
#  ('cgagagtttcatcgag', 'MR.F.13C-Pal.D6.R1'),
#  ('cgagagttcgtgagtg', 'MR.A.13C-Van.D30.R1'),
#  ('cgagagttggatatct', 'MR.A.12C-Con.D6.R2'),
#  ('cgagagttgacaccgt', 'MR.M.13C-Cel.D30.R1'),
#  ('gacatagtatcgtacg', 'MR.A.13C-Ami.D6.R2'),
#  ('gacatagtactatctg', 'MR.F.13C-Xyl.D6.R2'),
#  ('gacatagttagcgagt', 'MR.F.13C-Xyl.D3.R1'),
#  ('gacatagtctgcgtgt', 'MR.A.13C-Pal.D14.R2'),
#  ('gacatagttcatcgag', 'MR.F.13C-Van.D30.R3'),
#  ('gacatagtcgtgagtg', 'MR.F.13C-Van.D14.R1'),
#  ('gacatagtggatatct', 'MR.A.13C-Ami.D1.R2'),
#  ('gacatagtgacaccgt', 'MR.M.13C-Ami.D6.R1'),
#  ('acgctactatcgtacg', 'MR.F.13C-Xyl.D6.R1'),
#  ('acgctactactatctg', 'MR.A.13C-Xyl.D6.R1'),
#  ('acgctacttagcgagt', 'MR.F.13C-Xyl.D3.R2'),
#  ('acgctactctgcgtgt', 'MR.A.H2O-Con.D30.R3'),
#  ('acgctacttcatcgag', 'MR.F.12C-Con.D6.R1'),
#  ('acgctactcgtgagtg', 'MR.M.12C-Con.D6.R2'),
#  ('acgctactggatatct', 'MR.F.12C-Con.D14.R1'),
#  ('acgctactgacaccgt', 'MR.F.13C-Cel.D6.R1'),
#  ('actcactgatcgtacg', 'MR.F.13C-Pal.D6.R2'),
#  ('actcactgactatctg', 'MR.F.H2O-Con.D30.R1'),
#  ('actcactgtagcgagt', 'MR.M.13C-Xyl.D1.R2'),
#  ('actcactgctgcgtgt', 'MR.M.13C-Ami.D14.R2'),
#  ('actcactgtcatcgag', 'MR.A.13C-Cel.D30.R2'),
#  ('actcactgcgtgagtg', 'MR.A.13C-Pal.D6.R1'),
#  ('actcactgggatatct', 'MR.A.12C-Con.D3.R1'),
#  ('actcactggacaccgt', 'MR.F.H2O-Con.D30.R3'),
#  ('tgagtacgatcgtacg', 'MR.A.13C-Pal.D30.R2'),
#  ('tgagtacgactatctg', 'MR.F.13C-Pal.D30.R2'),
#  ('tgagtacgtagcgagt', 'MR.A.13C-Xyl.D6.R2'),
#  ('tgagtacgctgcgtgt', 'MR.A.12C-Con.D1.R2'),
#  ('tgagtacgtcatcgag', 'MR.M.13C-Xyl.D6.R2'),
#  ('tgagtacgcgtgagtg', 'MR.F.13C-Cel.D14.R2'),
#  ('tgagtacgggatatct', 'MR.M.13C-Van.D30.R1'),
#  ('actacgaccgtgagtg', 'MR.A.13C-Pal.D6.R2'),
#  ('gtctgctagacaccgt', 'MR.F.13C-Van.D6.R1'),
#  ('cgagagttctactata', 'MR.F.13C-Xyl.D1.R1'),
#  ('gacatagtgtcagata', 'MR.F.13C-Cel.D30.R2'),
#  ('acgctactctactata', 'MR.M.13C-Xyl.D3.R2')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 1695651 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 4780891.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                         Sample  seq_count
# 0           MR.A.13C-Ami.D6.R1     100368
# 1          MR.F.13C-Pal.D14.R1      18129
# 2           MR.F.13C-Xyl.D3.R2      14735
# 3          MR.M.H2O-Con.D30.R2      34233
# 4    MR.M.13C-Xyl.D3.R1_Frac18      85836
# 5           MR.M.13C-Ami.D3.R1      28191
# 6           MR.M.13C-Xyl.D6.R2      17818
# 7           MR.A.12C-Con.D3.R2      29344
# 8           MR.A.13C-Xyl.D3.R1      54929
# 9           MR.F.12C-Con.D6.R1      13782
# 10         MR.M.12C-Con.D30.R3      91647
# 11   MR.M.13C-Xyl.D3.R1_Frac20      61380
# 12          MR.M.12C-Con.D1.R1      60719
# 13          MR.M.13C-Ami.D6.R2      23544
# 14         MR.A.13C-Pal.D14.R2      14983
# 15          MR.A.13C-Ami.D3.R1      14044
# 16         MR.F.H2O-Con.D30.R3      12276
# 17         MR.F.13C-Xyl.D14.R2      37622
# 18         MR.A.13C-Ami.D14.R2      56437
# 19          MR.A.13C-Xyl.D3.R2      24739
# 20         MR.A.13C-Cel.D14.R1      39435
# 21          MR.A.12C-Con.D0.R2      78176
# 22          MR.F.13C-Van.D6.R1      34685
# 23         MR.F.12C-Con.D14.R2      14659
# 24         MR.F.13C-Cel.D30.R3      22204
# 25          MR.A.13C-Cel.D6.R1      58919
# 26         MR.F.13C-Xyl.D14.R1      19451
# 27         MR.F.13C-Van.D30.R3      60165
# 28         MR.M.13C-Pal.D14.R1      63675
# 29         MR.M.13C-Van.D30.R1      86708
# ..                         ...        ...
# 141         MR.A.13C-Pal.D6.R1      21969
# 142         MR.M.13C-Cel.D6.R2      12407
# 143         MR.M.13C-Ami.D6.R1      23610
# 144         MR.F.13C-Ami.D1.R1      10549
# 145         MR.F.13C-Van.D6.R2      14354
# 146        MR.F.12C-Con.D30.R1      19373
# 147         MR.M.12C-Con.D0.R2      19318
# 148         MR.M.12C-Con.D6.R2      19509
# 149        MR.M.13C-Cel.D14.R1      58925
# 150        MR.A.13C-Ami.D14.R3      24317
# 151         MR.M.13C-Pal.D6.R1      31499
# 152        MR.F.13C-Van.D14.R1      11607
# 153        MR.A.13C-Van.D14.R1      17153
# 154        MR.A.13C-Van.D30.R3      13789
# 155                  Unfrac_MC      41263
# 156        MR.F.13C-Van.D14.R2      16035
# 157         MR.A.12C-Con.D1.R2      13599
# 158         MR.M.12C-Con.D1.R2      13263
# 159         MR.F.13C-Xyl.D6.R1      14569
# 160        MR.A.13C-Van.D30.R2      19141
# 161        MR.F.13C-Cel.D30.R2      19047
# 162        MR.A.13C-Xyl.D14.R1      21083
# 163        MR.M.12C-Con.D14.R1      24226
# 164         MR.F.12C-Con.D0.R1      16400
# 165        MR.A.13C-Cel.D30.R2       8987
# 166       Unfrac_water_control       1866
# 167        MR.M.13C-Ami.D14.R2       6940
# 168         MR.F.13C-Xyl.D3.R1       9457
# 169         MR.F.13C-Ami.D3.R1       5721
# 170                  Unfrac_NC        467
#
# [171 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 1000,]
# Out:
#        Sample seq_count
# 170 Unfrac_NC       467
