# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/fullCyc2_lib16/run1'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib16'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'fullCyc2_lib16'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-fullCyc2_lib16.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib16

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                          #Sample  primer_number    exp_type  \
# 385      CC.F.151027.12C-Pal.D14             40  Enrichment
# 397      CF.M.151027.12C-Cel.D14             41  Enrichment
# 409      MW.F.151027.12C-Xyl.D02             42  Enrichment
# 421      SS.A.151026.12C-Ami.D04             43  Enrichment
# 433      MW.M.151027.12C-Xyl.D04             44  Enrichment
# 445      MR.A.151027.12C-Cel.D28             45  Enrichment
# 457      BH.M.151026.12C-Cel.D28             46  Enrichment
# 469      SS.M.151026.12C-Pal.D14             47  Enrichment
# 481      CC.M.151027.12C-Xyl.D02             48  Enrichment
# 493      MR.M.151027.H2O-Con.D02             49  Enrichment
# 505      MR.M.151027.12C-Pal.D14             50  Enrichment
# 517      MP.M.151026.12C-Cel.D28             51  Enrichment
Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 397          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 409          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 421          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 433          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 445          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 457          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 469          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 481          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 493          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 505          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 517          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 529          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 541          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 553          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 565          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 577          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 600          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 612          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 624          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 636          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 648          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 660          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 672          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 684          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 696          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 708          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 720          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 732          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 744          Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# ...                  ...             ...                    ...
# 1908         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 1920         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 1932         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 1944         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 1956         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 1968         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 1980         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 1992         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2004         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2016         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2028         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2040         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2074         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2086         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2098         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2110         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2122         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2134         Enr5_170113  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2146         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2158         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2170         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2182         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2194         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2206         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2218         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2230         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2241         Enr6_160809  fullCyc2_lib16  fullCyc2_lib16_pool_1
# 2254                 NaN  fullCyc2_lib16  fullCyc2_lib16_pool_2
# 2266                 NaN  fullCyc2_lib16  fullCyc2_lib16_pool_2
# 2278                 NaN  fullCyc2_lib16  fullCyc2_lib16_pool_2
#
#      pool_plate_well                  soil_ID substrate   day     ...       \
# 385               H5  CC.F.151027.12C-Pal.D14   12C-Pal  14.0     ...
# 397               A6  CF.M.151027.12C-Cel.D14   12C-Cel  14.0     ...
# 409               B6  MW.F.151027.12C-Xyl.D02   12C-Xyl   2.0     ...
# 421               C6  SS.A.151026.12C-Ami.D04   12C-Ami   4.0     ...
# 433               D6  MW.M.151027.12C-Xyl.D04   12C-Xyl   4.0     ...
# 445               E6  MR.A.151027.12C-Cel.D28   12C-Cel  28.0     ...
# 457               F6  BH.M.151026.12C-Cel.D28   12C-Cel  28.0     ...
# 469               G6  SS.M.151026.12C-Pal.D14   12C-Pal  14.0     ...
# 481               H6  CC.M.151027.12C-Xyl.D02   12C-Xyl   2.0     ...
# 493               A7  MR.M.151027.H2O-Con.D02   H2O-Con   2.0     ...
# 505               B7  MR.M.151027.12C-Pal.D14   12C-Pal  14.0     ...
# 517               C7  MP.M.151026.12C-Cel.D28   12C-Cel  28.0     ...
# 529               D7  BH.F.151026.12C-Cel.D28   12C-Cel  28.0     ...
# 541               E7  MP.F.151026.12C-Ami.D02   12C-Ami   2.0     ...
# 553               F7  MW.F.151027.H2O-Con.D14   H2O-Con  14.0     ...
# 565               G7  PP.M.151026.H2O-Con.D02   H2O-Con   2.0     ...
# 577               H7  SS.F.151026.12C-Xyl.D02   12C-Xyl   2.0     ...
# 600               B8  CC.F.151027.12C-Xyl.D02   12C-Xyl   2.0     ...
# 612               C8  MR.A.151027.H2O-Con.D14   H2O-Con  14.0     ...
# 624               D8  MW.F.151027.12C-Van.D02   12C-Van   2.0     ...
# 636               E8  MR.F.151027.12C-Xyl.D02   12C-Xyl   2.0     ...
# 648               F8  EL.M.151026.12C-Pal.D28   12C-Pal  28.0     ...
# 660               G8  BH.F.151026.12C-Pal.D28   12C-Pal  28.0     ...
# 672               H8  BH.M.151026.12C-Van.D04   12C-Van   4.0     ...
# 684               A9  EL.M.151026.12C-Van.D04   12C-Van   4.0     ...
# 696               B9  CF.F.151027.12C-Cel.D28   12C-Cel  28.0     ...
# 409         NaN          14.439           NaN     ACTATCTG     CTACGCAG
# 421         NaN           43.02           NaN     TAGCGAGT     CTACGCAG
# 433         NaN           0.412           NaN     CTGCGTGT     CTACGCAG
# 445         NaN            0.36           NaN     TCATCGAG     CTACGCAG
# 457         NaN          19.119           NaN     CGTGAGTG     CTACGCAG
# 469         NaN          21.595           NaN     GGATATCT     CTACGCAG
# 481         NaN          25.867           NaN     GACACCGT     CTACGCAG
# 493         NaN          13.817           NaN     ATCGTACG     GGAGACTA
# 505         NaN          20.508           NaN     ACTATCTG     GGAGACTA
# 517         NaN           6.027           NaN     TAGCGAGT     GGAGACTA
# 529         NaN          10.943           NaN     CTGCGTGT     GGAGACTA
# 541         NaN          17.437           NaN     TCATCGAG     GGAGACTA
# 553         NaN          23.079           NaN     CGTGAGTG     GGAGACTA
# 565         NaN          23.945           NaN     GGATATCT     GGAGACTA
# 577         NaN          13.418           NaN     GACACCGT     GGAGACTA
# 600         NaN           8.102           NaN     ACTATCTG     GTCGCTCG
# 612         NaN           0.539           NaN     TAGCGAGT     GTCGCTCG
# 624         NaN          14.918           NaN     CTGCGTGT     GTCGCTCG
# 636         NaN          12.991           NaN     TCATCGAG     GTCGCTCG
# 648         NaN           0.318           NaN     CGTGAGTG     GTCGCTCG
# 660         NaN          12.579           NaN     GGATATCT     GTCGCTCG
# 672         NaN          15.327           NaN     GACACCGT     GTCGCTCG
# 684         NaN           3.621           NaN     ATCGTACG     GTCGTAGT
# 696         NaN          20.605           NaN     ACTATCTG     GTCGTAGT
# 708         NaN           20.14           NaN     TAGCGAGT     GTCGTAGT
# 720         NaN          15.063           NaN     CTGCGTGT     GTCGTAGT
# 732         NaN           7.292           NaN     TCATCGAG     GTCGTAGT
# 744         NaN           1.494           NaN     GGATATCT     GTCGTAGT
# ...         ...             ...           ...          ...          ...
# 1908        NaN           2.457           NaN     TCATCGAG     ACTATGTC
# 1920        NaN          32.189           NaN     CGTGAGTG     ACTATGTC
# 1932        NaN           0.132           NaN     GGATATCT     ACTATGTC
# 1944        NaN           1.217           NaN     GACACCGT     ACTATGTC
# 1956        NaN          13.162           NaN     ATCGTACG     AGTAGCGT
# 1968        NaN           0.928           NaN     ACTATCTG     AGTAGCGT
# 1980        NaN           4.147           NaN     TAGCGAGT     AGTAGCGT
# 1992        NaN           0.983           NaN     CTGCGTGT     AGTAGCGT
# 2004        NaN            0.91           NaN     TCATCGAG     AGTAGCGT
# 2016        NaN           2.468           NaN     CGTGAGTG     AGTAGCGT
# 2028        NaN          13.788           NaN     GGATATCT     AGTAGCGT
# 2040        NaN           0.463           NaN     GACACCGT     AGTAGCGT
# 2074        NaN           6.329           NaN     TAGCGAGT     CAGTGAGT
# 2086        NaN           0.939           NaN     CTGCGTGT     CAGTGAGT
# 2098        NaN          14.598           NaN     TCATCGAG     CAGTGAGT
# 2110        NaN          17.467           NaN     CGTGAGTG     CAGTGAGT
# 2122        NaN          22.741           NaN     GGATATCT     CAGTGAGT
# 2134        NaN           0.304           NaN     GACACCGT     CAGTGAGT
# 2146        NaN           0.258           NaN     ATCGTACG     CGTACTCA
# 2158        NaN          21.471           NaN     ACTATCTG     CGTACTCA
# 2170        NaN          15.241           NaN     TAGCGAGT     CGTACTCA
# 2182        NaN           8.042           NaN     CTGCGTGT     CGTACTCA
# 2194        NaN          21.855           NaN     TCATCGAG     CGTACTCA
# 2206        NaN          22.623           NaN     CGTGAGTG     CGTACTCA
# 2218        NaN          25.446           NaN     GGATATCT     CGTACTCA
# 2230        NaN          13.228           NaN     CGTGAGTG     GTCGTAGT
# 2241        NaN            32.6           NaN     GACACCGT     TAGCAGAC
# 2254        NaN           0.197  Correct_soil     CTACTATA     AACTCTCG
# 2266        NaN           0.352  Correct_soil     GTCAGATA     ACTATGTC
# 2278        NaN           0.289  Correct_soil     CTACTATA     AGTAGCGT
#
# [107 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 20 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 107

[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacggacaccgt', 'CC.F.151027.12C-Pal.D14'),
#  ('ctgcgtagatcgtacg', 'CF.M.151027.12C-Cel.D14'),
#  ('ctgcgtagactatctg', 'MW.F.151027.12C-Xyl.D02'),
#  ('ctgcgtagtagcgagt', 'SS.A.151026.12C-Ami.D04'),
#  ('ctgcgtagctgcgtgt', 'MW.M.151027.12C-Xyl.D04'),
#  ('ctgcgtagtcatcgag', 'MR.A.151027.12C-Cel.D28'),
#  ('ctgcgtagcgtgagtg', 'BH.M.151026.12C-Cel.D28'),
#  ('ctgcgtagggatatct', 'SS.M.151026.12C-Pal.D14'),
#  ('ctgcgtaggacaccgt', 'CC.M.151027.12C-Xyl.D02'),
#  ('tagtctccatcgtacg', 'MR.M.151027.H2O-Con.D02'),
#  ('tagtctccactatctg', 'MR.M.151027.12C-Pal.D14'),
#  ('tagtctcctagcgagt', 'MP.M.151026.12C-Cel.D28'),
#  ('tagtctccctgcgtgt', 'BH.F.151026.12C-Cel.D28'),
#  ('tagtctcctcatcgag', 'MP.F.151026.12C-Ami.D02'),
#  ('tagtctcccgtgagtg', 'MW.F.151027.H2O-Con.D14'),
#  ('tagtctccggatatct', 'PP.M.151026.H2O-Con.D02'),
#  ('tagtctccgacaccgt', 'SS.F.151026.12C-Xyl.D02'),
#  ('cgagcgacactatctg', 'CC.F.151027.12C-Xyl.D02'),
#  ('cgagcgactagcgagt', 'MR.A.151027.H2O-Con.D14'),
#  ('cgagcgacctgcgtgt', 'MW.F.151027.12C-Van.D02'),
#  ('cgagcgactcatcgag', 'MR.F.151027.12C-Xyl.D02'),
#  ('cgagcgaccgtgagtg', 'EL.M.151026.12C-Pal.D28'),
#  ('cgagcgacggatatct', 'BH.F.151026.12C-Pal.D28'),
#  ('cgagcgacgacaccgt', 'BH.M.151026.12C-Van.D04'),
#  ('actacgacatcgtacg', 'EL.M.151026.12C-Van.D04'),
#  ('actacgacactatctg', 'CF.F.151027.12C-Cel.D28'),
#  ('actacgactagcgagt', 'CF.M.151027.H2O-Con.D14'),
#  ('actacgacctgcgtgt', 'SS.M.151026.H2O-Con.D02'),
#  ('actacgactcatcgag', 'BH.F.151026.H2O-Con.D14'),
#  ('actacgacggatatct', 'MW.A.151027.12C-Xyl.D04'),
#  ('actacgacgacaccgt', 'PP.F.151026.12C-Ami.D02'),
#  ('gtctgctaatcgtacg', 'MF.M.151026.H2O-Con.D04'),
#  ('gtctgctaactatctg', 'PP.F.151026.H2O-Con.D04'),
#  ('gtctgctatagcgagt', 'CF.F.151027.H2O-Con.D14'),
#  ('gtctgctactgcgtgt', 'MF.M.151026.12C-Cel.D14'),
#  ('gtctgctacgtgagtg', 'MP.A.151026.H2O-Con.D14'),
#  ('gtctatgaatcgtacg', 'BH.A.151026.12C-Xyl.D04'),
#  ('gtctatgaactatctg', 'MR.F.151027.12C-Cel.D14'),
#  ('gtctatgatagcgagt', 'CC.F.151027.12C-Cel.D28'),
#  ('gtctatgactgcgtgt', 'MW.F.151027.12C-Pal.D14'),
#  ('gtctatgacgtgagtg', 'MW.M.151027.H2O-Con.D02'),
#  ('tatagcgaactatctg', 'MR.A.151027.12C-Xyl.D02'),
#  ('tatagcgatagcgagt', 'CC.A.151027.H2O-Con.D02'),
#  ('cgagagttcgttacta', 'MR.M.13C-Ami.D14.R1_Frac6'),
#  ('cgagagttagagtcac', 'MR.M.13C-Ami.D14.R1_Frac7'),
#  ('cgagagtttacgagac', 'MR.M.13C-Ami.D14.R1_Frac8'),
#  ('cgagagttacgtctcg', 'MR.M.13C-Ami.D14.R1_Frac9'),
#  ('cgagagtttcgacgag', 'MR.M.13C-Ami.D14.R1_Frac10'),
#  ('cgagagttgatcgtgt', 'MR.M.13C-Ami.D14.R1_Frac11'),
#  ('cgagagttgtcagata', 'MR.M.13C-Ami.D14.R1_Frac12'),
#  ('gacatagtctactata', 'MR.M.13C-Ami.D14.R1_Frac13'),
#  ('gacatagtcgttacta', 'MR.M.13C-Ami.D14.R1_Frac14'),
#  ('gacatagtagagtcac', 'MR.M.13C-Ami.D14.R1_Frac15'),
#  ('gacatagttacgagac', 'MR.M.13C-Ami.D14.R1_Frac16'),
#  ('gacatagtacgtctcg', 'MR.M.13C-Ami.D14.R1_Frac17'),
#  ('gacatagttcgacgag', 'MR.M.13C-Ami.D14.R1_Frac18'),
#  ('gacatagtgatcgtgt', 'MR.M.13C-Ami.D14.R1_Frac19'),
#  ('acgctactcgttacta', 'MR.M.13C-Ami.D14.R1_Frac22'),
#  ('acgctactagagtcac', 'MR.M.13C-Ami.D14.R1_Frac23'),
#  ('acgctacttacgagac', 'MR.M.13C-Ami.D14.R1_Frac24'),
#  ('acgctactacgtctcg', 'MR.M.13C-Ami.D14.R1_Frac25'),
#  ('acgctacttcgacgag', 'MR.M.13C-Ami.D14.R1_Frac26'),
#  ('acgctactgatcgtgt', 'MR.M.13C-Ami.D14.R1_Frac27'),
#  ('acgctactgtcagata', 'MR.M.13C-Ami.D14.R1_NC'),
#  ('actcactgctactata', 'MR.M.13C-Ami.D14.R1_MC'),
#  ('cgagagttatcgtacg', 'EL.M.151026.12C-Van.D02'),
#  ('cgagagttactatctg', 'CF.A.151027.12C-Xyl.D04'),
#  ('cgagagtttagcgagt', 'MW.M.151027.12C-Ami.D02'),
#  ('cgagagttctgcgtgt', 'PP.A.151026.12C-Ami.D02'),
#  ('cgagagtttcatcgag', 'MW.F.151027.H2O-Con.D02'),
#  ('cgagagttcgtgagtg', 'EL.F.151026.12C-Xyl.D02'),
#  ('cgagagttggatatct', 'BH.F.151026.H2O-Con.D28'),
#  ('cgagagttgacaccgt', 'PP.M.151026.H2O-Con.D04'),
#  ('gacatagtatcgtacg', 'CF.F.151027.12C-Pal.D14'),
#  ('gacatagtactatctg', 'CF.F.151027.H2O-Con.D28'),
#  ('gacatagttagcgagt', 'MF.F.151026.12C-Ami.D04'),
#  ('gacatagtctgcgtgt', 'EL.F.151026.12C-Ami.D04'),
#  ('gacatagttcatcgag', 'MR.M.151027.H2O-Con.D14'),
#  ('gacatagtcgtgagtg', 'SS.A.151026.12C-Van.D02'),
#  ('gacatagtggatatct', 'CC.A.151027.12C-Pal.D14'),
#  ('gacatagtgacaccgt', 'EL.F.151026.H2O-Con.D02'),
#  ('acgctactatcgtacg', 'CC.M.151027.12C-Cel.D28'),
#  ('acgctactactatctg', 'MW.A.151027.H2O-Con.D14'),
#  ('acgctacttagcgagt', 'SS.F.151026.H2O-Con.D28'),
#  ('acgctactctgcgtgt', 'MW.A.151027.12C-Xyl.D02'),
#  ('acgctacttcatcgag', 'EL.A.151026.12C-Pal.D14'),
#  ('acgctactcgtgagtg', 'PP.A.151026.12C-Van.D02'),
#  ('acgctactggatatct', 'MR.F.151027.12C-Cel.D28'),
#  ('acgctactgacaccgt', 'PP.A.151026.H2O-Con.D28'),
#  ('actcactgtagcgagt', 'BH.F.151026.H2O-Con.D02'),
#  ('actcactgctgcgtgt', 'EL.F.151026.12C-Xyl.D04'),
#  ('actcactgtcatcgag', 'SS.F.151026.12C-Van.D04'),
#  ('actcactgcgtgagtg', 'MW.F.151027.12C-Ami.D02'),
#  ('actcactgggatatct', 'MW.F.151027.12C-Ami.D04'),
#  ('actcactggacaccgt', 'Enr5_H2O_con'),
#  ('tgagtacgatcgtacg', 'Enr6_H2O_con'),
#  ('tgagtacgactatctg', 'MF.F.151026.12C-Pal.D28'),
#  ('tgagtacgtagcgagt', 'MF.M.151026.12C-Xyl.D04'),
#  ('tgagtacgctgcgtgt', 'MP.A.151026.12C-Pal.D14'),
#  ('tgagtacgtcatcgag', 'MP.F.151026.H2O-Con.D04'),
#  ('tgagtacgcgtgagtg', 'EL.F.151026.12C-Van.D02'),
#  ('tgagtacgggatatct', 'MP.F.151026.12C-Ami.D04'),
#  ('actacgaccgtgagtg', 'BH.F.151026.12C-Xyl.D04'),
#  ('gtctgctagacaccgt', 'CC.M.151027.H2O-Con.D28'),
#  ('cgagagttctactata', 'MR.M.13C-Ami.D14.R1_Frac5'),
#  ('gacatagtgtcagata', 'MR.M.13C-Ami.D14.R1_Frac20'),
#  ('acgctactctactata', 'MR.M.13C-Ami.D14.R1_Frac21')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 7885567.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                          Sample  seq_count
# 0    MR.M.13C-Ami.D14.R1_Frac20      86580
# 1     MR.M.13C-Ami.D14.R1_Frac8     184474
# 2     MR.M.13C-Ami.D14.R1_Frac6     158875
# 3       CC.A.151027.H2O-Con.D02     110996
# 4       BH.F.151026.12C-Xyl.D04      53677
# 5    MR.M.13C-Ami.D14.R1_Frac27     105765
# 6       MW.M.151027.12C-Ami.D02     120886
# 7     MR.M.13C-Ami.D14.R1_Frac7     169055
# 8       CF.F.151027.H2O-Con.D14      35464
# 9       EL.M.151026.12C-Pal.D28      93185
# 10    MR.M.13C-Ami.D14.R1_Frac5     194536
# 11      BH.F.151026.12C-Pal.D28      50994
# 12   MR.M.13C-Ami.D14.R1_Frac26     210088
# 13   MR.M.13C-Ami.D14.R1_Frac18      93819
# 14      PP.A.151026.H2O-Con.D28     137279
# 15   MR.M.13C-Ami.D14.R1_Frac11     185740
# 16    MR.M.13C-Ami.D14.R1_Frac9     154146
# 17      MW.A.151027.12C-Xyl.D02      90186
# 18      EL.F.151026.H2O-Con.D02     105610
# 19   MR.M.13C-Ami.D14.R1_Frac13     141655
# 20   MR.M.13C-Ami.D14.R1_Frac12     187020
# 21      CC.F.151027.12C-Cel.D28      55535
# 22      PP.M.151026.H2O-Con.D02      42314
# 23      PP.A.151026.12C-Van.D02      61849
# 24      MW.A.151027.12C-Xyl.D04      60720
# 25      MW.F.151027.12C-Pal.D14      72202
# 26      BH.F.151026.H2O-Con.D14      43899
# 27      CF.M.151027.12C-Cel.D14      51162
# 28      CC.F.151027.12C-Xyl.D02      31835
# 29      CC.M.151027.12C-Xyl.D02      59897
# ..                          ...        ...
# 77      CF.F.151027.12C-Pal.D14      62218
# 78      BH.M.151026.12C-Cel.D28      45505
# 79      MW.F.151027.12C-Xyl.D02      39237
# 80      CC.M.151027.12C-Cel.D28      58936
# 81   MR.M.13C-Ami.D14.R1_Frac16      76684
# 82      PP.F.151026.12C-Ami.D02      58956
# 83      MP.F.151026.H2O-Con.D04      39344
# 84      MR.F.151027.12C-Cel.D14      33454
# 85      MR.A.151027.H2O-Con.D14      52905
# 86      EL.F.151026.12C-Van.D02      41903
# 87      BH.F.151026.H2O-Con.D28      68438
# 88      SS.A.151026.12C-Van.D02      35661
# 89      CF.F.151027.H2O-Con.D28      55208
# 90      BH.M.151026.12C-Van.D04      58822
# 91      EL.F.151026.12C-Xyl.D02      69474
# 92      BH.F.151026.12C-Cel.D28      47708
# 93      MP.F.151026.12C-Ami.D02      43220
# 94      MR.M.151027.H2O-Con.D02      58808
# 95      SS.F.151026.12C-Xyl.D02      59158
# 96      CC.M.151027.H2O-Con.D28      39828
# 97      MF.F.151026.12C-Pal.D28      30208
# 98      MW.F.151027.12C-Van.D02      26754
# 99      CF.F.151027.12C-Cel.D28      32972
# 100     MR.M.151027.12C-Pal.D14      23989
# 101     MF.M.151026.H2O-Con.D04      34794
# 102     MR.F.151027.12C-Cel.D28      63224
# 103     SS.A.151026.12C-Ami.D04      30408
# 104     CF.M.151027.H2O-Con.D14      29757
# 105                Enr6_H2O_con      15693
# 106                Enr5_H2O_con      10400
#
# [107 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 50000,]
# Out:
#                         Sample seq_count
# 8      CF.F.151027.H2O-Con.D14     35464
# 22     PP.M.151026.H2O-Con.D02     42314
# 26     BH.F.151026.H2O-Con.D14     43899
# 28     CC.F.151027.12C-Xyl.D02     31835
# 38     SS.M.151026.H2O-Con.D02     32001
# 46     MP.A.151026.12C-Pal.D14     35238
# 48     MF.M.151026.12C-Cel.D14     45801
# 49     MW.F.151027.12C-Ami.D02     47898
# 50     MP.A.151026.H2O-Con.D14     48405
# 53     MW.F.151027.H2O-Con.D14     38146
# 54     MR.F.151027.12C-Xyl.D02     40383
# 60      MR.M.13C-Ami.D14.R1_NC     35907
# 64     SS.M.151026.12C-Pal.D14     48650
# 67  MR.M.13C-Ami.D14.R1_Frac21     38890
# 70     PP.F.151026.H2O-Con.D04     22655
# 73     MF.M.151026.12C-Xyl.D04     34546
# 75     MP.M.151026.12C-Cel.D28     34133
# 76      MR.M.13C-Ami.D14.R1_MC     41370
# 78     BH.M.151026.12C-Cel.D28     45505
# 79     MW.F.151027.12C-Xyl.D02     39237
# 83     MP.F.151026.H2O-Con.D04     39344
# 84     MR.F.151027.12C-Cel.D14     33454
# 86     EL.F.151026.12C-Van.D02     41903
# 88     SS.A.151026.12C-Van.D02     35661
# 92     BH.F.151026.12C-Cel.D28     47708
# 93     MP.F.151026.12C-Ami.D02     43220
# 96     CC.M.151027.H2O-Con.D28     39828
# 97     MF.F.151026.12C-Pal.D28     30208
# 98     MW.F.151027.12C-Van.D02     26754
# 99     CF.F.151027.12C-Cel.D28     32972
# 100    MR.M.151027.12C-Pal.D14     23989
# 101    MF.M.151026.H2O-Con.D04     34794
# 103    SS.A.151026.12C-Ami.D04     30408
# 104    CF.M.151027.H2O-Con.D14     29757
# 105               Enr6_H2O_con     15693
# 106               Enr5_H2O_con     10400

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 107 samples
# You should have 107 samples
