# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/fullCyc2_lib9/run1'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib9'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'fullCyc2_lib9'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-fullCyc2_lib9.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib9

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Find out what's changed in ggplot2 at
# http://github.com/tidyverse/ggplot2/releases.
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                          #Sample  primer_number exp_type extraction_plate_ID  \
# 11      MR.F.13C-Ami.D6.R2_Frac7            129      SIP                 NaN
# 24      MR.F.13C-Ami.D6.R2_Frac8            130      SIP                 NaN
# 37      MR.F.13C-Ami.D6.R2_Frac9            131      SIP                 NaN
# 50     MR.F.13C-Ami.D6.R2_Frac10            132      SIP                 NaN
# 63     MR.F.13C-Ami.D6.R2_Frac11            133      SIP                 NaN
# 76     MR.F.13C-Ami.D6.R2_Frac12            134      SIP                 NaN
# 89     MR.F.13C-Ami.D6.R2_Frac13            135      SIP                 NaN
# 103    MR.F.13C-Ami.D6.R2_Frac14            136      SIP                 NaN
# 117    MR.F.13C-Ami.D6.R2_Frac15            137      SIP                 NaN
# 131    MR.F.13C-Ami.D6.R2_Frac16            138      SIP                 NaN
# 145    MR.F.13C-Ami.D6.R2_Frac17            139      SIP                 NaN
# 158    MR.F.13C-Ami.D6.R2_Frac18            140      SIP                 NaN
# 171    MR.F.13C-Ami.D6.R2_Frac19            141      SIP                 NaN
# 184    MR.F.13C-Ami.D6.R2_Frac20            142      SIP                 NaN
# 197    MR.F.13C-Ami.D6.R2_Frac21            143      SIP                 NaN
# 210    MR.F.13C-Ami.D6.R2_Frac22            144      SIP                 NaN
# 222    MR.F.13C-Ami.D6.R2_Frac23            145      SIP                 NaN
# 234    MR.F.13C-Ami.D6.R2_Frac24            146      SIP                 NaN
# 246    MR.F.13C-Ami.D6.R2_Frac25            147      SIP                 NaN
# 258    MR.F.13C-Ami.D6.R2_Frac26            148      SIP                 NaN
# 270    MR.F.13C-Ami.D6.R2_Frac27            149      SIP                 NaN
# 282        MR.F.13C-Ami.D6.R2_NC            150      SIP                 NaN
# 294     MR.M.13C-Xyl.D1.R1_Frac5            151      SIP                 NaN
# 306     MR.M.13C-Xyl.D1.R1_Frac6            152      SIP                 NaN
# 318     MR.M.13C-Xyl.D1.R1_Frac7            153      SIP                 NaN
# 330     MR.M.13C-Xyl.D1.R1_Frac8            154      SIP                 NaN
# 342     MR.M.13C-Xyl.D1.R1_Frac9            155      SIP                 NaN
# 355    MR.M.13C-Xyl.D1.R1_Frac10            156      SIP                 NaN
# 368    MR.M.13C-Xyl.D1.R1_Frac11            157      SIP                 NaN
# 381    MR.M.13C-Xyl.D1.R1_Frac12            158      SIP                 NaN
# ...                          ...            ...      ...                 ...
# 1941  MR.A.12C-Con.D14.R1_Frac18             15      SIP                 NaN
# 1953  MR.A.12C-Con.D14.R1_Frac19             16      SIP                 NaN
# 1965  MR.A.12C-Con.D14.R1_Frac20             17      SIP                 NaN
# 1977  MR.A.12C-Con.D14.R1_Frac21             18      SIP                 NaN
# 1989  MR.A.12C-Con.D14.R1_Frac22             19      SIP                 NaN
# 2001  MR.A.12C-Con.D14.R1_Frac23             20      SIP                 NaN
# 2013  MR.A.12C-Con.D14.R1_Frac24             21      SIP                 NaN
# 2025  MR.A.12C-Con.D14.R1_Frac25             22      SIP                 NaN
# 2037  MR.A.12C-Con.D14.R1_Frac26             23      SIP                 NaN
# 2049  MR.A.12C-Con.D14.R1_Frac27             24      SIP                 NaN
# 2060      MR.A.12C-Con.D14.R1_NC             25      SIP                 NaN
# 2071      MR.A.12C-Con.D14.R1_MC             26      SIP                 NaN
# 2083    MR.A.12C-Con.D1.R1_Frac4             27      SIP                 NaN
# 2095    MR.A.12C-Con.D1.R1_Frac5             28      SIP                 NaN
# 2107    MR.A.12C-Con.D1.R1_Frac6             29      SIP                 NaN
# 2119    MR.A.12C-Con.D1.R1_Frac7             30      SIP                 NaN
# 2131    MR.A.12C-Con.D1.R1_Frac8             31      SIP                 NaN
# 2143    MR.A.12C-Con.D1.R1_Frac9             32      SIP                 NaN
# 2155   MR.A.12C-Con.D1.R1_Frac10             33      SIP                 NaN
# 2167   MR.A.12C-Con.D1.R1_Frac11             34      SIP                 NaN
# 2179   MR.A.12C-Con.D1.R1_Frac12             35      SIP                 NaN
# 2191   MR.A.12C-Con.D1.R1_Frac13             36      SIP                 NaN
# 2203   MR.A.12C-Con.D1.R1_Frac14             37      SIP                 NaN
# 2215   MR.A.12C-Con.D1.R1_Frac15             38      SIP                 NaN
# 2227   MR.A.12C-Con.D1.R1_Frac16             39      SIP                 NaN
# 2238  MR.A.13C-Cel.D30.R3_Frac22             70      SIP                 NaN
# 2250    MR.F.12C-Con.D6.R2_Frac5             80      SIP                 NaN
# 2262   MR.F.12C-Con.D6.R2_Frac22             97      SIP                 NaN
# 2274   MR.F.12C-Con.D3.R1_Frac14            112      SIP                 NaN
# 2286   MR.F.12C-Con.D3.R1_Frac15            113      SIP                 NaN
#
#          library_ID         pool_plate_ID pool_plate_well  \
# 11    fullCyc2_lib9  fullCyc2_lib9_pool_2              A5
# 24    fullCyc2_lib9  fullCyc2_lib9_pool_2              B5
# 37    fullCyc2_lib9  fullCyc2_lib9_pool_2              C5
# 50    fullCyc2_lib9  fullCyc2_lib9_pool_2              D5
# 63    fullCyc2_lib9  fullCyc2_lib9_pool_2              E5
# 76    fullCyc2_lib9  fullCyc2_lib9_pool_2              F5
# 89    fullCyc2_lib9  fullCyc2_lib9_pool_2              G5
# 103   fullCyc2_lib9  fullCyc2_lib9_pool_2              H5
# 117   fullCyc2_lib9  fullCyc2_lib9_pool_2              A6
# 131   fullCyc2_lib9  fullCyc2_lib9_pool_2              B6
# 145   fullCyc2_lib9  fullCyc2_lib9_pool_2              C6
# 158   fullCyc2_lib9  fullCyc2_lib9_pool_2              D6
# 171   fullCyc2_lib9  fullCyc2_lib9_pool_2              E6
# 184   fullCyc2_lib9  fullCyc2_lib9_pool_2              F6
# 197   fullCyc2_lib9  fullCyc2_lib9_pool_2              G6
# 210   fullCyc2_lib9  fullCyc2_lib9_pool_2              H6
# 222   fullCyc2_lib9  fullCyc2_lib9_pool_2              A7
# 234   fullCyc2_lib9  fullCyc2_lib9_pool_2              B7
# 246   fullCyc2_lib9  fullCyc2_lib9_pool_2              C7
# 258   fullCyc2_lib9  fullCyc2_lib9_pool_2              D7
# 270   fullCyc2_lib9  fullCyc2_lib9_pool_2              E7
# 282   fullCyc2_lib9  fullCyc2_lib9_pool_2              F7
# 294   fullCyc2_lib9  fullCyc2_lib9_pool_2              G7
# 306   fullCyc2_lib9  fullCyc2_lib9_pool_2              H7
# 318   fullCyc2_lib9  fullCyc2_lib9_pool_2              A8
# 330   fullCyc2_lib9  fullCyc2_lib9_pool_2              B8
# 342   fullCyc2_lib9  fullCyc2_lib9_pool_2              C8
# 355   fullCyc2_lib9  fullCyc2_lib9_pool_2              D8
# 368   fullCyc2_lib9  fullCyc2_lib9_pool_2              E8
# 381   fullCyc2_lib9  fullCyc2_lib9_pool_2              F8
# ...             ...                   ...             ...
# 1941  fullCyc2_lib9  fullCyc2_lib9_pool_1              G2
# 1953  fullCyc2_lib9  fullCyc2_lib9_pool_1              H2
# 1965  fullCyc2_lib9  fullCyc2_lib9_pool_1              A3
# 1977  fullCyc2_lib9  fullCyc2_lib9_pool_1              B3
# 1989  fullCyc2_lib9  fullCyc2_lib9_pool_1              C3
# 2001  fullCyc2_lib9  fullCyc2_lib9_pool_1              D3
# 2013  fullCyc2_lib9  fullCyc2_lib9_pool_1              E3
# 2025  fullCyc2_lib9  fullCyc2_lib9_pool_1              F3
# 2037  fullCyc2_lib9  fullCyc2_lib9_pool_1              G3
# 2049  fullCyc2_lib9  fullCyc2_lib9_pool_1              H3
# 2060  fullCyc2_lib9  fullCyc2_lib9_pool_1              A4
# 2071  fullCyc2_lib9  fullCyc2_lib9_pool_1              B4
# 2083  fullCyc2_lib9  fullCyc2_lib9_pool_1              C4
# 2095  fullCyc2_lib9  fullCyc2_lib9_pool_1              D4
# 2107  fullCyc2_lib9  fullCyc2_lib9_pool_1              E4
# 2119  fullCyc2_lib9  fullCyc2_lib9_pool_1              F4
# 2131  fullCyc2_lib9  fullCyc2_lib9_pool_1              G4
# 2143  fullCyc2_lib9  fullCyc2_lib9_pool_1              H4
# 2155  fullCyc2_lib9  fullCyc2_lib9_pool_1              A5
# 2167  fullCyc2_lib9  fullCyc2_lib9_pool_1              B5
# 2179  fullCyc2_lib9  fullCyc2_lib9_pool_1              C5
# 2191  fullCyc2_lib9  fullCyc2_lib9_pool_1              D5
# 2203  fullCyc2_lib9  fullCyc2_lib9_pool_1              E5
# 2215  fullCyc2_lib9  fullCyc2_lib9_pool_1              F5
# 2227  fullCyc2_lib9  fullCyc2_lib9_pool_1              G5
# 2238  fullCyc2_lib9  fullCyc2_lib9_pool_1              F9
# 2250  fullCyc2_lib9  fullCyc2_lib9_pool_1             H10
# 2262  fullCyc2_lib9  fullCyc2_lib9_pool_2              A1
# 2274  fullCyc2_lib9  fullCyc2_lib9_pool_2              H2
# 2286  fullCyc2_lib9  fullCyc2_lib9_pool_2              A3
#
#                   soil_ID substrate   day     ...       \
# 11     MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 24     MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 37     MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 50     MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 63     MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 76     MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 89     MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 103    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 117    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 131    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 145    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 158    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 171    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 184    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 197    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 210    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 222    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 234    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 246    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 258    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 270    MR.F.13C-Ami.D6.R2   13C-Ami   6.0     ...
# 282    MR.F.13C-Ami.D6.R2   13C-Ami   NaN     ...
# 294    MR.M.13C-Xyl.D1.R1   13C-Xyl   1.0     ...
# 306    MR.M.13C-Xyl.D1.R1   13C-Xyl   1.0     ...
# 318    MR.M.13C-Xyl.D1.R1   13C-Xyl   1.0     ...
# 330    MR.M.13C-Xyl.D1.R1   13C-Xyl   1.0     ...
# 342    MR.M.13C-Xyl.D1.R1   13C-Xyl   1.0     ...
# 355    MR.M.13C-Xyl.D1.R1   13C-Xyl   1.0     ...
# 368    MR.M.13C-Xyl.D1.R1   13C-Xyl   1.0     ...
# 381    MR.M.13C-Xyl.D1.R1   13C-Xyl   1.0     ...
# ...                   ...       ...   ...     ...
# 1941  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 1953  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 1965  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 1977  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 1989  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 2001  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 2013  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 2025  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 2037  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 2049  MR.A.12C-Con.D14.R1   12C-Con  14.0     ...
# 2060  MR.A.12C-Con.D14.R1   12C-Con   NaN     ...
# 2071  MR.A.12C-Con.D14.R1   12C-Con   NaN     ...
# 2083   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2095   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2107   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2119   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2131   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2143   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2155   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2167   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2179   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2191   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2203   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2215   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2227   MR.A.12C-Con.D1.R1   12C-Con   1.0     ...
# 2238  MR.A.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 2250   MR.F.12C-Con.D6.R2   12C-Con   6.0     ...
# 2262   MR.F.12C-Con.D6.R2   12C-Con   6.0     ...
# 2274   MR.F.12C-Con.D3.R1   12C-Con   3.0     ...
# 2286   MR.F.12C-Con.D3.R1   12C-Con   3.0     ...
#
#       water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 11                            NaN        NaN        NaN        NaN        NaN
# 24                            NaN        NaN        NaN        NaN        NaN
# 37                            NaN        NaN        NaN        NaN        NaN
# 50                            NaN        NaN        NaN        NaN        NaN
# 63                            NaN        NaN        NaN        NaN        NaN
# 76                            NaN        NaN        NaN        NaN        NaN
# 89                            NaN        NaN        NaN        NaN        NaN
# 103                           NaN        NaN        NaN        NaN        NaN
# 117                           NaN        NaN        NaN        NaN        NaN
# 131                           NaN        NaN        NaN        NaN        NaN
# 145                           NaN        NaN        NaN        NaN        NaN
# 158                           NaN        NaN        NaN        NaN        NaN
# 171                           NaN        NaN        NaN        NaN        NaN
# 184                           NaN        NaN        NaN        NaN        NaN
# 197                           NaN        NaN        NaN        NaN        NaN
# 210                           NaN        NaN        NaN        NaN        NaN
# 222                           NaN        NaN        NaN        NaN        NaN
# 234                           NaN        NaN        NaN        NaN        NaN
# 246                           NaN        NaN        NaN        NaN        NaN
# 258                           NaN        NaN        NaN        NaN        NaN
# 270                           NaN        NaN        NaN        NaN        NaN
# 282                           NaN        NaN        NaN        NaN        NaN
# 294                           NaN        NaN        NaN        NaN        NaN
# 306                           NaN        NaN        NaN        NaN        NaN
# 318                           NaN        NaN        NaN        NaN        NaN
# 330                           NaN        NaN        NaN        NaN        NaN
# 342                           NaN        NaN        NaN        NaN        NaN
# 355                           NaN        NaN        NaN        NaN        NaN
# 368                           NaN        NaN        NaN        NaN        NaN
# 381                           NaN        NaN        NaN        NaN        NaN
# ...                           ...        ...        ...        ...        ...
# 1941                          NaN        NaN        NaN        NaN        NaN
# 1953                          NaN        NaN        NaN        NaN        NaN
# 1965                          NaN        NaN        NaN        NaN        NaN
# 1977                          NaN        NaN        NaN        NaN        NaN
# 1989                          NaN        NaN        NaN        NaN        NaN
# 2001                          NaN        NaN        NaN        NaN        NaN
# 2013                          NaN        NaN        NaN        NaN        NaN
# 2025                          NaN        NaN        NaN        NaN        NaN
# 2037                          NaN        NaN        NaN        NaN        NaN
# 2049                          NaN        NaN        NaN        NaN        NaN
# 2060                          NaN        NaN        NaN        NaN        NaN
# 2071                          NaN        NaN        NaN        NaN        NaN
# 2083                          NaN        NaN        NaN        NaN        NaN
# 2095                          NaN        NaN        NaN        NaN        NaN
# 2107                          NaN        NaN        NaN        NaN        NaN
# 2119                          NaN        NaN        NaN        NaN        NaN
# 2131                          NaN        NaN        NaN        NaN        NaN
# 2143                          NaN        NaN        NaN        NaN        NaN
# 2155                          NaN        NaN        NaN        NaN        NaN
# 2167                          NaN        NaN        NaN        NaN        NaN
# 2179                          NaN        NaN        NaN        NaN        NaN
# 2191                          NaN        NaN        NaN        NaN        NaN
# 2203                          NaN        NaN        NaN        NaN        NaN
# 2215                          NaN        NaN        NaN        NaN        NaN
# 2227                          NaN        NaN        NaN        NaN        NaN
# 2238                          NaN        NaN        NaN        NaN        NaN
# 2250                          NaN        NaN        NaN        NaN        NaN
# 2262                          NaN        NaN        NaN        NaN        NaN
# 2274                          NaN        NaN        NaN        NaN        NaN
# 2286                          NaN        NaN        NaN        NaN        NaN
#
#      clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 11          NaN           0.193   NaN     CTACTATA     CGTACTCA
# 24          NaN            0.35   NaN     CGTTACTA     CGTACTCA
# 37          NaN           0.432   NaN     AGAGTCAC     CGTACTCA
# 50          NaN           0.453   NaN     TACGAGAC     CGTACTCA
# 63          NaN           0.766   NaN     ACGTCTCG     CGTACTCA
# 76          NaN           1.191   NaN     TCGACGAG     CGTACTCA
# 89          NaN           1.577   NaN     GATCGTGT     CGTACTCA
# 103         NaN           2.772   NaN     GTCAGATA     CGTACTCA
# 117         NaN           5.953   NaN     CTACTATA     CTACGCAG
# 131         NaN          15.008   NaN     CGTTACTA     CTACGCAG
# 145         NaN          12.938   NaN     AGAGTCAC     CTACGCAG
# 158         NaN          18.857   NaN     TACGAGAC     CTACGCAG
# 171         NaN           23.31   NaN     ACGTCTCG     CTACGCAG
# 184         NaN          17.469   NaN     TCGACGAG     CTACGCAG
# 197         NaN          11.076   NaN     GATCGTGT     CTACGCAG
# 210         NaN           5.993   NaN     GTCAGATA     CTACGCAG
# 222         NaN           4.217   NaN     CTACTATA     GGAGACTA
# 234         NaN           2.427   NaN     CGTTACTA     GGAGACTA
# 246         NaN           1.432   NaN     AGAGTCAC     GGAGACTA
# 258         NaN           1.167   NaN     TACGAGAC     GGAGACTA
# 270         NaN           0.748   NaN     ACGTCTCG     GGAGACTA
# 282         NaN             NaN   NaN     TCGACGAG     GGAGACTA
# 294         NaN           0.196   NaN     GATCGTGT     GGAGACTA
# 306         NaN            0.22   NaN     GTCAGATA     GGAGACTA
# 318         NaN           0.221   NaN     CTACTATA     GTCGCTCG
# 330         NaN           0.249   NaN     CGTTACTA     GTCGCTCG
# 342         NaN           0.298   NaN     AGAGTCAC     GTCGCTCG
# 355         NaN           0.329   NaN     TACGAGAC     GTCGCTCG
# 368         NaN           0.503   NaN     ACGTCTCG     GTCGCTCG
# 381         NaN           1.018   NaN     TCGACGAG     GTCGCTCG
# ...         ...             ...   ...          ...          ...
# 1941        NaN           9.612   NaN     GGATATCT     ACTATGTC
# 1953        NaN           8.178   NaN     GACACCGT     ACTATGTC
# 1965        NaN           5.045   NaN     ATCGTACG     AGTAGCGT
# 1977        NaN           3.884   NaN     ACTATCTG     AGTAGCGT
# 1989        NaN           2.665   NaN     TAGCGAGT     AGTAGCGT
# 2001        NaN           2.447   NaN     CTGCGTGT     AGTAGCGT
# 2013        NaN           1.822   NaN     TCATCGAG     AGTAGCGT
# 2025        NaN           0.796   NaN     CGTGAGTG     AGTAGCGT
# 2037        NaN            0.58   NaN     GGATATCT     AGTAGCGT
# 2049        NaN           0.409   NaN     GACACCGT     AGTAGCGT
# 2060        NaN             NaN   NaN     ATCGTACG     CAGTGAGT
# 2071        NaN             NaN   NaN     ACTATCTG     CAGTGAGT
# 2083        NaN           0.301   NaN     TAGCGAGT     CAGTGAGT
# 2095        NaN           0.308   NaN     CTGCGTGT     CAGTGAGT
# 2107        NaN           0.323   NaN     TCATCGAG     CAGTGAGT
# 2119        NaN           0.339   NaN     CGTGAGTG     CAGTGAGT
# 2131        NaN           0.347   NaN     GGATATCT     CAGTGAGT
# 2143        NaN           0.371   NaN     GACACCGT     CAGTGAGT
# 2155        NaN           0.376   NaN     ATCGTACG     CGTACTCA
# 2167        NaN           0.373   NaN     ACTATCTG     CGTACTCA
# 2179        NaN           0.441   NaN     TAGCGAGT     CGTACTCA
# 2191        NaN            1.02   NaN     CTGCGTGT     CGTACTCA
# 2203        NaN           4.161   NaN     TCATCGAG     CGTACTCA
# 2215        NaN          12.681   NaN     CGTGAGTG     CGTACTCA
# 2227        NaN          24.188   NaN     GGATATCT     CGTACTCA
# 2238        NaN           2.186   NaN     CGTGAGTG     GTCGTAGT
# 2250        NaN           0.218   NaN     GACACCGT     TAGCAGAC
# 2262        NaN           1.465   NaN     CTACTATA     AACTCTCG
# 2274        NaN           4.613   NaN     GTCAGATA     ACTATGTC
# 2286        NaN          12.591   NaN     CTACTATA     AGTAGCGT
#
# [184 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 20 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 184

[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MR.F.13C-Ami.D6.R2_Frac7'),
#  ('tgagtacgcgttacta', 'MR.F.13C-Ami.D6.R2_Frac8'),
#  ('tgagtacgagagtcac', 'MR.F.13C-Ami.D6.R2_Frac9'),
#  ('tgagtacgtacgagac', 'MR.F.13C-Ami.D6.R2_Frac10'),
#  ('tgagtacgacgtctcg', 'MR.F.13C-Ami.D6.R2_Frac11'),
#  ('tgagtacgtcgacgag', 'MR.F.13C-Ami.D6.R2_Frac12'),
#  ('tgagtacggatcgtgt', 'MR.F.13C-Ami.D6.R2_Frac13'),
#  ('tgagtacggtcagata', 'MR.F.13C-Ami.D6.R2_Frac14'),
#  ('ctgcgtagctactata', 'MR.F.13C-Ami.D6.R2_Frac15'),
#  ('ctgcgtagcgttacta', 'MR.F.13C-Ami.D6.R2_Frac16'),
#  ('ctgcgtagagagtcac', 'MR.F.13C-Ami.D6.R2_Frac17'),
#  ('ctgcgtagtacgagac', 'MR.F.13C-Ami.D6.R2_Frac18'),
#  ('ctgcgtagacgtctcg', 'MR.F.13C-Ami.D6.R2_Frac19'),
#  ('ctgcgtagtcgacgag', 'MR.F.13C-Ami.D6.R2_Frac20'),
#  ('ctgcgtaggatcgtgt', 'MR.F.13C-Ami.D6.R2_Frac21'),
#  ('ctgcgtaggtcagata', 'MR.F.13C-Ami.D6.R2_Frac22'),
#  ('tagtctccctactata', 'MR.F.13C-Ami.D6.R2_Frac23'),
#  ('tagtctcccgttacta', 'MR.F.13C-Ami.D6.R2_Frac24'),
#  ('tagtctccagagtcac', 'MR.F.13C-Ami.D6.R2_Frac25'),
#  ('tagtctcctacgagac', 'MR.F.13C-Ami.D6.R2_Frac26'),
#  ('tagtctccacgtctcg', 'MR.F.13C-Ami.D6.R2_Frac27'),
#  ('tagtctcctcgacgag', 'MR.F.13C-Ami.D6.R2_NC'),
#  ('tagtctccgatcgtgt', 'MR.M.13C-Xyl.D1.R1_Frac5'),
#  ('tagtctccgtcagata', 'MR.M.13C-Xyl.D1.R1_Frac6'),
#  ('cgagcgacctactata', 'MR.M.13C-Xyl.D1.R1_Frac7'),
#  ('cgagcgaccgttacta', 'MR.M.13C-Xyl.D1.R1_Frac8'),
#  ('cgagcgacagagtcac', 'MR.M.13C-Xyl.D1.R1_Frac9'),
#  ('cgagcgactacgagac', 'MR.M.13C-Xyl.D1.R1_Frac10'),
#  ('cgagcgacacgtctcg', 'MR.M.13C-Xyl.D1.R1_Frac11'),
#  ('cgagcgactcgacgag', 'MR.M.13C-Xyl.D1.R1_Frac12'),
#  ('tgagtacggacaccgt', 'MR.A.12C-Con.D1.R1_Frac17'),
#  ('ctgcgtagatcgtacg', 'MR.A.12C-Con.D1.R1_Frac18'),
#  ('ctgcgtagactatctg', 'MR.A.12C-Con.D1.R1_Frac19'),
#  ('ctgcgtagtagcgagt', 'MR.A.12C-Con.D1.R1_Frac20'),
#  ('ctgcgtagctgcgtgt', 'MR.A.12C-Con.D1.R1_Frac21'),
#  ('ctgcgtagtcatcgag', 'MR.A.12C-Con.D1.R1_Frac22'),
#  ('ctgcgtagcgtgagtg', 'MR.A.12C-Con.D1.R1_Frac23'),
#  ('ctgcgtagggatatct', 'MR.A.12C-Con.D1.R1_Frac24'),
#  ('ctgcgtaggacaccgt', 'MR.A.12C-Con.D1.R1_Frac25'),
#  ('tagtctccatcgtacg', 'MR.A.12C-Con.D1.R1_Frac26'),
#  ('tagtctccactatctg', 'MR.A.12C-Con.D1.R1_Frac27'),
#  ('tagtctcctagcgagt', 'MR.A.12C-Con.D1.R1_NC'),
#  ('tagtctccctgcgtgt', 'MR.A.13C-Cel.D30.R3_Frac4'),
#  ('tagtctcctcatcgag', 'MR.A.13C-Cel.D30.R3_Frac5'),
#  ('tagtctcccgtgagtg', 'MR.A.13C-Cel.D30.R3_Frac6'),
#  ('tagtctccggatatct', 'MR.A.13C-Cel.D30.R3_Frac7'),
#  ('tagtctccgacaccgt', 'MR.A.13C-Cel.D30.R3_Frac8'),
#  ('cgagcgacatcgtacg', 'MR.A.13C-Cel.D30.R3_Frac9'),
#  ('cgagcgacactatctg', 'MR.A.13C-Cel.D30.R3_Frac10'),
#  ('cgagcgactagcgagt', 'MR.A.13C-Cel.D30.R3_Frac11'),
#  ('cgagcgacctgcgtgt', 'MR.A.13C-Cel.D30.R3_Frac12'),
#  ('cgagcgactcatcgag', 'MR.A.13C-Cel.D30.R3_Frac13'),
#  ('cgagcgaccgtgagtg', 'MR.A.13C-Cel.D30.R3_Frac14'),
#  ('cgagcgacggatatct', 'MR.A.13C-Cel.D30.R3_Frac15'),
#  ('cgagcgacgacaccgt', 'MR.A.13C-Cel.D30.R3_Frac16'),
#  ('actacgacatcgtacg', 'MR.A.13C-Cel.D30.R3_Frac17'),
#  ('actacgacactatctg', 'MR.A.13C-Cel.D30.R3_Frac18'),
#  ('actacgactagcgagt', 'MR.A.13C-Cel.D30.R3_Frac19'),
#  ('actacgacctgcgtgt', 'MR.A.13C-Cel.D30.R3_Frac20'),
#  ('actacgactcatcgag', 'MR.A.13C-Cel.D30.R3_Frac21'),
#  ('actacgacggatatct', 'MR.A.13C-Cel.D30.R3_Frac23'),
#  ('actacgacgacaccgt', 'MR.A.13C-Cel.D30.R3_Frac24'),
#  ('gtctgctaatcgtacg', 'MR.A.13C-Cel.D30.R3_Frac25'),
#  ('gtctgctaactatctg', 'MR.A.13C-Cel.D30.R3_Frac26'),
#  ('gtctgctatagcgagt', 'MR.A.13C-Cel.D30.R3_Frac27'),
#  ('gtctgctactgcgtgt', 'MR.A.13C-Cel.D30.R3_NC'),
#  ('gtctgctatcatcgag', 'MR.F.12C-Con.D6.R2_Frac2'),
#  ('gtctgctacgtgagtg', 'MR.F.12C-Con.D6.R2_Frac3'),
#  ('gtctgctaggatatct', 'MR.F.12C-Con.D6.R2_Frac4'),
#  ('gtctatgaatcgtacg', 'MR.F.12C-Con.D6.R2_Frac6'),
#  ('gtctatgaactatctg', 'MR.F.12C-Con.D6.R2_Frac7'),
#  ('gtctatgatagcgagt', 'MR.F.12C-Con.D6.R2_Frac8'),
#  ('gtctatgactgcgtgt', 'MR.F.12C-Con.D6.R2_Frac9'),
#  ('gtctatgatcatcgag', 'MR.F.12C-Con.D6.R2_Frac10'),
#  ('gtctatgacgtgagtg', 'MR.F.12C-Con.D6.R2_Frac11'),
#  ('gtctatgaggatatct', 'MR.F.12C-Con.D6.R2_Frac12'),
#  ('gtctatgagacaccgt', 'MR.F.12C-Con.D6.R2_Frac13'),
#  ('tatagcgaatcgtacg', 'MR.F.12C-Con.D6.R2_Frac14'),
#  ('tatagcgaactatctg', 'MR.F.12C-Con.D6.R2_Frac15'),
#  ('tatagcgatagcgagt', 'MR.F.12C-Con.D6.R2_Frac16'),
#  ('tatagcgactgcgtgt', 'MR.F.12C-Con.D6.R2_Frac17'),
#  ('tatagcgatcatcgag', 'MR.F.12C-Con.D6.R2_Frac18'),
#  ('tatagcgacgtgagtg', 'MR.F.12C-Con.D6.R2_Frac19'),
#  ('tatagcgaggatatct', 'MR.F.12C-Con.D6.R2_Frac20'),
#  ('tatagcgagacaccgt', 'MR.F.12C-Con.D6.R2_Frac21'),
#  ('cgagagttcgttacta', 'MR.F.12C-Con.D6.R2_Frac23'),
#  ('cgagagttagagtcac', 'MR.F.12C-Con.D6.R2_Frac24'),
#  ('cgagagtttacgagac', 'MR.F.12C-Con.D6.R2_Frac25'),
#  ('cgagagttacgtctcg', 'MR.F.12C-Con.D6.R2_Frac26'),
#  ('cgagagtttcgacgag', 'MR.F.12C-Con.D6.R2_NC'),
#  ('cgagagttgatcgtgt', 'MR.F.12C-Con.D3.R1_Frac5'),
#  ('cgagagttgtcagata', 'MR.F.12C-Con.D3.R1_Frac6'),
#  ('gacatagtctactata', 'MR.F.12C-Con.D3.R1_Frac7'),
#  ('gacatagtcgttacta', 'MR.F.12C-Con.D3.R1_Frac8'),
#  ('gacatagtagagtcac', 'MR.F.12C-Con.D3.R1_Frac9'),
#  ('gacatagttacgagac', 'MR.F.12C-Con.D3.R1_Frac10'),
#  ('gacatagtacgtctcg', 'MR.F.12C-Con.D3.R1_Frac11'),
#  ('gacatagttcgacgag', 'MR.F.12C-Con.D3.R1_Frac12'),
#  ('gacatagtgatcgtgt', 'MR.F.12C-Con.D3.R1_Frac13'),
#  ('acgctactcgttacta', 'MR.F.12C-Con.D3.R1_Frac16'),
#  ('acgctactagagtcac', 'MR.F.12C-Con.D3.R1_Frac17'),
#  ('acgctacttacgagac', 'MR.F.12C-Con.D3.R1_Frac18'),
#  ('acgctactacgtctcg', 'MR.F.12C-Con.D3.R1_Frac19'),
#  ('acgctacttcgacgag', 'MR.F.12C-Con.D3.R1_Frac20'),
#  ('acgctactgatcgtgt', 'MR.F.12C-Con.D3.R1_Frac21'),
#  ('acgctactgtcagata', 'MR.F.12C-Con.D3.R1_Frac22'),
#  ('actcactgctactata', 'MR.F.12C-Con.D3.R1_Frac23'),
#  ('actcactgcgttacta', 'MR.F.12C-Con.D3.R1_Frac24'),
#  ('actcactgagagtcac', 'MR.F.12C-Con.D3.R1_Frac25'),
#  ('actcactgtacgagac', 'MR.F.12C-Con.D3.R1_Frac26'),
#  ('actcactgacgtctcg', 'MR.F.12C-Con.D3.R1_Frac27'),
#  ('actcactgtcgacgag', 'MR.F.12C-Con.D3.R1_NC'),
#  ('actcactggatcgtgt', 'MR.F.13C-Ami.D6.R2_Frac5'),
#  ('actcactggtcagata', 'MR.F.13C-Ami.D6.R2_Frac6'),
#  ('cgagcgacgatcgtgt', 'MR.M.13C-Xyl.D1.R1_Frac13'),
#  ('cgagcgacgtcagata', 'MR.M.13C-Xyl.D1.R1_Frac14'),
#  ('actacgacctactata', 'MR.M.13C-Xyl.D1.R1_Frac15'),
#  ('actacgaccgttacta', 'MR.M.13C-Xyl.D1.R1_Frac16'),
#  ('actacgacagagtcac', 'MR.M.13C-Xyl.D1.R1_Frac17'),
#  ('actacgactacgagac', 'MR.M.13C-Xyl.D1.R1_Frac18'),
#  ('actacgacacgtctcg', 'MR.M.13C-Xyl.D1.R1_Frac19'),
#  ('actacgactcgacgag', 'MR.M.13C-Xyl.D1.R1_Frac20'),
#  ('actacgacgatcgtgt', 'MR.M.13C-Xyl.D1.R1_Frac21'),
#  ('actacgacgtcagata', 'MR.M.13C-Xyl.D1.R1_Frac22'),
#  ('gtctgctactactata', 'MR.M.13C-Xyl.D1.R1_Frac23'),
#  ('gtctgctacgttacta', 'MR.M.13C-Xyl.D1.R1_Frac24'),
#  ('gtctgctaagagtcac', 'MR.M.13C-Xyl.D1.R1_Frac25'),
#  ('gtctgctatacgagac', 'MR.M.13C-Xyl.D1.R1_Frac26'),
#  ('gtctgctaacgtctcg', 'MR.M.13C-Xyl.D1.R1_NC'),
#  ('gtctgctatcgacgag', 'MR.A.13C-Xyl.D6.R1_Frac3'),
#  ('gtctgctagatcgtgt', 'MR.A.13C-Xyl.D6.R1_Frac4'),
#  ('gtctgctagtcagata', 'MR.A.13C-Xyl.D6.R1_Frac5'),
#  ('gtctatgactactata', 'MR.A.13C-Xyl.D6.R1_Frac6'),
#  ('gtctatgacgttacta', 'MR.A.13C-Xyl.D6.R1_Frac7'),
#  ('gtctatgaagagtcac', 'MR.A.13C-Xyl.D6.R1_Frac8'),
#  ('gtctatgatacgagac', 'MR.A.13C-Xyl.D6.R1_Frac9'),
#  ('gtctatgaacgtctcg', 'MR.A.13C-Xyl.D6.R1_Frac10'),
#  ('gtctatgatcgacgag', 'MR.A.13C-Xyl.D6.R1_Frac11'),
#  ('gtctatgagatcgtgt', 'MR.A.13C-Xyl.D6.R1_Frac12'),
#  ('gtctatgagtcagata', 'MR.A.13C-Xyl.D6.R1_Frac13'),
#  ('cgagagttatcgtacg', 'MR.A.12C-Con.D14.R1_Frac4'),
#  ('cgagagttactatctg', 'MR.A.12C-Con.D14.R1_Frac5'),
#  ('cgagagtttagcgagt', 'MR.A.12C-Con.D14.R1_Frac6'),
#  ('cgagagttctgcgtgt', 'MR.A.12C-Con.D14.R1_Frac7'),
#  ('cgagagtttcatcgag', 'MR.A.12C-Con.D14.R1_Frac8'),
#  ('cgagagttcgtgagtg', 'MR.A.12C-Con.D14.R1_Frac9'),
#  ('cgagagttggatatct', 'MR.A.12C-Con.D14.R1_Frac10'),
#  ('cgagagttgacaccgt', 'MR.A.12C-Con.D14.R1_Frac11'),
#  ('gacatagtatcgtacg', 'MR.A.12C-Con.D14.R1_Frac12'),
#  ('gacatagtactatctg', 'MR.A.12C-Con.D14.R1_Frac13'),
#  ('gacatagttagcgagt', 'MR.A.12C-Con.D14.R1_Frac14'),
#  ('gacatagtctgcgtgt', 'MR.A.12C-Con.D14.R1_Frac15'),
#  ('gacatagttcatcgag', 'MR.A.12C-Con.D14.R1_Frac16'),
#  ('gacatagtcgtgagtg', 'MR.A.12C-Con.D14.R1_Frac17'),
#  ('gacatagtggatatct', 'MR.A.12C-Con.D14.R1_Frac18'),
#  ('gacatagtgacaccgt', 'MR.A.12C-Con.D14.R1_Frac19'),
#  ('acgctactatcgtacg', 'MR.A.12C-Con.D14.R1_Frac20'),
#  ('acgctactactatctg', 'MR.A.12C-Con.D14.R1_Frac21'),
#  ('acgctacttagcgagt', 'MR.A.12C-Con.D14.R1_Frac22'),
#  ('acgctactctgcgtgt', 'MR.A.12C-Con.D14.R1_Frac23'),
#  ('acgctacttcatcgag', 'MR.A.12C-Con.D14.R1_Frac24'),
#  ('acgctactcgtgagtg', 'MR.A.12C-Con.D14.R1_Frac25'),
#  ('acgctactggatatct', 'MR.A.12C-Con.D14.R1_Frac26'),
#  ('acgctactgacaccgt', 'MR.A.12C-Con.D14.R1_Frac27'),
#  ('actcactgatcgtacg', 'MR.A.12C-Con.D14.R1_NC'),
#  ('actcactgactatctg', 'MR.A.12C-Con.D14.R1_MC'),
#  ('actcactgtagcgagt', 'MR.A.12C-Con.D1.R1_Frac4'),
#  ('actcactgctgcgtgt', 'MR.A.12C-Con.D1.R1_Frac5'),
#  ('actcactgtcatcgag', 'MR.A.12C-Con.D1.R1_Frac6'),
#  ('actcactgcgtgagtg', 'MR.A.12C-Con.D1.R1_Frac7'),
#  ('actcactgggatatct', 'MR.A.12C-Con.D1.R1_Frac8'),
#  ('actcactggacaccgt', 'MR.A.12C-Con.D1.R1_Frac9'),
#  ('tgagtacgatcgtacg', 'MR.A.12C-Con.D1.R1_Frac10'),
#  ('tgagtacgactatctg', 'MR.A.12C-Con.D1.R1_Frac11'),
#  ('tgagtacgtagcgagt', 'MR.A.12C-Con.D1.R1_Frac12'),
#  ('tgagtacgctgcgtgt', 'MR.A.12C-Con.D1.R1_Frac13'),
#  ('tgagtacgtcatcgag', 'MR.A.12C-Con.D1.R1_Frac14'),
#  ('tgagtacgcgtgagtg', 'MR.A.12C-Con.D1.R1_Frac15'),
#  ('tgagtacgggatatct', 'MR.A.12C-Con.D1.R1_Frac16'),
#  ('actacgaccgtgagtg', 'MR.A.13C-Cel.D30.R3_Frac22'),
#  ('gtctgctagacaccgt', 'MR.F.12C-Con.D6.R2_Frac5'),
#  ('cgagagttctactata', 'MR.F.12C-Con.D6.R2_Frac22'),
#  ('gacatagtgtcagata', 'MR.F.12C-Con.D3.R1_Frac14'),
#  ('acgctactctactata', 'MR.F.12C-Con.D3.R1_Frac15')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 1982568 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 2270355.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                          Sample  seq_count
# 0     MR.A.12C-Con.D1.R1_Frac12      17931
# 1     MR.F.13C-Ami.D6.R2_Frac14      18234
# 2     MR.A.12C-Con.D14.R1_Frac8      20338
# 3      MR.F.12C-Con.D3.R1_Frac7      19194
# 4    MR.A.12C-Con.D14.R1_Frac20      10974
# 5      MR.A.13C-Xyl.D6.R1_Frac9      24170
# 6     MR.F.12C-Con.D6.R2_Frac25      19768
# 7      MR.F.13C-Ami.D6.R2_Frac5      21668
# 8    MR.A.12C-Con.D14.R1_Frac27      17139
# 9     MR.F.13C-Ami.D6.R2_Frac10      13975
# 10    MR.F.12C-Con.D3.R1_Frac26      13908
# 11    MR.F.12C-Con.D3.R1_Frac20      14511
# 12    MR.M.13C-Xyl.D1.R1_Frac22      13711
# 13   MR.A.12C-Con.D14.R1_Frac25      10851
# 14    MR.F.12C-Con.D6.R2_Frac26      13990
# 15   MR.A.13C-Cel.D30.R3_Frac25      12497
# 16    MR.F.13C-Ami.D6.R2_Frac13      16369
# 17   MR.A.13C-Cel.D30.R3_Frac11      12427
# 18   MR.A.12C-Con.D14.R1_Frac16      21779
# 19     MR.A.13C-Xyl.D6.R1_Frac5      21846
# 20       MR.A.12C-Con.D14.R1_MC       7072
# 21    MR.F.12C-Con.D3.R1_Frac13      19684
# 22   MR.A.13C-Cel.D30.R3_Frac15      13900
# 23    MR.F.12C-Con.D3.R1_Frac27      10034
# 24    MR.A.12C-Con.D1.R1_Frac24       8361
# 25    MR.F.13C-Ami.D6.R2_Frac20       9404
# 26    MR.F.12C-Con.D3.R1_Frac12      14630
# 27   MR.A.12C-Con.D14.R1_Frac11      30315
# 28    MR.F.12C-Con.D3.R1_Frac10      24721
# 29   MR.A.12C-Con.D14.R1_Frac22      16231
# ..                          ...        ...
# 154   MR.M.13C-Xyl.D1.R1_Frac20       7383
# 155   MR.F.12C-Con.D6.R2_Frac20       9347
# 156   MR.F.13C-Ami.D6.R2_Frac22      14638
# 157   MR.F.12C-Con.D3.R1_Frac15      16438
# 158   MR.A.13C-Cel.D30.R3_Frac6      11396
# 159       MR.F.12C-Con.D6.R2_NC       1324
# 160   MR.M.13C-Xyl.D1.R1_Frac12       9723
# 161   MR.F.12C-Con.D6.R2_Frac18       8357
# 162   MR.M.13C-Xyl.D1.R1_Frac11       8687
# 163   MR.F.12C-Con.D3.R1_Frac19       9248
# 164    MR.F.13C-Ami.D6.R2_Frac9       9268
# 165       MR.F.13C-Ami.D6.R2_NC        914
# 166   MR.A.12C-Con.D1.R1_Frac10      12172
# 167   MR.F.12C-Con.D6.R2_Frac10       8701
# 168   MR.M.13C-Xyl.D1.R1_Frac26       9897
# 169   MR.F.12C-Con.D3.R1_Frac23      11503
# 170   MR.F.12C-Con.D6.R2_Frac23      11018
# 171   MR.F.12C-Con.D6.R2_Frac17       5991
# 172  MR.A.13C-Cel.D30.R3_Frac24       9427
# 173      MR.A.13C-Cel.D30.R3_NC        247
# 174  MR.A.13C-Cel.D30.R3_Frac26       6399
# 175   MR.A.12C-Con.D1.R1_Frac20      12035
# 176  MR.A.13C-Cel.D30.R3_Frac18       5042
# 177   MR.A.12C-Con.D1.R1_Frac13       9882
# 178      MR.A.12C-Con.D14.R1_NC       1299
# 179   MR.F.12C-Con.D6.R2_Frac21       8797
# 180   MR.M.13C-Xyl.D1.R1_Frac25       6419
# 181       MR.M.13C-Xyl.D1.R1_NC        747
# 182       MR.F.12C-Con.D3.R1_NC        318
# 183       MR.A.12C-Con.D1.R1_NC        308
#
# [184 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 5000,]
# Out:
#                        Sample seq_count
# 138 MR.M.13C-Xyl.D1.R1_Frac19      4848
# 159     MR.F.12C-Con.D6.R2_NC      1324
# 165     MR.F.13C-Ami.D6.R2_NC       914
# 173    MR.A.13C-Cel.D30.R3_NC       247
# 178    MR.A.12C-Con.D14.R1_NC      1299
# 181     MR.M.13C-Xyl.D1.R1_NC       747
# 182     MR.F.12C-Con.D3.R1_NC       318
# 183     MR.A.12C-Con.D1.R1_NC       308

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 184 samples
# You should have 184 samples
