# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/fullCyc2_lib2/run2'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib2'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'fullCyc2_lib2'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-fullCyc2_lib2.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib2

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                              #Sample  primer_number exp_type  \
# 4         MR.F.13C-Cel.D30.R3_Frac11            129      SIP
# 17        MR.F.13C-Cel.D30.R3_Frac12            130      SIP
# 30        MR.F.13C-Cel.D30.R3_Frac13            131      SIP
# 43        MR.F.13C-Cel.D30.R3_Frac14            132      SIP
# 56        MR.F.13C-Cel.D30.R3_Frac15            133      SIP
# 69        MR.F.13C-Cel.D30.R3_Frac16            134      SIP
# 82        MR.F.13C-Cel.D30.R3_Frac17            135      SIP
# 96        MR.F.13C-Cel.D30.R3_Frac18            136      SIP
# 110       MR.F.13C-Cel.D30.R3_Frac19            137      SIP
# 124       MR.F.13C-Cel.D30.R3_Frac20            138      SIP
# 138       MR.F.13C-Cel.D30.R3_Frac21            139      SIP
# 151       MR.F.13C-Cel.D30.R3_Frac22            140      SIP
# 164       MR.F.13C-Cel.D30.R3_Frac23            141      SIP
# 177       MR.F.13C-Cel.D30.R3_Frac24            142      SIP
# 190       MR.F.13C-Cel.D30.R3_Frac25            143      SIP
# 203       MR.F.13C-Cel.D30.R3_Frac26            144      SIP
# 216       MR.F.13C-Cel.D30.R3_Frac27            145      SIP
# 228           MR.F.13C-Cel.D30.R3_NC            146      SIP
# 240         MR.F.13C-Pal.D6.R1_Frac5            147      SIP
# 252         MR.F.13C-Pal.D6.R1_Frac6            148      SIP
# 264         MR.F.13C-Pal.D6.R1_Frac7            149      SIP
# 276         MR.F.13C-Pal.D6.R1_Frac8            150      SIP
# 288         MR.F.13C-Pal.D6.R1_Frac9            151      SIP
# 300        MR.F.13C-Pal.D6.R1_Frac10            152      SIP
# 312        MR.F.13C-Pal.D6.R1_Frac11            153      SIP
# 324        MR.F.13C-Pal.D6.R1_Frac12            154      SIP
# 336        MR.F.13C-Pal.D6.R1_Frac13            155      SIP
# 348        MR.F.13C-Pal.D6.R1_Frac14            156      SIP
# 361        MR.F.13C-Pal.D6.R1_Frac15            157      SIP
# 374        MR.F.13C-Pal.D6.R1_Frac16            158      SIP
# ...                              ...            ...      ...
# 1934      MR.M.13C-Van.D14.R1_Frac19             15      SIP
# 1946      MR.M.13C-Van.D14.R1_Frac20             16      SIP
# 1958      MR.M.13C-Van.D14.R1_Frac21             17      SIP
# 1970      MR.M.13C-Van.D14.R1_Frac22             18      SIP
# 1982      MR.M.13C-Van.D14.R1_Frac23             19      SIP
# 1994      MR.M.13C-Van.D14.R1_Frac24             20      SIP
# 2006      MR.M.13C-Van.D14.R1_Frac25             21      SIP
# 2018      MR.M.13C-Van.D14.R1_Frac26             22      SIP
# 2030      MR.M.13C-Van.D14.R1_Frac27             23      SIP
# 2042      MR.M.13C-Van.D14.R1_Frac28             24      SIP
# 2053          MR.M.13C-Van.D14.R1_NC             25      SIP
# 2064          MR.M.13C-Van.D14.R1_MC             26      SIP
# 2076   MR.M.13C-Ami.D14.R1_Frac5_bad             27      SIP
# 2088   MR.M.13C-Ami.D14.R1_Frac6_bad             28      SIP
# 2100   MR.M.13C-Ami.D14.R1_Frac7_bad             29      SIP
# 2112   MR.M.13C-Ami.D14.R1_Frac8_bad             30      SIP
# 2124   MR.M.13C-Ami.D14.R1_Frac9_bad             31      SIP
# 2136  MR.M.13C-Ami.D14.R1_Frac10_bad             32      SIP
# 2148  MR.M.13C-Ami.D14.R1_Frac11_bad             33      SIP
# 2160  MR.M.13C-Ami.D14.R1_Frac12_bad             34      SIP
# 2172  MR.M.13C-Ami.D14.R1_Frac13_bad             35      SIP
# 2184  MR.M.13C-Ami.D14.R1_Frac14_bad             36      SIP
# 2196  MR.M.13C-Ami.D14.R1_Frac15_bad             37      SIP
# 2208  MR.M.13C-Ami.D14.R1_Frac16_bad             38      SIP
# 2220  MR.M.13C-Ami.D14.R1_Frac17_bad             39      SIP
# 2231       MR.M.12C-Con.D1.R1_Frac24             70      SIP
# 2243       MR.F.13C-Cel.D6.R2_Frac10             80      SIP
# 2255       MR.F.13C-Cel.D6.R2_Frac27             97      SIP
# 2267      MR.M.13C-Cel.D14.R2_Frac19            112      SIP
# 2279      MR.M.13C-Cel.D14.R2_Frac20            113      SIP
#
#      extraction_plate_ID     library_ID         pool_plate_ID pool_plate_well  \
# 4                    NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              A5
# 17                   NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              B5
# 30                   NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              C5
# 43                   NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              D5
# 56                   NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              E5
# 69                   NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              F5
# 82                   NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              G5
# 96                   NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              H5
# 110                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              A6
# 124                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              B6
# 138                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              C6
# 151                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              D6
# 164                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              E6
# 177                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              F6
# 190                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              G6
# 203                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              H6
# 216                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              A7
# 228                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              B7
# 240                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              C7
# 252                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              D7
# 264                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              E7
# 276                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              F7
# 288                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              G7
# 300                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              H7
# 312                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              A8
# 324                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              B8
# 336                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              C8
# 348                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              D8
# 361                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              E8
# 374                  NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              F8
# ...                  ...            ...                   ...             ...
# 1934                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              G2
# 1946                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              H2
# 1958                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              A3
# 1970                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              B3
# 1982                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              C3
# 1994                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              D3
# 2006                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              E3
# 2018                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              F3
# 2030                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              G3
# 2042                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              H3
# 2053                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              A4
# 2064                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              B4
# 2076                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              C4
# 2088                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              D4
# 2100                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              E4
# 2112                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              F4
# 2124                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              G4
# 2136                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              H4
# 2148                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              A5
# 2160                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              B5
# 2172                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              C5
# 2184                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              D5
# 2196                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              E5
# 2208                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              F5
# 2220                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              G5
# 2231                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1              F9
# 2243                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_1             H10
# 2255                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              A1
# 2267                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              H2
# 2279                 NaN  fullCyc2_lib2  FullCyc2_lib2_Pool_2              A3
#
#                   soil_ID substrate   day     ...       \
# 4     MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 17    MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 30    MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 43    MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 56    MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 69    MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 82    MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 96    MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 110   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 124   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 138   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 151   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 164   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 177   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 190   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 203   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 216   MR.F.13C-Cel.D30.R3   13C-Cel  30.0     ...
# 228   MR.F.13C-Cel.D30.R3   13C-Cel   NaN     ...
# 240    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 252    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 264    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 276    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 288    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 300    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 312    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 324    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 336    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 348    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 361    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# 374    MR.F.13C-Pal.D6.R1   13C-Pal   6.0     ...
# ...                   ...       ...   ...     ...
# 1934  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 1946  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 1958  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 1970  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 1982  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 1994  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 2006  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 2018  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 2030  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 2042  MR.M.13C-Van.D14.R1   13C-Van  14.0     ...
# 2053  MR.M.13C-Van.D14.R1   13C-Van   NaN     ...
# 2064  MR.M.13C-Van.D14.R1   13C-Van   NaN     ...
# 2076  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2088  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2100  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2112  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2124  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2136  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2148  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2160  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2172  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2184  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2196  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2208  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2220  MR.M.13C-Ami.D14.R1   13C-Ami  14.0     ...
# 2231   MR.M.12C-Con.D1.R1   12C-Con   1.0     ...
# 2243   MR.F.13C-Cel.D6.R2   13C-Cel   6.0     ...
# 2255   MR.F.13C-Cel.D6.R2   13C-Cel   6.0     ...
# 2267  MR.M.13C-Cel.D14.R2   13C-Cel  14.0     ...
# 2279  MR.M.13C-Cel.D14.R2   13C-Cel  14.0     ...
#
#       water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 4                             NaN        NaN        NaN        NaN        NaN
# 17                            NaN        NaN        NaN        NaN        NaN
# 30                            NaN        NaN        NaN        NaN        NaN
# 43                            NaN        NaN        NaN        NaN        NaN
# 56                            NaN        NaN        NaN        NaN        NaN
# 69                            NaN        NaN        NaN        NaN        NaN
# 82                            NaN        NaN        NaN        NaN        NaN
# 96                            NaN        NaN        NaN        NaN        NaN
# 110                           NaN        NaN        NaN        NaN        NaN
# 124                           NaN        NaN        NaN        NaN        NaN
# 138                           NaN        NaN        NaN        NaN        NaN
# 151                           NaN        NaN        NaN        NaN        NaN
# 164                           NaN        NaN        NaN        NaN        NaN
# 177                           NaN        NaN        NaN        NaN        NaN
# 190                           NaN        NaN        NaN        NaN        NaN
# 203                           NaN        NaN        NaN        NaN        NaN
# 216                           NaN        NaN        NaN        NaN        NaN
# 228                           NaN        NaN        NaN        NaN        NaN
# 240                           NaN        NaN        NaN        NaN        NaN
# 252                           NaN        NaN        NaN        NaN        NaN
# 264                           NaN        NaN        NaN        NaN        NaN
# 276                           NaN        NaN        NaN        NaN        NaN
# 288                           NaN        NaN        NaN        NaN        NaN
# 300                           NaN        NaN        NaN        NaN        NaN
# 312                           NaN        NaN        NaN        NaN        NaN
# 324                           NaN        NaN        NaN        NaN        NaN
# 336                           NaN        NaN        NaN        NaN        NaN
# 348                           NaN        NaN        NaN        NaN        NaN
# 361                           NaN        NaN        NaN        NaN        NaN
# 374                           NaN        NaN        NaN        NaN        NaN
# ...                           ...        ...        ...        ...        ...
# 1934                          NaN        NaN        NaN        NaN        NaN
# 1946                          NaN        NaN        NaN        NaN        NaN
# 1958                          NaN        NaN        NaN        NaN        NaN
# 1970                          NaN        NaN        NaN        NaN        NaN
# 1982                          NaN        NaN        NaN        NaN        NaN
# 1994                          NaN        NaN        NaN        NaN        NaN
# 2006                          NaN        NaN        NaN        NaN        NaN
# 2018                          NaN        NaN        NaN        NaN        NaN
# 2030                          NaN        NaN        NaN        NaN        NaN
# 2042                          NaN        NaN        NaN        NaN        NaN
# 2053                          NaN        NaN        NaN        NaN        NaN
# 2064                          NaN        NaN        NaN        NaN        NaN
# 2076                          NaN        NaN        NaN        NaN        NaN
# 2088                          NaN        NaN        NaN        NaN        NaN
# 2100                          NaN        NaN        NaN        NaN        NaN
# 2112                          NaN        NaN        NaN        NaN        NaN
# 2124                          NaN        NaN        NaN        NaN        NaN
# 2136                          NaN        NaN        NaN        NaN        NaN
# 2148                          NaN        NaN        NaN        NaN        NaN
# 2160                          NaN        NaN        NaN        NaN        NaN
# 2172                          NaN        NaN        NaN        NaN        NaN
# 2184                          NaN        NaN        NaN        NaN        NaN
# 2196                          NaN        NaN        NaN        NaN        NaN
# 2208                          NaN        NaN        NaN        NaN        NaN
# 2220                          NaN        NaN        NaN        NaN        NaN
# 2231                          NaN        NaN        NaN        NaN        NaN
# 2243                          NaN        NaN        NaN        NaN        NaN
# 2255                          NaN        NaN        NaN        NaN        NaN
# 2267                          NaN        NaN        NaN        NaN        NaN
# 2279                          NaN        NaN        NaN        NaN        NaN
#
#      clay__perc DNA_conc__ng_ul       notes  fwd_barcode  rev_barcode
# 4           NaN          -0.028         NaN     CTACTATA     CGTACTCA
# 17          NaN          -0.021         NaN     CGTTACTA     CGTACTCA
# 30          NaN           0.035         NaN     AGAGTCAC     CGTACTCA
# 43          NaN            0.23         NaN     TACGAGAC     CGTACTCA
# 56          NaN           0.934         NaN     ACGTCTCG     CGTACTCA
# 69          NaN           3.038         NaN     TCGACGAG     CGTACTCA
# 82          NaN           3.465         NaN     GATCGTGT     CGTACTCA
# 96          NaN            4.93         NaN     GTCAGATA     CGTACTCA
# 110         NaN           5.605         NaN     CTACTATA     CTACGCAG
# 124         NaN           3.979         NaN     CGTTACTA     CTACGCAG
# 138         NaN           2.308         NaN     AGAGTCAC     CTACGCAG
# 151         NaN           1.496         NaN     TACGAGAC     CTACGCAG
# 164         NaN           0.848         NaN     ACGTCTCG     CTACGCAG
# 177         NaN           0.431         NaN     TCGACGAG     CTACGCAG
# 190         NaN           0.195         NaN     GATCGTGT     CTACGCAG
# 203         NaN           0.133         NaN     GTCAGATA     CTACGCAG
# 216         NaN           0.062         NaN     CTACTATA     GGAGACTA
# 228         NaN             NaN         NaN     CGTTACTA     GGAGACTA
# 240         NaN           0.044         NaN     AGAGTCAC     GGAGACTA
# 252         NaN           0.042         NaN     TACGAGAC     GGAGACTA
# 264         NaN           0.045         NaN     ACGTCTCG     GGAGACTA
# 276         NaN            0.05         NaN     TCGACGAG     GGAGACTA
# 288         NaN           0.052         NaN     GATCGTGT     GGAGACTA
# 300         NaN           0.065         NaN     GTCAGATA     GGAGACTA
# 312         NaN           0.076         NaN     CTACTATA     GTCGCTCG
# 324         NaN           0.117         NaN     CGTTACTA     GTCGCTCG
# 336         NaN           0.295         NaN     AGAGTCAC     GTCGCTCG
# 348         NaN           0.921         NaN     TACGAGAC     GTCGCTCG
# 361         NaN           2.402         NaN     ACGTCTCG     GTCGCTCG
# 374         NaN           4.511         NaN     TCGACGAG     GTCGCTCG
# ...         ...             ...         ...          ...          ...
# 1934        NaN          12.595         NaN     GGATATCT     ACTATGTC
# 1946        NaN           6.011         NaN     GACACCGT     ACTATGTC
# 1958        NaN           4.052         NaN     ATCGTACG     AGTAGCGT
# 1970        NaN           2.763         NaN     ACTATCTG     AGTAGCGT
# 1982        NaN           1.597         NaN     TAGCGAGT     AGTAGCGT
# 1994        NaN           0.603         NaN     CTGCGTGT     AGTAGCGT
# 2006        NaN           0.338         NaN     TCATCGAG     AGTAGCGT
# 2018        NaN           0.014         NaN     CGTGAGTG     AGTAGCGT
# 2030        NaN          -0.158         NaN     GGATATCT     AGTAGCGT
# 2042        NaN          -0.283         NaN     GACACCGT     AGTAGCGT
# 2053        NaN             NaN         NaN     ATCGTACG     CAGTGAGT
# 2064        NaN             NaN         NaN     ACTATCTG     CAGTGAGT
# 2076        NaN          -1.275  wrong_soil     TAGCGAGT     CAGTGAGT
# 2088        NaN          -1.267  wrong_soil     CTGCGTGT     CAGTGAGT
# 2100        NaN          -1.272  wrong_soil     TCATCGAG     CAGTGAGT
# 2112        NaN           -1.26  wrong_soil     CGTGAGTG     CAGTGAGT
# 2124        NaN          -1.235  wrong_soil     GGATATCT     CAGTGAGT
# 2136        NaN          -1.189  wrong_soil     GACACCGT     CAGTGAGT
# 2148        NaN           -1.07  wrong_soil     ATCGTACG     CGTACTCA
# 2160        NaN          -0.895  wrong_soil     ACTATCTG     CGTACTCA
# 2172        NaN          -0.602  wrong_soil     TAGCGAGT     CGTACTCA
# 2184        NaN           0.424  wrong_soil     CTGCGTGT     CGTACTCA
# 2196        NaN           3.047  wrong_soil     TCATCGAG     CGTACTCA
# 2208        NaN          13.636  wrong_soil     CGTGAGTG     CGTACTCA
# 2220        NaN          19.623  wrong_soil     GGATATCT     CGTACTCA
# 2231        NaN          -0.239         NaN     CGTGAGTG     GTCGTAGT
# 2243        NaN          -0.686         NaN     GACACCGT     TAGCAGAC
# 2255        NaN          -0.559         NaN     CTACTATA     AACTCTCG
# 2267        NaN          11.862         NaN     GTCAGATA     ACTATGTC
# 2279        NaN          11.896         NaN     CTACTATA     AGTAGCGT
#
# [181 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 10 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 181
[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MR.F.13C-Cel.D30.R3_Frac11'),
#  ('tgagtacgcgttacta', 'MR.F.13C-Cel.D30.R3_Frac12'),
#  ('tgagtacgagagtcac', 'MR.F.13C-Cel.D30.R3_Frac13'),
#  ('tgagtacgtacgagac', 'MR.F.13C-Cel.D30.R3_Frac14'),
#  ('tgagtacgacgtctcg', 'MR.F.13C-Cel.D30.R3_Frac15'),
#  ('tgagtacgtcgacgag', 'MR.F.13C-Cel.D30.R3_Frac16'),
#  ('tgagtacggatcgtgt', 'MR.F.13C-Cel.D30.R3_Frac17'),
#  ('tgagtacggtcagata', 'MR.F.13C-Cel.D30.R3_Frac18'),
#  ('ctgcgtagctactata', 'MR.F.13C-Cel.D30.R3_Frac19'),
#  ('ctgcgtagcgttacta', 'MR.F.13C-Cel.D30.R3_Frac20'),
#  ('ctgcgtagagagtcac', 'MR.F.13C-Cel.D30.R3_Frac21'),
#  ('ctgcgtagtacgagac', 'MR.F.13C-Cel.D30.R3_Frac22'),
#  ('ctgcgtagacgtctcg', 'MR.F.13C-Cel.D30.R3_Frac23'),
#  ('ctgcgtagtcgacgag', 'MR.F.13C-Cel.D30.R3_Frac24'),
#  ('ctgcgtaggatcgtgt', 'MR.F.13C-Cel.D30.R3_Frac25'),
#  ('ctgcgtaggtcagata', 'MR.F.13C-Cel.D30.R3_Frac26'),
#  ('tagtctccctactata', 'MR.F.13C-Cel.D30.R3_Frac27'),
#  ('tagtctcccgttacta', 'MR.F.13C-Cel.D30.R3_NC'),
#  ('tagtctccagagtcac', 'MR.F.13C-Pal.D6.R1_Frac5'),
#  ('tagtctcctacgagac', 'MR.F.13C-Pal.D6.R1_Frac6'),
#  ('tagtctccacgtctcg', 'MR.F.13C-Pal.D6.R1_Frac7'),
#  ('tagtctcctcgacgag', 'MR.F.13C-Pal.D6.R1_Frac8'),
#  ('tagtctccgatcgtgt', 'MR.F.13C-Pal.D6.R1_Frac9'),
#  ('tagtctccgtcagata', 'MR.F.13C-Pal.D6.R1_Frac10'),
#  ('cgagcgacctactata', 'MR.F.13C-Pal.D6.R1_Frac11'),
#  ('cgagcgaccgttacta', 'MR.F.13C-Pal.D6.R1_Frac12'),
#  ('cgagcgacagagtcac', 'MR.F.13C-Pal.D6.R1_Frac13'),
#  ('cgagcgactacgagac', 'MR.F.13C-Pal.D6.R1_Frac14'),
#  ('cgagcgacacgtctcg', 'MR.F.13C-Pal.D6.R1_Frac15'),
#  ('cgagcgactcgacgag', 'MR.F.13C-Pal.D6.R1_Frac16'),
#  ('tgagtacggacaccgt', 'MR.M.13C-Ami.D14.R1_Frac18_bad'),
#  ('ctgcgtagatcgtacg', 'MR.M.13C-Ami.D14.R1_Frac19_bad'),
#  ('ctgcgtagactatctg', 'MR.M.13C-Ami.D14.R1_Frac20_bad'),
#  ('ctgcgtagtagcgagt', 'MR.M.13C-Ami.D14.R1_Frac21_bad'),
#  ('ctgcgtagctgcgtgt', 'MR.M.13C-Ami.D14.R1_Frac22_bad'),
#  ('ctgcgtagtcatcgag', 'MR.M.13C-Ami.D14.R1_Frac23_bad'),
#  ('ctgcgtagcgtgagtg', 'MR.M.13C-Ami.D14.R1_Frac24_bad'),
#  ('ctgcgtagggatatct', 'MR.M.13C-Ami.D14.R1_Frac25_bad'),
#  ('ctgcgtaggacaccgt', 'MR.M.13C-Ami.D14.R1_Frac26_bad'),
#  ('tagtctccatcgtacg', 'MR.M.13C-Ami.D14.R1_Frac27_bad'),
#  ('tagtctccactatctg', 'MR.M.13C-Ami.D14.R1_Frac28_bad'),
#  ('tagtctcctagcgagt', 'MR.M.13C-Ami.D14.R1_NC_bad'),
#  ('tagtctccctgcgtgt', 'MR.M.12C-Con.D1.R1_Frac6'),
#  ('tagtctcctcatcgag', 'MR.M.12C-Con.D1.R1_Frac7'),
#  ('tagtctcccgtgagtg', 'MR.M.12C-Con.D1.R1_Frac8'),
#  ('tagtctccggatatct', 'MR.M.12C-Con.D1.R1_Frac9'),
#  ('tagtctccgacaccgt', 'MR.M.12C-Con.D1.R1_Frac10'),
#  ('cgagcgacatcgtacg', 'MR.M.12C-Con.D1.R1_Frac11'),
#  ('cgagcgacactatctg', 'MR.M.12C-Con.D1.R1_Frac12'),
#  ('cgagcgactagcgagt', 'MR.M.12C-Con.D1.R1_Frac13'),
#  ('cgagcgacctgcgtgt', 'MR.M.12C-Con.D1.R1_Frac14'),
#  ('cgagcgactcatcgag', 'MR.M.12C-Con.D1.R1_Frac15'),
#  ('cgagcgaccgtgagtg', 'MR.M.12C-Con.D1.R1_Frac16'),
#  ('cgagcgacggatatct', 'MR.M.12C-Con.D1.R1_Frac17'),
#  ('cgagcgacgacaccgt', 'MR.M.12C-Con.D1.R1_Frac18'),
#  ('actacgacatcgtacg', 'MR.M.12C-Con.D1.R1_Frac19'),
#  ('actacgacactatctg', 'MR.M.12C-Con.D1.R1_Frac20'),
#  ('actacgactagcgagt', 'MR.M.12C-Con.D1.R1_Frac21'),
#  ('actacgacctgcgtgt', 'MR.M.12C-Con.D1.R1_Frac22'),
#  ('actacgactcatcgag', 'MR.M.12C-Con.D1.R1_Frac23'),
#  ('actacgacggatatct', 'MR.M.12C-Con.D1.R1_Frac25'),
#  ('actacgacgacaccgt', 'MR.M.12C-Con.D1.R1_Frac26'),
#  ('gtctgctaatcgtacg', 'MR.M.12C-Con.D1.R1_Frac27'),
#  ('gtctgctaactatctg', 'MR.M.12C-Con.D1.R1_Frac28'),
#  ('gtctgctatagcgagt', 'MR.M.12C-Con.D1.R1_NC'),
#  ('gtctgctactgcgtgt', 'MR.F.13C-Cel.D6.R2_Frac6'),
#  ('gtctgctatcatcgag', 'MR.F.13C-Cel.D6.R2_Frac7'),
#  ('gtctgctacgtgagtg', 'MR.F.13C-Cel.D6.R2_Frac8'),
#  ('gtctgctaggatatct', 'MR.F.13C-Cel.D6.R2_Frac9'),
#  ('gtctatgaatcgtacg', 'MR.F.13C-Cel.D6.R2_Frac11'),
#  ('gtctatgaactatctg', 'MR.F.13C-Cel.D6.R2_Frac12'),
#  ('gtctatgatagcgagt', 'MR.F.13C-Cel.D6.R2_Frac13'),
#  ('gtctatgactgcgtgt', 'MR.F.13C-Cel.D6.R2_Frac14'),
#  ('gtctatgatcatcgag', 'MR.F.13C-Cel.D6.R2_Frac15'),
#  ('gtctatgacgtgagtg', 'MR.F.13C-Cel.D6.R2_Frac16'),
#  ('gtctatgaggatatct', 'MR.F.13C-Cel.D6.R2_Frac17'),
#  ('gtctatgagacaccgt', 'MR.F.13C-Cel.D6.R2_Frac18'),
#  ('tatagcgaatcgtacg', 'MR.F.13C-Cel.D6.R2_Frac19'),
#  ('tatagcgaactatctg', 'MR.F.13C-Cel.D6.R2_Frac20'),
#  ('tatagcgatagcgagt', 'MR.F.13C-Cel.D6.R2_Frac21'),
#  ('tatagcgactgcgtgt', 'MR.F.13C-Cel.D6.R2_Frac22'),
#  ('tatagcgatcatcgag', 'MR.F.13C-Cel.D6.R2_Frac23'),
#  ('tatagcgacgtgagtg', 'MR.F.13C-Cel.D6.R2_Frac24'),
#  ('tatagcgaggatatct', 'MR.F.13C-Cel.D6.R2_Frac25'),
#  ('tatagcgagacaccgt', 'MR.F.13C-Cel.D6.R2_Frac26'),
#  ('cgagagttcgttacta', 'MR.F.13C-Cel.D6.R2_NC'),
#  ('cgagagttagagtcac', 'MR.M.13C-Cel.D14.R2_Frac6'),
#  ('cgagagtttacgagac', 'MR.M.13C-Cel.D14.R2_Frac7'),
#  ('cgagagttacgtctcg', 'MR.M.13C-Cel.D14.R2_Frac8'),
#  ('cgagagtttcgacgag', 'MR.M.13C-Cel.D14.R2_Frac9'),
#  ('cgagagttgatcgtgt', 'MR.M.13C-Cel.D14.R2_Frac10'),
#  ('cgagagttgtcagata', 'MR.M.13C-Cel.D14.R2_Frac11'),
#  ('gacatagtctactata', 'MR.M.13C-Cel.D14.R2_Frac12'),
#  ('gacatagtcgttacta', 'MR.M.13C-Cel.D14.R2_Frac13'),
#  ('gacatagtagagtcac', 'MR.M.13C-Cel.D14.R2_Frac14'),
#  ('gacatagttacgagac', 'MR.M.13C-Cel.D14.R2_Frac15'),
#  ('gacatagtacgtctcg', 'MR.M.13C-Cel.D14.R2_Frac16'),
#  ('gacatagttcgacgag', 'MR.M.13C-Cel.D14.R2_Frac17'),
#  ('gacatagtgatcgtgt', 'MR.M.13C-Cel.D14.R2_Frac18'),
#  ('acgctactcgttacta', 'MR.M.13C-Cel.D14.R2_Frac21'),
#  ('acgctactagagtcac', 'MR.M.13C-Cel.D14.R2_Frac22'),
#  ('acgctacttacgagac', 'MR.M.13C-Cel.D14.R2_Frac23'),
#  ('acgctactacgtctcg', 'MR.M.13C-Cel.D14.R2_Frac24'),
#  ('acgctacttcgacgag', 'MR.M.13C-Cel.D14.R2_Frac25'),
#  ('acgctactgatcgtgt', 'MR.M.13C-Cel.D14.R2_Frac26'),
#  ('acgctactgtcagata', 'MR.M.13C-Cel.D14.R2_Frac27'),
#  ('actcactgctactata', 'MR.M.13C-Cel.D14.R2_Frac28'),
#  ('actcactgcgttacta', 'MR.M.13C-Cel.D14.R2_NC'),
#  ('actcactgagagtcac', 'MR.F.13C-Cel.D30.R3_Frac5'),
#  ('actcactgtacgagac', 'MR.F.13C-Cel.D30.R3_Frac6'),
#  ('actcactgacgtctcg', 'MR.F.13C-Cel.D30.R3_Frac7'),
#  ('actcactgtcgacgag', 'MR.F.13C-Cel.D30.R3_Frac8'),
#  ('actcactggatcgtgt', 'MR.F.13C-Cel.D30.R3_Frac9'),
#  ('actcactggtcagata', 'MR.F.13C-Cel.D30.R3_Frac10'),
#  ('cgagcgacgatcgtgt', 'MR.F.13C-Pal.D6.R1_Frac17'),
#  ('cgagcgacgtcagata', 'MR.F.13C-Pal.D6.R1_Frac18'),
#  ('actacgacctactata', 'MR.F.13C-Pal.D6.R1_Frac19'),
#  ('actacgaccgttacta', 'MR.F.13C-Pal.D6.R1_Frac20'),
#  ('actacgacagagtcac', 'MR.F.13C-Pal.D6.R1_Frac21'),
#  ('actacgactacgagac', 'MR.F.13C-Pal.D6.R1_Frac22'),
#  ('actacgacacgtctcg', 'MR.F.13C-Pal.D6.R1_Frac23'),
#  ('actacgactcgacgag', 'MR.F.13C-Pal.D6.R1_Frac24'),
#  ('actacgacgatcgtgt', 'MR.F.13C-Pal.D6.R1_Frac25'),
#  ('actacgacgtcagata', 'MR.F.13C-Pal.D6.R1_Frac26'),
#  ('gtctgctactactata', 'MR.F.13C-Pal.D6.R1_NC'),
#  ('gtctgctacgttacta', 'MR.A.13C-Pal.D30.R3_Frac6'),
#  ('gtctgctaagagtcac', 'MR.A.13C-Pal.D30.R3_Frac7'),
#  ('gtctgctatacgagac', 'MR.A.13C-Pal.D30.R3_Frac8'),
#  ('gtctgctaacgtctcg', 'MR.A.13C-Pal.D30.R3_Frac9'),
#  ('gtctgctatcgacgag', 'MR.A.13C-Pal.D30.R3_Frac10'),
#  ('gtctgctagatcgtgt', 'MR.A.13C-Pal.D30.R3_Frac11'),
#  ('gtctgctagtcagata', 'MR.A.13C-Pal.D30.R3_Frac12'),
#  ('gtctatgactactata', 'MR.A.13C-Pal.D30.R3_Frac13'),
#  ('gtctatgacgttacta', 'MR.A.13C-Pal.D30.R3_Frac14'),
#  ('gtctatgaagagtcac', 'MR.A.13C-Pal.D30.R3_Frac15'),
#  ('gtctatgatacgagac', 'MR.A.13C-Pal.D30.R3_Frac16'),
#  ('gtctatgaacgtctcg', 'MR.A.13C-Pal.D30.R3_Frac17'),
#  ('cgagagttatcgtacg', 'MR.M.13C-Van.D14.R1_Frac5'),
#  ('cgagagttactatctg', 'MR.M.13C-Van.D14.R1_Frac6'),
#  ('cgagagtttagcgagt', 'MR.M.13C-Van.D14.R1_Frac7'),
#  ('cgagagttctgcgtgt', 'MR.M.13C-Van.D14.R1_Frac8'),
#  ('cgagagtttcatcgag', 'MR.M.13C-Van.D14.R1_Frac9'),
#  ('cgagagttcgtgagtg', 'MR.M.13C-Van.D14.R1_Frac10'),
#  ('cgagagttggatatct', 'MR.M.13C-Van.D14.R1_Frac11'),
#  ('cgagagttgacaccgt', 'MR.M.13C-Van.D14.R1_Frac12'),
#  ('gacatagtatcgtacg', 'MR.M.13C-Van.D14.R1_Frac13'),
#  ('gacatagtactatctg', 'MR.M.13C-Van.D14.R1_Frac14'),
#  ('gacatagttagcgagt', 'MR.M.13C-Van.D14.R1_Frac15'),
#  ('gacatagtctgcgtgt', 'MR.M.13C-Van.D14.R1_Frac16'),
#  ('gacatagttcatcgag', 'MR.M.13C-Van.D14.R1_Frac17'),
#  ('gacatagtcgtgagtg', 'MR.M.13C-Van.D14.R1_Frac18'),
#  ('gacatagtggatatct', 'MR.M.13C-Van.D14.R1_Frac19'),
#  ('gacatagtgacaccgt', 'MR.M.13C-Van.D14.R1_Frac20'),
#  ('acgctactatcgtacg', 'MR.M.13C-Van.D14.R1_Frac21'),
#  ('acgctactactatctg', 'MR.M.13C-Van.D14.R1_Frac22'),
#  ('acgctacttagcgagt', 'MR.M.13C-Van.D14.R1_Frac23'),
#  ('acgctactctgcgtgt', 'MR.M.13C-Van.D14.R1_Frac24'),
#  ('acgctacttcatcgag', 'MR.M.13C-Van.D14.R1_Frac25'),
#  ('acgctactcgtgagtg', 'MR.M.13C-Van.D14.R1_Frac26'),
#  ('acgctactggatatct', 'MR.M.13C-Van.D14.R1_Frac27'),
#  ('acgctactgacaccgt', 'MR.M.13C-Van.D14.R1_Frac28'),
#  ('actcactgatcgtacg', 'MR.M.13C-Van.D14.R1_NC'),
#  ('actcactgactatctg', 'MR.M.13C-Van.D14.R1_MC'),
#  ('actcactgtagcgagt', 'MR.M.13C-Ami.D14.R1_Frac5_bad'),
#  ('actcactgctgcgtgt', 'MR.M.13C-Ami.D14.R1_Frac6_bad'),
#  ('actcactgtcatcgag', 'MR.M.13C-Ami.D14.R1_Frac7_bad'),
#  ('actcactgcgtgagtg', 'MR.M.13C-Ami.D14.R1_Frac8_bad'),
#  ('actcactgggatatct', 'MR.M.13C-Ami.D14.R1_Frac9_bad'),
#  ('actcactggacaccgt', 'MR.M.13C-Ami.D14.R1_Frac10_bad'),
#  ('tgagtacgatcgtacg', 'MR.M.13C-Ami.D14.R1_Frac11_bad'),
#  ('tgagtacgactatctg', 'MR.M.13C-Ami.D14.R1_Frac12_bad'),
#  ('tgagtacgtagcgagt', 'MR.M.13C-Ami.D14.R1_Frac13_bad'),
#  ('tgagtacgctgcgtgt', 'MR.M.13C-Ami.D14.R1_Frac14_bad'),
#  ('tgagtacgtcatcgag', 'MR.M.13C-Ami.D14.R1_Frac15_bad'),
#  ('tgagtacgcgtgagtg', 'MR.M.13C-Ami.D14.R1_Frac16_bad'),
#  ('tgagtacgggatatct', 'MR.M.13C-Ami.D14.R1_Frac17_bad'),
#  ('actacgaccgtgagtg', 'MR.M.12C-Con.D1.R1_Frac24'),
#  ('gtctgctagacaccgt', 'MR.F.13C-Cel.D6.R2_Frac10'),
#  ('cgagagttctactata', 'MR.F.13C-Cel.D6.R2_Frac27'),
#  ('gacatagtgtcagata', 'MR.M.13C-Cel.D14.R2_Frac19'),
#  ('acgctactctactata', 'MR.M.13C-Cel.D14.R2_Frac20')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 2617985 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 4371176.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                              Sample  seq_count
# 0    MR.M.13C-Ami.D14.R1_Frac10_bad      45125
# 1         MR.M.13C-Van.D14.R1_Frac5      22870
# 2    MR.M.13C-Ami.D14.R1_Frac26_bad      34479
# 3     MR.M.13C-Ami.D14.R1_Frac5_bad      19855
# 4          MR.M.12C-Con.D1.R1_Frac8      12848
# 5        MR.M.13C-Van.D14.R1_Frac20      24033
# 6    MR.M.13C-Ami.D14.R1_Frac23_bad      20926
# 7        MR.F.13C-Cel.D30.R3_Frac16      30092
# 8         MR.F.13C-Pal.D6.R1_Frac16      21249
# 9         MR.F.13C-Cel.D6.R2_Frac12      19561
# 10        MR.F.13C-Cel.D6.R2_Frac23      17473
# 11        MR.F.13C-Pal.D6.R1_Frac24      27146
# 12   MR.M.13C-Ami.D14.R1_Frac19_bad      51402
# 13        MR.F.13C-Pal.D6.R1_Frac26      37200
# 14       MR.M.13C-Van.D14.R1_Frac17      55619
# 15         MR.F.13C-Pal.D6.R1_Frac8      33755
# 16   MR.M.13C-Ami.D14.R1_Frac18_bad      24481
# 17       MR.M.13C-Van.D14.R1_Frac26       8285
# 18       MR.M.13C-Cel.D14.R2_Frac20      14482
# 19       MR.F.13C-Cel.D30.R3_Frac23      10286
# 20       MR.M.13C-Cel.D14.R2_Frac27      27304
# 21       MR.F.13C-Cel.D30.R3_Frac17      24732
# 22        MR.F.13C-Cel.D6.R2_Frac14      15614
# 23   MR.M.13C-Ami.D14.R1_Frac12_bad      37604
# 24        MR.M.12C-Con.D1.R1_Frac25      18927
# 25   MR.M.13C-Ami.D14.R1_Frac15_bad      24774
# 26         MR.F.13C-Pal.D6.R1_Frac7      18757
# 27        MR.F.13C-Pal.D6.R1_Frac22      28490
# 28        MR.M.13C-Van.D14.R1_Frac9      40383
# 29       MR.F.13C-Cel.D30.R3_Frac14      34220
# ..                              ...        ...
# 151   MR.M.13C-Ami.D14.R1_Frac7_bad      16276
# 152      MR.M.13C-Van.D14.R1_Frac22      15603
# 153       MR.M.13C-Cel.D14.R2_Frac8      12194
# 154      MR.M.13C-Van.D14.R1_Frac23      12920
# 155        MR.F.13C-Pal.D6.R1_Frac5      22544
# 156        MR.M.12C-Con.D1.R1_Frac9      31700
# 157      MR.A.13C-Pal.D30.R3_Frac10      26313
# 158       MR.M.12C-Con.D1.R1_Frac16      14496
# 159      MR.M.13C-Cel.D14.R2_Frac15      28250
# 160      MR.M.13C-Van.D14.R1_Frac15      38703
# 161       MR.M.12C-Con.D1.R1_Frac17      19727
# 162      MR.M.13C-Van.D14.R1_Frac24       8852
# 163       MR.M.13C-Van.D14.R1_Frac6      13048
# 164       MR.F.13C-Cel.D6.R2_Frac24      16356
# 165   MR.M.13C-Ami.D14.R1_Frac6_bad      14302
# 166       MR.M.12C-Con.D1.R1_Frac21      13017
# 167       MR.F.13C-Pal.D6.R1_Frac25      28310
# 168       MR.F.13C-Cel.D6.R2_Frac17      21149
# 169       MR.M.12C-Con.D1.R1_Frac22       7059
# 170      MR.F.13C-Cel.D30.R3_Frac19       9403
# 171      MR.M.13C-Cel.D14.R2_Frac22      15799
# 172      MR.M.13C-Van.D14.R1_Frac18      16502
# 173      MR.F.13C-Cel.D30.R3_Frac26      24601
# 174           MR.F.13C-Pal.D6.R1_NC        125
# 175          MR.M.13C-Cel.D14.R2_NC        327
# 176          MR.F.13C-Cel.D30.R3_NC        305
# 177      MR.M.13C-Ami.D14.R1_NC_bad        108
# 178          MR.M.13C-Van.D14.R1_NC        344
# 179           MR.M.12C-Con.D1.R1_NC        240
# 180           MR.F.13C-Cel.D6.R2_NC        358
#
# [181 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 10000,]
# Out:
#                         Sample seq_count
# 17  MR.M.13C-Van.D14.R1_Frac26      8285
# 67   MR.M.12C-Con.D1.R1_Frac14      9822
# 83   MR.M.12C-Con.D1.R1_Frac24      9714
# 143  MR.F.13C-Cel.D6.R2_Frac22      8949
# 162 MR.M.13C-Van.D14.R1_Frac24      8852
# 169  MR.M.12C-Con.D1.R1_Frac22      7059
# 170 MR.F.13C-Cel.D30.R3_Frac19      9403
# 174      MR.F.13C-Pal.D6.R1_NC       125
# 175     MR.M.13C-Cel.D14.R2_NC       327
# 176     MR.F.13C-Cel.D30.R3_NC       305
# 177 MR.M.13C-Ami.D14.R1_NC_bad       108
# 178     MR.M.13C-Van.D14.R1_NC       344
# 179      MR.M.12C-Con.D1.R1_NC       240
# 180      MR.F.13C-Cel.D6.R2_NC       358

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 181 samples
# You should have 181 samples
