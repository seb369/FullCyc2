# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/fullCyc2_lib3/run2'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib3'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'fullCyc2_lib3'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-fullCyc2_lib3.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib3

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                          #Sample  primer_number exp_type extraction_plate_ID  \
# 5      MR.M.13C-Ami.D6.R1_Frac26            129      SIP                 NaN
# 18     MR.M.13C-Ami.D6.R1_Frac27            130      SIP                 NaN
# 31     MR.M.13C-Ami.D6.R1_Frac28            131      SIP                 NaN
# 44         MR.M.13C-Ami.D6.R1_NC            132      SIP                 NaN
# 57     MR.F.13C-Cel.D14.R2_Frac6            133      SIP                 NaN
# 70     MR.F.13C-Cel.D14.R2_Frac7            134      SIP                 NaN
# 83     MR.F.13C-Cel.D14.R2_Frac8            135      SIP                 NaN
# 97     MR.F.13C-Cel.D14.R2_Frac9            136      SIP                 NaN
# 111   MR.F.13C-Cel.D14.R2_Frac10            137      SIP                 NaN
# 125   MR.F.13C-Cel.D14.R2_Frac11            138      SIP                 NaN
# 139   MR.F.13C-Cel.D14.R2_Frac12            139      SIP                 NaN
# 152   MR.F.13C-Cel.D14.R2_Frac13            140      SIP                 NaN
# 165   MR.F.13C-Cel.D14.R2_Frac14            141      SIP                 NaN
# 178   MR.F.13C-Cel.D14.R2_Frac15            142      SIP                 NaN
# 191   MR.F.13C-Cel.D14.R2_Frac16            143      SIP                 NaN
# 204   MR.F.13C-Cel.D14.R2_Frac17            144      SIP                 NaN
# 349     MR.M.12C-Con.D6.R2_Frac6            156      SIP                 NaN
# 362     MR.M.12C-Con.D6.R2_Frac7            157      SIP                 NaN
# 375     MR.M.12C-Con.D6.R2_Frac8            158      SIP                 NaN
# 387    MR.A.13C-Cel.D14.R1_Frac7             40      SIP                 NaN
# 399    MR.A.13C-Cel.D14.R1_Frac8             41      SIP                 NaN
# 411    MR.A.13C-Cel.D14.R1_Frac9             42      SIP                 NaN
# 423   MR.A.13C-Cel.D14.R1_Frac10             43      SIP                 NaN
# 435   MR.A.13C-Cel.D14.R1_Frac11             44      SIP                 NaN
# 447   MR.A.13C-Cel.D14.R1_Frac12             45      SIP                 NaN
# 459   MR.A.13C-Cel.D14.R1_Frac13             46      SIP                 NaN
# 471   MR.A.13C-Cel.D14.R1_Frac14             47      SIP                 NaN
# 483   MR.A.13C-Cel.D14.R1_Frac15             48      SIP                 NaN
# 495   MR.A.13C-Cel.D14.R1_Frac16             49      SIP                 NaN
# 507   MR.A.13C-Cel.D14.R1_Frac17             50      SIP                 NaN
# ...                          ...            ...      ...                 ...
# 1959   MR.A.12C-Con.D30.R3_Frac9             17      SIP                 NaN
# 1971  MR.A.12C-Con.D30.R3_Frac10             18      SIP                 NaN
# 1983  MR.A.12C-Con.D30.R3_Frac11             19      SIP                 NaN
# 1995  MR.A.12C-Con.D30.R3_Frac12             20      SIP                 NaN
# 2007  MR.A.12C-Con.D30.R3_Frac13             21      SIP                 NaN
# 2019  MR.A.12C-Con.D30.R3_Frac14             22      SIP                 NaN
# 2031  MR.A.12C-Con.D30.R3_Frac15             23      SIP                 NaN
# 2043  MR.A.12C-Con.D30.R3_Frac16             24      SIP                 NaN
# 2054  MR.A.12C-Con.D30.R3_Frac17             25      SIP                 NaN
# 2065  MR.A.12C-Con.D30.R3_Frac18             26      SIP                 NaN
# 2077  MR.A.12C-Con.D30.R3_Frac19             27      SIP                 NaN
# 2089  MR.A.12C-Con.D30.R3_Frac20             28      SIP                 NaN
# 2101  MR.A.12C-Con.D30.R3_Frac21             29      SIP                 NaN
# 2113  MR.A.12C-Con.D30.R3_Frac22             30      SIP                 NaN
# 2125  MR.A.12C-Con.D30.R3_Frac23             31      SIP                 NaN
# 2137  MR.A.12C-Con.D30.R3_Frac24             32      SIP                 NaN
# 2149  MR.A.12C-Con.D30.R3_Frac25             33      SIP                 NaN
# 2161  MR.A.12C-Con.D30.R3_Frac26             34      SIP                 NaN
# 2173  MR.A.12C-Con.D30.R3_Frac27             35      SIP                 NaN
# 2185  MR.A.12C-Con.D30.R3_Frac28             36      SIP                 NaN
# 2197      MR.A.12C-Con.D30.R3_NC             37      SIP                 NaN
# 2209      MR.A.12C-Con.D30.R3_MC             38      SIP                 NaN
# 2221   MR.A.13C-Cel.D14.R1_Frac6             39      SIP                 NaN
# 2232   MR.F.13C-Xyl.D3.R1_Frac14             70      SIP                 NaN
# 2244   MR.F.13C-Xyl.D3.R1_Frac24             80      SIP                 NaN
# 2256   MR.F.13C-Xyl.D6.R1_Frac18             97      SIP                 NaN
# 2268    MR.M.13C-Ami.D6.R1_Frac9            112      SIP                 NaN
# 2280   MR.M.13C-Ami.D6.R1_Frac10            113      SIP                 NaN
# 2290  MR.F.12C-Con.D14.R1_Frac11            185      SIP                 NaN
# 2296  MR.F.12C-Con.D14.R1_Frac18            192      SIP                 NaN
#
#          library_ID        pool_plate_ID pool_plate_well              soil_ID  \
# 5     fullCyc2_lib3  fullCyc2_lib3_Pool2              A5   MR.M.13C-Ami.D6.R1
# 18    fullCyc2_lib3  fullCyc2_lib3_Pool2              B5   MR.M.13C-Ami.D6.R1
# 31    fullCyc2_lib3  fullCyc2_lib3_Pool2              C5   MR.M.13C-Ami.D6.R1
# 44    fullCyc2_lib3  fullCyc2_lib3_Pool2              D5   MR.M.13C-Ami.D6.R1
# 57    fullCyc2_lib3  fullCyc2_lib3_Pool2              E5  MR.F.13C-Cel.D14.R2
# 70    fullCyc2_lib3  fullCyc2_lib3_Pool2              F5  MR.F.13C-Cel.D14.R2
# 83    fullCyc2_lib3  fullCyc2_lib3_Pool2              G5  MR.F.13C-Cel.D14.R2
# 97    fullCyc2_lib3  fullCyc2_lib3_Pool2              H5  MR.F.13C-Cel.D14.R2
# 111   fullCyc2_lib3  fullCyc2_lib3_Pool2              A6  MR.F.13C-Cel.D14.R2
# 125   fullCyc2_lib3  fullCyc2_lib3_Pool2              B6  MR.F.13C-Cel.D14.R2
# 139   fullCyc2_lib3  fullCyc2_lib3_Pool2              C6  MR.F.13C-Cel.D14.R2
# 152   fullCyc2_lib3  fullCyc2_lib3_Pool2              D6  MR.F.13C-Cel.D14.R2
# 165   fullCyc2_lib3  fullCyc2_lib3_Pool2              E6  MR.F.13C-Cel.D14.R2
# 178   fullCyc2_lib3  fullCyc2_lib3_Pool2              F6  MR.F.13C-Cel.D14.R2
# 191   fullCyc2_lib3  fullCyc2_lib3_Pool2              G6  MR.F.13C-Cel.D14.R2
# 204   fullCyc2_lib3  fullCyc2_lib3_Pool2              H6  MR.F.13C-Cel.D14.R2
# 349   fullCyc2_lib3  fullCyc2_lib3_Pool2              D8   MR.M.12C-Con.D6.R2
# 362   fullCyc2_lib3  fullCyc2_lib3_Pool2              E8   MR.M.12C-Con.D6.R2
# 375   fullCyc2_lib3  fullCyc2_lib3_Pool2              F8   MR.M.12C-Con.D6.R2
# 387   fullCyc2_lib3  fullCyc2_lib3_Pool1              H5  MR.A.13C-Cel.D14.R1
# 399   fullCyc2_lib3  fullCyc2_lib3_Pool1              A6  MR.A.13C-Cel.D14.R1
# 411   fullCyc2_lib3  fullCyc2_lib3_Pool1              B6  MR.A.13C-Cel.D14.R1
# 423   fullCyc2_lib3  fullCyc2_lib3_Pool1              C6  MR.A.13C-Cel.D14.R1
# 435   fullCyc2_lib3  fullCyc2_lib3_Pool1              D6  MR.A.13C-Cel.D14.R1
# 447   fullCyc2_lib3  fullCyc2_lib3_Pool1              E6  MR.A.13C-Cel.D14.R1
# 459   fullCyc2_lib3  fullCyc2_lib3_Pool1              F6  MR.A.13C-Cel.D14.R1
# 471   fullCyc2_lib3  fullCyc2_lib3_Pool1              G6  MR.A.13C-Cel.D14.R1
# 483   fullCyc2_lib3  fullCyc2_lib3_Pool1              H6  MR.A.13C-Cel.D14.R1
# 495   fullCyc2_lib3  fullCyc2_lib3_Pool1              A7  MR.A.13C-Cel.D14.R1
# 507   fullCyc2_lib3  fullCyc2_lib3_Pool1              B7  MR.A.13C-Cel.D14.R1
# ...             ...                  ...             ...                  ...
# 1959  fullCyc2_lib3  fullCyc2_lib3_Pool1              A3  MR.A.12C-Con.D30.R3
# 1971  fullCyc2_lib3  fullCyc2_lib3_Pool1              B3  MR.A.12C-Con.D30.R3
# 1983  fullCyc2_lib3  fullCyc2_lib3_Pool1              C3  MR.A.12C-Con.D30.R3
# 1995  fullCyc2_lib3  fullCyc2_lib3_Pool1              D3  MR.A.12C-Con.D30.R3
# 2007  fullCyc2_lib3  fullCyc2_lib3_Pool1              E3  MR.A.12C-Con.D30.R3
# 2019  fullCyc2_lib3  fullCyc2_lib3_Pool1              F3  MR.A.12C-Con.D30.R3
# 2031  fullCyc2_lib3  fullCyc2_lib3_Pool1              G3  MR.A.12C-Con.D30.R3
# 2043  fullCyc2_lib3  fullCyc2_lib3_Pool1              H3  MR.A.12C-Con.D30.R3
# 2054  fullCyc2_lib3  fullCyc2_lib3_Pool1              A4  MR.A.12C-Con.D30.R3
# 2065  fullCyc2_lib3  fullCyc2_lib3_Pool1              B4  MR.A.12C-Con.D30.R3
# 2077  fullCyc2_lib3  fullCyc2_lib3_Pool1              C4  MR.A.12C-Con.D30.R3
# 2089  fullCyc2_lib3  fullCyc2_lib3_Pool1              D4  MR.A.12C-Con.D30.R3
# 2101  fullCyc2_lib3  fullCyc2_lib3_Pool1              E4  MR.A.12C-Con.D30.R3
# 2113  fullCyc2_lib3  fullCyc2_lib3_Pool1              F4  MR.A.12C-Con.D30.R3
# 2125  fullCyc2_lib3  fullCyc2_lib3_Pool1              G4  MR.A.12C-Con.D30.R3
# 2137  fullCyc2_lib3  fullCyc2_lib3_Pool1              H4  MR.A.12C-Con.D30.R3
# 2149  fullCyc2_lib3  fullCyc2_lib3_Pool1              A5  MR.A.12C-Con.D30.R3
# 2161  fullCyc2_lib3  fullCyc2_lib3_Pool1              B5  MR.A.12C-Con.D30.R3
# 2173  fullCyc2_lib3  fullCyc2_lib3_Pool1              C5  MR.A.12C-Con.D30.R3
# 2185  fullCyc2_lib3  fullCyc2_lib3_Pool1              D5  MR.A.12C-Con.D30.R3
# 2197  fullCyc2_lib3  fullCyc2_lib3_Pool1              E5  MR.A.12C-Con.D30.R3
# 2209  fullCyc2_lib3  fullCyc2_lib3_Pool1              F5  MR.A.12C-Con.D30.R3
# 2221  fullCyc2_lib3  fullCyc2_lib3_Pool1              G5  MR.A.13C-Cel.D14.R1
# 2232  fullCyc2_lib3  fullCyc2_lib3_Pool1              F9   MR.F.13C-Xyl.D3.R1
# 2244  fullCyc2_lib3  fullCyc2_lib3_Pool1             H10   MR.F.13C-Xyl.D3.R1
# 2256  fullCyc2_lib3  fullCyc2_lib3_Pool2              A1   MR.F.13C-Xyl.D6.R1
# 2268  fullCyc2_lib3  fullCyc2_lib3_Pool2              H2   MR.M.13C-Ami.D6.R1
# 2280  fullCyc2_lib3  fullCyc2_lib3_Pool2              A3   MR.M.13C-Ami.D6.R1
# 2290  fullCyc2_lib3  fullCyc2_lib3_Pool2             A12  MR.F.12C-Con.D14.R1
# 2296  fullCyc2_lib3  fullCyc2_lib3_Pool2             H12  MR.F.12C-Con.D14.R1
#
#      substrate   day     ...       water_holding_capacity__g.g  percent_N  \
# 5      13C-Ami   6.0     ...                               NaN        NaN
# 18     13C-Ami   6.0     ...                               NaN        NaN
# 31     13C-Ami   6.0     ...                               NaN        NaN
# 44     13C-Ami   6.0     ...                               NaN        NaN
# 57     13C-Cel  14.0     ...                               NaN        NaN
# 70     13C-Cel  14.0     ...                               NaN        NaN
# 83     13C-Cel  14.0     ...                               NaN        NaN
# 97     13C-Cel  14.0     ...                               NaN        NaN
# 111    13C-Cel  14.0     ...                               NaN        NaN
# 125    13C-Cel  14.0     ...                               NaN        NaN
# 139    13C-Cel  14.0     ...                               NaN        NaN
# 152    13C-Cel  14.0     ...                               NaN        NaN
# 165    13C-Cel  14.0     ...                               NaN        NaN
# 178    13C-Cel  14.0     ...                               NaN        NaN
# 191    13C-Cel  14.0     ...                               NaN        NaN
# 204    13C-Cel  14.0     ...                               NaN        NaN
# 349    12C-Con   6.0     ...                               NaN        NaN
# 362    12C-Con   6.0     ...                               NaN        NaN
# 375    12C-Con   6.0     ...                               NaN        NaN
# 387    13C-Cel  14.0     ...                               NaN        NaN
# 399    13C-Cel  14.0     ...                               NaN        NaN
# 411    13C-Cel  14.0     ...                               NaN        NaN
# 423    13C-Cel  14.0     ...                               NaN        NaN
# 435    13C-Cel  14.0     ...                               NaN        NaN
# 447    13C-Cel  14.0     ...                               NaN        NaN
# 459    13C-Cel  14.0     ...                               NaN        NaN
# 471    13C-Cel  14.0     ...                               NaN        NaN
# 483    13C-Cel  14.0     ...                               NaN        NaN
# 495    13C-Cel  14.0     ...                               NaN        NaN
# 507    13C-Cel  14.0     ...                               NaN        NaN
# ...        ...   ...     ...                               ...        ...
# 1959   12C-Con  30.0     ...                               NaN        NaN
# 1971   12C-Con  30.0     ...                               NaN        NaN
# 1983   12C-Con  30.0     ...                               NaN        NaN
# 1995   12C-Con  30.0     ...                               NaN        NaN
# 2007   12C-Con  30.0     ...                               NaN        NaN
# 2019   12C-Con  30.0     ...                               NaN        NaN
# 2031   12C-Con  30.0     ...                               NaN        NaN
# 2043   12C-Con  30.0     ...                               NaN        NaN
# 2054   12C-Con  30.0     ...                               NaN        NaN
# 2065   12C-Con  30.0     ...                               NaN        NaN
# 2077   12C-Con  30.0     ...                               NaN        NaN
# 2089   12C-Con  30.0     ...                               NaN        NaN
# 2101   12C-Con  30.0     ...                               NaN        NaN
# 2113   12C-Con  30.0     ...                               NaN        NaN
# 2125   12C-Con  30.0     ...                               NaN        NaN
# 2137   12C-Con  30.0     ...                               NaN        NaN
# 2149   12C-Con  30.0     ...                               NaN        NaN
# 2161   12C-Con  30.0     ...                               NaN        NaN
# 2173   12C-Con  30.0     ...                               NaN        NaN
# 2185   12C-Con  30.0     ...                               NaN        NaN
# 2197   12C-Con  30.0     ...                               NaN        NaN
# 2209   12C-Con  30.0     ...                               NaN        NaN
# 2221   13C-Cel  14.0     ...                               NaN        NaN
# 2232   13C-Xyl   3.0     ...                               NaN        NaN
# 2244   13C-Xyl   3.0     ...                               NaN        NaN
# 2256   13C-Xyl   6.0     ...                               NaN        NaN
# 2268   13C-Ami   6.0     ...                               NaN        NaN
# 2280   13C-Ami   6.0     ...                               NaN        NaN
# 2290   12C-Con  14.0     ...                               NaN        NaN
# 2296   12C-Con  14.0     ...                               NaN        NaN
#
#       percent_C sand__perc silt__perc clay__perc DNA_conc__ng_ul notes  \
# 5           NaN        NaN        NaN        NaN           1.372   NaN
# 18          NaN        NaN        NaN        NaN           1.102   NaN
# 31          NaN        NaN        NaN        NaN           0.606   NaN
# 44          NaN        NaN        NaN        NaN             NaN   NaN
# 57          NaN        NaN        NaN        NaN            0.01   NaN
# 70          NaN        NaN        NaN        NaN           0.019   NaN
# 83          NaN        NaN        NaN        NaN            0.05   NaN
# 97          NaN        NaN        NaN        NaN           0.073   NaN
# 111         NaN        NaN        NaN        NaN           0.172   NaN
# 125         NaN        NaN        NaN        NaN           0.375   NaN
# 139         NaN        NaN        NaN        NaN           0.308   NaN
# 152         NaN        NaN        NaN        NaN            0.44   NaN
# 165         NaN        NaN        NaN        NaN           0.878   NaN
# 178         NaN        NaN        NaN        NaN           5.823   NaN
# 191         NaN        NaN        NaN        NaN          16.886   NaN
# 204         NaN        NaN        NaN        NaN            33.1   NaN
# 349         NaN        NaN        NaN        NaN           0.073   NaN
# 362         NaN        NaN        NaN        NaN           0.094   NaN
# 375         NaN        NaN        NaN        NaN           0.094   NaN
# 387         NaN        NaN        NaN        NaN          -0.322   NaN
# 399         NaN        NaN        NaN        NaN          -0.297   NaN
# 411         NaN        NaN        NaN        NaN          -0.211   NaN
# 423         NaN        NaN        NaN        NaN          -0.213   NaN
# 435         NaN        NaN        NaN        NaN          -0.106   NaN
# 447         NaN        NaN        NaN        NaN          -0.136   NaN
# 459         NaN        NaN        NaN        NaN          -0.156   NaN
# 471         NaN        NaN        NaN        NaN           0.298   NaN
# 483         NaN        NaN        NaN        NaN           0.394   NaN
# 495         NaN        NaN        NaN        NaN             1.8   NaN
# 507         NaN        NaN        NaN        NaN           5.583   NaN
# ...         ...        ...        ...        ...             ...   ...
# 1959        NaN        NaN        NaN        NaN          -0.138   NaN
# 1971        NaN        NaN        NaN        NaN          -0.159   NaN
# 1983        NaN        NaN        NaN        NaN          -0.158   NaN
# 1995        NaN        NaN        NaN        NaN          -0.108   NaN
# 2007        NaN        NaN        NaN        NaN          -0.038   NaN
# 2019        NaN        NaN        NaN        NaN           0.602   NaN
# 2031        NaN        NaN        NaN        NaN           2.218   NaN
# 2043        NaN        NaN        NaN        NaN            5.44   NaN
# 2054        NaN        NaN        NaN        NaN           7.121   NaN
# 2065        NaN        NaN        NaN        NaN           7.474   NaN
# 2077        NaN        NaN        NaN        NaN           5.882   NaN
# 2089        NaN        NaN        NaN        NaN           3.726   NaN
# 2101        NaN        NaN        NaN        NaN           2.953   NaN
# 2113        NaN        NaN        NaN        NaN           1.807   NaN
# 2125        NaN        NaN        NaN        NaN           1.078   NaN
# 2137        NaN        NaN        NaN        NaN           0.634   NaN
# 2149        NaN        NaN        NaN        NaN            0.99   NaN
# 2161        NaN        NaN        NaN        NaN            0.55   NaN
# 2173        NaN        NaN        NaN        NaN           0.127   NaN
# 2185        NaN        NaN        NaN        NaN            0.05   NaN
# 2197        NaN        NaN        NaN        NaN             NaN   NaN
# 2209        NaN        NaN        NaN        NaN             NaN   NaN
# 2221        NaN        NaN        NaN        NaN          -0.333   NaN
# 2232        NaN        NaN        NaN        NaN           0.309   NaN
# 2244        NaN        NaN        NaN        NaN           0.921   NaN
# 2256        NaN        NaN        NaN        NaN          10.341   NaN
# 2268        NaN        NaN        NaN        NaN           0.023   NaN
# 2280        NaN        NaN        NaN        NaN          -0.004   NaN
# 2290        NaN        NaN        NaN        NaN          -0.053   NaN
# 2296        NaN        NaN        NaN        NaN           12.36   NaN
#
#       fwd_barcode  rev_barcode
# 5        CTACTATA     CGTACTCA
# 18       CGTTACTA     CGTACTCA
# 31       AGAGTCAC     CGTACTCA
# 44       TACGAGAC     CGTACTCA
# 57       ACGTCTCG     CGTACTCA
# 70       TCGACGAG     CGTACTCA
# 83       GATCGTGT     CGTACTCA
# 97       GTCAGATA     CGTACTCA
# 111      CTACTATA     CTACGCAG
# 125      CGTTACTA     CTACGCAG
# 139      AGAGTCAC     CTACGCAG
# 152      TACGAGAC     CTACGCAG
# 165      ACGTCTCG     CTACGCAG
# 178      TCGACGAG     CTACGCAG
# 191      GATCGTGT     CTACGCAG
# 204      GTCAGATA     CTACGCAG
# 349      TACGAGAC     GTCGCTCG
# 362      ACGTCTCG     GTCGCTCG
# 375      TCGACGAG     GTCGCTCG
# 387      GACACCGT     CGTACTCA
# 399      ATCGTACG     CTACGCAG
# 411      ACTATCTG     CTACGCAG
# 423      TAGCGAGT     CTACGCAG
# 435      CTGCGTGT     CTACGCAG
# 447      TCATCGAG     CTACGCAG
# 459      CGTGAGTG     CTACGCAG
# 471      GGATATCT     CTACGCAG
# 483      GACACCGT     CTACGCAG
# 495      ATCGTACG     GGAGACTA
# 507      ACTATCTG     GGAGACTA
# ...           ...          ...
# 1959     ATCGTACG     AGTAGCGT
# 1971     ACTATCTG     AGTAGCGT
# 1983     TAGCGAGT     AGTAGCGT
# 1995     CTGCGTGT     AGTAGCGT
# 2007     TCATCGAG     AGTAGCGT
# 2019     CGTGAGTG     AGTAGCGT
# 2031     GGATATCT     AGTAGCGT
# 2043     GACACCGT     AGTAGCGT
# 2054     ATCGTACG     CAGTGAGT
# 2065     ACTATCTG     CAGTGAGT
# 2077     TAGCGAGT     CAGTGAGT
# 2089     CTGCGTGT     CAGTGAGT
# 2101     TCATCGAG     CAGTGAGT
# 2113     CGTGAGTG     CAGTGAGT
# 2125     GGATATCT     CAGTGAGT
# 2137     GACACCGT     CAGTGAGT
# 2149     ATCGTACG     CGTACTCA
# 2161     ACTATCTG     CGTACTCA
# 2173     TAGCGAGT     CGTACTCA
# 2185     CTGCGTGT     CGTACTCA
# 2197     TCATCGAG     CGTACTCA
# 2209     CGTGAGTG     CGTACTCA
# 2221     GGATATCT     CGTACTCA
# 2232     CGTGAGTG     GTCGTAGT
# 2244     GACACCGT     TAGCAGAC
# 2256     CTACTATA     AACTCTCG
# 2268     GTCAGATA     ACTATGTC
# 2280     CTACTATA     AGTAGCGT
# 2290     CTACTATA     TCGCTATA
# 2296     GTCAGATA     TCGCTATA
#
# [181 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 10 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 181
[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MR.M.13C-Ami.D6.R1_Frac26'),
#  ('tgagtacgcgttacta', 'MR.M.13C-Ami.D6.R1_Frac27'),
#  ('tgagtacgagagtcac', 'MR.M.13C-Ami.D6.R1_Frac28'),
#  ('tgagtacgtacgagac', 'MR.M.13C-Ami.D6.R1_NC'),
#  ('tgagtacgacgtctcg', 'MR.F.13C-Cel.D14.R2_Frac6'),
#  ('tgagtacgtcgacgag', 'MR.F.13C-Cel.D14.R2_Frac7'),
#  ('tgagtacggatcgtgt', 'MR.F.13C-Cel.D14.R2_Frac8'),
#  ('tgagtacggtcagata', 'MR.F.13C-Cel.D14.R2_Frac9'),
#  ('ctgcgtagctactata', 'MR.F.13C-Cel.D14.R2_Frac10'),
#  ('ctgcgtagcgttacta', 'MR.F.13C-Cel.D14.R2_Frac11'),
#  ('ctgcgtagagagtcac', 'MR.F.13C-Cel.D14.R2_Frac12'),
#  ('ctgcgtagtacgagac', 'MR.F.13C-Cel.D14.R2_Frac13'),
#  ('ctgcgtagacgtctcg', 'MR.F.13C-Cel.D14.R2_Frac14'),
#  ('ctgcgtagtcgacgag', 'MR.F.13C-Cel.D14.R2_Frac15'),
#  ('ctgcgtaggatcgtgt', 'MR.F.13C-Cel.D14.R2_Frac16'),
#  ('ctgcgtaggtcagata', 'MR.F.13C-Cel.D14.R2_Frac17'),
#  ('cgagcgactacgagac', 'MR.M.12C-Con.D6.R2_Frac6'),
#  ('cgagcgacacgtctcg', 'MR.M.12C-Con.D6.R2_Frac7'),
#  ('cgagcgactcgacgag', 'MR.M.12C-Con.D6.R2_Frac8'),
#  ('tgagtacggacaccgt', 'MR.A.13C-Cel.D14.R1_Frac7'),
#  ('ctgcgtagatcgtacg', 'MR.A.13C-Cel.D14.R1_Frac8'),
#  ('ctgcgtagactatctg', 'MR.A.13C-Cel.D14.R1_Frac9'),
#  ('ctgcgtagtagcgagt', 'MR.A.13C-Cel.D14.R1_Frac10'),
#  ('ctgcgtagctgcgtgt', 'MR.A.13C-Cel.D14.R1_Frac11'),
#  ('ctgcgtagtcatcgag', 'MR.A.13C-Cel.D14.R1_Frac12'),
#  ('ctgcgtagcgtgagtg', 'MR.A.13C-Cel.D14.R1_Frac13'),
#  ('ctgcgtagggatatct', 'MR.A.13C-Cel.D14.R1_Frac14'),
#  ('ctgcgtaggacaccgt', 'MR.A.13C-Cel.D14.R1_Frac15'),
#  ('tagtctccatcgtacg', 'MR.A.13C-Cel.D14.R1_Frac16'),
#  ('tagtctccactatctg', 'MR.A.13C-Cel.D14.R1_Frac17'),
#  ('tagtctcctagcgagt', 'MR.A.13C-Cel.D14.R1_Frac18'),
#  ('tagtctccctgcgtgt', 'MR.A.13C-Cel.D14.R1_Frac19'),
#  ('tagtctcctcatcgag', 'MR.A.13C-Cel.D14.R1_Frac20'),
#  ('tagtctcccgtgagtg', 'MR.A.13C-Cel.D14.R1_Frac21'),
#  ('tagtctccggatatct', 'MR.A.13C-Cel.D14.R1_Frac22'),
#  ('tagtctccgacaccgt', 'MR.A.13C-Cel.D14.R1_Frac23'),
#  ('cgagcgacatcgtacg', 'MR.A.13C-Cel.D14.R1_Frac24'),
#  ('cgagcgacactatctg', 'MR.A.13C-Cel.D14.R1_Frac25'),
#  ('cgagcgactagcgagt', 'MR.A.13C-Cel.D14.R1_Frac26'),
#  ('cgagcgacctgcgtgt', 'MR.A.13C-Cel.D14.R1_Frac27'),
#  ('cgagcgactcatcgag', 'MR.A.13C-Cel.D14.R1_NC'),
#  ('cgagcgaccgtgagtg', 'MR.F.13C-Xyl.D3.R1_Frac6'),
#  ('cgagcgacggatatct', 'MR.F.13C-Xyl.D3.R1_Frac7'),
#  ('cgagcgacgacaccgt', 'MR.F.13C-Xyl.D3.R1_Frac8'),
#  ('actacgacatcgtacg', 'MR.F.13C-Xyl.D3.R1_Frac9'),
#  ('actacgacactatctg', 'MR.F.13C-Xyl.D3.R1_Frac10'),
#  ('actacgactagcgagt', 'MR.F.13C-Xyl.D3.R1_Frac11'),
#  ('actacgacctgcgtgt', 'MR.F.13C-Xyl.D3.R1_Frac12'),
#  ('actacgactcatcgag', 'MR.F.13C-Xyl.D3.R1_Frac13'),
#  ('actacgacggatatct', 'MR.F.13C-Xyl.D3.R1_Frac15'),
#  ('actacgacgacaccgt', 'MR.F.13C-Xyl.D3.R1_Frac16'),
#  ('gtctgctaatcgtacg', 'MR.F.13C-Xyl.D3.R1_Frac17'),
#  ('gtctgctaactatctg', 'MR.F.13C-Xyl.D3.R1_Frac18'),
#  ('gtctgctatagcgagt', 'MR.F.13C-Xyl.D3.R1_Frac19'),
#  ('gtctgctactgcgtgt', 'MR.F.13C-Xyl.D3.R1_Frac20'),
#  ('gtctgctatcatcgag', 'MR.F.13C-Xyl.D3.R1_Frac21'),
#  ('gtctgctacgtgagtg', 'MR.F.13C-Xyl.D3.R1_Frac22'),
#  ('gtctgctaggatatct', 'MR.F.13C-Xyl.D3.R1_Frac23'),
#  ('gtctatgaatcgtacg', 'MR.F.13C-Xyl.D3.R1_Frac25'),
#  ('gtctatgaactatctg', 'MR.F.13C-Xyl.D3.R1_Frac26'),
#  ('gtctatgatagcgagt', 'MR.F.13C-Xyl.D3.R1_Frac27'),
#  ('gtctatgactgcgtgt', 'MR.F.13C-Xyl.D3.R1_NC'),
#  ('gtctatgatcatcgag', 'MR.F.13C-Xyl.D6.R1_Frac6'),
#  ('gtctatgacgtgagtg', 'MR.F.13C-Xyl.D6.R1_Frac7'),
#  ('gtctatgaggatatct', 'MR.F.13C-Xyl.D6.R1_Frac8'),
#  ('gtctatgagacaccgt', 'MR.F.13C-Xyl.D6.R1_Frac9'),
#  ('tatagcgaatcgtacg', 'MR.F.13C-Xyl.D6.R1_Frac10'),
#  ('tatagcgaactatctg', 'MR.F.13C-Xyl.D6.R1_Frac11'),
#  ('tatagcgatagcgagt', 'MR.F.13C-Xyl.D6.R1_Frac12'),
#  ('tatagcgactgcgtgt', 'MR.F.13C-Xyl.D6.R1_Frac13'),
#  ('tatagcgatcatcgag', 'MR.F.13C-Xyl.D6.R1_Frac14'),
#  ('tatagcgacgtgagtg', 'MR.F.13C-Xyl.D6.R1_Frac15'),
#  ('tatagcgaggatatct', 'MR.F.13C-Xyl.D6.R1_Frac16'),
#  ('tatagcgagacaccgt', 'MR.F.13C-Xyl.D6.R1_Frac17'),
#  ('cgagagttcgttacta', 'MR.F.13C-Xyl.D6.R1_Frac19'),
#  ('cgagagttagagtcac', 'MR.F.13C-Xyl.D6.R1_Frac20'),
#  ('cgagagtttacgagac', 'MR.F.13C-Xyl.D6.R1_Frac21'),
#  ('cgagagttacgtctcg', 'MR.F.13C-Xyl.D6.R1_Frac22'),
#  ('cgagagtttcgacgag', 'MR.F.13C-Xyl.D6.R1_Frac23'),
#  ('cgagagttgatcgtgt', 'MR.F.13C-Xyl.D6.R1_Frac24'),
#  ('cgagagttgtcagata', 'MR.F.13C-Xyl.D6.R1_Frac25'),
#  ('gacatagtctactata', 'MR.F.13C-Xyl.D6.R1_Frac26'),
#  ('gacatagtcgttacta', 'MR.F.13C-Xyl.D6.R1_Frac27'),
#  ('gacatagtagagtcac', 'MR.F.13C-Xyl.D6.R1_Frac28'),
#  ('gacatagttacgagac', 'MR.F.13C-Xyl.D6.R1_NC'),
#  ('gacatagtacgtctcg', 'MR.M.13C-Ami.D6.R1_Frac6'),
#  ('gacatagttcgacgag', 'MR.M.13C-Ami.D6.R1_Frac7'),
#  ('gacatagtgatcgtgt', 'MR.M.13C-Ami.D6.R1_Frac8'),
#  ('acgctactcgttacta', 'MR.M.13C-Ami.D6.R1_Frac11'),
#  ('acgctactagagtcac', 'MR.M.13C-Ami.D6.R1_Frac12'),
#  ('acgctacttacgagac', 'MR.M.13C-Ami.D6.R1_Frac13'),
#  ('acgctactacgtctcg', 'MR.M.13C-Ami.D6.R1_Frac14'),
#  ('acgctacttcgacgag', 'MR.M.13C-Ami.D6.R1_Frac15'),
#  ('acgctactgatcgtgt', 'MR.M.13C-Ami.D6.R1_Frac16'),
#  ('acgctactgtcagata', 'MR.M.13C-Ami.D6.R1_Frac17'),
#  ('actcactgctactata', 'MR.M.13C-Ami.D6.R1_Frac18'),
#  ('actcactgcgttacta', 'MR.M.13C-Ami.D6.R1_Frac19'),
#  ('actcactgagagtcac', 'MR.M.13C-Ami.D6.R1_Frac20'),
#  ('actcactgtacgagac', 'MR.M.13C-Ami.D6.R1_Frac21'),
#  ('actcactgacgtctcg', 'MR.M.13C-Ami.D6.R1_Frac22'),
#  ('actcactgtcgacgag', 'MR.M.13C-Ami.D6.R1_Frac23'),
#  ('actcactggatcgtgt', 'MR.M.13C-Ami.D6.R1_Frac24'),
#  ('actcactggtcagata', 'MR.M.13C-Ami.D6.R1_Frac25'),
#  ('cgagcgacgatcgtgt', 'MR.M.12C-Con.D6.R2_Frac9'),
#  ('cgagcgacgtcagata', 'MR.M.12C-Con.D6.R2_Frac10'),
#  ('actacgacctactata', 'MR.M.12C-Con.D6.R2_Frac11'),
#  ('actacgaccgttacta', 'MR.M.12C-Con.D6.R2_Frac12'),
#  ('actacgacagagtcac', 'MR.M.12C-Con.D6.R2_Frac13'),
#  ('actacgactacgagac', 'MR.M.12C-Con.D6.R2_Frac14'),
#  ('actacgacacgtctcg', 'MR.M.12C-Con.D6.R2_Frac15'),
#  ('actacgactcgacgag', 'MR.M.12C-Con.D6.R2_Frac16'),
#  ('actacgacgatcgtgt', 'MR.M.12C-Con.D6.R2_Frac17'),
#  ('actacgacgtcagata', 'MR.M.12C-Con.D6.R2_Frac18'),
#  ('gtctgctactactata', 'MR.M.12C-Con.D6.R2_Frac19'),
#  ('gtctgctacgttacta', 'MR.M.12C-Con.D6.R2_Frac20'),
#  ('gtctgctaagagtcac', 'MR.M.12C-Con.D6.R2_Frac21'),
#  ('gtctgctatacgagac', 'MR.M.12C-Con.D6.R2_Frac22'),
#  ('gtctgctaacgtctcg', 'MR.M.12C-Con.D6.R2_Frac23'),
#  ('gtctgctatcgacgag', 'MR.M.12C-Con.D6.R2_Frac24'),
#  ('gtctgctagatcgtgt', 'MR.M.12C-Con.D6.R2_Frac25'),
#  ('gtctgctagtcagata', 'MR.M.12C-Con.D6.R2_Frac26'),
#  ('gtctatgactactata', 'MR.M.12C-Con.D6.R2_Frac27'),
#  ('gtctatgacgttacta', 'MR.M.12C-Con.D6.R2_NC'),
#  ('gtctatgaagagtcac', 'MR.F.12C-Con.D14.R1_Frac5'),
#  ('gtctatgatacgagac', 'MR.F.12C-Con.D14.R1_Frac6'),
#  ('gtctatgaacgtctcg', 'MR.F.12C-Con.D14.R1_Frac7'),
#  ('gtctatgatcgacgag', 'MR.F.12C-Con.D14.R1_Frac8'),
#  ('gtctatgagatcgtgt', 'MR.F.12C-Con.D14.R1_Frac9'),
#  ('gtctatgagtcagata', 'MR.F.12C-Con.D14.R1_Frac10'),
#  ('tatagcgacgttacta', 'MR.F.12C-Con.D14.R1_Frac12'),
#  ('tatagcgaagagtcac', 'MR.F.12C-Con.D14.R1_Frac13'),
#  ('tatagcgatacgagac', 'MR.F.12C-Con.D14.R1_Frac14'),
#  ('tatagcgaacgtctcg', 'MR.F.12C-Con.D14.R1_Frac15'),
#  ('tatagcgatcgacgag', 'MR.F.12C-Con.D14.R1_Frac16'),
#  ('tatagcgagatcgtgt', 'MR.F.12C-Con.D14.R1_Frac17'),
#  ('cgagagttatcgtacg', 'MR.A.13C-Pal.D30.R3_Frac18'),
#  ('cgagagttactatctg', 'MR.A.13C-Pal.D30.R3_Frac19'),
#  ('cgagagtttagcgagt', 'MR.A.13C-Pal.D30.R3_Frac20'),
#  ('cgagagttctgcgtgt', 'MR.A.13C-Pal.D30.R3_Frac21'),
#  ('cgagagtttcatcgag', 'MR.A.13C-Pal.D30.R3_Frac22'),
#  ('cgagagttcgtgagtg', 'MR.A.13C-Pal.D30.R3_Frac23'),
#  ('cgagagttggatatct', 'MR.A.13C-Pal.D30.R3_Frac24'),
#  ('cgagagttgacaccgt', 'MR.A.13C-Pal.D30.R3_Frac25'),
#  ('gacatagtatcgtacg', 'MR.A.13C-Pal.D30.R3_Frac26'),
#  ('gacatagtactatctg', 'MR.A.13C-Pal.D30.R3_Frac27'),
#  ('gacatagttagcgagt', 'MR.A.13C-Pal.D30.R3_Frac28'),
#  ('gacatagtctgcgtgt', 'MR.A.13C-Pal.D30.R3_NC'),
#  ('gacatagttcatcgag', 'MR.A.12C-Con.D30.R3_Frac5'),
#  ('gacatagtcgtgagtg', 'MR.A.12C-Con.D30.R3_Frac6'),
#  ('gacatagtggatatct', 'MR.A.12C-Con.D30.R3_Frac7'),
#  ('gacatagtgacaccgt', 'MR.A.12C-Con.D30.R3_Frac8'),
#  ('acgctactatcgtacg', 'MR.A.12C-Con.D30.R3_Frac9'),
#  ('acgctactactatctg', 'MR.A.12C-Con.D30.R3_Frac10'),
#  ('acgctacttagcgagt', 'MR.A.12C-Con.D30.R3_Frac11'),
#  ('acgctactctgcgtgt', 'MR.A.12C-Con.D30.R3_Frac12'),
#  ('acgctacttcatcgag', 'MR.A.12C-Con.D30.R3_Frac13'),
#  ('acgctactcgtgagtg', 'MR.A.12C-Con.D30.R3_Frac14'),
#  ('acgctactggatatct', 'MR.A.12C-Con.D30.R3_Frac15'),
#  ('acgctactgacaccgt', 'MR.A.12C-Con.D30.R3_Frac16'),
#  ('actcactgatcgtacg', 'MR.A.12C-Con.D30.R3_Frac17'),
#  ('actcactgactatctg', 'MR.A.12C-Con.D30.R3_Frac18'),
#  ('actcactgtagcgagt', 'MR.A.12C-Con.D30.R3_Frac19'),
#  ('actcactgctgcgtgt', 'MR.A.12C-Con.D30.R3_Frac20'),
#  ('actcactgtcatcgag', 'MR.A.12C-Con.D30.R3_Frac21'),
#  ('actcactgcgtgagtg', 'MR.A.12C-Con.D30.R3_Frac22'),
#  ('actcactgggatatct', 'MR.A.12C-Con.D30.R3_Frac23'),
#  ('actcactggacaccgt', 'MR.A.12C-Con.D30.R3_Frac24'),
#  ('tgagtacgatcgtacg', 'MR.A.12C-Con.D30.R3_Frac25'),
#  ('tgagtacgactatctg', 'MR.A.12C-Con.D30.R3_Frac26'),
#  ('tgagtacgtagcgagt', 'MR.A.12C-Con.D30.R3_Frac27'),
#  ('tgagtacgctgcgtgt', 'MR.A.12C-Con.D30.R3_Frac28'),
#  ('tgagtacgtcatcgag', 'MR.A.12C-Con.D30.R3_NC'),
#  ('tgagtacgcgtgagtg', 'MR.A.12C-Con.D30.R3_MC'),
#  ('tgagtacgggatatct', 'MR.A.13C-Cel.D14.R1_Frac6'),
#  ('actacgaccgtgagtg', 'MR.F.13C-Xyl.D3.R1_Frac14'),
#  ('gtctgctagacaccgt', 'MR.F.13C-Xyl.D3.R1_Frac24'),
#  ('cgagagttctactata', 'MR.F.13C-Xyl.D6.R1_Frac18'),
#  ('gacatagtgtcagata', 'MR.M.13C-Ami.D6.R1_Frac9'),
#  ('acgctactctactata', 'MR.M.13C-Ami.D6.R1_Frac10'),
#  ('tatagcgactactata', 'MR.F.12C-Con.D14.R1_Frac11'),
#  ('tatagcgagtcagata', 'MR.F.12C-Con.D14.R1_Frac18')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)
# Out:
# Unable to assign 3085898 reads to samples

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 5176899.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                          Sample  seq_count
# 0     MR.M.13C-Ami.D6.R1_Frac17      58347
# 1    MR.A.13C-Cel.D14.R1_Frac18      25290
# 2    MR.A.12C-Con.D30.R3_Frac18      17114
# 3     MR.F.13C-Xyl.D3.R1_Frac21      77273
# 4    MR.A.13C-Cel.D14.R1_Frac15      33480
# 5    MR.F.13C-Cel.D14.R2_Frac15      26459
# 6     MR.M.13C-Ami.D6.R1_Frac12      28027
# 7     MR.F.13C-Xyl.D6.R1_Frac28      37233
# 8     MR.M.13C-Ami.D6.R1_Frac10      28606
# 9     MR.A.12C-Con.D30.R3_Frac5      29140
# 10    MR.F.13C-Xyl.D6.R1_Frac20      24418
# 11    MR.M.12C-Con.D6.R2_Frac19      19288
# 12    MR.F.13C-Xyl.D3.R1_Frac13      49820
# 13    MR.M.12C-Con.D6.R2_Frac18      65347
# 14   MR.F.13C-Cel.D14.R2_Frac17      61011
# 15    MR.F.13C-Xyl.D6.R1_Frac18      19223
# 16   MR.A.13C-Pal.D30.R3_Frac28      33518
# 17    MR.M.13C-Ami.D6.R1_Frac15      71354
# 18    MR.M.13C-Ami.D6.R1_Frac23      27205
# 19    MR.F.13C-Xyl.D3.R1_Frac16      63915
# 20    MR.F.13C-Xyl.D3.R1_Frac22      14194
# 21    MR.F.13C-Xyl.D6.R1_Frac17      25898
# 22    MR.M.13C-Ami.D6.R1_Frac16      48612
# 23     MR.F.13C-Xyl.D3.R1_Frac7      40099
# 24   MR.F.12C-Con.D14.R1_Frac18      95734
# 25     MR.F.13C-Xyl.D6.R1_Frac9      25428
# 26     MR.M.12C-Con.D6.R2_Frac8      37907
# 27   MR.A.12C-Con.D30.R3_Frac24      50574
# 28    MR.M.12C-Con.D6.R2_Frac23      16178
# 29   MR.A.12C-Con.D30.R3_Frac12      20941
# ..                          ...        ...
# 151      MR.A.12C-Con.D30.R3_MC      15509
# 152   MR.F.12C-Con.D14.R1_Frac9      20769
# 153   MR.F.12C-Con.D14.R1_Frac7      22969
# 154   MR.F.13C-Cel.D14.R2_Frac7      22304
# 155   MR.F.12C-Con.D14.R1_Frac5      24053
# 156   MR.F.13C-Xyl.D6.R1_Frac27      20626
# 157  MR.A.12C-Con.D30.R3_Frac22      25618
# 158  MR.A.12C-Con.D30.R3_Frac10      23853
# 159   MR.M.12C-Con.D6.R2_Frac15      16500
# 160   MR.M.12C-Con.D6.R2_Frac14      39665
# 161  MR.A.12C-Con.D30.R3_Frac26      13276
# 162  MR.A.13C-Cel.D14.R1_Frac23      25412
# 163   MR.A.12C-Con.D30.R3_Frac7      33557
# 164   MR.M.12C-Con.D6.R2_Frac24      24001
# 165   MR.F.13C-Xyl.D3.R1_Frac10       5281
# 166   MR.M.12C-Con.D6.R2_Frac27      28480
# 167   MR.M.13C-Ami.D6.R1_Frac24      15142
# 168  MR.A.13C-Pal.D30.R3_Frac22      40425
# 169  MR.A.12C-Con.D30.R3_Frac28      14487
# 170    MR.M.12C-Con.D6.R2_Frac6      22506
# 171   MR.F.13C-Xyl.D3.R1_Frac19      31111
# 172  MR.A.12C-Con.D30.R3_Frac21      26751
# 173  MR.F.13C-Cel.D14.R2_Frac12      19685
# 174      MR.A.13C-Cel.D14.R1_NC        617
# 175      MR.A.13C-Pal.D30.R3_NC       1042
# 176       MR.M.13C-Ami.D6.R1_NC       1148
# 177      MR.A.12C-Con.D30.R3_NC        832
# 178       MR.F.13C-Xyl.D6.R1_NC       1079
# 179       MR.F.13C-Xyl.D3.R1_NC        650
# 180       MR.M.12C-Con.D6.R2_NC        711
#
# [181 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 10000,]
# Out:
#                        Sample seq_count
# 165 MR.F.13C-Xyl.D3.R1_Frac10      5281
# 174    MR.A.13C-Cel.D14.R1_NC       617
# 175    MR.A.13C-Pal.D30.R3_NC      1042
# 176     MR.M.13C-Ami.D6.R1_NC      1148
# 177    MR.A.12C-Con.D30.R3_NC       832
# 178     MR.F.13C-Xyl.D6.R1_NC      1079
# 179     MR.F.13C-Xyl.D3.R1_NC       650
# 180     MR.M.12C-Con.D6.R2_NC       711

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 181 samples
# You should have 181 samples
