# %% [markdown]
# # Description:
#
# * Demultiplexing libraries from MiSeq run

# %% [markdown]
# ## Setting variables (user input)

# %%
import os

seqdir = '/home/backup_files/raw_reads/fullcyc2.Barnett.2018/fullCyc2_lib15/run1'
workdir = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib15'

# metadata file location(s)
metadata = '/home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/FullCyc2_master_metadata.txt'

# Library
library = 'fullCyc2_lib15'

# Index and paired files
index_read1_file = 'index_read1.fq.gz'
index_read2_file = 'index_read2.fq.gz'
read12_screed = 'pear_merged-fullCyc2_lib15.assembled.fastq_screed'

# %% [markdown]
# ## Init

# %%
import os
import json
import screed
import pandas as pd
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import scipy.stats as stats
import screed
from glob import glob

# %%
# %cd $workdir
# Out:
# /home/seq_data/fullCyc2/amplicon/515F-806R/final_dataset/library_QC/fullCyc2_lib15

# %%
# %load_ext rpy2.ipython
#%load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# Out:
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
# Attaching package: ‘dplyr’
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   warnings.warn(x, RRuntimeWarning)
# /home/sam/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   warnings.warn(x, RRuntimeWarning)

# %% [markdown]
# ## Loading metadata tables

# %%
# loading metadata sheet
df_meta = pd.read_csv(os.path.join(seqdir, metadata), delimiter="\t")
df_meta.head(n=3)
# Out:
#                    #Sample  primer_number    exp_type extraction_plate_ID  \
# 0              EL.A.151026            129        bulk            14012016
# 1  CC.M.151027.12C-Van.D02            129  Enrichment         Enr2_160509
# 2  MF.M.151026.12C-Ami.D02            129  Enrichment         Enr5_170113
#
#        library_ID          pool_plate_ID pool_plate_well  \
# 0   Chantal_Pool9                    NaN             NaN
# 1  fullCyc2_lib14  fullCyc2_lib14_pool_2              A5
# 2  fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
#
#                    soil_ID substrate  day     ...       \
# 0              EL.A.151026       NaN  NaN     ...
# 1  CC.M.151027.12C-Van.D02   12C-Van  2.0     ...
# 2  MF.M.151026.12C-Ami.D02   12C-Ami  2.0     ...
#
#    water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 0                        0.778    0.20905     2.0399       40.0       26.7
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
#
#   clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 0       33.3          19.965   NaN     CTACTATA     CGTACTCA
# 1        NaN           34.44   NaN     CTACTATA     CGTACTCA
# 2        NaN          27.183   NaN     CTACTATA     CGTACTCA
#
# [3 rows x 38 columns]

# %%
# filter only metadata from this library
df_meta = pd.DataFrame(df_meta[df_meta.library_ID==library])
df_meta
# Out:
#                       #Sample  primer_number    exp_type  extraction_plate_ID  \
# 2     MF.M.151026.12C-Ami.D02            129  Enrichment          Enr5_170113
# 15    MR.F.151027.12C-Ami.D02            130  Enrichment          Enr5_170113
# 28    BH.A.151026.H2O-Con.D04            131  Enrichment          Enr5_170113
# 41    CF.A.151027.12C-Van.D02            132  Enrichment          Enr5_170113
# 54    MR.M.151027.12C-Xyl.D02            133  Enrichment          Enr5_170113
# 67    PP.A.151026.12C-Pal.D14            134  Enrichment          Enr5_170113
# 80    BH.M.151026.12C-Xyl.D02            135  Enrichment          Enr5_170113
# 94    BH.F.151026.12C-Pal.D14            136  Enrichment          Enr5_170113
# 108   MF.M.151026.H2O-Con.D02            137  Enrichment          Enr5_170113
# 122   MR.A.151027.12C-Pal.D28            138  Enrichment          Enr5_170113
# 136   PP.M.151026.12C-Van.D04            139  Enrichment          Enr5_170113
# 149   MW.M.151027.12C-Xyl.D02            140  Enrichment          Enr5_170113
# 162   CC.A.151027.H2O-Con.D28            141  Enrichment          Enr5_170113
# 175   SS.F.151026.12C-Cel.D28            142  Enrichment          Enr5_170113
# 188   CF.F.151027.12C-Van.D04            143  Enrichment          Enr5_170113
# 201   EL.A.151026.12C-Cel.D28            144  Enrichment          Enr5_170113
# 214   MF.A.151026.12C-Xyl.D02            145  Enrichment          Enr5_170113
# 226   CC.M.151027.12C-Ami.D02            146  Enrichment          Enr5_170113
# 238   PP.M.151026.12C-Xyl.D04            147  Enrichment          Enr5_170113
# 250   MW.A.151027.12C-Cel.D28            148  Enrichment          Enr5_170113
# 262   BH.A.151026.12C-Pal.D14            149  Enrichment          Enr5_170113
# 274   SS.M.151026.12C-Pal.D28            150  Enrichment          Enr5_170113
# 286   MF.M.151026.12C-Van.D02            151  Enrichment          Enr5_170113
# 298   MP.A.151026.12C-Ami.D04            152  Enrichment          Enr5_170113
# 310   EL.M.151026.12C-Ami.D04            153  Enrichment          Enr5_170113
# 322   MP.F.151026.H2O-Con.D02            154  Enrichment          Enr5_170113
# 334   MF.F.151026.H2O-Con.D04            155  Enrichment          Enr5_170113
# 346   PP.M.151026.12C-Cel.D28            156  Enrichment          Enr5_170113
# 359   EL.M.151026.12C-Xyl.D02            157  Enrichment          Enr5_170113
# 372   SS.A.151026.H2O-Con.D04            158  Enrichment          Enr5_170113
# ...                       ...            ...         ...                  ...
# 1955  MP.M.151026.12C-Ami.D04             17  Enrichment  Unfrac2_Enr3_160525
# 1967  EL.M.151026.12C-Pal.D14             18  Enrichment  Unfrac2_Enr3_160525
# 1979  MF.M.151026.12C-Xyl.D02             19  Enrichment  Unfrac2_Enr3_160525
# 1991  BH.M.151026.12C-Ami.D04             20  Enrichment  Unfrac2_Enr3_160525
# 2003  PP.M.151026.12C-Ami.D02             21  Enrichment  Unfrac2_Enr3_160525
# 2015  BH.A.151026.12C-Pal.D28             22  Enrichment  Unfrac2_Enr3_160525
# 2027  MP.F.151026.H2O-Con.D28             23  Enrichment  Unfrac2_Enr3_160525
# 2039  CF.F.151027.12C-Cel.D14             24  Enrichment  Unfrac2_Enr3_160525
# 2051  CF.M.151027.12C-Cel.D28             25  Enrichment  Unfrac2_Enr3_160525
# 2062  SS.F.151026.12C-Van.D02             26  Enrichment  Unfrac2_Enr3_160525
# 2073  CF.A.151027.12C-Ami.D04             27  Enrichment  Unfrac2_Enr3_160525
# 2085  SS.M.151026.12C-Van.D04             28  Enrichment  Unfrac2_Enr3_160525
# 2097  MW.A.151027.12C-Pal.D14             29  Enrichment  Unfrac2_Enr3_160525
# 2109  MP.M.151026.12C-Xyl.D02             30  Enrichment  Unfrac2_Enr3_160525
# 2121  MR.F.151027.12C-Van.D02             31  Enrichment  Unfrac2_Enr3_160525
# 2133             Enr3_H2O_con             32  Enrichment  Unfrac2_Enr3_160525
# 2145  EL.A.151026.H2O-Con.D02             33  Enrichment          Enr4_160627
# 2157  CF.A.151027.12C-Cel.D28             34  Enrichment          Enr4_160627
# 2169  MF.M.151026.12C-Cel.D28             35  Enrichment          Enr4_160627
# 2181  MW.M.151027.H2O-Con.D14             36  Enrichment          Enr4_160627
# 2193  EL.F.151026.12C-Ami.D02             37  Enrichment          Enr4_160627
# 2205  MF.F.151026.H2O-Con.D28             38  Enrichment          Enr4_160627
# 2217  PP.M.151026.12C-Van.D02             39  Enrichment          Enr4_160627
# 2229  CF.A.151027.12C-Ami.D02             70  Enrichment          Enr4_160627
# 2240  CC.A.151027.12C-Van.D02             80  Enrichment          Enr4_160627
# 2252  CC.M.151027.12C-Cel.D14             97  Enrichment          Enr4_160627
# 2264  MR.A.151027.12C-Cel.D14            112  Enrichment          Enr4_160627
# 2276  BH.A.151026.12C-Van.D02            113  Enrichment          Enr4_160627
# 2288  MF.F.151026.12C-Xyl.D04            185  Enrichment          Enr5_170113
# 2295     Enr_2_mock_community            192  Enrichment                  NaN
#
#           library_ID          pool_plate_ID pool_plate_well  \
# 2     fullCyc2_lib15  fullCyc2_lib15_pool_2              A5
# 15    fullCyc2_lib15  fullCyc2_lib15_pool_2              B5
# 28    fullCyc2_lib15  fullCyc2_lib15_pool_2              C5
# 41    fullCyc2_lib15  fullCyc2_lib15_pool_2              D5
# 54    fullCyc2_lib15  fullCyc2_lib15_pool_2              E5
# 67    fullCyc2_lib15  fullCyc2_lib15_pool_2              F5
# 80    fullCyc2_lib15  fullCyc2_lib15_pool_2              G5
# 94    fullCyc2_lib15  fullCyc2_lib15_pool_2              H5
# 108   fullCyc2_lib15  fullCyc2_lib15_pool_2              A6
# 122   fullCyc2_lib15  fullCyc2_lib15_pool_2              B6
# 136   fullCyc2_lib15  fullCyc2_lib15_pool_2              C6
# 149   fullCyc2_lib15  fullCyc2_lib15_pool_2              D6
# 162   fullCyc2_lib15  fullCyc2_lib15_pool_2              E6
# 175   fullCyc2_lib15  fullCyc2_lib15_pool_2              F6
# 188   fullCyc2_lib15  fullCyc2_lib15_pool_2              G6
# 201   fullCyc2_lib15  fullCyc2_lib15_pool_2              H6
# 214   fullCyc2_lib15  fullCyc2_lib15_pool_2              A7
# 226   fullCyc2_lib15  fullCyc2_lib15_pool_2              B7
# 238   fullCyc2_lib15  fullCyc2_lib15_pool_2              C7
# 250   fullCyc2_lib15  fullCyc2_lib15_pool_2              D7
# 262   fullCyc2_lib15  fullCyc2_lib15_pool_2              E7
# 274   fullCyc2_lib15  fullCyc2_lib15_pool_2              F7
# 286   fullCyc2_lib15  fullCyc2_lib15_pool_2              G7
# 298   fullCyc2_lib15  fullCyc2_lib15_pool_2              H7
# 310   fullCyc2_lib15  fullCyc2_lib15_pool_2              A8
# 322   fullCyc2_lib15  fullCyc2_lib15_pool_2              B8
# 334   fullCyc2_lib15  fullCyc2_lib15_pool_2              C8
# 346   fullCyc2_lib15  fullCyc2_lib15_pool_2              D8
# 359   fullCyc2_lib15  fullCyc2_lib15_pool_2              E8
# 372   fullCyc2_lib15  fullCyc2_lib15_pool_2              F8
# ...              ...                    ...             ...
# 1955  fullCyc2_lib15  fullCyc2_lib15_pool_1              A3
# 1967  fullCyc2_lib15  fullCyc2_lib15_pool_1              B3
# 1979  fullCyc2_lib15  fullCyc2_lib15_pool_1              C3
# 1991  fullCyc2_lib15  fullCyc2_lib15_pool_1              D3
# 2003  fullCyc2_lib15  fullCyc2_lib15_pool_1              E3
# 2015  fullCyc2_lib15  fullCyc2_lib15_pool_1              F3
# 2027  fullCyc2_lib15  fullCyc2_lib15_pool_1              G3
# 2039  fullCyc2_lib15  fullCyc2_lib15_pool_1              H3
# 2051  fullCyc2_lib15  fullCyc2_lib15_pool_1              A4
# 2062  fullCyc2_lib15  fullCyc2_lib15_pool_1              B4
# 2073  fullCyc2_lib15  fullCyc2_lib15_pool_1              C4
# 2085  fullCyc2_lib15  fullCyc2_lib15_pool_1              D4
# 2097  fullCyc2_lib15  fullCyc2_lib15_pool_1              E4
# 2109  fullCyc2_lib15  fullCyc2_lib15_pool_1              F4
# 2121  fullCyc2_lib15  fullCyc2_lib15_pool_1              G4
# 2133  fullCyc2_lib15  fullCyc2_lib15_pool_1              H4
# 2145  fullCyc2_lib15  fullCyc2_lib15_pool_1              A5
# 2157  fullCyc2_lib15  fullCyc2_lib15_pool_1              B5
# 2169  fullCyc2_lib15  fullCyc2_lib15_pool_1              C5
# 2181  fullCyc2_lib15  fullCyc2_lib15_pool_1              D5
# 2193  fullCyc2_lib15  fullCyc2_lib15_pool_1              E5
# 2205  fullCyc2_lib15  fullCyc2_lib15_pool_1              F5
# 2217  fullCyc2_lib15  fullCyc2_lib15_pool_1              G5
# 2229  fullCyc2_lib15  fullCyc2_lib15_pool_1              F9
# 2240  fullCyc2_lib15  fullCyc2_lib15_pool_1             H10
# 2252  fullCyc2_lib15  fullCyc2_lib15_pool_2              A1
# 2264  fullCyc2_lib15  fullCyc2_lib15_pool_2              H2
# 2276  fullCyc2_lib15  fullCyc2_lib15_pool_2              A3
# 2288  fullCyc2_lib15  fullCyc2_lib15_pool_2             A12
# 2295  fullCyc2_lib15  fullCyc2_lib15_pool_2             H12
#
#                       soil_ID substrate   day     ...       \
# 2     MF.M.151026.12C-Ami.D02   12C-Ami   2.0     ...
# 15    MR.F.151027.12C-Ami.D02   12C-Ami   2.0     ...
# 28    BH.A.151026.H2O-Con.D04   H2O-Con   4.0     ...
# 41    CF.A.151027.12C-Van.D02   12C-Van   2.0     ...
# 54    MR.M.151027.12C-Xyl.D02   12C-Xyl   2.0     ...
# 67    PP.A.151026.12C-Pal.D14   12C-Pal  14.0     ...
# 80    BH.M.151026.12C-Xyl.D02   12C-Xyl   2.0     ...
# 94    BH.F.151026.12C-Pal.D14   12C-Pal  14.0     ...
# 108   MF.M.151026.H2O-Con.D02   H2O-Con   2.0     ...
# 122   MR.A.151027.12C-Pal.D28   12C-Pal  28.0     ...
# 136   PP.M.151026.12C-Van.D04   12C-Van   4.0     ...
# 149   MW.M.151027.12C-Xyl.D02   12C-Xyl   2.0     ...
# 162   CC.A.151027.H2O-Con.D28   H2O-Con  28.0     ...
# 175   SS.F.151026.12C-Cel.D28   12C-Cel  28.0     ...
# 188   CF.F.151027.12C-Van.D04   12C-Van   4.0     ...
# 201   EL.A.151026.12C-Cel.D28   12C-Cel  28.0     ...
# 214   MF.A.151026.12C-Xyl.D02   12C-Xyl   2.0     ...
# 226   CC.M.151027.12C-Ami.D02   12C-Ami   2.0     ...
# 238   PP.M.151026.12C-Xyl.D04   12C-Xyl   4.0     ...
# 250   MW.A.151027.12C-Cel.D28   12C-Cel  28.0     ...
# 262   BH.A.151026.12C-Pal.D14   12C-Pal  14.0     ...
# 274   SS.M.151026.12C-Pal.D28   12C-Pal  28.0     ...
# 286   MF.M.151026.12C-Van.D02   12C-Van   2.0     ...
# 298   MP.A.151026.12C-Ami.D04   12C-Ami   4.0     ...
# 310   EL.M.151026.12C-Ami.D04   12C-Ami   4.0     ...
# 322   MP.F.151026.H2O-Con.D02   H2O-Con   2.0     ...
# 334   MF.F.151026.H2O-Con.D04   H2O-Con   4.0     ...
# 346   PP.M.151026.12C-Cel.D28   12C-Cel  28.0     ...
# 359   EL.M.151026.12C-Xyl.D02   12C-Xyl   2.0     ...
# 372   SS.A.151026.H2O-Con.D04   H2O-Con   4.0     ...
# ...                       ...       ...   ...     ...
# 1955  MP.M.151026.12C-Ami.D04   12C-Ami   4.0     ...
# 1967  EL.M.151026.12C-Pal.D14   12C-Pal  14.0     ...
# 1979  MF.M.151026.12C-Xyl.D02   12C-Xyl   2.0     ...
# 1991  BH.M.151026.12C-Ami.D04   12C-Ami   4.0     ...
# 2003  PP.M.151026.12C-Ami.D02   12C-Ami   2.0     ...
# 2015  BH.A.151026.12C-Pal.D28   12C-Pal  28.0     ...
# 2027  MP.F.151026.H2O-Con.D28   H2O-Con  28.0     ...
# 2039  CF.F.151027.12C-Cel.D14   12C-Cel  14.0     ...
# 2051  CF.M.151027.12C-Cel.D28   12C-Cel  28.0     ...
# 2062  SS.F.151026.12C-Van.D02   12C-Van   2.0     ...
# 2073  CF.A.151027.12C-Ami.D04   12C-Ami   4.0     ...
# 2085  SS.M.151026.12C-Van.D04   12C-Van   4.0     ...
# 2097  MW.A.151027.12C-Pal.D14   12C-Pal  14.0     ...
# 2109  MP.M.151026.12C-Xyl.D02   12C-Xyl   2.0     ...
# 2121  MR.F.151027.12C-Van.D02   12C-Van   2.0     ...
# 2133             Enr3_H2O_con       NaN   NaN     ...
# 2145  EL.A.151026.H2O-Con.D02   H2O-Con   2.0     ...
# 2157  CF.A.151027.12C-Cel.D28   12C-Cel  28.0     ...
# 2169  MF.M.151026.12C-Cel.D28   12C-Cel  28.0     ...
# 2181  MW.M.151027.H2O-Con.D14   H2O-Con  14.0     ...
# 2193  EL.F.151026.12C-Ami.D02   12C-Ami   2.0     ...
# 2205  MF.F.151026.H2O-Con.D28   H2O-Con  28.0     ...
# 2217  PP.M.151026.12C-Van.D02   12C-Van   2.0     ...
# 2229  CF.A.151027.12C-Ami.D02   12C-Ami   2.0     ...
# 2240  CC.A.151027.12C-Van.D02   12C-Van   2.0     ...
# 2252  CC.M.151027.12C-Cel.D14   12C-Cel  14.0     ...
# 2264  MR.A.151027.12C-Cel.D14   12C-Cel  14.0     ...
# 2276  BH.A.151026.12C-Van.D02   12C-Van   2.0     ...
# 2288  MF.F.151026.12C-Xyl.D04   12C-Xyl   4.0     ...
# 2295                      NaN       NaN   NaN     ...
#
#       water_holding_capacity__g.g  percent_N  percent_C sand__perc silt__perc  \
# 2                             NaN        NaN        NaN        NaN        NaN
# 15                            NaN        NaN        NaN        NaN        NaN
# 28                            NaN        NaN        NaN        NaN        NaN
# 41                            NaN        NaN        NaN        NaN        NaN
# 54                            NaN        NaN        NaN        NaN        NaN
# 67                            NaN        NaN        NaN        NaN        NaN
# 80                            NaN        NaN        NaN        NaN        NaN
# 94                            NaN        NaN        NaN        NaN        NaN
# 108                           NaN        NaN        NaN        NaN        NaN
# 122                           NaN        NaN        NaN        NaN        NaN
# 136                           NaN        NaN        NaN        NaN        NaN
# 149                           NaN        NaN        NaN        NaN        NaN
# 162                           NaN        NaN        NaN        NaN        NaN
# 175                           NaN        NaN        NaN        NaN        NaN
# 188                           NaN        NaN        NaN        NaN        NaN
# 201                           NaN        NaN        NaN        NaN        NaN
# 214                           NaN        NaN        NaN        NaN        NaN
# 226                           NaN        NaN        NaN        NaN        NaN
# 238                           NaN        NaN        NaN        NaN        NaN
# 250                           NaN        NaN        NaN        NaN        NaN
# 262                           NaN        NaN        NaN        NaN        NaN
# 274                           NaN        NaN        NaN        NaN        NaN
# 286                           NaN        NaN        NaN        NaN        NaN
# 298                           NaN        NaN        NaN        NaN        NaN
# 310                           NaN        NaN        NaN        NaN        NaN
# 322                           NaN        NaN        NaN        NaN        NaN
# 334                           NaN        NaN        NaN        NaN        NaN
# 346                           NaN        NaN        NaN        NaN        NaN
# 359                           NaN        NaN        NaN        NaN        NaN
# 372                           NaN        NaN        NaN        NaN        NaN
# ...                           ...        ...        ...        ...        ...
# 1955                          NaN        NaN        NaN        NaN        NaN
# 1967                          NaN        NaN        NaN        NaN        NaN
# 1979                          NaN        NaN        NaN        NaN        NaN
# 1991                          NaN        NaN        NaN        NaN        NaN
# 2003                          NaN        NaN        NaN        NaN        NaN
# 2015                          NaN        NaN        NaN        NaN        NaN
# 2027                          NaN        NaN        NaN        NaN        NaN
# 2039                          NaN        NaN        NaN        NaN        NaN
# 2051                          NaN        NaN        NaN        NaN        NaN
# 2062                          NaN        NaN        NaN        NaN        NaN
# 2073                          NaN        NaN        NaN        NaN        NaN
# 2085                          NaN        NaN        NaN        NaN        NaN
# 2097                          NaN        NaN        NaN        NaN        NaN
# 2109                          NaN        NaN        NaN        NaN        NaN
# 2121                          NaN        NaN        NaN        NaN        NaN
# 2133                          NaN        NaN        NaN        NaN        NaN
# 2145                          NaN        NaN        NaN        NaN        NaN
# 2157                          NaN        NaN        NaN        NaN        NaN
# 2169                          NaN        NaN        NaN        NaN        NaN
# 2181                          NaN        NaN        NaN        NaN        NaN
# 2193                          NaN        NaN        NaN        NaN        NaN
# 2205                          NaN        NaN        NaN        NaN        NaN
# 2217                          NaN        NaN        NaN        NaN        NaN
# 2229                          NaN        NaN        NaN        NaN        NaN
# 2240                          NaN        NaN        NaN        NaN        NaN
# 2252                          NaN        NaN        NaN        NaN        NaN
# 2264                          NaN        NaN        NaN        NaN        NaN
# 2276                          NaN        NaN        NaN        NaN        NaN
# 2288                          NaN        NaN        NaN        NaN        NaN
# 2295                          NaN        NaN        NaN        NaN        NaN
#
#      clay__perc DNA_conc__ng_ul notes  fwd_barcode  rev_barcode
# 2           NaN          27.183   NaN     CTACTATA     CGTACTCA
# 15          NaN          17.164   NaN     CGTTACTA     CGTACTCA
# 28          NaN          15.454   NaN     AGAGTCAC     CGTACTCA
# 41          NaN            0.08   NaN     TACGAGAC     CGTACTCA
# 54          NaN          23.908   NaN     ACGTCTCG     CGTACTCA
# 67          NaN           8.612   NaN     TCGACGAG     CGTACTCA
# 80          NaN          16.857   NaN     GATCGTGT     CGTACTCA
# 94          NaN          10.706   NaN     GTCAGATA     CGTACTCA
# 108         NaN          28.049   NaN     CTACTATA     CTACGCAG
# 122         NaN           1.097   NaN     CGTTACTA     CTACGCAG
# 136         NaN          25.094   NaN     AGAGTCAC     CTACGCAG
# 149         NaN           1.049   NaN     TACGAGAC     CTACGCAG
# 162         NaN           0.104   NaN     ACGTCTCG     CTACGCAG
# 175         NaN          10.968   NaN     TCGACGAG     CTACGCAG
# 188         NaN          27.625   NaN     GATCGTGT     CTACGCAG
# 201         NaN           0.289   NaN     GTCAGATA     CTACGCAG
# 214         NaN           0.213   NaN     CTACTATA     GGAGACTA
# 226         NaN          31.053   NaN     CGTTACTA     GGAGACTA
# 238         NaN          27.496   NaN     AGAGTCAC     GGAGACTA
# 250         NaN           0.099   NaN     TACGAGAC     GGAGACTA
# 262         NaN          22.227   NaN     ACGTCTCG     GGAGACTA
# 274         NaN          29.386   NaN     TCGACGAG     GGAGACTA
# 286         NaN           34.81   NaN     GATCGTGT     GGAGACTA
# 298         NaN            9.41   NaN     GTCAGATA     GGAGACTA
# 310         NaN             4.7   NaN     CTACTATA     GTCGCTCG
# 322         NaN          22.076   NaN     CGTTACTA     GTCGCTCG
# 334         NaN          21.857   NaN     AGAGTCAC     GTCGCTCG
# 346         NaN          33.718   NaN     TACGAGAC     GTCGCTCG
# 359         NaN           8.956   NaN     ACGTCTCG     GTCGCTCG
# 372         NaN          47.966   NaN     TCGACGAG     GTCGCTCG
# ...         ...             ...   ...          ...          ...
# 1955        NaN          21.141   NaN     ATCGTACG     AGTAGCGT
# 1967        NaN            26.7   NaN     ACTATCTG     AGTAGCGT
# 1979        NaN          18.545   NaN     TAGCGAGT     AGTAGCGT
# 1991        NaN          12.888   NaN     CTGCGTGT     AGTAGCGT
# 2003        NaN           23.49   NaN     TCATCGAG     AGTAGCGT
# 2015        NaN          19.406   NaN     CGTGAGTG     AGTAGCGT
# 2027        NaN          23.213   NaN     GGATATCT     AGTAGCGT
# 2039        NaN          16.452   NaN     GACACCGT     AGTAGCGT
# 2051        NaN          10.735   NaN     ATCGTACG     CAGTGAGT
# 2062        NaN           6.996   NaN     ACTATCTG     CAGTGAGT
# 2073        NaN           1.009   NaN     TAGCGAGT     CAGTGAGT
# 2085        NaN          11.949   NaN     CTGCGTGT     CAGTGAGT
# 2097        NaN           1.608   NaN     TCATCGAG     CAGTGAGT
# 2109        NaN          10.346   NaN     CGTGAGTG     CAGTGAGT
# 2121        NaN           5.836   NaN     GGATATCT     CAGTGAGT
# 2133        NaN           0.385   NaN     GACACCGT     CAGTGAGT
# 2145        NaN           7.628   NaN     ATCGTACG     CGTACTCA
# 2157        NaN           2.323   NaN     ACTATCTG     CGTACTCA
# 2169        NaN          30.397   NaN     TAGCGAGT     CGTACTCA
# 2181        NaN          10.717   NaN     CTGCGTGT     CGTACTCA
# 2193        NaN          17.349   NaN     TCATCGAG     CGTACTCA
# 2205        NaN           26.76   NaN     CGTGAGTG     CGTACTCA
# 2217        NaN          18.924   NaN     GGATATCT     CGTACTCA
# 2229        NaN           2.167   NaN     CGTGAGTG     GTCGTAGT
# 2240        NaN           2.797   NaN     GACACCGT     TAGCAGAC
# 2252        NaN          30.228   NaN     CTACTATA     AACTCTCG
# 2264        NaN           5.139   NaN     GTCAGATA     ACTATGTC
# 2276        NaN           5.957   NaN     CTACTATA     AGTAGCGT
# 2288        NaN           9.825   NaN     CTACTATA     TCGCTATA
# 2295        NaN             NaN   NaN     GTCAGATA     TCGCTATA
#
# [190 rows x 38 columns]

# %% [markdown]
# # Uncompress index files and create screed db

# %%
def uncomp(fileName, directory):
    output = fileName.replace(".gz", "")
    fileName = os.path.join(directory, fileName)
    # !cd $workdir; \
        pigz -k -d -p 20 -c -f $fileName > $output
    return os.path.splitext(output)[0]
    
index_read1_file = uncomp(index_read1_file, seqdir)
index_read2_file = uncomp(index_read2_file, seqdir)

# %%
os.chdir(workdir)
screed.read_fastq_sequences(index_read1_file+".fq")
screed.read_fastq_sequences(index_read2_file+".fq")

index_read1_screed = index_read1_file + '.fq_screed'
index_read2_screed = index_read2_file + '.fq_screed'

# %% [markdown]
# # Demultiplex

# %%
# rev-comp functions
def complement(seq): 
    idx = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N':'N'} 
    idx.update( {x.lower():y.lower() for x,y in idx.items()} )
    return ''.join(idx[x] for x in list(seq))

def revComp(seq):
    seq = seq[::-1]
    return complement(seq)

# %%
# loading/editing metadata

df_meta.columns = ['Sample'] + list((df_meta.columns)[1:])

df_meta['Barcode_FR'] = [(revComp(y) + x).lower() for x,y \
                         in zip(df_meta.fwd_barcode,df_meta.rev_barcode)]


## format of barcode=>sample dict: [revBarcode=read1 + fwdBarcode=read2] : sampleID
map_d = {x:y for x,y in zip(df_meta.Barcode_FR, df_meta.Sample)}

# %%
# resulting dict of sample => barcode_FR 
n_print = 190

[(list(map_d.keys())[i], map_d[list(map_d.keys())[i]]) for i in range(n_print)]
# Out:
# [('tgagtacgctactata', 'MF.M.151026.12C-Ami.D02'),
#  ('tgagtacgcgttacta', 'MR.F.151027.12C-Ami.D02'),
#  ('tgagtacgagagtcac', 'BH.A.151026.H2O-Con.D04'),
#  ('tgagtacgtacgagac', 'CF.A.151027.12C-Van.D02'),
#  ('tgagtacgacgtctcg', 'MR.M.151027.12C-Xyl.D02'),
#  ('tgagtacgtcgacgag', 'PP.A.151026.12C-Pal.D14'),
#  ('tgagtacggatcgtgt', 'BH.M.151026.12C-Xyl.D02'),
#  ('tgagtacggtcagata', 'BH.F.151026.12C-Pal.D14'),
#  ('ctgcgtagctactata', 'MF.M.151026.H2O-Con.D02'),
#  ('ctgcgtagcgttacta', 'MR.A.151027.12C-Pal.D28'),
#  ('ctgcgtagagagtcac', 'PP.M.151026.12C-Van.D04'),
#  ('ctgcgtagtacgagac', 'MW.M.151027.12C-Xyl.D02'),
#  ('ctgcgtagacgtctcg', 'CC.A.151027.H2O-Con.D28'),
#  ('ctgcgtagtcgacgag', 'SS.F.151026.12C-Cel.D28'),
#  ('ctgcgtaggatcgtgt', 'CF.F.151027.12C-Van.D04'),
#  ('ctgcgtaggtcagata', 'EL.A.151026.12C-Cel.D28'),
#  ('tagtctccctactata', 'MF.A.151026.12C-Xyl.D02'),
#  ('tagtctcccgttacta', 'CC.M.151027.12C-Ami.D02'),
#  ('tagtctccagagtcac', 'PP.M.151026.12C-Xyl.D04'),
#  ('tagtctcctacgagac', 'MW.A.151027.12C-Cel.D28'),
#  ('tagtctccacgtctcg', 'BH.A.151026.12C-Pal.D14'),
#  ('tagtctcctcgacgag', 'SS.M.151026.12C-Pal.D28'),
#  ('tagtctccgatcgtgt', 'MF.M.151026.12C-Van.D02'),
#  ('tagtctccgtcagata', 'MP.A.151026.12C-Ami.D04'),
#  ('cgagcgacctactata', 'EL.M.151026.12C-Ami.D04'),
#  ('cgagcgaccgttacta', 'MP.F.151026.H2O-Con.D02'),
#  ('cgagcgacagagtcac', 'MF.F.151026.H2O-Con.D04'),
#  ('cgagcgactacgagac', 'PP.M.151026.12C-Cel.D28'),
#  ('cgagcgacacgtctcg', 'EL.M.151026.12C-Xyl.D02'),
#  ('cgagcgactcgacgag', 'SS.A.151026.H2O-Con.D04'),
#  ('tgagtacggacaccgt', 'PP.A.151026.12C-Cel.D28'),
#  ('ctgcgtagatcgtacg', 'BH.A.151026.12C-Van.D04'),
#  ('ctgcgtagactatctg', 'MR.F.151027.H2O-Con.D04'),
#  ('ctgcgtagtagcgagt', 'EL.A.151026.12C-Pal.D28'),
#  ('ctgcgtagctgcgtgt', 'BH.M.151026.12C-Van.D02'),
#  ('ctgcgtagtcatcgag', 'PP.A.151026.H2O-Con.D14'),
#  ('ctgcgtagcgtgagtg', 'MW.A.151027.12C-Van.D04'),
#  ('ctgcgtagggatatct', 'MR.F.151027.H2O-Con.D02'),
#  ('ctgcgtaggacaccgt', 'MW.M.151027.12C-Cel.D14'),
#  ('tagtctccatcgtacg', 'CC.M.151027.12C-Xyl.D04'),
#  ('tagtctccactatctg', 'PP.A.151026.12C-Xyl.D04'),
#  ('tagtctcctagcgagt', 'MW.M.151027.H2O-Con.D04'),
#  ('tagtctccctgcgtgt', 'CF.M.151027.12C-Ami.D02'),
#  ('tagtctcctcatcgag', 'SS.A.151026.H2O-Con.D14'),
#  ('tagtctcccgtgagtg', 'BH.M.151026.12C-Cel.D14'),
#  ('tagtctccggatatct', 'MR.A.151027.H2O-Con.D28'),
#  ('tagtctccgacaccgt', 'CF.F.151027.12C-Xyl.D04'),
#  ('cgagcgacatcgtacg', 'MR.F.151027.12C-Pal.D28'),
#  ('cgagcgacactatctg', 'MP.M.151026.H2O-Con.D28'),
#  ('cgagcgactagcgagt', 'PP.F.151026.12C-Van.D04'),
#  ('cgagcgacctgcgtgt', 'MF.F.151026.12C-Van.D02'),
#  ('cgagcgactcatcgag', 'SS.F.151026.H2O-Con.D04'),
#  ('cgagcgaccgtgagtg', 'MF.M.151026.12C-Pal.D28'),
#  ('cgagcgacggatatct', 'CC.F.151027.12C-Xyl.D04'),
#  ('cgagcgacgacaccgt', 'PP.F.151026.H2O-Con.D28'),
#  ('actacgacatcgtacg', 'PP.F.151026.12C-Ami.D04'),
#  ('actacgacactatctg', 'MW.F.151027.12C-Cel.D14'),
#  ('actacgactagcgagt', 'EL.M.151026.12C-Cel.D14'),
#  ('actacgacctgcgtgt', 'SS.M.151026.12C-Xyl.D04'),
#  ('actacgactcatcgag', 'MW.A.151027.H2O-Con.D02'),
#  ('actacgacggatatct', 'MP.F.151026.12C-Pal.D14'),
#  ('actacgacgacaccgt', 'PP.M.151026.12C-Pal.D28'),
#  ('gtctgctaatcgtacg', 'PP.A.151026.12C-Van.D04'),
#  ('gtctgctaactatctg', 'PP.A.151026.H2O-Con.D04'),
#  ('gtctgctatagcgagt', 'CF.F.151027.12C-Pal.D28'),
#  ('gtctgctactgcgtgt', 'MP.A.151026.12C-Van.D02'),
#  ('gtctgctatcatcgag', 'MP.M.151026.H2O-Con.D02'),
#  ('gtctgctacgtgagtg', 'MP.A.151026.12C-Ami.D02'),
#  ('gtctgctaggatatct', 'SS.F.151026.12C-Pal.D14'),
#  ('gtctatgaatcgtacg', 'CC.F.151027.H2O-Con.D02'),
#  ('gtctatgaactatctg', 'CC.A.151027.12C-Van.D04'),
#  ('gtctatgatagcgagt', 'CC.F.151027.H2O-Con.D28'),
#  ('gtctatgactgcgtgt', 'CF.F.151027.12C-Van.D02'),
#  ('gtctatgatcatcgag', 'MW.A.151027.12C-Van.D02'),
#  ('gtctatgacgtgagtg', 'PP.M.151026.H2O-Con.D14'),
#  ('gtctatgaggatatct', 'SS.F.151026.12C-Ami.D04'),
#  ('gtctatgagacaccgt', 'BH.F.151026.12C-Van.D04'),
#  ('tatagcgaatcgtacg', 'BH.M.151026.12C-Pal.D28'),
#  ('tatagcgaactatctg', 'EL.A.151026.H2O-Con.D28'),
#  ('tatagcgatagcgagt', 'EL.F.151026.12C-Pal.D28'),
#  ('tatagcgactgcgtgt', 'EL.F.151026.12C-Pal.D14'),
#  ('tatagcgatcatcgag', 'SS.A.151026.12C-Pal.D14'),
#  ('tatagcgacgtgagtg', 'EL.M.151026.12C-Xyl.D04'),
#  ('tatagcgaggatatct', 'SS.F.151026.12C-Cel.D14'),
#  ('tatagcgagacaccgt', 'SS.M.151026.H2O-Con.D28'),
#  ('cgagagttcgttacta', 'EL.A.151026.12C-Xyl.D04'),
#  ('cgagagttagagtcac', 'SS.F.151026.12C-Ami.D02'),
#  ('cgagagtttacgagac', 'CF.A.151027.12C-Pal.D14'),
#  ('cgagagttacgtctcg', 'CF.M.151027.12C-Pal.D28'),
#  ('cgagagtttcgacgag', 'MP.A.151026.12C-Xyl.D02'),
#  ('cgagagttgatcgtgt', 'CC.M.151027.12C-Ami.D04'),
#  ('cgagagttgtcagata', 'MW.A.151027.12C-Pal.D28'),
#  ('gacatagtctactata', 'MW.F.151027.H2O-Con.D04'),
#  ('gacatagtcgttacta', 'CC.F.151027.12C-Pal.D28'),
#  ('gacatagtagagtcac', 'CC.A.151027.12C-Ami.D02'),
#  ('gacatagttacgagac', 'MR.F.151027.12C-Ami.D04'),
#  ('gacatagtacgtctcg', 'MP.F.151026.12C-Xyl.D04'),
#  ('gacatagttcgacgag', 'MP.F.151026.12C-Cel.D14'),
#  ('gacatagtgatcgtgt', 'SS.A.151026.H2O-Con.D02'),
#  ('acgctactcgttacta', 'EL.A.151026.H2O-Con.D14'),
#  ('acgctactagagtcac', 'MR.M.151027.H2O-Con.D28'),
#  ('acgctacttacgagac', 'BH.M.151026.12C-Ami.D02'),
#  ('acgctactacgtctcg', 'SS.M.151026.H2O-Con.D14'),
#  ('acgctacttcgacgag', 'EL.A.151026.12C-Ami.D04'),
#  ('acgctactgatcgtgt', 'MP.A.151026.H2O-Con.D04'),
#  ('acgctactgtcagata', 'MW.M.151027.H2O-Con.D28'),
#  ('actcactgctactata', 'CC.A.151027.12C-Pal.D28'),
#  ('actcactgcgttacta', 'BH.F.151026.12C-Ami.D04'),
#  ('actcactgagagtcac', 'MF.M.151026.H2O-Con.D28'),
#  ('actcactgtacgagac', 'MP.F.151026.12C-Van.D04'),
#  ('actcactgacgtctcg', 'CC.A.151027.12C-Ami.D04'),
#  ('actcactgtcgacgag', 'EL.A.151026.12C-Van.D02'),
#  ('actcactggatcgtgt', 'Enr4_H20_con'),
#  ('actcactggtcagata', 'MW.A.151027.12C-Ami.D04'),
#  ('cgagcgacgatcgtgt', 'MR.M.151027.12C-Pal.D28'),
#  ('cgagcgacgtcagata', 'MR.A.151027.H2O-Con.D02'),
#  ('actacgaccgttacta', 'MW.M.151027.12C-Van.D04'),
#  ('actacgacagagtcac', 'MP.M.151026.12C-Pal.D28'),
#  ('actacgactacgagac', 'MF.A.151026.H2O-Con.D02'),
#  ('actacgacacgtctcg', 'BH.M.151026.H2O-Con.D04'),
#  ('actacgactcgacgag', 'CF.M.151027.H2O-Con.D02'),
#  ('actacgacgatcgtgt', 'SS.M.151026.12C-Ami.D04'),
#  ('actacgacgtcagata', 'PP.M.151026.12C-Ami.D04'),
#  ('gtctgctactactata', 'PP.A.151026.12C-Pal.D28'),
#  ('gtctgctacgttacta', 'BH.A.151026.H2O-Con.D28'),
#  ('gtctgctatacgagac', 'BH.M.151026.12C-Xyl.D04'),
#  ('gtctgctaacgtctcg', 'SS.A.151026.12C-Xyl.D02'),
#  ('gtctgctatcgacgag', 'CC.A.151027.12C-Xyl.D02'),
#  ('gtctgctagatcgtgt', 'CC.F.151027.12C-Cel.D14'),
#  ('gtctgctagtcagata', 'PP.M.151026.12C-Xyl.D02'),
#  ('gtctatgactactata', 'EL.A.151026.12C-Cel.D14'),
#  ('gtctatgacgttacta', 'MF.F.151026.12C-Pal.D14'),
#  ('gtctatgaagagtcac', 'CC.F.151027.12C-Ami.D04'),
#  ('gtctatgatacgagac', 'MP.A.151026.12C-Pal.D28'),
#  ('gtctatgaacgtctcg', 'SS.A.151026.12C-Van.D04'),
#  ('gtctatgatcgacgag', 'SS.F.151026.12C-Pal.D28'),
#  ('gtctatgagatcgtgt', 'MP.F.151026.12C-Xyl.D02'),
#  ('gtctatgagtcagata', 'MF.F.151026.12C-Van.D04'),
#  ('tatagcgacgttacta', 'EL.M.151026.12C-Ami.D02'),
#  ('tatagcgaagagtcac', 'MP.M.151026.12C-Xyl.D04'),
#  ('tatagcgatacgagac', 'CF.M.151027.H2O-Con.D04'),
#  ('tatagcgaacgtctcg', 'MP.M.151026.H2O-Con.D04'),
#  ('tatagcgatcgacgag', 'MP.A.151026.12C-Van.D04'),
#  ('tatagcgagatcgtgt', 'Enr_2_negative_control'),
#  ('cgagagttatcgtacg', 'MP.A.151026.H2O-Con.D02'),
#  ('cgagagttactatctg', 'CF.M.151027.H2O-Con.D28'),
#  ('cgagagtttagcgagt', 'CF.M.151027.12C-Pal.D14'),
#  ('cgagagttctgcgtgt', 'MP.F.151026.12C-Pal.D28'),
#  ('cgagagtttcatcgag', 'MR.A.151027.H2O-Con.D04'),
#  ('cgagagttcgtgagtg', 'MR.A.151027.12C-Pal.D14'),
#  ('cgagagttggatatct', 'SS.F.151026.H2O-Con.D14'),
#  ('cgagagttgacaccgt', 'BH.A.151026.12C-Ami.D04'),
#  ('gacatagtatcgtacg', 'MR.F.151027.12C-Xyl.D04'),
#  ('gacatagtactatctg', 'MF.A.151026.H2O-Con.D04'),
#  ('gacatagttagcgagt', 'EL.M.151026.H2O-Con.D28'),
#  ('gacatagtctgcgtgt', 'MW.F.151027.12C-Pal.D28'),
#  ('gacatagttcatcgag', 'EL.F.151026.H2O-Con.D14'),
#  ('gacatagtcgtgagtg', 'MP.A.151026.H2O-Con.D28'),
#  ('gacatagtggatatct', 'EL.F.151026.H2O-Con.D28'),
#  ('gacatagtgacaccgt', 'CC.M.151027.12C-Pal.D14'),
#  ('acgctactatcgtacg', 'MP.M.151026.12C-Ami.D04'),
#  ('acgctactactatctg', 'EL.M.151026.12C-Pal.D14'),
#  ('acgctacttagcgagt', 'MF.M.151026.12C-Xyl.D02'),
#  ('acgctactctgcgtgt', 'BH.M.151026.12C-Ami.D04'),
#  ('acgctacttcatcgag', 'PP.M.151026.12C-Ami.D02'),
#  ('acgctactcgtgagtg', 'BH.A.151026.12C-Pal.D28'),
#  ('acgctactggatatct', 'MP.F.151026.H2O-Con.D28'),
#  ('acgctactgacaccgt', 'CF.F.151027.12C-Cel.D14'),
#  ('actcactgatcgtacg', 'CF.M.151027.12C-Cel.D28'),
#  ('actcactgactatctg', 'SS.F.151026.12C-Van.D02'),
#  ('actcactgtagcgagt', 'CF.A.151027.12C-Ami.D04'),
#  ('actcactgctgcgtgt', 'SS.M.151026.12C-Van.D04'),
#  ('actcactgtcatcgag', 'MW.A.151027.12C-Pal.D14'),
#  ('actcactgcgtgagtg', 'MP.M.151026.12C-Xyl.D02'),
#  ('actcactgggatatct', 'MR.F.151027.12C-Van.D02'),
#  ('actcactggacaccgt', 'Enr3_H2O_con'),
#  ('tgagtacgatcgtacg', 'EL.A.151026.H2O-Con.D02'),
#  ('tgagtacgactatctg', 'CF.A.151027.12C-Cel.D28'),
#  ('tgagtacgtagcgagt', 'MF.M.151026.12C-Cel.D28'),
#  ('tgagtacgctgcgtgt', 'MW.M.151027.H2O-Con.D14'),
#  ('tgagtacgtcatcgag', 'EL.F.151026.12C-Ami.D02'),
#  ('tgagtacgcgtgagtg', 'MF.F.151026.H2O-Con.D28'),
#  ('tgagtacgggatatct', 'PP.M.151026.12C-Van.D02'),
#  ('actacgaccgtgagtg', 'CF.A.151027.12C-Ami.D02'),
#  ('gtctgctagacaccgt', 'CC.A.151027.12C-Van.D02'),
#  ('cgagagttctactata', 'CC.M.151027.12C-Cel.D14'),
#  ('gacatagtgtcagata', 'MR.A.151027.12C-Cel.D14'),
#  ('acgctactctactata', 'BH.A.151026.12C-Van.D02'),
#  ('tatagcgactactata', 'MF.F.151026.12C-Xyl.D04'),
#  ('tatagcgagtcagata', 'Enr_2_mock_community')]

# %%
# loading screed databases 
ir1db = screed.ScreedDB(index_read1_screed)
ir2db = screed.ScreedDB(index_read2_screed)
amp_db = screed.ScreedDB(read12_screed)

# %%
# demultiplexing: naming reads by sample

outFile = re.sub('fastq_screed', 'dmult.fastq', read12_screed)

counter = 0
unassigned = 0
cnt = Counter()
outFile = os.path.join(workdir, os.path.split(outFile)[1])
c = 0
with open(outFile, "w") as out:
    for rec in amp_db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["quality"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
        
        
print ("Unable to assign %s reads to samples"%unassigned)

# %%
# number of sequences
n_lines = !wc -l $outFile
n_lines = int(re.sub(' .+', '', n_lines[0]))
print('Number of sequences: {}'.format(n_lines/4))
# Out:
# Number of sequences: 12641636.0

# %% [markdown]
# # Stats on sequences

# %% [markdown]
# ## Number of sequences per sample

# %%
# counting sequences for each sample
re_seqName = re.compile(r'_\d+ orig_name.+')

seq_cnt = dict()
with open(outFile, 'r') as fn:
    for line in fn.readlines():
        if re.search(re_seqName, line):
            sampleName = re.sub(re_seqName, '', line).rstrip().lstrip('@')
            try:
                seq_cnt[sampleName] += 1
            except KeyError:
                seq_cnt[sampleName] = 1

# %%
# converting to dataframe
df_seq_cnt = pd.DataFrame.from_dict(seq_cnt, orient='index')
df_seq_cnt.index.name = 'Sample'
df_seq_cnt.reset_index(inplace=True)
df_seq_cnt.columns = ['Sample', 'seq_count']
df_seq_cnt
# Out:
#                       Sample  seq_count
# 0    EL.F.151026.H2O-Con.D14      56501
# 1    SS.F.151026.H2O-Con.D14     155516
# 2    MW.M.151027.12C-Xyl.D02      52247
# 3    PP.A.151026.H2O-Con.D14      32275
# 4    MP.A.151026.12C-Ami.D02      67543
# 5    EL.A.151026.12C-Van.D02      82632
# 6    MP.A.151026.12C-Xyl.D02      89571
# 7    MF.M.151026.12C-Xyl.D02      53917
# 8    MP.F.151026.12C-Van.D04      65169
# 9    MW.A.151027.H2O-Con.D02      28151
# 10   MW.F.151027.H2O-Con.D04      82247
# 11   CC.M.151027.12C-Xyl.D04      36602
# 12   MR.F.151027.12C-Van.D02      93913
# 13   CF.A.151027.12C-Pal.D14     152998
# 14   BH.M.151026.12C-Xyl.D02      60705
# 15   CF.M.151027.H2O-Con.D28      60874
# 16   CF.F.151027.12C-Pal.D28      37395
# 17   MW.M.151027.H2O-Con.D28      96643
# 18   CC.A.151027.12C-Pal.D28      99740
# 19   BH.A.151026.12C-Van.D02      86006
# 20   BH.A.151026.12C-Pal.D14      37367
# 21   SS.F.151026.12C-Pal.D14      69037
# 22   BH.F.151026.12C-Van.D04     235575
# 23   SS.F.151026.12C-Pal.D28      51890
# 24   EL.A.151026.12C-Cel.D14      66077
# 25   BH.M.151026.12C-Ami.D02      96592
# 26   MP.M.151026.H2O-Con.D28      41395
# 27   MR.F.151027.12C-Ami.D02      71223
# 28   MR.F.151027.H2O-Con.D04      48126
# 29   MR.A.151027.12C-Pal.D14     118971
# ..                       ...        ...
# 160  CC.F.151027.H2O-Con.D02      57508
# 161  MR.M.151027.12C-Xyl.D02      53810
# 162  MW.M.151027.H2O-Con.D14      41491
# 163  PP.A.151026.12C-Pal.D28      74926
# 164  PP.M.151026.12C-Ami.D04      58644
# 165  EL.F.151026.12C-Pal.D14      49757
# 166  PP.A.151026.H2O-Con.D04      46965
# 167  SS.A.151026.12C-Van.D04      44993
# 168  PP.M.151026.H2O-Con.D14      69164
# 169  PP.A.151026.12C-Cel.D28      75924
# 170  MP.M.151026.H2O-Con.D04      50109
# 171  CC.M.151027.12C-Pal.D14      87860
# 172  CC.F.151027.12C-Cel.D14      44546
# 173  BH.A.151026.12C-Van.D04      41441
# 174  MF.M.151026.H2O-Con.D28      63005
# 175  MP.F.151026.12C-Pal.D28      82574
# 176  CC.M.151027.12C-Ami.D02      33753
# 177  PP.F.151026.12C-Van.D04      42940
# 178  CC.A.151027.12C-Van.D04      55570
# 179  BH.M.151026.H2O-Con.D04      49217
# 180  SS.F.151026.12C-Ami.D04      98176
# 181  EL.M.151026.12C-Cel.D14      30568
# 182  SS.A.151026.H2O-Con.D04      26377
# 183  CF.M.151027.H2O-Con.D04      38542
# 184  SS.A.151026.H2O-Con.D14      22826
# 185  MF.F.151026.12C-Pal.D14      49627
# 186  PP.F.151026.12C-Ami.D04      33100
# 187             Enr3_H2O_con       3556
# 188   Enr_2_negative_control       6825
# 189             Enr4_H20_con       1869
#
# [190 rows x 2 columns]

# %%
# %%R -i df_seq_cnt -w 900 -h 350
#
# df_seq_cnt$Sample = reorder(df_seq_cnt$Sample, desc(df_seq_cnt$seq_count))
#
# ggplot(df_seq_cnt, aes(Sample, seq_count)) +
#     geom_bar(stat='identity') +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R
# df_seq_cnt[df_seq_cnt$seq_count < 20000,]
# Out:
#                     Sample seq_count
# 187           Enr3_H2O_con      3556
# 188 Enr_2_negative_control      6825
# 189           Enr4_H20_con      1869

# %% [markdown]
# ### Are the number of samples returned the same as expected?

# %%
print ("You got " + str(len(df_seq_cnt)) + " samples")
print ("You should have " + str(len(df_meta)) + " samples")
# Out:
# You got 190 samples
# You should have 190 samples
